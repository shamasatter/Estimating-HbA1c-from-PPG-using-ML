# %% [markdown]
# >__ACK:__ *** This whole code is developed by __Shama Satter__ ***

# %% [markdown]
# # __Create environment for running AI program__

# %% [markdown]
# > __Install libraris__ https://pypi.org

# %%
# %pip install pandas
# %pip install heartpy
# %pip install tsfel
# %pip install librosa
# %pip install statsmodels
# %pip install lightgbm
# %pip install catboost
# %pip install xgboost

# %% [markdown]
# > __Import libraries and dependencies__

# %%
import pandas as pd
import numpy as np
import heartpy as hp
from   matplotlib import pyplot as plt
import tsfel
import scipy 
import sklearn as sk
from   sklearn.ensemble import RandomForestRegressor
import librosa
import csv
import pandas as pd
import os
import xgboost as xgb
import random
import statsmodels.regression
from   warnings import filterwarnings
import lightgbm as ltb
from   sklearn import metrics
import catboost as cab
from   sklearn.model_selection import GridSearchCV
import time
from   datetime import datetime
from   sklearn.metrics import mean_squared_error, accuracy_score
from   sklearn.metrics import r2_score
from   IPython.display import clear_output
from sklearn.model_selection import KFold

# %% [markdown]
# # __Data collection & preprocessing__

# %% [markdown]
# > Mount Gdrive

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %% [markdown]
# > Inserting Data

# %%
## PPG Data
# define parent directory of PPG files
# PPG_dataDirectory = 'gdrive/My Drive/Colab Notebooks/SCI#02/DataBase/data/'
PPG_dataDirectory = './DataBase/Selected_PPG_wrist/'
# PPG CSV filenames
PPG_data =  [   
            '210823_4.csv',   
            '210830_0.csv',   
            '210927_0.csv',             
            '210927_1.csv',             
            '210927_2.csv',            
            '210928_0.csv',                       
            '210928_1.csv',          
            '210929_0.csv',           
            '210930_0.csv',            
            '210930_1.csv',            
            '210930_2.csv',           
            '210930_3.csv',            
            '210930_4.csv',           
            '210930_5.csv',         
            '211001_0.csv',         
            '211001_1.csv', 
            '211001_2.csv',
            '211018_1.csv',
            '211018_2.csv',
            '211018_3.csv',
            '211018_4.csv',
            '211019_0.csv',
            '211026_0.csv',
            '211026_1.csv',
            '211026_2.csv',
            '211026_3.csv',
            '211115_0.csv',
            '211115_1.csv',         
            ]
# Assigning complete filename of PPG CSV data
PPG_csvData = []
for fileName in PPG_data:
    PPG_csvData.append(PPG_dataDirectory+fileName)


## HbA1c data
HbA1c_data  =   [ 
                8.4,5.4,7.6,5.5,5.4,6.0,5.3,6.3,5.7,4.9,5.6,5.5,5.2,5.2,5.5,5.8,5.7,5.6,5.5,5.7,5.6,7.4,6.2,7.0,6.3,5.3,8.2,6.7
                ]


## SpO2 data
SpO2_data   =   [ 96,97,97,98,97,96,97,97,96,96,97,95,95,98,97,95,97,97,97,97,97,96,97,96,97,98,97,97                
                ]


## Age data
Age_data    =   [ 
                34,25,63,26,25,63,30,27,25,34,
                35
                ]


## Gender data
Gender_data =   [ 
                'M','F','M','M','F','M','F','M','M','M',
                'M','M','F','F','M','M','M','M','M','M','M','M','M','M','M','M','M','M'
                ]


                
## BMI data
BMI_data    =   [ 
                28.71,23.6,28.71,24,23.6,23.3,27.9,25.8,25.82,19.71,22.72,33.96,20.64,22.04,25.26,20.6,20.4,33.3,26.4,22.2,30.1,28.71,19.6,25.8,29.1,32.8,30.4,21.7
                ]


print('*****************PPG_csvData******************')
print(PPG_csvData)
print('Data counted = '+ str(len(PPG_csvData)))
print('******************HbA1c_data******************')
print(HbA1c_data)
print('Data counted = '+ str(len(HbA1c_data)))
print('******************SpO2_data*******************')
print(SpO2_data)
print('Data counted = '+ str(len(SpO2_data)))
print('*******************Age_data*******************')
print(Age_data)
print('Data counted = '+ str(len(Age_data)))
print('*****************Gender_data******************')
print(Gender_data)
print('Data counted = '+ str(len(Gender_data)))


print('******************BMI_data********************')
print(BMI_data)
print('Data counted = '+ str(len(BMI_data)))
# Out:
# *****************PPG_csvData******************
# ['./DataBase/Selected_PPG_wrist/210823_4.csv', './DataBase/Selected_PPG_wrist/210830_0.csv', './DataBase/Selected_PPG_wrist/210927_0.csv', './DataBase/Selected_PPG_wrist/210927_1.csv', './DataBase/Selected_PPG_wrist/210927_2.csv', './DataBase/Selected_PPG_wrist/210928_0.csv', './DataBase/Selected_PPG_wrist/210928_1.csv', './DataBase/Selected_PPG_wrist/210929_0.csv', './DataBase/Selected_PPG_wrist/210930_0.csv', './DataBase/Selected_PPG_wrist/210930_1.csv', './DataBase/Selected_PPG_wrist/210930_2.csv', './DataBase/Selected_PPG_wrist/210930_3.csv', './DataBase/Selected_PPG_wrist/210930_4.csv', './DataBase/Selected_PPG_wrist/210930_5.csv', './DataBase/Selected_PPG_wrist/211001_0.csv', './DataBase/Selected_PPG_wrist/211001_1.csv', './DataBase/Selected_PPG_wrist/211001_2.csv', './DataBase/Selected_PPG_wrist/211018_1.csv', './DataBase/Selected_PPG_wrist/211018_2.csv', './DataBase/Selected_PPG_wrist/211018_3.csv', './DataBase/Selected_PPG_wrist/211018_4.csv', './DataBase/Selected_PPG_wrist/211019_0.csv', './DataBase/Selected_PPG_wrist/211026_0.csv', './DataBase/Selected_PPG_wrist/211026_1.csv', './DataBase/Selected_PPG_wrist/211026_2.csv', './DataBase/Selected_PPG_wrist/211026_3.csv', './DataBase/Selected_PPG_wrist/211115_0.csv', './DataBase/Selected_PPG_wrist/211115_1.csv']
# Data counted = 28
# ******************HbA1c_data******************
# [8.4, 5.4, 7.6, 5.5, 5.4, 6.0, 5.3, 6.3, 5.7, 4.9, 5.6, 5.5, 5.2, 5.2, 5.5, 5.8, 5.7, 5.6, 5.5, 5.7, 5.6, 7.4, 6.2, 7.0, 6.3, 5.3, 8.2, 6.7]
# Data counted = 28
# ******************SpO2_data*******************
# [96, 97, 97, 98, 97, 96, 97, 97, 96, 96, 97, 95, 95, 98, 97, 95, 97, 97, 97, 97, 97, 96, 97, 96, 97, 98, 97, 97]
# Data counted = 28
# *******************Age_data*******************
# [34, 25, 63, 26, 25, 63, 30, 27, 25, 34, 35]
# Data counted = 11
# *****************Gender_data******************
# ['M', 'F', 'M', 'M', 'F', 'M', 'F', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M']
# Data counted = 28
# ******************BMI_data********************
# [28.71, 23.6, 28.71, 24, 23.6, 23.3, 27.9, 25.8, 25.82, 19.71, 22.72, 33.96, 20.64, 22.04, 25.26, 20.6, 20.4, 33.3, 26.4, 22.2, 30.1, 28.71, 19.6, 25.8, 29.1, 32.8, 30.4, 21.7]
# Data counted = 28

# %% [markdown]
# > Making array

# %%
PPG_csvArray  = np.asarray(PPG_csvData)
HbA1c_Array   = np.asarray(HbA1c_data)
SpO2_Array    = np.asarray(SpO2_data)
Age_Array     = np.asarray(Age_data)
Gender_Array  = np.asarray(Gender_data)
BMI_Array     = np.asarray(BMI_data)

# %% [markdown]
# # __User Defined Functions and Algorithms__

# %% [markdown]
# > __Function 00:__ Visualize PPG signal

# %%
def visual_PPG(PPG, drawFigure=True):

    for i in range (0,len(PPG)):
        
        # Getting corresponding Combined PPG Data 
        dat    = pd.read_csv(PPG[i], delimiter=',', header=None)
        print('********************************')
        print('Index='+str(i)+' || '+str(PPG[i]))
        print('********************************')
        if (dat.shape[1] == 3):
           bs = dat.iloc[:,2]
           gs = dat.iloc[:,1]
           rs = dat.iloc[:,0]
        else:
           bs = dat.iloc[:,3]
           gs = dat.iloc[:,2]
           rs = dat.iloc[:,1]
    
        # Visualization **Don't mention inside the pseudo code**
        if drawFigure:
           plt.rcParams.update(plt.rcParamsDefault)
           plt.rcParams['font.size'] = '8'
           fig,axs = plt.subplots(3, figsize=(20, 5))
           axs[0].set(title='Visualization of Wrist PPG Signal')
           axs[0].plot(bs, color='blue', label='blue signal')
           axs[0].set(ylabel = ' ')
           axs[0].legend(loc=1)
           axs[0].grid(True)
           axs[1].plot(gs, color='green', label='green signal')
           axs[1].set(ylabel = ' ', xlabel = ' ')
           axs[1].legend(loc=1)
           axs[1].grid(True)
           axs[2].plot(rs, color='red', label='red signal')
           axs[2].set(ylabel = ' ', xlabel = ' ')
           axs[2].legend(loc=1)
           axs[2].grid(True)
           plt.show()
        
    # Return
    return

# %% [markdown]
# > __Function 01:__ BA_Plot

# %%
def bland_altman_plot(data1, data2):
    data1     = np.asarray(data1)
    data2     = np.asarray(data2)
    mean      = np.mean([data1, data2], axis=0)
    diff      = data1 - data2                   # Difference between data1 and data2
    md        = np.mean(diff)                   # Mean of the difference
    sd        = np.std(diff, axis=0)            # Standard deviation of the difference

    plt.scatter(mean, diff,   c = 'black')
    plt.axhline(md,           color='green', linestyle='--')
    plt.axhline(md + 1.96*sd, color='red',   linestyle='--')
    plt.axhline(md - 1.96*sd, color='red',   linestyle='--')
    plt.xlabel("Average of the two measures", fontsize = 14)
    plt.ylabel("Difference between the two measures", fontsize = 14)
    plt.title("Bland-Altman plot for estimated %HbA1c values", fontsize = 14)
    # plt.savefig('./Figure/RF_trans_BA_Plot.png', bbox_inches = "tight", transparent = True, dpi = 400)

# %% [markdown]
# > __Function 02:__ EGA_Plot

# %%
from matplotlib.patches import Circle, Wedge, Polygon, Path
from matplotlib.collections import PatchCollection

def error_grid_analysis(ref,est):
    fig, ax = plt.subplots()

    polygons = []

    A  = [[4.0,4.0],[5.7,4.0],[5.7,5.4],[7.2,6.5],[12.0,6.5],[12.0,12.0],[6.5,12.0],[6.5,7.2],[5.4,5.7],[4.0,5.7]]
    Bd = [[5.7,4.0],[5.7,5.4],[7.2,6.5],[12.0,6.5],[12.0,5.7],[6.5,5.7],[6.5,4.0]]
    Bu = [[4.0,5.7],[5.4,5.7],[6.5,7.2],[6.5,12.0],[5.7,12.0],[5.7,6.5],[4.0,6.5]]
    Cd = [[6.5,4.0],[6.5,5.7],[12.0,5.7],[12.0,4.0]]
    Cu = [[4.0,6.5],[5.7,6.5],[5.7,12.0],[4.0,12.0]]

    # print(np.asarray(A).shape)
    pA  = Polygon(np.asarray(A))
    pBd = Polygon(np.asarray(Bd))
    pBu = Polygon(np.asarray(Bu))
    pCd = Polygon(np.asarray(Cd))
    pCu = Polygon(np.asarray(Cu))

    polygons.append(pA)
    polygons.append(pBd)
    polygons.append(pBu)
    polygons.append(pCd)
    polygons.append(pCu)


    p = PatchCollection(polygons)
    p.set_color([[0,1,0,0.3],[1,1,0,0.3],[1,1,0,0.3],[1,0,0,0.3],[1,0,0,0.3]])
    ax.add_collection(p)



    plt.plot([4.0,12.0],[4.0,12.0])


    x = ref
    y = est

    sA = []
    sB = []
    sC = []
    for i in range(len(y)):
        sA.append(int(pA.contains_point ([x[i],y[i]]))*30)
        sB.append(int(pBd.contains_point([x[i],y[i]]) or pBu.contains_point([x[i],y[i]]))*30)
        sC.append(int(pCd.contains_point([x[i],y[i]]) or pCu.contains_point([x[i],y[i]]))*30)


    plt.scatter(x,y,s=sA,color=[0.227, 0.513, 0.282,1])
    plt.scatter(x,y,s=sB,color=[0.886, 0.654, 0.133,1])
    plt.scatter(x,y,s=sC,color=[0.941, 0, 0.098,1])

    lx = np.linspace(min(x), max(x), 100)
    z = np.polyfit(x, y, 1)
    p = np.poly1d(z)
    plt.plot(lx,p(lx))


    plt.text(10.5,9,'A',fontsize=26)
    plt.text(9,10.5,'A',fontsize=26)
    plt.text(10.5,5.94,'B',fontsize=26)
    plt.text(5.94,10.5,'B',fontsize=26)
    plt.text(10.5,4.7,'C',fontsize=26)
    plt.text(4.7,10.5,'C',fontsize=26)
    fig.set_figheight(8)
    fig.set_figwidth(8)
    plt.xlim([4.0,12.0])
    plt.ylim([4.0,12.0])
    plt.xlabel('HbA1c Invasive device (%NGSP)',fontsize=15)
    plt.ylabel('HbA1c Estimated (%NGSP)',fontsize=15)
    plt.title('Error Grid Analysis (EGA) for estimated %HbA1c values',fontsize=15)
    plt.show()

# %% [markdown]
# > __Function 03:__ Evaluation
# >> ACK: __Developed by Shama__. _To visualize performance and evaluate model_

# %%
def evaluation_metrics_including_BA_and_EGA_plot(modelName, predictedValue, exactValue):
    print('############ HbA1c Evaluation Metrics of ' + modelName + ' Regression ############')
    CVy = np.asarray(predictedValue)
    CVx = np.asarray(exactValue)
    print('Diff STD  = ',np.std(CVx-CVy))
    print('MSE       = ',np.sum((CVx-CVy)**2)/CVy.shape[0])
    print('ME        = ',np.sum((CVx-CVy))/CVy.shape[0])
    print('MAD       = ',np.sum(np.abs(CVx-CVy))/CVy.shape[0])
    print('RMSE      = ',np.sqrt(np.sum((CVx-CVy)**2)/CVy.shape[0]))
    print('R2 score  = ',r2_score(CVx,CVy))
    print('Pearson R and p-value: ',scipy.stats.pearsonr(CVx,CVy))
    print('##################################################################################\n')
    bland_altman_plot  (predictedValue, exactValue)
    error_grid_analysis(predictedValue, exactValue)

# %% [markdown]
# > __Algorithm 01:__ Baseline Dirft Removal by ()
# >> ACK: __Developed by Shama__. _This algorithm ()_

# %%
### Initialize Second Order Section
sos  = scipy.signal.butter(2, 8, fs=32, output='sos')  ###
sos1 = scipy.signal.butter(2, 0.5,btype='high', fs=36, output='sos') ###
def removing_baseline_drift (ppgSignal, showFigure='False'): 
   # Getting corresponding Combined PPG Data 
   dat   = pd.read_csv(ppgSignal, delimiter=',', header=None)
   if (dat.shape[1] == 3):
      bs = dat.iloc[:,2]
      gs = dat.iloc[:,1]
      rs = dat.iloc[:,0]
   else:
      bs = dat.iloc[:,3]
      gs = dat.iloc[:,2]
      rs = dat.iloc[:,1]
   fil_s_b = scipy.signal.sosfilt(sos, bs)[10:]
   fil_s_g = scipy.signal.sosfilt(sos, gs)[10:]
   fil_s_r = scipy.signal.sosfilt(sos, rs)[10:]

   fil_s_b1 = scipy.signal.sosfilt(sos1, fil_s_b)[110:] + np.mean(fil_s_b)
   fil_s_g1 = scipy.signal.sosfilt(sos1, fil_s_g)[110:] + np.mean(fil_s_g)
   fil_s_r1 = scipy.signal.sosfilt(sos1, fil_s_r)[110:] + np.mean(fil_s_r)
   
   ### Visualization
   if showFigure=='True':
      print('***************Blue**************')
      plt.rcParams.update(plt.rcParamsDefault)
      plt.rcParams['font.size'] = '9'
      fig,axs = plt.subplots(2, figsize=(20, 2.5))
      axs[0].set(title='Visualization of PPG Signal before and after filtering')
      axs[0].plot(pd.DataFrame(fil_s_b), color='blue', label='after first filtering')
      axs[0].set(ylabel = ' ', xlabel = ' ')
      axs[0].legend(loc=1)
      axs[0].grid(True)
      axs[1].plot(pd.DataFrame(fil_s_b1), color='blue', label='After 2nd filter and baseline_drift_removal')
      axs[1].set(ylabel = ' ', xlabel = ' ')
      axs[1].legend(loc=1)
      axs[1].grid(True)
      plt.show()

      print('***************Green**************')
      plt.rcParams.update(plt.rcParamsDefault)
      plt.rcParams['font.size'] = '9'
      fig,axs = plt.subplots(2, figsize=(20, 2.5))
      axs[0].set(title='Visualization of PPG Signal before and after filtering')
      axs[0].plot(pd.DataFrame(fil_s_g), color='green', label='after first filtering')
      axs[0].set(ylabel = ' ', xlabel = ' ')
      axs[0].legend(loc=1)
      axs[0].grid(True)
      axs[1].plot(pd.DataFrame(fil_s_g1), color='green', label='After 2nd filter and baseline_drift_removal')
      axs[1].set(ylabel = ' ', xlabel = ' ')
      axs[1].legend(loc=1)
      axs[1].grid(True)
      plt.show()
      
      print('***************Red**************')
      plt.rcParams.update(plt.rcParamsDefault)
      plt.rcParams['font.size'] = '9'
      fig,axs = plt.subplots(2, figsize=(20, 2.5))
      axs[0].set(title='Visualization of PPG Signal before and after filtering')
      axs[0].plot(pd.DataFrame(fil_s_r), color='red', label='after first filtering')
      axs[0].set(ylabel = ' ', xlabel = ' ')
      axs[0].legend(loc=1)
      axs[0].grid(True)
      axs[1].plot(pd.DataFrame(fil_s_r1), color='red', label='After 2nd filter and baseline_drift_removal')
      axs[1].set(ylabel = ' ', xlabel = ' ')
      axs[1].legend(loc=1)
      axs[1].grid(True)
      plt.show()

   ## Return outcome
   return(fil_s_r1, fil_s_g1, fil_s_b1)

# %% [markdown]
# >> Test Algorithm 01:

# %%
# for i in range(len(PPG_csvArray)):
#     print(f'**********PPG_info:{PPG_csvArray[i]}**********')
#     r,g,b = removing_baseline_drift(ppgSignal=PPG_csvArray[i], showFigure='True')

# %% [markdown]
# > __Algorithm 02:__ splitSignal into discrete segments

# %%
def splitSignal (individualSignal, horizonSize=50, windowSize=200):
    overallSignal  = []
    completeFlag   = 0
    for i in range (0, len(individualSignal), horizonSize):
        if i+windowSize < len(individualSignal): #Only consider sets with windowSize data
            splittedSignal = []
            for j in range(windowSize):
                splittedSignal.append(individualSignal[i+j])
            overallSignal.append(splittedSignal)
    x = np.array(overallSignal) 
    return (x)

# %% [markdown]
# >> Test algorithm 02

# %%
horizonSet = 7*13
windowSet  = 7*13
countData  = 0
for i in range(len(PPG_csvArray)):
    r,g,b = removing_baseline_drift(ppgSignal=PPG_csvArray[i], showFigure='False')
    r_ = splitSignal(individualSignal=r, horizonSize=horizonSet, windowSize=windowSet)
    print(r_.shape)
    countData += r_.shape[0]*r_.shape[1]
print(f'dCount={countData}')
### Plotting on the first one
pd.DataFrame(r_[0]).plot()
plt.show()
# Out:
# (10, 91)
# (37, 91)
# (38, 91)
# (31, 91)
# (32, 91)
# (15, 91)
# (35, 91)
# (35, 91)
# (25, 91)
# (30, 91)
# (22, 91)
# (21, 91)
# (34, 91)
# (35, 91)
# (28, 91)
# (35, 91)
# (38, 91)
# (18, 91)
# (31, 91)
# (28, 91)
# (36, 91)
# (32, 91)
# (37, 91)
# (45, 91)
# (26, 91)
# (21, 91)
# (50, 91)
# (40, 91)
# dCount=78715

# %% [markdown]
# > __Algorithm 03:__ Butter Low-pass Filter (Ignore this in SCI)

# %%
def butter_lowPass(cutoff, fs, order=5):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = scipy.signal.butter(order, normal_cutoff, btype='low', analog=False)
    return b, a

def butter_lowPass_filter(data, cutoff, fs, order=5):
    b, a = butter_lowPass(cutoff, fs, order=order)
    y = scipy.signal.lfilter(b, a, data)
    return y

# %% [markdown]
# >> Test Algorithm 03

# %%
print('Actual Splitted Signal')
pd.DataFrame(r_[0]).plot()
plt.show()
print('After applying mean function')
data = r_[0]-np.mean(r_[0])
pd.DataFrame(data).plot()
plt.show()
print('After applying filter')
filteredSignal_r = butter_lowPass_filter(
    data  = data, 
    cutoff= 8, 
    fs    = 32, 
    order = 6)
pd.DataFrame(filteredSignal_r).plot()
plt.show()
# Out:
# Actual Splitted Signal
# After applying mean function
# After applying filter

# %% [markdown]
# > __Algorithm 04:__ Determine AC_DC_from_Signal
# >> ACK: __Developed by Shama__. _This algorithm is developed to determine __r1__ and __r2__ which significantly improve the performance of the trained models_

# %%
def determine_ac_dc_from_PPG (Signal):
    uPeak =  scipy.signal.find_peaks(Signal)
    uPeak =  pd.DataFrame(uPeak[0])
    lPeak =  scipy.signal.find_peaks(-Signal)
    lPeak =  pd.DataFrame(lPeak[0])

    if (len(uPeak)<len(lPeak)):
        indexLength = len(uPeak)
    else:
        indexLength = len(lPeak)

    for index in range(indexLength):
        newValue_ac =  Signal[uPeak.iloc[index]] - Signal[lPeak.iloc[index]]
        newValue_dc =  Signal[lPeak.iloc[index]]
        if index ==0:
            allValue_ac = newValue_ac
            allValue_dc = newValue_dc
        else:
            allValue_ac =  np.append(allValue_ac,newValue_ac)
            allValue_dc =  np.append(allValue_dc,newValue_dc)

    meanValue_ac = np.mean(allValue_ac)
    meanValue_dc = np.mean(allValue_dc)

    return meanValue_ac,meanValue_dc

# %% [markdown]
# > __Algorithm 05:__ Kaiser–Teager Energy

# %%
def get_kaiser_teager_energy(x):
    x         = np.array(x)
    l         = len(x)
    squ       = x[1:l-1]**2
    oddi      = x[0:l-2]
    eveni     = x[2:l]
    ex        = squ - (oddi*eveni)
    kte       = np.zeros([l,])
    kte[0]    = ex[0]
    kte[-1]   = ex[-1]
    kte[1:-1] = ex
    return kte

# %% [markdown]
# > __Algorithm 06v1:__ Constructing Features Set _(Red, Green, Blue; Reflected, FeatureCount=[4+4+r1+r2]+[HbA1c]=11)_
# >> ACK: __Developed by Shama, Guided by Honorable Professor Kim__. _Significantly improve the performance_

# %%
def construct_feature_set_v1 (PPG, HbA1c, SpO2, BMI, samplingRate=32):
    # Initialization
    sr         = samplingRate
    l          = 0

    for i in range (0,len(PPG)):
        
        # Getting corresponding PPG Data
        # > __Algorithm 01:__ Baseline Dirft Removal by () 
        r,g,b = removing_baseline_drift(ppgSignal=PPG[i], showFigure='False')
        print('PPG_data_info:'+str(PPG[i]))

        # > __Algorithm 04:__ Determine AC_DC_from_Signal
        r_ac,r_dc = determine_ac_dc_from_PPG(r)
        g_ac,g_dc = determine_ac_dc_from_PPG(g)
        b_ac,b_dc = determine_ac_dc_from_PPG(b)

        # Calculate r1 & r2
        r1 = (g_ac/g_dc)/(r_ac/r_dc)
        r2 = (b_ac/b_dc)/(r_ac/r_dc)

        # > __Algorithm 02:__ Split_Signal
        r_sp = splitSignal(individualSignal=r, horizonSize=horizonSet, windowSize=windowSet)
        g_sp = splitSignal(individualSignal=g, horizonSize=horizonSet, windowSize=windowSet)
        b_sp = splitSignal(individualSignal=b, horizonSize=horizonSet, windowSize=windowSet)
        
        # Constructing Feature Set
        for j in range(len(r_sp)):  ### You can also use r_sp.shape[0]
            # Initialize frame
            featureFrame       = []
            
            # >>>>>>>>>>>>>>>>Red>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
            # > __Algorithm 03:__ Filter
            filteredSignal_r   = butter_lowPass_filter(
                data  = r_sp[j]-np.mean(r_sp[j]), 
                cutoff= 8, 
                fs    = sr, 
                order = 6
                )

            fqSignal_r, psdSignal_r    = scipy.signal.welch(
                x       = filteredSignal_r, 
                nperseg = len(filteredSignal_r) # Added to overcome error
                ) 


            # > __Algorithm 05:__ Kaiser–Teager Energy
            kteSignal_r            = get_kaiser_teager_energy(
                filteredSignal_r
                )



            # Insert Feature one by one
            # Add new feature (5)
            ar_coeffs_r, _r        = statsmodels.regression.linear_model.yule_walker(filteredSignal_r, order = 2)
            # featureFrame           = np.append(featureFrame,ar_coeffs_r)
            
            # Add new feature
            zcSignal_r             = tsfel.feature_extraction.features.zero_cross(filteredSignal_r)
            featureFrame           = np.append(featureFrame,zcSignal_r)
            
            # Add new feature
            skewSignal_r           = tsfel.feature_extraction.features.skewness(filteredSignal_r)
            # featureFrame           = np.append(featureFrame,skewSignal_r)
            
            # Add new feature
            absWavelength_r        = tsfel.feature_extraction.wavelet_abs_mean(filteredSignal_r)
            maWavelength_r         = np.mean(absWavelength_r)
            # featureFrame           = np.append(featureFrame,maWavelength_r)
            
            # Add new feature
            autocorr_r             = tsfel.feature_extraction.autocorr(filteredSignal_r)
            # featureFrame           = np.append(featureFrame,autocorr_r)
            
            # Add new feature
            kurtSpectral_r         = tsfel.feature_extraction.features.spectral_kurtosis(filteredSignal_r, sr)
            # featureFrame           = np.append(featureFrame,kurtSpectral_r)
            
            # Add new feature
            skewSpectral_r         = tsfel.feature_extraction.features.spectral_skewness(filteredSignal_r, sr)
            # featureFrame           = np.append(featureFrame,skewSpectral_r)
            
            # Add new feature
            sum_abs_diff_r         = tsfel.feature_extraction.features.sum_abs_diff(filteredSignal_r)
            featureFrame           = np.append(featureFrame,sum_abs_diff_r)
            
            # Add new feature
            kurtPSD_r              = scipy.stats.kurtosis(psdSignal_r)
            # featureFrame           = np.append(featureFrame,kurtPSD_r)
            
            # Add new feature
            varPSD_r               = np.var(psdSignal_r)
            featureFrame           = np.append(featureFrame,varPSD_r)
            
            # Add new feature
            meanPSD_r              = np.mean(psdSignal_r)
            # featureFrame           = np.append(featureFrame,meanPSD_r)
            
            # Add new feature
            skewKTE_r              = scipy.stats.skew(kteSignal_r)
            # featureFrame           = np.append(featureFrame,skewKTE_r)
            
            # Add new feature
            kurtKTE_r              = scipy.stats.kurtosis(kteSignal_r)
            # featureFrame           = np.append(featureFrame,kurtKTE_r)
            
            # Add new feature
            varKTE_r               = np.var(kteSignal_r)
            featureFrame           = np.append(featureFrame,varKTE_r)
            
            # Add new feature
            meanKTE_r              = np.mean(kteSignal_r)
            # featureFrame           = np.append(featureFrame,meanKTE_r)
            
            
            # >>>>>>>>>>>>>>>>Green>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
           
            # > __Algorithm 03:__ Butter Low-pass Filter
            filteredSignal_g = butter_lowPass_filter(
                data  = g_sp[j]-np.mean(g_sp[j]), 
                cutoff= 8, 
                fs    = sr, 
                order = 6
                )

            fqSignal_g, psdSignal_g    = scipy.signal.welch(
                x       = filteredSignal_g, 
                nperseg = len(filteredSignal_g) # Added to overcome error
                ) 
           
            # > __Algorithm 05:__ Kaiser–Teager Energy
            kteSignal_g            = get_kaiser_teager_energy(
                filteredSignal_g
                )
            
            
            # Insert Feature one by one
            # Add new feature
            ar_coeffs_g, _g        = statsmodels.regression.linear_model.yule_walker(filteredSignal_g, order = 2)
            # featureFrame           = np.append(featureFrame,ar_coeffs_g)
            
            # Add new feature
            zcSignal_g             = tsfel.feature_extraction.features.zero_cross(filteredSignal_g)
            featureFrame           = np.append(featureFrame,zcSignal_g)
            
            # Add new feature
            skewSignal_g           = tsfel.feature_extraction.features.skewness(filteredSignal_g)
            # featureFrame           = np.append(featureFrame,skewSignal_g)
            
            # Add new feature
            absWavelength_g        = tsfel.feature_extraction.wavelet_abs_mean(filteredSignal_g)
            maWavelength_g         = np.mean(absWavelength_g)
            # featureFrame           = np.append(featureFrame,maWavelength_g)
            
            # Add new feature
            autocorr_g             = tsfel.feature_extraction.autocorr(filteredSignal_g)
            # featureFrame           = np.append(featureFrame,autocorr_g)
            
            # Add new feature
            kurtSpectral_g         = tsfel.feature_extraction.features.spectral_kurtosis(filteredSignal_g, sr)
            # featureFrame           = np.append(featureFrame,kurtSpectral_g)
            
            # Add new feature
            skewSpectral_g         = tsfel.feature_extraction.features.spectral_skewness(filteredSignal_g, sr)
            # featureFrame           = np.append(featureFrame,skewSpectral_g)
            
            # Add new feature
            sum_abs_diff_g         = tsfel.feature_extraction.features.sum_abs_diff(filteredSignal_g)
            featureFrame           = np.append(featureFrame,sum_abs_diff_g)
            
            # Add new feature
            kurtPSD_g              = scipy.stats.kurtosis(psdSignal_g)
            # featureFrame           = np.append(featureFrame,kurtPSD_g)
            
            # Add new feature
            varPSD_g               = np.var(psdSignal_g)
            featureFrame           = np.append(featureFrame,varPSD_g)
            
            # Add new feature
            meanPSD_g              = np.mean(psdSignal_g)
            # featureFrame           = np.append(featureFrame,meanPSD_g)
            
            # Add new feature
            skewKTE_g              = scipy.stats.skew(kteSignal_g)
            # featureFrame           = np.append(featureFrame,skewKTE_g)
            
            # Add new feature
            kurtKTE_g              = scipy.stats.kurtosis(kteSignal_g)
            # featureFrame           = np.append(featureFrame,kurtKTE_g)
            
            # Add new feature
            varKTE_g               = np.var(kteSignal_g)
            featureFrame           = np.append(featureFrame,varKTE_g)
            
            # Add new feature
            meanKTE_g              = np.mean(kteSignal_g)
            # featureFrame           = np.append(featureFrame,meanKTE_g)


            # >>>>>>>>>>>>>>>>Add_r1_r2_as_features>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
            # filteredSignal_b = butter_lowPass_filter(
            #     data  = b_sp[j]-np.mean(b_sp[j]), 
            #     cutoff= 8, 
            #     fs    = sr, 
            #     order = 6
            #     )

            
            featureFrame           = np.append(featureFrame,r1)
            featureFrame           = np.append(featureFrame,r2)
            
            
            # >>>>>>>>>>>>>>>>Add_other_features>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
            # featureFrame           = np.append(featureFrame,SpO2[i])
            # featureFrame           = np.append(featureFrame,BMI[i])

            # >>>>>>>>>>>>>>> Add output feature 
            featureFrame           = np.append(featureFrame,HbA1c[i])

            ## Insert featureFrame into featureSet
            # Initialized feature set array 
            if l == 0:
                k = len(featureFrame)
                # print('kCount='+str(k))
                featureSet = np.empty([150000,k]) 
            # Save into featureSet
            featureSet[l][:k] = featureFrame
            # Length increased for next cycle
            l = l + 1


            # Checking outputs
            print(f'iCount={i} || jCount={j} || lCount={l} || fCount={len(featureFrame)}')
            print(featureFrame)

        # Check point    
        # print('iCount='+str(i))

    # Gather all
    print('**********************************************************************')
    print('*****************************Summary**********************************')    
    featureSet = featureSet[0:l][:]
    # Check for null
    featureSet = featureSet[~np.isnan(featureSet).any(axis=1)]
    print('**********************************************************************')
    return featureSet

# %% [markdown]
# > __Algorithm 06v2:__ Constructing Features Set _(Red, Green, Blue; Reflected, FeatureCount=[4+4+r1+r2+SpO2+BMI]+[HbA1c]=13)_
# >> ACK: __Developed by Shama, Guided by Honorable Professor Kim__. _Significantly improve the performance_

# %%
def construct_feature_set_v2 (PPG, HbA1c, SpO2, BMI, samplingRate=32):
    # Initialization
    sr         = samplingRate
    l          = 0

    for i in range (0,len(PPG)):
        
        # Getting corresponding PPG Data
        # > __Algorithm 01:__ Baseline Dirft Removal by () 
        r,g,b = removing_baseline_drift(ppgSignal=PPG[i], showFigure='False')
        print('PPG_data_info:'+str(PPG[i]))

        # > __Algorithm 04:__ Determine AC_DC_from_Signal
        r_ac,r_dc = determine_ac_dc_from_PPG(r)
        g_ac,g_dc = determine_ac_dc_from_PPG(g)
        b_ac,b_dc = determine_ac_dc_from_PPG(b)

        # Calculate r1 & r2
        r1 = (g_ac/g_dc)/(r_ac/r_dc)
        r2 = (b_ac/b_dc)/(r_ac/r_dc)

        # > __Algorithm 02:__ Split_Signal
        r_sp = splitSignal(individualSignal=r, horizonSize=horizonSet, windowSize=windowSet)
        g_sp = splitSignal(individualSignal=g, horizonSize=horizonSet, windowSize=windowSet)
        b_sp = splitSignal(individualSignal=b, horizonSize=horizonSet, windowSize=windowSet)
        
        # Constructing Feature Set
        for j in range(len(r_sp)):  ### You can also use r_sp.shape[0]
            # Initialize frame
            featureFrame       = []
            
            # >>>>>>>>>>>>>>>>Red>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
            # > __Algorithm 03:__ Filter
            filteredSignal_r   = butter_lowPass_filter(
                data  = r_sp[j]-np.mean(r_sp[j]), 
                cutoff= 8, 
                fs    = sr, 
                order = 6
                )

            fqSignal_r, psdSignal_r    = scipy.signal.welch(
                x       = filteredSignal_r, 
                nperseg = len(filteredSignal_r) # Added to overcome error
                ) 


            # > __Algorithm 05:__ Kaiser–Teager Energy
            kteSignal_r            = get_kaiser_teager_energy(
                filteredSignal_r
                )



            # Insert Feature one by one
            # Add new feature (5)
            ar_coeffs_r, _r        = statsmodels.regression.linear_model.yule_walker(filteredSignal_r, order = 2)
            # featureFrame           = np.append(featureFrame,ar_coeffs_r)
            
            # Add new feature
            zcSignal_r             = tsfel.feature_extraction.features.zero_cross(filteredSignal_r)
            featureFrame           = np.append(featureFrame,zcSignal_r)
            
            # Add new feature
            skewSignal_r           = tsfel.feature_extraction.features.skewness(filteredSignal_r)
            # featureFrame           = np.append(featureFrame,skewSignal_r)
            
            # Add new feature
            absWavelength_r        = tsfel.feature_extraction.wavelet_abs_mean(filteredSignal_r)
            maWavelength_r         = np.mean(absWavelength_r)
            # featureFrame           = np.append(featureFrame,maWavelength_r)
            
            # Add new feature
            autocorr_r             = tsfel.feature_extraction.autocorr(filteredSignal_r)
            # featureFrame           = np.append(featureFrame,autocorr_r)
            
            # Add new feature
            kurtSpectral_r         = tsfel.feature_extraction.features.spectral_kurtosis(filteredSignal_r, sr)
            # featureFrame           = np.append(featureFrame,kurtSpectral_r)
            
            # Add new feature
            skewSpectral_r         = tsfel.feature_extraction.features.spectral_skewness(filteredSignal_r, sr)
            # featureFrame           = np.append(featureFrame,skewSpectral_r)
            
            # Add new feature
            sum_abs_diff_r         = tsfel.feature_extraction.features.sum_abs_diff(filteredSignal_r)
            featureFrame           = np.append(featureFrame,sum_abs_diff_r)
            
            # Add new feature
            kurtPSD_r              = scipy.stats.kurtosis(psdSignal_r)
            # featureFrame           = np.append(featureFrame,kurtPSD_r)
            
            # Add new feature
            varPSD_r               = np.var(psdSignal_r)
            featureFrame           = np.append(featureFrame,varPSD_r)
            
            # Add new feature
            meanPSD_r              = np.mean(psdSignal_r)
            # featureFrame           = np.append(featureFrame,meanPSD_r)
            
            # Add new feature
            skewKTE_r              = scipy.stats.skew(kteSignal_r)
            # featureFrame           = np.append(featureFrame,skewKTE_r)
            
            # Add new feature
            kurtKTE_r              = scipy.stats.kurtosis(kteSignal_r)
            # featureFrame           = np.append(featureFrame,kurtKTE_r)
            
            # Add new feature
            varKTE_r               = np.var(kteSignal_r)
            featureFrame           = np.append(featureFrame,varKTE_r)
            
            # Add new feature
            meanKTE_r              = np.mean(kteSignal_r)
            # featureFrame           = np.append(featureFrame,meanKTE_r)
            
            
            # >>>>>>>>>>>>>>>>Green>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
           
            # > __Algorithm 03:__ Butter Low-pass Filter
            filteredSignal_g = butter_lowPass_filter(
                data  = g_sp[j]-np.mean(g_sp[j]), 
                cutoff= 8, 
                fs    = sr, 
                order = 6
                )

            fqSignal_g, psdSignal_g    = scipy.signal.welch(
                x       = filteredSignal_g, 
                nperseg = len(filteredSignal_g) # Added to overcome error
                ) 
           
            # > __Algorithm 05:__ Kaiser–Teager Energy
            kteSignal_g            = get_kaiser_teager_energy(
                filteredSignal_g
                )
            
            
            # Insert Feature one by one
            # Add new feature
            ar_coeffs_g, _g        = statsmodels.regression.linear_model.yule_walker(filteredSignal_g, order = 2)
            # featureFrame           = np.append(featureFrame,ar_coeffs_g)
            
            # Add new feature
            zcSignal_g             = tsfel.feature_extraction.features.zero_cross(filteredSignal_g)
            featureFrame           = np.append(featureFrame,zcSignal_g)
            
            # Add new feature
            skewSignal_g           = tsfel.feature_extraction.features.skewness(filteredSignal_g)
            # featureFrame           = np.append(featureFrame,skewSignal_g)
            
            # Add new feature
            absWavelength_g        = tsfel.feature_extraction.wavelet_abs_mean(filteredSignal_g)
            maWavelength_g         = np.mean(absWavelength_g)
            # featureFrame           = np.append(featureFrame,maWavelength_g)
            
            # Add new feature
            autocorr_g             = tsfel.feature_extraction.autocorr(filteredSignal_g)
            # featureFrame           = np.append(featureFrame,autocorr_g)
            
            # Add new feature
            kurtSpectral_g         = tsfel.feature_extraction.features.spectral_kurtosis(filteredSignal_g, sr)
            # featureFrame           = np.append(featureFrame,kurtSpectral_g)
            
            # Add new feature
            skewSpectral_g         = tsfel.feature_extraction.features.spectral_skewness(filteredSignal_g, sr)
            # featureFrame           = np.append(featureFrame,skewSpectral_g)
            
            # Add new feature
            sum_abs_diff_g         = tsfel.feature_extraction.features.sum_abs_diff(filteredSignal_g)
            featureFrame           = np.append(featureFrame,sum_abs_diff_g)
            
            # Add new feature
            kurtPSD_g              = scipy.stats.kurtosis(psdSignal_g)
            # featureFrame           = np.append(featureFrame,kurtPSD_g)
            
            # Add new feature
            varPSD_g               = np.var(psdSignal_g)
            featureFrame           = np.append(featureFrame,varPSD_g)
            
            # Add new feature
            meanPSD_g              = np.mean(psdSignal_g)
            # featureFrame           = np.append(featureFrame,meanPSD_g)
            
            # Add new feature
            skewKTE_g              = scipy.stats.skew(kteSignal_g)
            # featureFrame           = np.append(featureFrame,skewKTE_g)
            
            # Add new feature
            kurtKTE_g              = scipy.stats.kurtosis(kteSignal_g)
            # featureFrame           = np.append(featureFrame,kurtKTE_g)
            
            # Add new feature
            varKTE_g               = np.var(kteSignal_g)
            featureFrame           = np.append(featureFrame,varKTE_g)
            
            # Add new feature
            meanKTE_g              = np.mean(kteSignal_g)
            # featureFrame           = np.append(featureFrame,meanKTE_g)


            # >>>>>>>>>>>>>>>>Add_r1_r2_as_features>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
            
            featureFrame           = np.append(featureFrame,r1)
            featureFrame           = np.append(featureFrame,r2)
            
            
            # >>>>>>>>>>>>>>>>Add_other_features>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
            featureFrame           = np.append(featureFrame,SpO2[i])
            featureFrame           = np.append(featureFrame,BMI[i])

            # >>>>>>>>>>>>>>> Add output feature 
            featureFrame           = np.append(featureFrame,HbA1c[i])

            ## Insert featureFrame into featureSet
            # Initialized feature set array 
            if l == 0:
                k = len(featureFrame)
                # print('kCount='+str(k))
                featureSet = np.empty([150000,k]) 
            # Save into featureSet
            featureSet[l][:k] = featureFrame
            # Length increased for next cycle
            l = l + 1


            # Checking outputs
            print(f'iCount={i} || jCount={j} || lCount={l} || fCount={len(featureFrame)}')
            print(featureFrame)

        # Check point    
        # print('iCount='+str(i))

    # Gather all
    print('**********************************************************************')
    print('*****************************Summary**********************************')    
    featureSet = featureSet[0:l][:]
    # Check for null
    featureSet = featureSet[~np.isnan(featureSet).any(axis=1)]
    print('**********************************************************************')
    return featureSet

# %% [markdown]
# # __Main Function__

# %% [markdown]
# ## __Test 01:__

# %% [markdown]
# >  Utilizing __Algorithm 06v2:__ Constructing Features Set _(Red, Green, Blue; Reflected, FeatureCount=[4+4+r1+r2]+[HbA1c]=11)_

# %%
# Initialize
loo                = sk.model_selection.LeaveOneOut()
t1_scores          = []
t1_test_cases      = []
t1_train_cases     = []
countEpoch         = 0
percent            = 0.02
# XG Boost
t1_results_xg      = []
t1_e_results_xg    = []
# Random Forest
t1_results_rf      = []
t1_e_results_rf    = []
# Cat Boost
t1_results_cb      = []
t1_e_results_cb    = []
# Light GBM
t1_results_lg      = []
t1_e_results_lg    = []

for train_index, test_index in loo.split(PPG_csvArray):
    print('Epoch # '+str(countEpoch))
    countEpoch +=1

    X_train, X_test      = PPG_csvArray[train_index], PPG_csvArray[test_index]
    y_train, y_test      = HbA1c_Array [train_index], HbA1c_Array [test_index]
    sp_train, sp_test    = SpO2_Array  [train_index], SpO2_Array  [test_index]
    bmi_train, bmi_test  = BMI_Array   [train_index], BMI_Array   [test_index]
    
    
    # > __Algorithm 06v1:__ Constructing Features Set _(Red, Green, Blue; Reflected, FeatureCount=[4+4+r1+r2]+[HbA1c]=11)_
    print('*************************************************************')
    print('*********************Training Array Set**********************')
    print('*************************************************************')
    train_array = construct_feature_set_v1(
        PPG          = X_train,
        HbA1c        = y_train,
        SpO2         = sp_train,
        BMI          = bmi_train,
        samplingRate = 32
        )
    print('*************************************************************')
    print('*********************Testing Array Set***********************')
    print('*************************************************************')
    test_array  = construct_feature_set_v1(
        PPG          = X_test,
        HbA1c        = y_test,
        SpO2         = sp_test,
        BMI          = bmi_test,
        samplingRate = 32
        )
    
    feature_train, hba1c_train = train_array[:,:-1], train_array[:,-1]
    feature_test, hba1c_test   = test_array[:,:-1],  test_array[:,-1]
    
    train = np.sort(np.array(random.sample(range(feature_test.shape[0]), int(feature_test.shape[0] * percent))))
    if train.shape[0] == 0:
        feature_train, hba1c_train = np.append(feature_train, np.expand_dims(feature_test[0],axis=0), 0), np.append(hba1c_train, np.expand_dims(hba1c_test[0],axis=0), 0)
        # feature_test, hba1c_test = np.delete(feature_test, 0, axis = 0), np.delete(hba1c_test, 0, axis = 0)
    else:
        test = np.delete(np.arange(feature_test.shape[0]), train)

        feature_train, hba1c_train = np.append(feature_train, feature_test[train], 0), np.append(hba1c_train, hba1c_test[train], 0)
        feature_test, hba1c_test = np.delete(feature_test, train, axis = 0), np.delete(hba1c_test, train, axis = 0)
    
    feature_train, hba1c_train = sk.utils.shuffle(feature_train, hba1c_train, random_state=0)
    # print(feature_train.shape)
    # print(feature_test.shape)

    # XGboost
    xg = xgb.XGBRegressor(objective="reg:squarederror", random_state=42)
    xg.fit(feature_train, hba1c_train)
    t1_results_xg.append(np.nanmean(xg.predict(feature_test)))
    t1_e_results_xg.append(np.nanmean(hba1c_test))

    # Random Forest
    rf = RandomForestRegressor(random_state=42, n_estimators=1000, n_jobs=-1)
    rf.fit(feature_train, hba1c_train)
    t1_results_rf.append(np.nanmean(rf.predict(feature_test)))
    t1_e_results_rf.append(np.nanmean(hba1c_test))

    # Cat boost
    cb = cab.CatBoostRegressor()
    cb.fit(feature_train, hba1c_train)
    t1_results_cb.append(np.nanmean(cb.predict(feature_test)))
    t1_e_results_cb.append(np.nanmean(hba1c_test))

    # Light GBM
    # lg = ltb.LGBMRegressor(boosting_type='dart')
    lg = ltb.LGBMRegressor(
        application = 'regression',
        objective = 'root_mean_squared_error',
        boosting_type="dart",
        num_iterations = 3500,
        learning_rate = 0.05,
        num_leaves=150,
        tree_learner='feature',
        max_depth =10,
        min_data_in_leaf=7,
        bagging_fraction = 1,
        bagging_freq = 100,
        reg_sqrt='True',
        metric ='rmse',
        feature_fraction = 0.6,
        random_state=42
        ) 
    lg.fit(feature_train, hba1c_train)
    t1_results_lg.append(np.nanmean(lg.predict(feature_test)))
    t1_e_results_lg.append(np.nanmean(hba1c_test))



    t1_test_cases.append(X_test)
    t1_train_cases.append(X_train)

    clear_output(wait=True)
# Out:
# Epoch # 27
# *************************************************************
# *********************Training Array Set**********************
# *************************************************************
# PPG_data_info:./DataBase/Selected_PPG_wrist/210823_4.csv
# iCount=0 || jCount=0 || lCount=1 || fCount=11
# [7.00000000e+00 1.61312204e+02 4.10558183e+05 1.36127807e+02
#  7.00000000e+00 1.74190061e+02 5.03481979e+05 1.54951554e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=1 || lCount=2 || fCount=11
# [7.00000000e+00 1.73713036e+02 3.51560946e+05 1.21364809e+02
#  7.00000000e+00 1.82843593e+02 4.68460607e+05 1.32491539e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=2 || lCount=3 || fCount=11
# [6.00000000e+00 1.54907170e+02 1.65456467e+05 1.07901937e+02
#  6.00000000e+00 1.62510326e+02 2.92588034e+05 1.11369158e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=3 || lCount=4 || fCount=11
# [7.00000000e+00 1.61769923e+02 2.37911636e+05 9.17652058e+01
#  6.00000000e+00 1.75565987e+02 3.51616378e+05 1.20894133e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=4 || lCount=5 || fCount=11
# [6.00000000e+00 1.65802718e+02 2.81689078e+05 1.18233671e+02
#  6.00000000e+00 1.71134347e+02 4.16162401e+05 1.13538140e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=5 || lCount=6 || fCount=11
# [6.00000000e+00 1.70058097e+02 2.72924695e+05 1.22931421e+02
#  6.00000000e+00 1.83064413e+02 3.93325157e+05 1.27517168e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=6 || lCount=7 || fCount=11
# [6.00000000e+00 1.56658899e+02 2.18831851e+05 1.01261033e+02
#  6.00000000e+00 1.63203538e+02 3.58888557e+05 1.14850275e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=7 || lCount=8 || fCount=11
# [7.00000000e+00 1.48703447e+02 1.71084414e+05 9.05114879e+01
#  7.00000000e+00 1.63828904e+02 2.47001572e+05 1.07642156e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=8 || lCount=9 || fCount=11
# [7.00000000e+00 1.54631162e+02 2.19500971e+05 9.31845444e+01
#  7.00000000e+00 1.60331227e+02 2.97537408e+05 7.69965482e+01
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=9 || lCount=10 || fCount=11
# [7.00000000e+00 1.73304457e+02 2.06181451e+05 1.54463138e+02
#  7.00000000e+00 1.80983880e+02 2.72858551e+05 1.46044883e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# PPG_data_info:./DataBase/Selected_PPG_wrist/210830_0.csv
# iCount=1 || jCount=0 || lCount=11 || fCount=11
# [6.00000000e+00 5.36622112e+01 1.20219822e+04 3.86968504e+00
#  6.00000000e+00 7.14115935e+01 3.69170680e+04 7.05572951e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=1 || lCount=12 || fCount=11
# [5.00000000e+00 4.71806775e+01 1.84090477e+03 2.66880298e+00
#  5.00000000e+00 5.96340378e+01 7.78992216e+03 4.30603905e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=2 || lCount=13 || fCount=11
# [9.00000000e+00 3.79026957e+01 2.15920481e+02 7.27679788e-01
#  7.00000000e+00 4.87611407e+01 2.04592978e+03 1.60489300e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=3 || lCount=14 || fCount=11
# [6.00000000e+00 4.74109516e+01 7.81573710e+02 1.84600683e+00
#  6.00000000e+00 7.04502242e+01 7.10577496e+03 6.43960851e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=4 || lCount=15 || fCount=11
# [1.10000000e+01 4.55226536e+01 1.01044228e+03 6.15019707e-01
#  7.00000000e+00 6.67933951e+01 1.05092759e+04 3.09427773e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=5 || lCount=16 || fCount=11
# [7.00000000e+00 5.22974244e+01 2.05916120e+03 1.76437438e+00
#  6.00000000e+00 7.50534446e+01 1.89150644e+04 6.40508584e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=6 || lCount=17 || fCount=11
# [6.00000000e+00 5.11098752e+01 3.80292727e+03 1.28693690e+00
#  6.00000000e+00 7.34571094e+01 1.51200802e+04 6.70364275e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=7 || lCount=18 || fCount=11
# [7.00000000e+00 5.56081022e+01 2.49099757e+03 2.58237809e+00
#  7.00000000e+00 8.12992026e+01 1.43806560e+04 1.18496311e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=8 || lCount=19 || fCount=11
# [1.10000000e+01 5.17046070e+01 9.42064449e+02 1.68826637e+00
#  7.00000000e+00 7.48976676e+01 9.90838480e+03 7.11690760e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=9 || lCount=20 || fCount=11
# [6.00000000e+00 5.12040392e+01 2.57584596e+03 1.50701151e+00
#  6.00000000e+00 8.00289251e+01 2.06934370e+04 8.80635736e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=10 || lCount=21 || fCount=11
# [6.00000000e+00 5.62719403e+01 1.53131626e+03 2.65879994e+00
#  6.00000000e+00 8.32808643e+01 1.51879848e+04 1.08165517e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=11 || lCount=22 || fCount=11
# [7.00000000e+00 5.85009853e+01 3.98383571e+03 2.25841091e+00
#  7.00000000e+00 8.77577711e+01 3.03465226e+04 1.36476504e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=12 || lCount=23 || fCount=11
# [6.00000000e+00 5.44515467e+01 4.84828928e+03 3.07748807e+00
#  6.00000000e+00 8.26406990e+01 2.43605703e+04 1.48722413e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=13 || lCount=24 || fCount=11
# [7.00000000e+00 6.65121674e+01 7.15512558e+03 5.88393426e+00
#  7.00000000e+00 1.01551985e+02 3.72335451e+04 3.14498549e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=14 || lCount=25 || fCount=11
# [8.00000000e+00 6.05173199e+01 9.26965131e+02 3.79577859e+00
#  6.00000000e+00 9.03766631e+01 1.12255401e+04 1.85877416e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=15 || lCount=26 || fCount=11
# [6.00000000e+00 6.20451619e+01 3.86936212e+03 3.15221111e+00
#  6.00000000e+00 9.60389307e+01 3.36098916e+04 2.21746729e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=16 || lCount=27 || fCount=11
# [6.00000000e+00 7.43333504e+01 2.61723829e+04 8.11783057e+00
#  6.00000000e+00 1.17494645e+02 1.55687235e+05 4.79919725e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=17 || lCount=28 || fCount=11
# [6.00000000e+00 7.20000087e+01 1.33856143e+04 7.50601027e+00
#  6.00000000e+00 1.11153344e+02 9.33158326e+04 4.92030016e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=18 || lCount=29 || fCount=11
# [6.00000000e+00 6.72150552e+01 6.83301543e+03 6.04072158e+00
#  6.00000000e+00 1.11666257e+02 6.10556909e+04 4.26720460e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=19 || lCount=30 || fCount=11
# [6.00000000e+00 7.74982380e+01 1.46524381e+04 1.06307073e+01
#  6.00000000e+00 1.22730904e+02 1.02767864e+05 6.34777650e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=20 || lCount=31 || fCount=11
# [6.00000000e+00 7.38491806e+01 1.02530109e+04 7.56417016e+00
#  6.00000000e+00 1.16957058e+02 8.16341396e+04 6.80259145e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=21 || lCount=32 || fCount=11
# [6.00000000e+00 7.92349357e+01 1.79483751e+04 1.11183822e+01
#  6.00000000e+00 1.23872795e+02 1.36220203e+05 6.02715933e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=22 || lCount=33 || fCount=11
# [6.00000000e+00 8.71069870e+01 3.22231039e+04 1.46582579e+01
#  6.00000000e+00 1.33852718e+02 1.80212049e+05 8.41074448e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=23 || lCount=34 || fCount=11
# [7.00000000e+00 7.91284418e+01 2.82532677e+04 9.19956364e+00
#  7.00000000e+00 1.23687391e+02 1.98146664e+05 5.55534531e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=24 || lCount=35 || fCount=11
# [6.00000000e+00 7.48387371e+01 7.65890612e+03 1.25568002e+01
#  6.00000000e+00 1.24177457e+02 7.72755083e+04 7.59013109e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=25 || lCount=36 || fCount=11
# [7.00000000e+00 8.50029977e+01 2.20361070e+04 1.98480909e+01
#  7.00000000e+00 1.36578114e+02 1.46347345e+05 1.05491961e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=26 || lCount=37 || fCount=11
# [6.00000000e+00 8.62871423e+01 9.65211461e+03 1.12120928e+01
#  6.00000000e+00 1.25166177e+02 4.61606923e+04 5.37872716e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=27 || lCount=38 || fCount=11
# [6.00000000e+00 8.95448021e+01 3.92738759e+04 1.89154052e+01
#  6.00000000e+00 1.36113545e+02 2.03302293e+05 9.66488178e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=28 || lCount=39 || fCount=11
# [6.00000000e+00 8.85791445e+01 1.24300607e+04 1.95099039e+01
#  6.00000000e+00 1.39040585e+02 1.17703272e+05 1.20293254e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=29 || lCount=40 || fCount=11
# [6.00000000e+00 9.94612995e+01 4.71394193e+04 3.06222240e+01
#  6.00000000e+00 1.51493548e+02 2.63789746e+05 1.46975288e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=30 || lCount=41 || fCount=11
# [6.00000000e+00 9.39691110e+01 4.06171009e+04 2.90297967e+01
#  6.00000000e+00 1.47600086e+02 2.39869529e+05 1.63879119e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=31 || lCount=42 || fCount=11
# [7.00000000e+00 9.84474075e+01 2.99868170e+04 2.78316674e+01
#  7.00000000e+00 1.59232758e+02 2.36636954e+05 1.88876910e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=32 || lCount=43 || fCount=11
# [6.00000000e+00 1.06172304e+02 5.54492102e+04 3.70314402e+01
#  6.00000000e+00 1.63417147e+02 3.33156334e+05 2.44265573e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=33 || lCount=44 || fCount=11
# [6.00000000e+00 1.02308616e+02 8.35098626e+04 3.65374380e+01
#  6.00000000e+00 1.55770959e+02 4.37248182e+05 1.76749004e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=34 || lCount=45 || fCount=11
# [6.00000000e+00 9.12484397e+01 4.27431821e+04 3.24872144e+01
#  6.00000000e+00 1.50592048e+02 3.49677820e+05 1.95518338e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=35 || lCount=46 || fCount=11
# [5.00000000e+00 1.05409002e+02 1.12914832e+05 3.38413094e+01
#  6.00000000e+00 1.55575699e+02 5.08832654e+05 2.21874930e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=36 || lCount=47 || fCount=11
# [6.00000000e+00 1.04745057e+02 5.75096462e+04 4.22267895e+01
#  6.00000000e+00 1.59808053e+02 3.81173863e+05 2.28496317e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# PPG_data_info:./DataBase/Selected_PPG_wrist/210927_0.csv
# iCount=2 || jCount=0 || lCount=48 || fCount=11
# [1.10000000e+01 6.83467371e+01 1.08422612e+03 4.39506632e+00
#  1.10000000e+01 9.83106175e+01 7.90890426e+03 1.47652844e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=1 || lCount=49 || fCount=11
# [1.20000000e+01 1.42736356e+02 1.65308823e+04 8.95840489e+01
#  1.20000000e+01 2.36613487e+02 1.13493275e+05 3.47933475e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=2 || lCount=50 || fCount=11
# [1.20000000e+01 8.90599633e+01 2.78767430e+03 1.55299320e+01
#  1.20000000e+01 2.30495084e+02 1.67525521e+05 1.90827342e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=3 || lCount=51 || fCount=11
# [1.30000000e+01 6.14050169e+01 4.29994435e+02 1.84640836e+00
#  1.20000000e+01 2.06652299e+02 1.61957296e+05 1.36353449e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=4 || lCount=52 || fCount=11
# [1.30000000e+01 1.72086477e+02 4.23959856e+04 6.82855715e+01
#  1.10000000e+01 2.50984075e+02 1.75676338e+05 2.06113239e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=5 || lCount=53 || fCount=11
# [1.10000000e+01 1.93649706e+02 9.23798304e+04 9.04337299e+01
#  1.20000000e+01 2.47517291e+02 2.87906390e+05 2.69096300e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=6 || lCount=54 || fCount=11
# [1.20000000e+01 1.98042723e+02 8.05762076e+04 9.45541877e+01
#  1.20000000e+01 2.82555769e+02 4.65959306e+05 2.94799014e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=7 || lCount=55 || fCount=11
# [1.20000000e+01 1.69894223e+02 3.67775134e+04 8.63000252e+01
#  1.10000000e+01 2.76699280e+02 2.88369031e+05 5.07124677e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=8 || lCount=56 || fCount=11
# [1.30000000e+01 1.66535785e+02 2.37292852e+04 9.85824118e+01
#  1.10000000e+01 2.31524809e+02 8.35112774e+04 2.65250983e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=9 || lCount=57 || fCount=11
# [1.10000000e+01 1.77981533e+02 6.28388834e+04 5.25159649e+01
#  1.10000000e+01 2.52539978e+02 2.49094269e+05 2.18652811e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=10 || lCount=58 || fCount=11
# [1.10000000e+01 2.18471698e+02 8.41361662e+04 1.84549564e+02
#  1.10000000e+01 2.39430840e+02 1.43858793e+05 2.00647627e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=11 || lCount=59 || fCount=11
# [1.20000000e+01 1.99017725e+02 9.01255399e+04 1.06270022e+02
#  1.20000000e+01 2.10402653e+02 1.17939022e+05 1.46061272e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=12 || lCount=60 || fCount=11
# [1.10000000e+01 1.70646462e+02 1.98866107e+04 1.13358430e+02
#  1.20000000e+01 2.79622359e+02 3.31077702e+05 3.33247054e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=13 || lCount=61 || fCount=11
# [1.20000000e+01 2.35961002e+02 2.71280845e+05 2.29147121e+02
#  1.20000000e+01 3.71486910e+02 1.54686763e+06 1.30507828e+03
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=14 || lCount=62 || fCount=11
# [1.10000000e+01 1.50799285e+02 1.83110374e+04 1.03212033e+02
#  1.10000000e+01 2.37305134e+02 1.14713874e+05 5.05992803e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=15 || lCount=63 || fCount=11
# [1.10000000e+01 1.75019035e+02 5.30919222e+04 7.12489500e+01
#  1.10000000e+01 1.71552444e+02 4.34976790e+04 9.98493635e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=16 || lCount=64 || fCount=11
# [1.20000000e+01 1.67194701e+02 1.92927385e+04 8.08006987e+01
#  1.20000000e+01 2.49358101e+02 2.31645844e+05 3.82484925e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=17 || lCount=65 || fCount=11
# [1.10000000e+01 1.99304980e+02 6.87835795e+04 2.06268733e+02
#  1.10000000e+01 3.13673884e+02 4.86507313e+05 8.64573508e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=18 || lCount=66 || fCount=11
# [1.00000000e+01 1.57139024e+02 6.23042979e+04 7.69375151e+01
#  1.20000000e+01 2.21450442e+02 1.64329998e+05 3.54239385e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=19 || lCount=67 || fCount=11
# [1.20000000e+01 1.37911299e+02 2.79730822e+04 4.45335938e+01
#  1.00000000e+01 2.09671742e+02 1.52922463e+05 2.31572835e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=20 || lCount=68 || fCount=11
# [9.00000000e+00 1.37957899e+02 8.57246900e+03 1.24885905e+02
#  9.00000000e+00 1.79473342e+02 4.18354574e+04 2.74596345e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=21 || lCount=69 || fCount=11
# [1.20000000e+01 1.85734384e+02 3.88022780e+04 1.02681093e+02
#  1.20000000e+01 2.85981930e+02 2.41811618e+05 4.23737001e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=22 || lCount=70 || fCount=11
# [1.20000000e+01 2.05410478e+02 1.27623015e+05 1.51185568e+02
#  1.10000000e+01 2.70147191e+02 4.12665805e+05 4.74387623e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=23 || lCount=71 || fCount=11
# [1.10000000e+01 1.01285937e+02 3.47502069e+03 2.42119430e+01
#  1.10000000e+01 1.61430288e+02 4.13728419e+04 5.71945638e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=24 || lCount=72 || fCount=11
# [1.10000000e+01 1.31988307e+02 2.68920174e+04 3.92702057e+01
#  1.10000000e+01 2.26496802e+02 2.41901933e+05 2.26206691e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=25 || lCount=73 || fCount=11
# [4.00000000e+00 1.10306293e+02 3.25049763e+04 1.22450827e+02
#  5.00000000e+00 1.40799574e+02 1.98843179e+05 1.76918094e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=26 || lCount=74 || fCount=11
# [7.00000000e+00 1.60580887e+02 9.28170800e+05 4.54042225e+02
#  3.00000000e+00 1.79605304e+02 3.21054326e+06 1.44402812e+03
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=27 || lCount=75 || fCount=11
# [7.00000000e+00 9.30292467e+01 3.20034857e+04 3.43587410e+01
#  6.00000000e+00 1.17738629e+02 1.17154556e+05 3.30161967e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=28 || lCount=76 || fCount=11
# [1.50000000e+01 6.93632199e+01 1.33232029e+03 6.14351342e+00
#  1.00000000e+01 6.71543417e+01 1.39968103e+03 2.43480913e+00
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=29 || lCount=77 || fCount=11
# [1.10000000e+01 7.74647011e+01 1.75583181e+03 4.16620645e+00
#  1.30000000e+01 8.76791710e+01 2.12378858e+03 8.62026111e+00
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=30 || lCount=78 || fCount=11
# [1.10000000e+01 7.63630904e+01 2.17828730e+03 4.55035438e+00
#  1.10000000e+01 1.20493186e+02 1.32326739e+04 2.82413510e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=31 || lCount=79 || fCount=11
# [1.30000000e+01 8.79424230e+01 1.24483269e+03 4.93276491e+00
#  1.10000000e+01 1.11383890e+02 3.05231739e+03 2.32541775e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=32 || lCount=80 || fCount=11
# [1.10000000e+01 1.03293705e+02 8.15027814e+03 2.49620100e+01
#  1.00000000e+01 1.28373726e+02 2.82828635e+04 5.37066168e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=33 || lCount=81 || fCount=11
# [1.00000000e+01 1.41590484e+02 1.33418748e+04 9.29548108e+01
#  1.00000000e+01 2.19241694e+02 1.95057132e+05 3.28834212e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=34 || lCount=82 || fCount=11
# [1.00000000e+01 1.47246226e+02 2.65904933e+04 4.72291856e+01
#  1.00000000e+01 1.87993902e+02 9.65951606e+04 7.87089236e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=35 || lCount=83 || fCount=11
# [1.10000000e+01 1.68585160e+02 3.33691079e+04 8.42395292e+01
#  1.00000000e+01 1.67670666e+02 2.72427000e+04 8.06298912e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=36 || lCount=84 || fCount=11
# [1.30000000e+01 1.29261771e+02 2.26506511e+03 7.53133512e+01
#  1.10000000e+01 2.05655832e+02 5.18239791e+04 4.89447947e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=37 || lCount=85 || fCount=11
# [1.10000000e+01 2.12852493e+02 2.28178907e+05 1.11094659e+02
#  1.10000000e+01 3.56051154e+02 1.33656796e+06 1.29963751e+03
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# PPG_data_info:./DataBase/Selected_PPG_wrist/210927_1.csv
# iCount=3 || jCount=0 || lCount=86 || fCount=11
# [9.00000000e+00 1.32110396e+02 2.24300414e+04 4.32210312e+01
#  9.00000000e+00 1.92511833e+02 1.43685485e+05 1.85453919e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=1 || lCount=87 || fCount=11
# [9.00000000e+00 1.41261073e+02 2.64990230e+04 9.80872976e+01
#  9.00000000e+00 2.55931749e+02 4.10270202e+05 4.92952054e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=2 || lCount=88 || fCount=11
# [9.00000000e+00 1.72264725e+02 5.10197583e+04 1.67273254e+02
#  9.00000000e+00 2.47120666e+02 4.88730883e+05 4.07392367e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=3 || lCount=89 || fCount=11
# [1.00000000e+01 1.37497753e+02 4.67708133e+03 1.94251536e+02
#  1.00000000e+01 2.85363180e+02 6.98631471e+05 7.90479440e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=4 || lCount=90 || fCount=11
# [1.00000000e+01 2.20365728e+02 2.74763829e+05 2.56782639e+02
#  1.00000000e+01 3.63672593e+02 1.64900021e+06 2.20607349e+03
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=5 || lCount=91 || fCount=11
# [9.00000000e+00 1.65109559e+02 7.64297868e+04 1.11429621e+02
#  1.10000000e+01 2.59387580e+02 5.80897772e+05 6.07611672e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=6 || lCount=92 || fCount=11
# [1.00000000e+01 1.72922024e+02 1.02164596e+05 1.05036616e+02
#  1.00000000e+01 2.82652669e+02 8.24396354e+05 5.75865007e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=7 || lCount=93 || fCount=11
# [1.10000000e+01 1.45558423e+02 3.00642734e+04 1.35282869e+02
#  7.00000000e+00 2.26559703e+02 1.17551523e+05 8.96109661e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=8 || lCount=94 || fCount=11
# [9.00000000e+00 7.44221412e+01 2.75325387e+02 1.85633942e+01
#  1.10000000e+01 2.09982793e+02 2.17139122e+05 2.09314989e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=9 || lCount=95 || fCount=11
# [1.10000000e+01 1.75711944e+02 9.68864775e+04 1.06224173e+02
#  1.00000000e+01 2.45806121e+02 6.21613352e+05 3.92500169e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=10 || lCount=96 || fCount=11
# [5.00000000e+00 6.55805405e+01 9.63336686e+02 3.98252427e+01
#  1.00000000e+01 1.96300355e+02 1.85223450e+05 1.05698513e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=11 || lCount=97 || fCount=11
# [1.00000000e+01 1.51580474e+02 1.40739436e+05 1.26764082e+02
#  1.00000000e+01 2.19841406e+02 3.29639403e+05 2.35074166e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=12 || lCount=98 || fCount=11
# [9.00000000e+00 7.25834792e+01 3.72177037e+03 5.80286428e+00
#  9.00000000e+00 2.32649535e+02 2.58726302e+05 3.56938606e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=13 || lCount=99 || fCount=11
# [9.00000000e+00 1.72728573e+02 5.34069914e+04 9.47091485e+01
#  9.00000000e+00 2.35005129e+02 2.30542101e+05 3.29799038e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=14 || lCount=100 || fCount=11
# [1.00000000e+01 2.04575991e+02 1.45190940e+05 1.50200369e+02
#  1.00000000e+01 3.21518708e+02 1.11261114e+06 9.99756572e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=15 || lCount=101 || fCount=11
# [1.00000000e+01 1.75140683e+02 8.36036923e+04 1.04294996e+02
#  1.00000000e+01 2.70958804e+02 4.45902164e+05 5.99876722e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=16 || lCount=102 || fCount=11
# [8.00000000e+00 8.94958079e+01 1.39122555e+04 4.45130059e+01
#  1.00000000e+01 1.93848745e+02 1.29936500e+05 1.54383237e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=17 || lCount=103 || fCount=11
# [1.00000000e+01 1.37597835e+02 2.62472070e+04 9.29919564e+01
#  1.00000000e+01 2.40993715e+02 2.69230670e+05 3.97453972e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=18 || lCount=104 || fCount=11
# [1.00000000e+01 1.82873376e+02 1.93551026e+05 2.07758621e+02
#  1.00000000e+01 2.63163139e+02 7.78131529e+05 7.58883710e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=19 || lCount=105 || fCount=11
# [1.00000000e+01 4.40842455e+01 8.90773970e+01 1.58648987e+00
#  9.00000000e+00 2.51944002e+02 3.80563344e+05 4.75819696e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=20 || lCount=106 || fCount=11
# [9.00000000e+00 2.15912300e+02 3.34747295e+05 2.89088571e+02
#  1.00000000e+01 2.89214715e+02 9.75972564e+05 9.52712149e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=21 || lCount=107 || fCount=11
# [9.00000000e+00 1.67046022e+02 1.38297552e+05 1.56186965e+02
#  9.00000000e+00 2.53747052e+02 5.33064418e+05 4.42394746e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=22 || lCount=108 || fCount=11
# [9.00000000e+00 3.50718956e+01 1.88723219e+01 4.95550606e-01
#  1.00000000e+01 2.00230798e+02 2.40526762e+05 1.75820962e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=23 || lCount=109 || fCount=11
# [1.10000000e+01 2.02737372e+02 2.35943999e+05 2.96665279e+02
#  9.00000000e+00 3.03869240e+02 9.77178184e+05 1.24468116e+03
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=24 || lCount=110 || fCount=11
# [1.00000000e+01 2.15620991e+02 2.78099949e+05 2.35391788e+02
#  1.00000000e+01 2.91716116e+02 7.82554913e+05 6.14137030e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=25 || lCount=111 || fCount=11
# [1.00000000e+01 1.88920529e+02 9.44431084e+04 1.92599014e+02
#  1.00000000e+01 3.02623423e+02 8.46434729e+05 1.22156231e+03
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=26 || lCount=112 || fCount=11
# [9.00000000e+00 1.31548100e+02 3.36367688e+04 1.33155165e+02
#  1.00000000e+01 2.47871399e+02 4.40499123e+05 4.51023138e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=27 || lCount=113 || fCount=11
# [1.60000000e+01 6.70040464e+01 3.40228998e+01 5.12611218e+00
#  1.10000000e+01 2.17916111e+02 2.45207082e+05 2.41647464e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=28 || lCount=114 || fCount=11
# [1.00000000e+01 2.30904394e+02 2.62286405e+05 3.06982613e+02
#  1.00000000e+01 3.28335215e+02 1.46765075e+06 1.34562684e+03
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=29 || lCount=115 || fCount=11
# [9.00000000e+00 1.33790997e+02 4.10399466e+04 6.75886501e+01
#  1.10000000e+01 2.04368457e+02 2.16302514e+05 3.16065780e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=30 || lCount=116 || fCount=11
# [1.10000000e+01 1.40586988e+02 1.10014567e+04 9.15462252e+01
#  1.10000000e+01 2.09231080e+02 1.35169876e+05 2.83829890e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# PPG_data_info:./DataBase/Selected_PPG_wrist/210927_2.csv
# iCount=4 || jCount=0 || lCount=117 || fCount=11
# [9.00000000e+00 1.31957696e+02 2.90008792e+04 5.12354944e+01
#  8.00000000e+00 1.95991703e+02 1.44013117e+05 2.29905476e+02
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=1 || lCount=118 || fCount=11
# [9.00000000e+00 1.33742430e+02 1.92282812e+04 8.08095513e+01
#  9.00000000e+00 2.28235558e+02 2.54229640e+05 5.39358854e+02
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=2 || lCount=119 || fCount=11
# [9.00000000e+00 1.31835515e+02 2.69155241e+04 6.40126954e+01
#  9.00000000e+00 2.27791454e+02 1.98906299e+05 6.00314586e+02
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=3 || lCount=120 || fCount=11
# [1.00000000e+01 1.57960861e+02 6.26306535e+04 6.66144306e+01
#  1.00000000e+01 2.66972176e+02 6.05241890e+05 4.04328130e+02
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=4 || lCount=121 || fCount=11
# [9.00000000e+00 1.49495028e+02 3.93916624e+04 6.85748286e+01
#  9.00000000e+00 2.53129883e+02 4.05436036e+05 5.13120311e+02
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=5 || lCount=122 || fCount=11
# [9.00000000e+00 1.39253062e+02 3.12905624e+04 3.70716489e+01
#  9.00000000e+00 2.76439905e+02 5.31055500e+05 5.72244962e+02
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=6 || lCount=123 || fCount=11
# [9.00000000e+00 1.05185474e+02 4.89506851e+03 9.58929381e+01
#  9.00000000e+00 1.74879837e+02 1.08695165e+04 1.82149521e+03
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=7 || lCount=124 || fCount=11
# [1.00000000e+01 1.37244938e+02 3.78315255e+04 9.84794093e+01
#  9.00000000e+00 2.05064781e+02 2.47613479e+05 5.88977520e+02
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=8 || lCount=125 || fCount=11
# [9.00000000e+00 9.15212424e+01 1.19140625e+03 1.23398028e+01
#  1.00000000e+01 1.04030592e+02 3.13126008e+03 4.79286010e+01
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=9 || lCount=126 || fCount=11
# [9.00000000e+00 1.06299149e+02 1.47246075e+03 2.08426836e+02
#  9.00000000e+00 1.33509774e+02 3.97504929e+03 1.57005208e+03
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=10 || lCount=127 || fCount=11
# [9.00000000e+00 1.74430620e+02 2.79294244e+05 3.13380689e+02
#  9.00000000e+00 3.13756077e+02 2.80372550e+06 2.73933162e+03
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=11 || lCount=128 || fCount=11
# [7.00000000e+00 1.31632659e+02 4.03386560e+04 8.33316811e+01
#  7.00000000e+00 2.47669474e+02 7.39883233e+05 1.18369329e+03
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=12 || lCount=129 || fCount=11
# [8.00000000e+00 1.48050263e+02 5.31919083e+04 4.05989800e+02
#  8.00000000e+00 2.09013546e+02 1.99537945e+05 5.50174845e+03
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=13 || lCount=130 || fCount=11
# [9.00000000e+00 1.99336754e+02 1.52479850e+05 3.62915364e+02
#  9.00000000e+00 2.96460814e+02 9.13630703e+05 2.66031757e+03
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=14 || lCount=131 || fCount=11
# [1.00000000e+01 1.47960524e+02 5.54005471e+04 5.40142483e+01
#  1.00000000e+01 2.46548721e+02 7.56858969e+05 6.19413122e+02
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=15 || lCount=132 || fCount=11
# [9.00000000e+00 1.31433383e+02 6.00503544e+04 7.61915263e+01
#  7.00000000e+00 2.13498325e+02 4.72663982e+05 7.41808044e+02
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=16 || lCount=133 || fCount=11
# [1.00000000e+01 1.38314873e+02 3.17053251e+04 3.98147731e+01
#  1.00000000e+01 2.42838792e+02 3.21443686e+05 4.94734656e+02
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=17 || lCount=134 || fCount=11
# [9.00000000e+00 1.55926523e+02 4.74034285e+04 1.81845984e+02
#  1.00000000e+01 2.49095132e+02 3.49847379e+05 1.02965524e+03
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=18 || lCount=135 || fCount=11
# [1.00000000e+01 1.49128776e+02 4.96248003e+04 6.92094911e+01
#  1.00000000e+01 2.93405336e+02 6.46763499e+05 1.01660933e+03
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=19 || lCount=136 || fCount=11
# [9.00000000e+00 1.64824134e+02 5.39116327e+04 9.23239692e+01
#  9.00000000e+00 3.01048589e+02 8.01834473e+05 1.10994587e+03
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=20 || lCount=137 || fCount=11
# [9.00000000e+00 1.14618383e+02 2.67820473e+03 6.14900831e+01
#  9.00000000e+00 1.55742268e+02 1.76265729e+04 4.64600544e+02
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=21 || lCount=138 || fCount=11
# [9.00000000e+00 1.52534797e+02 3.49042876e+04 1.14021847e+02
#  9.00000000e+00 2.69005419e+02 1.77842148e+05 1.60279991e+03
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=22 || lCount=139 || fCount=11
# [8.00000000e+00 1.53259146e+02 7.34800388e+04 9.30743700e+01
#  1.10000000e+01 2.65477634e+02 5.77918619e+05 8.02624346e+02
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=23 || lCount=140 || fCount=11
# [8.00000000e+00 1.64255786e+02 6.76866575e+05 6.06900230e+02
#  4.00000000e+00 2.67868285e+02 5.97692011e+06 4.71193907e+03
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=24 || lCount=141 || fCount=11
# [8.00000000e+00 1.75036142e+02 8.56951440e+04 1.44003250e+02
#  1.00000000e+01 3.47527158e+02 8.66291231e+05 2.05435555e+03
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=25 || lCount=142 || fCount=11
# [1.40000000e+01 1.42336017e+02 2.21009061e+04 8.27823439e+01
#  9.00000000e+00 2.69789075e+02 5.14505163e+05 1.57737328e+03
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=26 || lCount=143 || fCount=11
# [1.10000000e+01 1.03527431e+02 4.89756172e+03 2.40957992e+01
#  8.00000000e+00 1.11373896e+02 3.38716731e+04 1.04998268e+02
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=27 || lCount=144 || fCount=11
# [7.00000000e+00 1.23641766e+02 2.90271968e+04 3.98810157e+01
#  7.00000000e+00 1.30549855e+02 6.18748955e+04 1.09423367e+02
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=28 || lCount=145 || fCount=11
# [1.30000000e+01 1.58533382e+02 7.43097509e+04 1.21640717e+02
#  1.10000000e+01 2.75045996e+02 9.14481164e+05 1.86206320e+03
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=29 || lCount=146 || fCount=11
# [1.00000000e+01 1.73448784e+02 5.36611229e+04 1.20658250e+02
#  1.00000000e+01 3.17398788e+02 7.09714628e+05 9.91686652e+02
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=30 || lCount=147 || fCount=11
# [1.00000000e+01 1.46840832e+02 5.29503969e+04 8.35212103e+01
#  1.00000000e+01 2.84431419e+02 8.95808600e+05 1.09434801e+03
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# iCount=4 || jCount=31 || lCount=148 || fCount=11
# [9.00000000e+00 1.52540381e+02 1.88848356e+04 9.86449724e+01
#  9.00000000e+00 2.47684938e+02 2.53404753e+05 7.68028860e+02
#  1.87902936e+00 1.17425987e+00 5.40000000e+00]
# PPG_data_info:./DataBase/Selected_PPG_wrist/210928_0.csv
# iCount=5 || jCount=0 || lCount=149 || fCount=11
# [9.00000000e+00 1.46804255e+02 6.40503225e+04 8.45808853e+01
#  1.00000000e+01 1.98412804e+02 2.68832911e+05 2.15296331e+02
#  1.72078308e+00 1.03295580e+00 6.00000000e+00]
# iCount=5 || jCount=1 || lCount=150 || fCount=11
# [1.10000000e+01 1.27602074e+02 2.44042485e+04 3.69306074e+01
#  1.10000000e+01 2.21383169e+02 2.45488926e+05 3.43076173e+02
#  1.72078308e+00 1.03295580e+00 6.00000000e+00]
# iCount=5 || jCount=2 || lCount=151 || fCount=11
# [9.00000000e+00 1.61087312e+02 2.30466575e+04 1.57427141e+02
#  9.00000000e+00 2.59922343e+02 2.50510667e+05 1.05635942e+03
#  1.72078308e+00 1.03295580e+00 6.00000000e+00]
# iCount=5 || jCount=3 || lCount=152 || fCount=11
# [9.00000000e+00 1.75965296e+02 5.01164903e+04 3.60993011e+02
#  9.00000000e+00 3.11502726e+02 4.60626275e+05 2.56077641e+03
#  1.72078308e+00 1.03295580e+00 6.00000000e+00]
# iCount=5 || jCount=4 || lCount=153 || fCount=11
# [9.00000000e+00 1.32899219e+02 4.51887776e+04 7.42787825e+01
#  1.00000000e+01 2.60857441e+02 5.68515002e+05 6.31300591e+02
#  1.72078308e+00 1.03295580e+00 6.00000000e+00]
# iCount=5 || jCount=5 || lCount=154 || fCount=11
# [1.20000000e+01 1.06098349e+02 8.64314796e+03 1.53628535e+01
#  1.00000000e+01 1.77426830e+02 6.41731206e+04 1.25582891e+02
#  1.72078308e+00 1.03295580e+00 6.00000000e+00]
# iCount=5 || jCount=6 || lCount=155 || fCount=11
# [1.00000000e+01 1.14577205e+02 6.93460475e+03 1.88689456e+01
#  1.00000000e+01 1.82959438e+02 8.39951620e+04 1.37916170e+02
#  1.72078308e+00 1.03295580e+00 6.00000000e+00]
# iCount=5 || jCount=7 || lCount=156 || fCount=11
# [1.00000000e+01 1.12956099e+02 1.43990489e+04 2.93027571e+01
#  1.10000000e+01 1.45374587e+02 5.88235929e+04 5.37201588e+01
#  1.72078308e+00 1.03295580e+00 6.00000000e+00]
# iCount=5 || jCount=8 || lCount=157 || fCount=11
# [1.00000000e+01 1.26132075e+02 1.58179163e+04 2.76440506e+01
#  1.00000000e+01 1.49888430e+02 3.52435552e+04 4.28938180e+01
#  1.72078308e+00 1.03295580e+00 6.00000000e+00]
# iCount=5 || jCount=9 || lCount=158 || fCount=11
# [1.00000000e+01 1.48323562e+02 8.64350356e+04 5.80064513e+01
#  1.00000000e+01 2.28498171e+02 4.46136929e+05 5.38135144e+02
#  1.72078308e+00 1.03295580e+00 6.00000000e+00]
# iCount=5 || jCount=10 || lCount=159 || fCount=11
# [1.00000000e+01 1.44986111e+02 1.19663863e+04 1.05882452e+02
#  1.20000000e+01 2.32695081e+02 1.28812750e+05 4.15217019e+02
#  1.72078308e+00 1.03295580e+00 6.00000000e+00]
# iCount=5 || jCount=11 || lCount=160 || fCount=11
# [1.00000000e+01 9.63968472e+01 6.52706963e+03 2.15030618e+01
#  1.10000000e+01 1.33581181e+02 3.54422642e+04 3.64255019e+01
#  1.72078308e+00 1.03295580e+00 6.00000000e+00]
# iCount=5 || jCount=12 || lCount=161 || fCount=11
# [7.00000000e+00 1.28708705e+02 1.24490086e+04 9.06822208e+01
#  1.00000000e+01 1.49183593e+02 1.61204988e+04 1.35584098e+02
#  1.72078308e+00 1.03295580e+00 6.00000000e+00]
# iCount=5 || jCount=13 || lCount=162 || fCount=11
# [6.00000000e+00 1.33824139e+02 9.62162995e+05 2.18027967e+02
#  6.00000000e+00 2.17720814e+02 4.33497880e+06 8.44617777e+02
#  1.72078308e+00 1.03295580e+00 6.00000000e+00]
# iCount=5 || jCount=14 || lCount=163 || fCount=11
# [8.00000000e+00 1.64198616e+02 3.45282660e+04 2.45268242e+02
#  1.00000000e+01 3.04705235e+02 4.98385410e+05 1.37135230e+03
#  1.72078308e+00 1.03295580e+00 6.00000000e+00]
# PPG_data_info:./DataBase/Selected_PPG_wrist/210928_1.csv
# iCount=6 || jCount=0 || lCount=164 || fCount=11
# [9.00000000e+00 3.88609188e+01 2.59213689e+02 2.09592020e+00
#  1.00000000e+01 5.70327225e+01 1.57848514e+03 3.49221207e+00
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=1 || lCount=165 || fCount=11
# [1.00000000e+01 7.46056626e+01 1.65776355e+03 5.04802549e+00
#  1.00000000e+01 9.82843765e+01 8.74833590e+03 7.56157810e+00
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=2 || lCount=166 || fCount=11
# [9.00000000e+00 8.00608490e+01 5.30010337e+03 7.68978965e+00
#  1.00000000e+01 8.54190577e+01 3.31593779e+03 6.74148041e+00
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=3 || lCount=167 || fCount=11
# [1.00000000e+01 1.12693257e+02 1.48932280e+04 2.48719704e+01
#  1.00000000e+01 1.63434638e+02 7.10921997e+04 8.46170326e+01
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=4 || lCount=168 || fCount=11
# [1.00000000e+01 9.60242970e+01 9.63331931e+03 1.36089507e+01
#  1.00000000e+01 1.37636290e+02 4.06638423e+04 5.33839673e+01
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=5 || lCount=169 || fCount=11
# [1.10000000e+01 9.44615685e+01 7.87046170e+03 1.30227990e+01
#  1.10000000e+01 1.24322430e+02 2.77392268e+04 2.05431819e+01
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=6 || lCount=170 || fCount=11
# [1.10000000e+01 9.47155406e+01 5.50740434e+03 1.73893571e+01
#  1.10000000e+01 1.23026689e+02 2.38512448e+04 3.27319135e+01
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=7 || lCount=171 || fCount=11
# [1.30000000e+01 8.90568692e+01 3.67336180e+03 1.48189172e+01
#  1.00000000e+01 1.28539189e+02 2.31810499e+04 4.61943932e+01
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=8 || lCount=172 || fCount=11
# [9.00000000e+00 1.16960401e+02 1.27406503e+04 4.12637495e+01
#  9.00000000e+00 1.30891672e+02 2.37308394e+04 8.94632310e+01
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=9 || lCount=173 || fCount=11
# [1.60000000e+01 5.98588582e+01 1.00131626e+02 3.84666523e+00
#  1.00000000e+01 1.35691039e+02 2.63289881e+04 3.87221940e+01
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=10 || lCount=174 || fCount=11
# [1.60000000e+01 5.00717688e+01 1.90805150e+02 1.17573671e+00
#  1.10000000e+01 1.34096864e+02 3.73902323e+04 5.51226721e+01
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=11 || lCount=175 || fCount=11
# [1.10000000e+01 8.68168172e+01 2.89212979e+03 1.31152887e+01
#  1.00000000e+01 1.49649837e+02 2.56132418e+04 7.44456119e+01
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=12 || lCount=176 || fCount=11
# [1.30000000e+01 5.00462678e+01 4.66512658e+01 1.54783290e+01
#  1.00000000e+01 1.41942008e+02 3.99050570e+04 7.89903553e+01
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=13 || lCount=177 || fCount=11
# [1.00000000e+01 9.92225268e+01 2.14205549e+03 9.70135817e+00
#  1.00000000e+01 1.53639583e+02 2.41047102e+04 9.55243418e+01
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=14 || lCount=178 || fCount=11
# [1.00000000e+01 1.31756997e+02 2.23371641e+04 6.60735610e+01
#  1.00000000e+01 1.79384825e+02 9.92750920e+04 1.21586920e+02
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=15 || lCount=179 || fCount=11
# [1.00000000e+01 9.59798004e+01 4.44637658e+03 1.71555807e+01
#  1.00000000e+01 1.49593115e+02 3.66703293e+04 8.16455635e+01
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=16 || lCount=180 || fCount=11
# [1.00000000e+01 1.29228042e+02 2.20209088e+04 4.72272039e+01
#  1.00000000e+01 1.64576269e+02 6.58384109e+04 9.43785397e+01
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=17 || lCount=181 || fCount=11
# [1.00000000e+01 1.12174272e+02 5.51567403e+03 2.36968199e+01
#  1.00000000e+01 2.10723915e+02 1.29176039e+05 1.62301551e+02
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=18 || lCount=182 || fCount=11
# [1.00000000e+01 7.35460926e+01 1.87859615e+03 4.99665794e+00
#  1.00000000e+01 1.76875300e+02 8.90265381e+04 1.28180494e+02
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=19 || lCount=183 || fCount=11
# [1.00000000e+01 8.99696408e+01 5.07149821e+02 2.01716575e+01
#  1.70000000e+01 1.27074518e+02 1.52480117e+03 2.96301312e+02
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=20 || lCount=184 || fCount=11
# [1.00000000e+01 1.40413736e+02 3.49102008e+04 3.29228683e+01
#  1.10000000e+01 1.65195608e+02 8.41226545e+04 1.01176086e+02
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=21 || lCount=185 || fCount=11
# [1.10000000e+01 1.63888396e+02 2.19194426e+04 1.94096757e+02
#  1.10000000e+01 1.98780892e+02 7.66999034e+04 3.48803196e+02
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=22 || lCount=186 || fCount=11
# [1.10000000e+01 1.28806021e+02 8.84576691e+03 3.61006567e+01
#  1.10000000e+01 1.85062795e+02 3.70680086e+04 1.33989885e+02
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=23 || lCount=187 || fCount=11
# [1.10000000e+01 7.92799986e+01 1.26082260e+03 8.84082222e+00
#  8.00000000e+00 9.18830582e+01 1.70941605e+03 2.65403134e+01
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=24 || lCount=188 || fCount=11
# [8.00000000e+00 9.76924008e+01 4.04202850e+03 2.39253889e+01
#  1.00000000e+01 1.78043821e+02 5.62929076e+04 1.23149186e+02
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=25 || lCount=189 || fCount=11
# [1.40000000e+01 2.03968334e+02 1.48876332e+05 3.85797010e+02
#  1.20000000e+01 2.75031302e+02 5.03708819e+05 7.91554339e+02
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=26 || lCount=190 || fCount=11
# [1.20000000e+01 1.66065739e+02 2.52187704e+04 9.15054951e+01
#  1.20000000e+01 2.53679445e+02 1.72578204e+05 2.91456245e+02
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=27 || lCount=191 || fCount=11
# [1.40000000e+01 2.29808354e+02 8.29298900e+04 1.67467756e+02
#  1.40000000e+01 2.78513922e+02 1.56131628e+05 3.61195409e+02
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=28 || lCount=192 || fCount=11
# [1.40000000e+01 1.79776675e+02 8.12469222e+03 1.26763793e+02
#  1.40000000e+01 2.64366747e+02 6.60532929e+04 4.39952752e+02
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=29 || lCount=193 || fCount=11
# [1.30000000e+01 1.64732782e+02 1.96577850e+04 7.37581505e+01
#  1.40000000e+01 2.17633214e+02 9.16626785e+04 3.10936936e+02
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=30 || lCount=194 || fCount=11
# [ 21.          76.31322273 276.34486036   8.26096936   9.
#   86.84334138 127.57112649  79.27110195   1.82757814   0.89357337
#    5.3       ]
# iCount=6 || jCount=31 || lCount=195 || fCount=11
# [1.10000000e+01 2.01135642e+02 6.45973210e+04 1.98671975e+02
#  1.10000000e+01 2.94410698e+02 3.35212093e+05 6.25227179e+02
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=32 || lCount=196 || fCount=11
# [1.30000000e+01 1.35605708e+02 8.59380408e+02 7.45955917e+01
#  1.10000000e+01 2.01539091e+02 1.73633373e+04 3.64096087e+02
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=33 || lCount=197 || fCount=11
# [1.00000000e+01 2.05320418e+02 1.16247952e+05 1.94734941e+02
#  1.00000000e+01 3.05275669e+02 5.34346386e+05 9.92127983e+02
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# iCount=6 || jCount=34 || lCount=198 || fCount=11
# [1.00000000e+01 1.99149703e+02 1.42003908e+05 2.08352930e+02
#  1.10000000e+01 3.08840304e+02 9.90019513e+05 1.21121478e+03
#  1.82757814e+00 8.93573368e-01 5.30000000e+00]
# PPG_data_info:./DataBase/Selected_PPG_wrist/210929_0.csv
# iCount=7 || jCount=0 || lCount=199 || fCount=11
# [6.00000000e+00 1.42853404e+02 1.89983066e+04 1.04122920e+02
#  1.00000000e+01 2.24151872e+02 2.17379741e+05 7.32943679e+02
#  2.14521814e+00 1.29838594e+00 6.30000000e+00]
# iCount=7 || jCount=1 || lCount=200 || fCount=11
# [9.00000000e+00 1.80401580e+02 9.77402227e+04 1.15237148e+02
#  9.00000000e+00 3.28453640e+02 1.14209919e+06 1.12772871e+03
#  2.14521814e+00 1.29838594e+00 6.30000000e+00]
# iCount=7 || jCount=2 || lCount=201 || fCount=11
# [4.00000000e+00 1.93671065e+02 2.70982499e+06 5.07416513e+03
#  3.00000000e+00 2.53182599e+02 6.84514414e+06 1.42311839e+04
#  2.14521814e+00 1.29838594e+00 6.30000000e+00]
# iCount=7 || jCount=3 || lCount=202 || fCount=11
# [1.10000000e+01 1.41772071e+02 2.76827181e+04 8.56049927e+01
#  1.10000000e+01 2.00264038e+02 6.00913680e+04 3.79720800e+02
#  2.14521814e+00 1.29838594e+00 6.30000000e+00]
# iCount=7 || jCount=4 || lCount=203 || fCount=11
# [9.00000000e+00 1.77404169e+02 1.06014011e+05 9.92517367e+01
#  9.00000000e+00 3.28890184e+02 1.15195521e+06 1.33009632e+03
#  2.14521814e+00 1.29838594e+00 6.30000000e+00]
# iCount=7 || jCount=5 || lCount=204 || fCount=11
# [9.00000000e+00 1.65944280e+02 5.83505762e+04 8.92913995e+01
#  9.00000000e+00 3.13110028e+02 9.53664550e+05 1.12302085e+03
#  2.14521814e+00 1.29838594e+00 6.30000000e+00]
# iCount=7 || jCount=6 || lCount=205 || fCount=11
# [1.30000000e+01 1.29426440e+02 9.86284193e+03 5.51111685e+01
#  1.10000000e+01 2.07067138e+02 6.70102161e+04 3.32458733e+02
#  2.14521814e+00 1.29838594e+00 6.30000000e+00]
# iCount=7 || jCount=7 || lCount=206 || fCount=11
# [1.00000000e+01 1.40191103e+02 3.11714574e+04 5.70057415e+01
#  9.00000000e+00 2.70774164e+02 4.72626232e+05 4.39079408e+02
#  2.14521814e+00 1.29838594e+00 6.30000000e+00]
# iCount=7 || jCount=8 || lCount=207 || fCount=11
# [1.00000000e+01 1.04401000e+02 1.37895071e+04 2.10776262e+01
#  1.20000000e+01 1.88016317e+02 1.48142629e+05 2.96310391e+02
#  2.14521814e+00 1.29838594e+00 6.30000000e+00]
# iCount=7 || jCount=9 || lCount=208 || fCount=11
# [9.00000000e+00 1.41034651e+02 3.42500833e+04 8.52979894e+01
#  9.00000000e+00 2.27660084e+02 2.53659737e+05 6.32954576e+02
#  2.14521814e+00 1.29838594e+00 6.30000000e+00]
# iCount=7 || jCount=10 || lCount=209 || fCount=11
# [1.10000000e+01 1.22187920e+02 2.66804296e+04 3.99759311e+01
#  1.20000000e+01 2.33291222e+02 2.93968563e+05 4.10776568e+02
#  2.14521814e+00 1.29838594e+00 6.30000000e+00]
# iCount=7 || jCount=11 || lCount=210 || fCount=11
# [7.00000000e+00 1.05874759e+02 1.58834724e+04 4.47658494e+01
#  5.00000000e+00 2.02895193e+02 1.96306084e+05 5.11221313e+02
#  2.14521814e+00 1.29838594e+00 6.30000000e+00]
# iCount=7 || jCount=12 || lCount=211 || fCount=11
# [1.00000000e+01 1.01808924e+02 1.75627480e+03 4.45896111e+01
#  1.00000000e+01 1.87164313e+02 7.31633200e+04 2.02352503e+02
#  2.14521814e+00 1.29838594e+00 6.30000000e+00]
# iCount=7 || jCount=13 || lCount=212 || fCount=11
# [9.00000000e+00 1.55668459e+02 5.72772680e+04 9.83897451e+01
#  1.00000000e+01 2.62256216e+02 5.04354140e+05 6.63438521e+02
#  2.14521814e+00 1.29838594e+00 6.30000000e+00]
# iCount=7 || jCount=14 || lCount=213 || fCount=11
# [9.00000000e+00 1.02867609e+02 6.04473771e+03 2.13947808e+01
#  9.00000000e+00 1.87007481e+02 9.83842470e+04 3.35344905e+02
#  2.14521814e+00 1.29838594e+00 6.30000000e+00]
# iCount=7 || jCount=15 || lCount=214 || fCount=11
# [1.20000000e+01 1.13947191e+02 1.01230707e+04 4.00969147e+01
#  1.00000000e+01 2.29912932e+02 3.13987071e+05 6.21297335e+02
#  2.14521814e+00 1.29838594e+00 6.30000000e+00]
# iCount=7 || jCount=16 || lCount=215 || fCount=11
# [9.00000000e+00 1.69970630e+02 8.45980405e+04 1.20874031e+02
#  9.00000000e+00 2.93820477e+02 9.45635794e+05 7.06686319e+02
#  2.14521814e+00 1.29838594e+00 6.30000000e+00]
# iCount=7 || jCount=17 || lCount=216 || fCount=11
# [9.00000000e+00 1.56282421e+02 5.67049195e+04 9.87074163e+01
#  9.00000000e+00 2.87161807e+02 8.11655993e+05 9.60299826e+02
#  2.14521814e+00 1.29838594e+00 6.30000000e+00]
# iCount=7 || jCount=18 || lCount=217 || fCount=11
# [6.00000000e+00 1.12475371e+02 6.46549357e+04 8.15501544e+01
#  7.00000000e+00 2.12503436e+02 6.96056097e+05 1.09286291e+03
#  2.14521814e+00 1.29838594e+00 6.30000000e+00]
# iCount=7 || jCount=19 || lCount=218 || fCount=11
# [1.00000000e+01 1.53468568e+02 6.67149735e+04 1.08718663e+02
#  1.00000000e+01 2.35240606e+02 3.85310045e+05 6.27601523e+02
#  2.14521814e+00 1.29838594e+00 6.30000000e+00]
# ...
# 707:	learn: 0.0246582	total: 1.34s	remaining: 553ms
# 708:	learn: 0.0246103	total: 1.34s	remaining: 551ms
# 709:	learn: 0.0245757	total: 1.34s	remaining: 549ms
# 710:	learn: 0.0245182	total: 1.35s	remaining: 547ms
# 711:	learn: 0.0244692	total: 1.35s	remaining: 545ms
# 712:	learn: 0.0244354	total: 1.35s	remaining: 543ms
# 713:	learn: 0.0244109	total: 1.35s	remaining: 541ms
# 714:	learn: 0.0243687	total: 1.35s	remaining: 540ms
# 715:	learn: 0.0243306	total: 1.35s	remaining: 538ms
# 716:	learn: 0.0243122	total: 1.36s	remaining: 536ms
# 717:	learn: 0.0242685	total: 1.36s	remaining: 534ms
# 718:	learn: 0.0242325	total: 1.36s	remaining: 532ms
# 719:	learn: 0.0241854	total: 1.36s	remaining: 530ms
# 720:	learn: 0.0241664	total: 1.36s	remaining: 528ms
# 721:	learn: 0.0241234	total: 1.37s	remaining: 527ms
# 722:	learn: 0.0241064	total: 1.37s	remaining: 525ms
# 723:	learn: 0.0240616	total: 1.37s	remaining: 523ms
# 724:	learn: 0.0240365	total: 1.37s	remaining: 521ms
# 725:	learn: 0.0239821	total: 1.37s	remaining: 519ms
# 726:	learn: 0.0239562	total: 1.38s	remaining: 517ms
# 727:	learn: 0.0239247	total: 1.38s	remaining: 515ms
# 728:	learn: 0.0238784	total: 1.38s	remaining: 513ms
# 729:	learn: 0.0238440	total: 1.38s	remaining: 511ms
# 730:	learn: 0.0238080	total: 1.38s	remaining: 509ms
# 731:	learn: 0.0237826	total: 1.39s	remaining: 508ms
# 732:	learn: 0.0237432	total: 1.39s	remaining: 506ms
# 733:	learn: 0.0237261	total: 1.39s	remaining: 504ms
# 734:	learn: 0.0236809	total: 1.39s	remaining: 502ms
# 735:	learn: 0.0236565	total: 1.39s	remaining: 500ms
# 736:	learn: 0.0236135	total: 1.4s	remaining: 498ms
# 737:	learn: 0.0235623	total: 1.4s	remaining: 496ms
# 738:	learn: 0.0235327	total: 1.4s	remaining: 494ms
# 739:	learn: 0.0234842	total: 1.4s	remaining: 492ms
# 740:	learn: 0.0234798	total: 1.4s	remaining: 491ms
# 741:	learn: 0.0234693	total: 1.41s	remaining: 489ms
# 742:	learn: 0.0234349	total: 1.41s	remaining: 487ms
# 743:	learn: 0.0233922	total: 1.41s	remaining: 485ms
# 744:	learn: 0.0233510	total: 1.41s	remaining: 483ms
# 745:	learn: 0.0232807	total: 1.41s	remaining: 481ms
# 746:	learn: 0.0232503	total: 1.41s	remaining: 479ms
# 747:	learn: 0.0232026	total: 1.42s	remaining: 477ms
# 748:	learn: 0.0231687	total: 1.42s	remaining: 475ms
# 749:	learn: 0.0231481	total: 1.42s	remaining: 474ms
# 750:	learn: 0.0231144	total: 1.42s	remaining: 472ms
# 751:	learn: 0.0230985	total: 1.42s	remaining: 469ms
# 752:	learn: 0.0230784	total: 1.43s	remaining: 468ms
# 753:	learn: 0.0230552	total: 1.43s	remaining: 465ms
# 754:	learn: 0.0230113	total: 1.43s	remaining: 464ms
# 755:	learn: 0.0230071	total: 1.43s	remaining: 462ms
# 756:	learn: 0.0229663	total: 1.43s	remaining: 460ms
# 757:	learn: 0.0229329	total: 1.43s	remaining: 458ms
# 758:	learn: 0.0228884	total: 1.44s	remaining: 456ms
# 759:	learn: 0.0228728	total: 1.44s	remaining: 454ms
# 760:	learn: 0.0228459	total: 1.44s	remaining: 452ms
# 761:	learn: 0.0228299	total: 1.44s	remaining: 450ms
# 762:	learn: 0.0227760	total: 1.44s	remaining: 448ms
# 763:	learn: 0.0227378	total: 1.45s	remaining: 446ms
# 764:	learn: 0.0227315	total: 1.45s	remaining: 445ms
# 765:	learn: 0.0227091	total: 1.45s	remaining: 443ms
# 766:	learn: 0.0227047	total: 1.45s	remaining: 441ms
# 767:	learn: 0.0226702	total: 1.45s	remaining: 439ms
# 768:	learn: 0.0226492	total: 1.45s	remaining: 437ms
# 769:	learn: 0.0226180	total: 1.46s	remaining: 435ms
# 770:	learn: 0.0225778	total: 1.46s	remaining: 433ms
# 771:	learn: 0.0225388	total: 1.46s	remaining: 431ms
# 772:	learn: 0.0225145	total: 1.46s	remaining: 429ms
# 773:	learn: 0.0224668	total: 1.46s	remaining: 428ms
# 774:	learn: 0.0224321	total: 1.47s	remaining: 426ms
# 775:	learn: 0.0224049	total: 1.47s	remaining: 424ms
# 776:	learn: 0.0223845	total: 1.47s	remaining: 422ms
# 777:	learn: 0.0223466	total: 1.47s	remaining: 420ms
# 778:	learn: 0.0223146	total: 1.47s	remaining: 418ms
# 779:	learn: 0.0223111	total: 1.48s	remaining: 416ms
# 780:	learn: 0.0223078	total: 1.48s	remaining: 414ms
# 781:	learn: 0.0222782	total: 1.48s	remaining: 412ms
# 782:	learn: 0.0222626	total: 1.48s	remaining: 410ms
# 783:	learn: 0.0222344	total: 1.48s	remaining: 409ms
# 784:	learn: 0.0222111	total: 1.49s	remaining: 407ms
# 785:	learn: 0.0221812	total: 1.49s	remaining: 405ms
# 786:	learn: 0.0221381	total: 1.49s	remaining: 403ms
# 787:	learn: 0.0221103	total: 1.49s	remaining: 401ms
# 788:	learn: 0.0220717	total: 1.49s	remaining: 399ms
# 789:	learn: 0.0220627	total: 1.49s	remaining: 397ms
# 790:	learn: 0.0220414	total: 1.5s	remaining: 395ms
# 791:	learn: 0.0220133	total: 1.5s	remaining: 394ms
# 792:	learn: 0.0219772	total: 1.5s	remaining: 392ms
# 793:	learn: 0.0219428	total: 1.5s	remaining: 390ms
# 794:	learn: 0.0219258	total: 1.5s	remaining: 388ms
# 795:	learn: 0.0218897	total: 1.51s	remaining: 386ms
# 796:	learn: 0.0218586	total: 1.51s	remaining: 384ms
# 797:	learn: 0.0218269	total: 1.51s	remaining: 382ms
# 798:	learn: 0.0217899	total: 1.51s	remaining: 380ms
# 799:	learn: 0.0217877	total: 1.51s	remaining: 379ms
# 800:	learn: 0.0217808	total: 1.51s	remaining: 377ms
# 801:	learn: 0.0217642	total: 1.52s	remaining: 375ms
# 802:	learn: 0.0217368	total: 1.52s	remaining: 373ms
# 803:	learn: 0.0216877	total: 1.52s	remaining: 371ms
# 804:	learn: 0.0216544	total: 1.52s	remaining: 369ms
# 805:	learn: 0.0216232	total: 1.52s	remaining: 367ms
# 806:	learn: 0.0215883	total: 1.53s	remaining: 365ms
# 807:	learn: 0.0215538	total: 1.53s	remaining: 363ms
# 808:	learn: 0.0215511	total: 1.53s	remaining: 361ms
# 809:	learn: 0.0215187	total: 1.53s	remaining: 360ms
# 810:	learn: 0.0214831	total: 1.53s	remaining: 358ms
# 811:	learn: 0.0214302	total: 1.54s	remaining: 356ms
# 812:	learn: 0.0213890	total: 1.54s	remaining: 354ms
# 813:	learn: 0.0213574	total: 1.54s	remaining: 352ms
# 814:	learn: 0.0213459	total: 1.54s	remaining: 350ms
# 815:	learn: 0.0213282	total: 1.54s	remaining: 348ms
# 816:	learn: 0.0212950	total: 1.55s	remaining: 346ms
# 817:	learn: 0.0212483	total: 1.55s	remaining: 345ms
# 818:	learn: 0.0212461	total: 1.55s	remaining: 343ms
# 819:	learn: 0.0212216	total: 1.55s	remaining: 341ms
# 820:	learn: 0.0211980	total: 1.55s	remaining: 339ms
# 821:	learn: 0.0211844	total: 1.56s	remaining: 337ms
# 822:	learn: 0.0211454	total: 1.56s	remaining: 335ms
# 823:	learn: 0.0211043	total: 1.56s	remaining: 334ms
# 824:	learn: 0.0210400	total: 1.56s	remaining: 332ms
# 825:	learn: 0.0210184	total: 1.56s	remaining: 330ms
# 826:	learn: 0.0209855	total: 1.57s	remaining: 328ms
# 827:	learn: 0.0209818	total: 1.57s	remaining: 326ms
# 828:	learn: 0.0209353	total: 1.57s	remaining: 324ms
# 829:	learn: 0.0208983	total: 1.57s	remaining: 322ms
# 830:	learn: 0.0208724	total: 1.57s	remaining: 320ms
# 831:	learn: 0.0208415	total: 1.58s	remaining: 319ms
# 832:	learn: 0.0208173	total: 1.58s	remaining: 317ms
# 833:	learn: 0.0207835	total: 1.58s	remaining: 315ms
# 834:	learn: 0.0207432	total: 1.58s	remaining: 313ms
# 835:	learn: 0.0206960	total: 1.59s	remaining: 311ms
# 836:	learn: 0.0206692	total: 1.59s	remaining: 309ms
# 837:	learn: 0.0206626	total: 1.59s	remaining: 307ms
# 838:	learn: 0.0206500	total: 1.59s	remaining: 305ms
# 839:	learn: 0.0206399	total: 1.59s	remaining: 304ms
# 840:	learn: 0.0206380	total: 1.59s	remaining: 302ms
# 841:	learn: 0.0206361	total: 1.6s	remaining: 300ms
# 842:	learn: 0.0206105	total: 1.6s	remaining: 298ms
# 843:	learn: 0.0206086	total: 1.6s	remaining: 296ms
# 844:	learn: 0.0205899	total: 1.6s	remaining: 294ms
# 845:	learn: 0.0205873	total: 1.6s	remaining: 292ms
# 846:	learn: 0.0205552	total: 1.61s	remaining: 290ms
# 847:	learn: 0.0205251	total: 1.61s	remaining: 289ms
# 848:	learn: 0.0205130	total: 1.61s	remaining: 287ms
# 849:	learn: 0.0204781	total: 1.61s	remaining: 285ms
# 850:	learn: 0.0204761	total: 1.61s	remaining: 283ms
# 851:	learn: 0.0204595	total: 1.62s	remaining: 281ms
# 852:	learn: 0.0203904	total: 1.62s	remaining: 279ms
# 853:	learn: 0.0203518	total: 1.62s	remaining: 277ms
# 854:	learn: 0.0203083	total: 1.62s	remaining: 275ms
# 855:	learn: 0.0202826	total: 1.62s	remaining: 273ms
# 856:	learn: 0.0202639	total: 1.63s	remaining: 271ms
# 857:	learn: 0.0202416	total: 1.63s	remaining: 269ms
# 858:	learn: 0.0202181	total: 1.63s	remaining: 268ms
# 859:	learn: 0.0201531	total: 1.63s	remaining: 266ms
# 860:	learn: 0.0201248	total: 1.63s	remaining: 264ms
# 861:	learn: 0.0201020	total: 1.64s	remaining: 262ms
# 862:	learn: 0.0200965	total: 1.64s	remaining: 260ms
# 863:	learn: 0.0200628	total: 1.64s	remaining: 258ms
# 864:	learn: 0.0200406	total: 1.64s	remaining: 256ms
# 865:	learn: 0.0200047	total: 1.64s	remaining: 254ms
# 866:	learn: 0.0199686	total: 1.65s	remaining: 252ms
# 867:	learn: 0.0199667	total: 1.65s	remaining: 251ms
# 868:	learn: 0.0199453	total: 1.65s	remaining: 249ms
# 869:	learn: 0.0199291	total: 1.65s	remaining: 247ms
# 870:	learn: 0.0198944	total: 1.65s	remaining: 245ms
# 871:	learn: 0.0198719	total: 1.66s	remaining: 243ms
# 872:	learn: 0.0198572	total: 1.66s	remaining: 241ms
# 873:	learn: 0.0198261	total: 1.66s	remaining: 239ms
# 874:	learn: 0.0198129	total: 1.66s	remaining: 237ms
# 875:	learn: 0.0198036	total: 1.66s	remaining: 235ms
# 876:	learn: 0.0197721	total: 1.66s	remaining: 233ms
# 877:	learn: 0.0197553	total: 1.67s	remaining: 232ms
# 878:	learn: 0.0197456	total: 1.67s	remaining: 230ms
# 879:	learn: 0.0197137	total: 1.67s	remaining: 228ms
# 880:	learn: 0.0196957	total: 1.67s	remaining: 226ms
# 881:	learn: 0.0196795	total: 1.67s	remaining: 224ms
# 882:	learn: 0.0196456	total: 1.68s	remaining: 222ms
# 883:	learn: 0.0196113	total: 1.68s	remaining: 220ms
# 884:	learn: 0.0196005	total: 1.68s	remaining: 218ms
# 885:	learn: 0.0195739	total: 1.68s	remaining: 216ms
# 886:	learn: 0.0195430	total: 1.68s	remaining: 214ms
# 887:	learn: 0.0195249	total: 1.68s	remaining: 212ms
# 888:	learn: 0.0195063	total: 1.69s	remaining: 210ms
# 889:	learn: 0.0194821	total: 1.69s	remaining: 209ms
# 890:	learn: 0.0194567	total: 1.69s	remaining: 207ms
# 891:	learn: 0.0194429	total: 1.69s	remaining: 205ms
# 892:	learn: 0.0194217	total: 1.69s	remaining: 203ms
# 893:	learn: 0.0193942	total: 1.7s	remaining: 201ms
# 894:	learn: 0.0193468	total: 1.7s	remaining: 199ms
# 895:	learn: 0.0193133	total: 1.7s	remaining: 197ms
# 896:	learn: 0.0192873	total: 1.7s	remaining: 195ms
# 897:	learn: 0.0192511	total: 1.7s	remaining: 193ms
# 898:	learn: 0.0192326	total: 1.7s	remaining: 192ms
# 899:	learn: 0.0191909	total: 1.71s	remaining: 190ms
# 900:	learn: 0.0191874	total: 1.71s	remaining: 188ms
# 901:	learn: 0.0191828	total: 1.71s	remaining: 186ms
# 902:	learn: 0.0191624	total: 1.71s	remaining: 184ms
# 903:	learn: 0.0191453	total: 1.71s	remaining: 182ms
# 904:	learn: 0.0191157	total: 1.72s	remaining: 180ms
# 905:	learn: 0.0190848	total: 1.72s	remaining: 178ms
# 906:	learn: 0.0190553	total: 1.72s	remaining: 176ms
# 907:	learn: 0.0190396	total: 1.72s	remaining: 174ms
# 908:	learn: 0.0190335	total: 1.72s	remaining: 173ms
# 909:	learn: 0.0189960	total: 1.73s	remaining: 171ms
# 910:	learn: 0.0189563	total: 1.73s	remaining: 169ms
# 911:	learn: 0.0189452	total: 1.73s	remaining: 167ms
# 912:	learn: 0.0189323	total: 1.73s	remaining: 165ms
# 913:	learn: 0.0189232	total: 1.73s	remaining: 163ms
# 914:	learn: 0.0189134	total: 1.73s	remaining: 161ms
# 915:	learn: 0.0188958	total: 1.74s	remaining: 159ms
# 916:	learn: 0.0188682	total: 1.74s	remaining: 157ms
# 917:	learn: 0.0188360	total: 1.74s	remaining: 155ms
# 918:	learn: 0.0188130	total: 1.74s	remaining: 154ms
# 919:	learn: 0.0188072	total: 1.74s	remaining: 152ms
# 920:	learn: 0.0187888	total: 1.75s	remaining: 150ms
# 921:	learn: 0.0187704	total: 1.75s	remaining: 148ms
# 922:	learn: 0.0187515	total: 1.75s	remaining: 146ms
# 923:	learn: 0.0187426	total: 1.75s	remaining: 144ms
# 924:	learn: 0.0187294	total: 1.75s	remaining: 142ms
# 925:	learn: 0.0187059	total: 1.75s	remaining: 140ms
# 926:	learn: 0.0186958	total: 1.76s	remaining: 138ms
# 927:	learn: 0.0186652	total: 1.76s	remaining: 136ms
# 928:	learn: 0.0186537	total: 1.76s	remaining: 134ms
# 929:	learn: 0.0186237	total: 1.76s	remaining: 133ms
# 930:	learn: 0.0185946	total: 1.76s	remaining: 131ms
# 931:	learn: 0.0185680	total: 1.76s	remaining: 129ms
# 932:	learn: 0.0185529	total: 1.77s	remaining: 127ms
# 933:	learn: 0.0185214	total: 1.77s	remaining: 125ms
# 934:	learn: 0.0184933	total: 1.77s	remaining: 123ms
# 935:	learn: 0.0184858	total: 1.77s	remaining: 121ms
# 936:	learn: 0.0184807	total: 1.77s	remaining: 119ms
# 937:	learn: 0.0184475	total: 1.78s	remaining: 117ms
# 938:	learn: 0.0184191	total: 1.78s	remaining: 116ms
# 939:	learn: 0.0184123	total: 1.78s	remaining: 114ms
# 940:	learn: 0.0183840	total: 1.78s	remaining: 112ms
# 941:	learn: 0.0183564	total: 1.78s	remaining: 110ms
# 942:	learn: 0.0183306	total: 1.79s	remaining: 108ms
# 943:	learn: 0.0182985	total: 1.79s	remaining: 106ms
# 944:	learn: 0.0182701	total: 1.79s	remaining: 104ms
# 945:	learn: 0.0182557	total: 1.79s	remaining: 102ms
# 946:	learn: 0.0182233	total: 1.79s	remaining: 100ms
# 947:	learn: 0.0181829	total: 1.8s	remaining: 98.5ms
# 948:	learn: 0.0181639	total: 1.8s	remaining: 96.7ms
# 949:	learn: 0.0181470	total: 1.8s	remaining: 94.8ms
# 950:	learn: 0.0181436	total: 1.8s	remaining: 92.9ms
# 951:	learn: 0.0181221	total: 1.8s	remaining: 91ms
# 952:	learn: 0.0181200	total: 1.81s	remaining: 89.1ms
# 953:	learn: 0.0180903	total: 1.81s	remaining: 87.2ms
# 954:	learn: 0.0180720	total: 1.81s	remaining: 85.3ms
# 955:	learn: 0.0180480	total: 1.81s	remaining: 83.4ms
# 956:	learn: 0.0180288	total: 1.81s	remaining: 81.5ms
# 957:	learn: 0.0180225	total: 1.81s	remaining: 79.6ms
# 958:	learn: 0.0179859	total: 1.82s	remaining: 77.7ms
# 959:	learn: 0.0179650	total: 1.82s	remaining: 75.8ms
# 960:	learn: 0.0179373	total: 1.82s	remaining: 73.9ms
# 961:	learn: 0.0179289	total: 1.82s	remaining: 72ms
# 962:	learn: 0.0179103	total: 1.82s	remaining: 70.1ms
# 963:	learn: 0.0178872	total: 1.83s	remaining: 68.2ms
# 964:	learn: 0.0178794	total: 1.83s	remaining: 66.3ms
# 965:	learn: 0.0178513	total: 1.83s	remaining: 64.4ms
# 966:	learn: 0.0178301	total: 1.83s	remaining: 62.5ms
# 967:	learn: 0.0178065	total: 1.83s	remaining: 60.7ms
# 968:	learn: 0.0177887	total: 1.84s	remaining: 58.8ms
# 969:	learn: 0.0177638	total: 1.84s	remaining: 56.9ms
# 970:	learn: 0.0177391	total: 1.84s	remaining: 55ms
# 971:	learn: 0.0177309	total: 1.84s	remaining: 53.1ms
# 972:	learn: 0.0177092	total: 1.84s	remaining: 51.2ms
# 973:	learn: 0.0176870	total: 1.85s	remaining: 49.3ms
# 974:	learn: 0.0176664	total: 1.85s	remaining: 47.4ms
# 975:	learn: 0.0176451	total: 1.85s	remaining: 45.5ms
# 976:	learn: 0.0176120	total: 1.85s	remaining: 43.6ms
# 977:	learn: 0.0175895	total: 1.85s	remaining: 41.7ms
# 978:	learn: 0.0175666	total: 1.86s	remaining: 39.8ms
# 979:	learn: 0.0175608	total: 1.86s	remaining: 37.9ms
# 980:	learn: 0.0175420	total: 1.86s	remaining: 36ms
# 981:	learn: 0.0175284	total: 1.86s	remaining: 34.1ms
# 982:	learn: 0.0175213	total: 1.86s	remaining: 32.2ms
# 983:	learn: 0.0175033	total: 1.87s	remaining: 30.3ms
# 984:	learn: 0.0174959	total: 1.87s	remaining: 28.4ms
# 985:	learn: 0.0174761	total: 1.87s	remaining: 26.6ms
# 986:	learn: 0.0174457	total: 1.87s	remaining: 24.7ms
# 987:	learn: 0.0174343	total: 1.87s	remaining: 22.8ms
# 988:	learn: 0.0174157	total: 1.88s	remaining: 20.9ms
# 989:	learn: 0.0173888	total: 1.88s	remaining: 19ms
# 990:	learn: 0.0173733	total: 1.88s	remaining: 17.1ms
# 991:	learn: 0.0173647	total: 1.88s	remaining: 15.2ms
# 992:	learn: 0.0173380	total: 1.88s	remaining: 13.3ms
# 993:	learn: 0.0173271	total: 1.89s	remaining: 11.4ms
# 994:	learn: 0.0173141	total: 1.89s	remaining: 9.49ms
# 995:	learn: 0.0173076	total: 1.89s	remaining: 7.59ms
# 996:	learn: 0.0172878	total: 1.89s	remaining: 5.69ms
# 997:	learn: 0.0172623	total: 1.89s	remaining: 3.79ms
# 998:	learn: 0.0172435	total: 1.9s	remaining: 1.9ms
# 999:	learn: 0.0172244	total: 1.9s	remaining: 0us
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] bagging_fraction is set=1, subsample=1.0 will be ignored. Current value: bagging_fraction=1
# [LightGBM] [Warning] bagging_freq is set=100, subsample_freq=0 will be ignored. Current value: bagging_freq=100
# c:\Users\RBM-WorkStation\AppData\Local\Programs\Python\Python39\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")

# %% [markdown]
# > Evaluation of __Test 1__

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'XG Boost',
    predictedValue = t1_results_xg,
    exactValue     = t1_e_results_xg
)
# Out:
# ############ HbA1c Evaluation Metrics of XG Boost Regression ############
# Diff STD  =  0.6839236323083985
# MSE       =  0.4695970624869011
# ME        =  0.04295960494450157
# MAD       =  0.3841708557946343
# RMSE      =  0.6852715246432621
# R2 score  =  0.4233289522896323
# Pearson R and p-value:  PearsonRResult(statistic=0.6567584436965028, pvalue=0.00014704642208743005)
# ##################################################################################

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'Random Forest',
    predictedValue = t1_results_rf,
    exactValue     = t1_e_results_rf
)
# Out:
# ############ HbA1c Evaluation Metrics of Random Forest Regression ############
# Diff STD  =  0.7495150370195398
# MSE       =  0.5637112400080923
# ME        =  0.04402782403992018
# MAD       =  0.5537203523682567
# RMSE      =  0.7508070591091244
# R2 score  =  0.3077555688699718
# Pearson R and p-value:  PearsonRResult(statistic=0.5624995284442201, pvalue=0.0018348371349651022)
# ##################################################################################

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'Cat Boost',
    predictedValue = t1_results_cb,
    exactValue     = t1_e_results_cb
)
# Out:
# ############ HbA1c Evaluation Metrics of Cat Boost Regression ############
# Diff STD  =  0.6458332162448521
# MSE       =  0.417111350160302
# ME        =  -0.0032873933643826625
# MAD       =  0.4718509363134835
# RMSE      =  0.6458415828671161
# R2 score  =  0.487782061423059
# Pearson R and p-value:  PearsonRResult(statistic=0.7069540591946345, pvalue=2.6033111519962244e-05)
# ##################################################################################

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'Light GBM',
    predictedValue = t1_results_lg,
    exactValue     = t1_e_results_lg
)
# Out:
# ############ HbA1c Evaluation Metrics of Light GBM Regression ############
# Diff STD  =  0.7615481589998163
# MSE       =  0.6337304418494059
# ME        =  0.23189403479476614
# MAD       =  0.5083269662615392
# RMSE      =  0.7960718823381503
# R2 score  =  0.22177111600342447
# Pearson R and p-value:  PearsonRResult(statistic=0.5485336939950953, pvalue=0.0025080623505783104)
# ##################################################################################

# %%
ltb.plot_importance(booster= lg)
plt.show()

# %% [markdown]
# ## __Test 02:__

# %% [markdown]
# >  Utilizing __Algorithm 06v2:__ Constructing Features Set _(Red, Green, Blue; Reflected, FeatureCount=4+4+r1+r2+SpO2+BMI=13)_

# %%
# Initialize
loo                = sk.model_selection.LeaveOneOut()
t2_scores          = []
t2_test_cases      = []
t2_train_cases     = []
countEpoch         = 0
percent            = 0.02
# XG Boost
t2_results_xg      = []
t2_e_results_xg    = []
# Random Forest
t2_results_rf      = []
t2_e_results_rf    = []
# Cat Boost
t2_results_cb      = []
t2_e_results_cb    = []
# Light GBM
t2_results_lg      = []
t2_e_results_lg    = []

for train_index, test_index in loo.split(PPG_csvArray):
    print('Epoch # '+str(countEpoch))
    countEpoch +=1

    X_train, X_test      = PPG_csvArray[train_index], PPG_csvArray[test_index]
    y_train, y_test      = HbA1c_Array [train_index], HbA1c_Array [test_index]
    sp_train, sp_test    = SpO2_Array  [train_index], SpO2_Array  [test_index]
    bmi_train, bmi_test  = BMI_Array   [train_index], BMI_Array   [test_index]
    
    
    # > __Algorithm 06v2:__ Constructing Features Set _(Red, Green, Blue; Reflected, FeatureCount=4+4+r1+r2+SpO2+BMI=13)_
    print('*************************************************************')
    print('*********************Training Array Set**********************')
    print('*************************************************************')
    train_array = construct_feature_set_v2(
        PPG          = X_train,
        HbA1c        = y_train,
        SpO2         = sp_train,
        BMI          = bmi_train,
        samplingRate = 32
        )
    print('*************************************************************')
    print('*********************Testing Array Set***********************')
    print('*************************************************************')
    test_array  = construct_feature_set_v2(
        PPG          = X_test,
        HbA1c        = y_test,
        SpO2         = sp_test,
        BMI          = bmi_test,
        samplingRate = 32
        )
    
    feature_train, hba1c_train = train_array[:,:-1], train_array[:,-1]
    feature_test, hba1c_test   = test_array[:,:-1],  test_array[:,-1]
    
    train = np.sort(np.array(random.sample(range(feature_test.shape[0]), int(feature_test.shape[0] * percent))))
    if train.shape[0] == 0:
        feature_train, hba1c_train = np.append(feature_train, np.expand_dims(feature_test[0],axis=0), 0), np.append(hba1c_train, np.expand_dims(hba1c_test[0],axis=0), 0)
        # feature_test, hba1c_test = np.delete(feature_test, 0, axis = 0), np.delete(hba1c_test, 0, axis = 0)
    else:
        test = np.delete(np.arange(feature_test.shape[0]), train)

        feature_train, hba1c_train = np.append(feature_train, feature_test[train], 0), np.append(hba1c_train, hba1c_test[train], 0)
        feature_test, hba1c_test = np.delete(feature_test, train, axis = 0), np.delete(hba1c_test, train, axis = 0)
    
    feature_train, hba1c_train = sk.utils.shuffle(feature_train, hba1c_train, random_state=0)
    # print(feature_train.shape)
    # print(feature_test.shape)

    # XGboost
    xg = xgb.XGBRegressor(objective="reg:squarederror", random_state=42)
    xg.fit(feature_train, hba1c_train)
    t2_results_xg.append(np.nanmean(xg.predict(feature_test)))
    t2_e_results_xg.append(np.nanmean(hba1c_test))

    # Random Forest
    rf = RandomForestRegressor(random_state=42, n_estimators=1000, n_jobs=-1)
    rf.fit(feature_train, hba1c_train)
    t2_results_rf.append(np.nanmean(rf.predict(feature_test)))
    t2_e_results_rf.append(np.nanmean(hba1c_test))

    # Cat boost
    cb = cab.CatBoostRegressor()
    cb.fit(feature_train, hba1c_train)
    t2_results_cb.append(np.nanmean(cb.predict(feature_test)))
    t2_e_results_cb.append(np.nanmean(hba1c_test))

    # Light GBM
    # lg = ltb.LGBMRegressor(boosting_type='dart')
    lg = ltb.LGBMRegressor(
        application = 'regression',
        objective = 'root_mean_squared_error',
        boosting_type="dart",
        num_iterations = 3500,
        learning_rate = 0.05,
        num_leaves=150,
        tree_learner='feature',
        max_depth =10,
        min_data_in_leaf=7,
        bagging_fraction = 1,
        bagging_freq = 100,
        reg_sqrt='True',
        metric ='rmse',
        feature_fraction = 0.6,
        random_state=42
        ) 
    lg.fit(feature_train, hba1c_train)
    t2_results_lg.append(np.nanmean(lg.predict(feature_test)))
    t2_e_results_lg.append(np.nanmean(hba1c_test))



    t2_test_cases.append(X_test)
    t2_train_cases.append(X_train)

    clear_output(wait=True)
# Out:
# Epoch # 27
# *************************************************************
# *********************Training Array Set**********************
# *************************************************************
# PPG_data_info:./DataBase/Selected_PPG_wrist/210823_4.csv
# iCount=0 || jCount=0 || lCount=1 || fCount=13
# [7.00000000e+00 1.61312204e+02 4.10558183e+05 1.36127807e+02
#  7.00000000e+00 1.74190061e+02 5.03481979e+05 1.54951554e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=1 || lCount=2 || fCount=13
# [7.00000000e+00 1.73713036e+02 3.51560946e+05 1.21364809e+02
#  7.00000000e+00 1.82843593e+02 4.68460607e+05 1.32491539e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=2 || lCount=3 || fCount=13
# [6.00000000e+00 1.54907170e+02 1.65456467e+05 1.07901937e+02
#  6.00000000e+00 1.62510326e+02 2.92588034e+05 1.11369158e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=3 || lCount=4 || fCount=13
# [7.00000000e+00 1.61769923e+02 2.37911636e+05 9.17652058e+01
#  6.00000000e+00 1.75565987e+02 3.51616378e+05 1.20894133e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=4 || lCount=5 || fCount=13
# [6.00000000e+00 1.65802718e+02 2.81689078e+05 1.18233671e+02
#  6.00000000e+00 1.71134347e+02 4.16162401e+05 1.13538140e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=5 || lCount=6 || fCount=13
# [6.00000000e+00 1.70058097e+02 2.72924695e+05 1.22931421e+02
#  6.00000000e+00 1.83064413e+02 3.93325157e+05 1.27517168e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=6 || lCount=7 || fCount=13
# [6.00000000e+00 1.56658899e+02 2.18831851e+05 1.01261033e+02
#  6.00000000e+00 1.63203538e+02 3.58888557e+05 1.14850275e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=7 || lCount=8 || fCount=13
# [7.00000000e+00 1.48703447e+02 1.71084414e+05 9.05114879e+01
#  7.00000000e+00 1.63828904e+02 2.47001572e+05 1.07642156e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=8 || lCount=9 || fCount=13
# [7.00000000e+00 1.54631162e+02 2.19500971e+05 9.31845444e+01
#  7.00000000e+00 1.60331227e+02 2.97537408e+05 7.69965482e+01
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=9 || lCount=10 || fCount=13
# [7.00000000e+00 1.73304457e+02 2.06181451e+05 1.54463138e+02
#  7.00000000e+00 1.80983880e+02 2.72858551e+05 1.46044883e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# PPG_data_info:./DataBase/Selected_PPG_wrist/210830_0.csv
# iCount=1 || jCount=0 || lCount=11 || fCount=13
# [6.00000000e+00 5.36622112e+01 1.20219822e+04 3.86968504e+00
#  6.00000000e+00 7.14115935e+01 3.69170680e+04 7.05572951e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=1 || lCount=12 || fCount=13
# [5.00000000e+00 4.71806775e+01 1.84090477e+03 2.66880298e+00
#  5.00000000e+00 5.96340378e+01 7.78992216e+03 4.30603905e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=2 || lCount=13 || fCount=13
# [9.00000000e+00 3.79026957e+01 2.15920481e+02 7.27679788e-01
#  7.00000000e+00 4.87611407e+01 2.04592978e+03 1.60489300e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=3 || lCount=14 || fCount=13
# [6.00000000e+00 4.74109516e+01 7.81573710e+02 1.84600683e+00
#  6.00000000e+00 7.04502242e+01 7.10577496e+03 6.43960851e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=4 || lCount=15 || fCount=13
# [1.10000000e+01 4.55226536e+01 1.01044228e+03 6.15019707e-01
#  7.00000000e+00 6.67933951e+01 1.05092759e+04 3.09427773e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=5 || lCount=16 || fCount=13
# [7.00000000e+00 5.22974244e+01 2.05916120e+03 1.76437438e+00
#  6.00000000e+00 7.50534446e+01 1.89150644e+04 6.40508584e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=6 || lCount=17 || fCount=13
# [6.00000000e+00 5.11098752e+01 3.80292727e+03 1.28693690e+00
#  6.00000000e+00 7.34571094e+01 1.51200802e+04 6.70364275e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=7 || lCount=18 || fCount=13
# [7.00000000e+00 5.56081022e+01 2.49099757e+03 2.58237809e+00
#  7.00000000e+00 8.12992026e+01 1.43806560e+04 1.18496311e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=8 || lCount=19 || fCount=13
# [1.10000000e+01 5.17046070e+01 9.42064449e+02 1.68826637e+00
#  7.00000000e+00 7.48976676e+01 9.90838480e+03 7.11690760e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=9 || lCount=20 || fCount=13
# [6.00000000e+00 5.12040392e+01 2.57584596e+03 1.50701151e+00
#  6.00000000e+00 8.00289251e+01 2.06934370e+04 8.80635736e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=10 || lCount=21 || fCount=13
# [6.00000000e+00 5.62719403e+01 1.53131626e+03 2.65879994e+00
#  6.00000000e+00 8.32808643e+01 1.51879848e+04 1.08165517e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=11 || lCount=22 || fCount=13
# [7.00000000e+00 5.85009853e+01 3.98383571e+03 2.25841091e+00
#  7.00000000e+00 8.77577711e+01 3.03465226e+04 1.36476504e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=12 || lCount=23 || fCount=13
# [6.00000000e+00 5.44515467e+01 4.84828928e+03 3.07748807e+00
#  6.00000000e+00 8.26406990e+01 2.43605703e+04 1.48722413e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=13 || lCount=24 || fCount=13
# [7.00000000e+00 6.65121674e+01 7.15512558e+03 5.88393426e+00
#  7.00000000e+00 1.01551985e+02 3.72335451e+04 3.14498549e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=14 || lCount=25 || fCount=13
# [8.00000000e+00 6.05173199e+01 9.26965131e+02 3.79577859e+00
#  6.00000000e+00 9.03766631e+01 1.12255401e+04 1.85877416e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=15 || lCount=26 || fCount=13
# [6.00000000e+00 6.20451619e+01 3.86936212e+03 3.15221111e+00
#  6.00000000e+00 9.60389307e+01 3.36098916e+04 2.21746729e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=16 || lCount=27 || fCount=13
# [6.00000000e+00 7.43333504e+01 2.61723829e+04 8.11783057e+00
#  6.00000000e+00 1.17494645e+02 1.55687235e+05 4.79919725e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=17 || lCount=28 || fCount=13
# [6.00000000e+00 7.20000087e+01 1.33856143e+04 7.50601027e+00
#  6.00000000e+00 1.11153344e+02 9.33158326e+04 4.92030016e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=18 || lCount=29 || fCount=13
# [6.00000000e+00 6.72150552e+01 6.83301543e+03 6.04072158e+00
#  6.00000000e+00 1.11666257e+02 6.10556909e+04 4.26720460e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=19 || lCount=30 || fCount=13
# [6.00000000e+00 7.74982380e+01 1.46524381e+04 1.06307073e+01
#  6.00000000e+00 1.22730904e+02 1.02767864e+05 6.34777650e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=20 || lCount=31 || fCount=13
# [6.00000000e+00 7.38491806e+01 1.02530109e+04 7.56417016e+00
#  6.00000000e+00 1.16957058e+02 8.16341396e+04 6.80259145e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=21 || lCount=32 || fCount=13
# [6.00000000e+00 7.92349357e+01 1.79483751e+04 1.11183822e+01
#  6.00000000e+00 1.23872795e+02 1.36220203e+05 6.02715933e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=22 || lCount=33 || fCount=13
# [6.00000000e+00 8.71069870e+01 3.22231039e+04 1.46582579e+01
#  6.00000000e+00 1.33852718e+02 1.80212049e+05 8.41074448e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=23 || lCount=34 || fCount=13
# [7.00000000e+00 7.91284418e+01 2.82532677e+04 9.19956364e+00
#  7.00000000e+00 1.23687391e+02 1.98146664e+05 5.55534531e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=24 || lCount=35 || fCount=13
# [6.00000000e+00 7.48387371e+01 7.65890612e+03 1.25568002e+01
#  6.00000000e+00 1.24177457e+02 7.72755083e+04 7.59013109e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=25 || lCount=36 || fCount=13
# [7.00000000e+00 8.50029977e+01 2.20361070e+04 1.98480909e+01
#  7.00000000e+00 1.36578114e+02 1.46347345e+05 1.05491961e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=26 || lCount=37 || fCount=13
# [6.00000000e+00 8.62871423e+01 9.65211461e+03 1.12120928e+01
#  6.00000000e+00 1.25166177e+02 4.61606923e+04 5.37872716e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=27 || lCount=38 || fCount=13
# [6.00000000e+00 8.95448021e+01 3.92738759e+04 1.89154052e+01
#  6.00000000e+00 1.36113545e+02 2.03302293e+05 9.66488178e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=28 || lCount=39 || fCount=13
# [6.00000000e+00 8.85791445e+01 1.24300607e+04 1.95099039e+01
#  6.00000000e+00 1.39040585e+02 1.17703272e+05 1.20293254e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=29 || lCount=40 || fCount=13
# [6.00000000e+00 9.94612995e+01 4.71394193e+04 3.06222240e+01
#  6.00000000e+00 1.51493548e+02 2.63789746e+05 1.46975288e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=30 || lCount=41 || fCount=13
# [6.00000000e+00 9.39691110e+01 4.06171009e+04 2.90297967e+01
#  6.00000000e+00 1.47600086e+02 2.39869529e+05 1.63879119e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=31 || lCount=42 || fCount=13
# [7.00000000e+00 9.84474075e+01 2.99868170e+04 2.78316674e+01
#  7.00000000e+00 1.59232758e+02 2.36636954e+05 1.88876910e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=32 || lCount=43 || fCount=13
# [6.00000000e+00 1.06172304e+02 5.54492102e+04 3.70314402e+01
#  6.00000000e+00 1.63417147e+02 3.33156334e+05 2.44265573e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=33 || lCount=44 || fCount=13
# [6.00000000e+00 1.02308616e+02 8.35098626e+04 3.65374380e+01
#  6.00000000e+00 1.55770959e+02 4.37248182e+05 1.76749004e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=34 || lCount=45 || fCount=13
# [6.00000000e+00 9.12484397e+01 4.27431821e+04 3.24872144e+01
#  6.00000000e+00 1.50592048e+02 3.49677820e+05 1.95518338e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=35 || lCount=46 || fCount=13
# [5.00000000e+00 1.05409002e+02 1.12914832e+05 3.38413094e+01
#  6.00000000e+00 1.55575699e+02 5.08832654e+05 2.21874930e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=36 || lCount=47 || fCount=13
# [6.00000000e+00 1.04745057e+02 5.75096462e+04 4.22267895e+01
#  6.00000000e+00 1.59808053e+02 3.81173863e+05 2.28496317e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# PPG_data_info:./DataBase/Selected_PPG_wrist/210927_0.csv
# iCount=2 || jCount=0 || lCount=48 || fCount=13
# [1.10000000e+01 6.83467371e+01 1.08422612e+03 4.39506632e+00
#  1.10000000e+01 9.83106175e+01 7.90890426e+03 1.47652844e+01
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=1 || lCount=49 || fCount=13
# [1.20000000e+01 1.42736356e+02 1.65308823e+04 8.95840489e+01
#  1.20000000e+01 2.36613487e+02 1.13493275e+05 3.47933475e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=2 || lCount=50 || fCount=13
# [1.20000000e+01 8.90599633e+01 2.78767430e+03 1.55299320e+01
#  1.20000000e+01 2.30495084e+02 1.67525521e+05 1.90827342e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=3 || lCount=51 || fCount=13
# [1.30000000e+01 6.14050169e+01 4.29994435e+02 1.84640836e+00
#  1.20000000e+01 2.06652299e+02 1.61957296e+05 1.36353449e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=4 || lCount=52 || fCount=13
# [1.30000000e+01 1.72086477e+02 4.23959856e+04 6.82855715e+01
#  1.10000000e+01 2.50984075e+02 1.75676338e+05 2.06113239e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=5 || lCount=53 || fCount=13
# [1.10000000e+01 1.93649706e+02 9.23798304e+04 9.04337299e+01
#  1.20000000e+01 2.47517291e+02 2.87906390e+05 2.69096300e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=6 || lCount=54 || fCount=13
# [1.20000000e+01 1.98042723e+02 8.05762076e+04 9.45541877e+01
#  1.20000000e+01 2.82555769e+02 4.65959306e+05 2.94799014e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=7 || lCount=55 || fCount=13
# [1.20000000e+01 1.69894223e+02 3.67775134e+04 8.63000252e+01
#  1.10000000e+01 2.76699280e+02 2.88369031e+05 5.07124677e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=8 || lCount=56 || fCount=13
# [1.30000000e+01 1.66535785e+02 2.37292852e+04 9.85824118e+01
#  1.10000000e+01 2.31524809e+02 8.35112774e+04 2.65250983e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=9 || lCount=57 || fCount=13
# [1.10000000e+01 1.77981533e+02 6.28388834e+04 5.25159649e+01
#  1.10000000e+01 2.52539978e+02 2.49094269e+05 2.18652811e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=10 || lCount=58 || fCount=13
# [1.10000000e+01 2.18471698e+02 8.41361662e+04 1.84549564e+02
#  1.10000000e+01 2.39430840e+02 1.43858793e+05 2.00647627e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=11 || lCount=59 || fCount=13
# [1.20000000e+01 1.99017725e+02 9.01255399e+04 1.06270022e+02
#  1.20000000e+01 2.10402653e+02 1.17939022e+05 1.46061272e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=12 || lCount=60 || fCount=13
# [1.10000000e+01 1.70646462e+02 1.98866107e+04 1.13358430e+02
#  1.20000000e+01 2.79622359e+02 3.31077702e+05 3.33247054e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=13 || lCount=61 || fCount=13
# [1.20000000e+01 2.35961002e+02 2.71280845e+05 2.29147121e+02
#  1.20000000e+01 3.71486910e+02 1.54686763e+06 1.30507828e+03
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=14 || lCount=62 || fCount=13
# [1.10000000e+01 1.50799285e+02 1.83110374e+04 1.03212033e+02
#  1.10000000e+01 2.37305134e+02 1.14713874e+05 5.05992803e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=15 || lCount=63 || fCount=13
# [1.10000000e+01 1.75019035e+02 5.30919222e+04 7.12489500e+01
#  1.10000000e+01 1.71552444e+02 4.34976790e+04 9.98493635e+01
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=16 || lCount=64 || fCount=13
# [1.20000000e+01 1.67194701e+02 1.92927385e+04 8.08006987e+01
#  1.20000000e+01 2.49358101e+02 2.31645844e+05 3.82484925e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=17 || lCount=65 || fCount=13
# [1.10000000e+01 1.99304980e+02 6.87835795e+04 2.06268733e+02
#  1.10000000e+01 3.13673884e+02 4.86507313e+05 8.64573508e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=18 || lCount=66 || fCount=13
# [1.00000000e+01 1.57139024e+02 6.23042979e+04 7.69375151e+01
#  1.20000000e+01 2.21450442e+02 1.64329998e+05 3.54239385e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=19 || lCount=67 || fCount=13
# [1.20000000e+01 1.37911299e+02 2.79730822e+04 4.45335938e+01
#  1.00000000e+01 2.09671742e+02 1.52922463e+05 2.31572835e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=20 || lCount=68 || fCount=13
# [9.00000000e+00 1.37957899e+02 8.57246900e+03 1.24885905e+02
#  9.00000000e+00 1.79473342e+02 4.18354574e+04 2.74596345e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=21 || lCount=69 || fCount=13
# [1.20000000e+01 1.85734384e+02 3.88022780e+04 1.02681093e+02
#  1.20000000e+01 2.85981930e+02 2.41811618e+05 4.23737001e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=22 || lCount=70 || fCount=13
# [1.20000000e+01 2.05410478e+02 1.27623015e+05 1.51185568e+02
#  1.10000000e+01 2.70147191e+02 4.12665805e+05 4.74387623e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=23 || lCount=71 || fCount=13
# [1.10000000e+01 1.01285937e+02 3.47502069e+03 2.42119430e+01
#  1.10000000e+01 1.61430288e+02 4.13728419e+04 5.71945638e+01
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=24 || lCount=72 || fCount=13
# [1.10000000e+01 1.31988307e+02 2.68920174e+04 3.92702057e+01
#  1.10000000e+01 2.26496802e+02 2.41901933e+05 2.26206691e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=25 || lCount=73 || fCount=13
# [4.00000000e+00 1.10306293e+02 3.25049763e+04 1.22450827e+02
#  5.00000000e+00 1.40799574e+02 1.98843179e+05 1.76918094e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=26 || lCount=74 || fCount=13
# [7.00000000e+00 1.60580887e+02 9.28170800e+05 4.54042225e+02
#  3.00000000e+00 1.79605304e+02 3.21054326e+06 1.44402812e+03
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=27 || lCount=75 || fCount=13
# [7.00000000e+00 9.30292467e+01 3.20034857e+04 3.43587410e+01
#  6.00000000e+00 1.17738629e+02 1.17154556e+05 3.30161967e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=28 || lCount=76 || fCount=13
# [1.50000000e+01 6.93632199e+01 1.33232029e+03 6.14351342e+00
#  1.00000000e+01 6.71543417e+01 1.39968103e+03 2.43480913e+00
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=29 || lCount=77 || fCount=13
# [1.10000000e+01 7.74647011e+01 1.75583181e+03 4.16620645e+00
#  1.30000000e+01 8.76791710e+01 2.12378858e+03 8.62026111e+00
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=30 || lCount=78 || fCount=13
# [1.10000000e+01 7.63630904e+01 2.17828730e+03 4.55035438e+00
#  1.10000000e+01 1.20493186e+02 1.32326739e+04 2.82413510e+01
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=31 || lCount=79 || fCount=13
# [1.30000000e+01 8.79424230e+01 1.24483269e+03 4.93276491e+00
#  1.10000000e+01 1.11383890e+02 3.05231739e+03 2.32541775e+01
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=32 || lCount=80 || fCount=13
# [1.10000000e+01 1.03293705e+02 8.15027814e+03 2.49620100e+01
#  1.00000000e+01 1.28373726e+02 2.82828635e+04 5.37066168e+01
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=33 || lCount=81 || fCount=13
# [1.00000000e+01 1.41590484e+02 1.33418748e+04 9.29548108e+01
#  1.00000000e+01 2.19241694e+02 1.95057132e+05 3.28834212e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=34 || lCount=82 || fCount=13
# [1.00000000e+01 1.47246226e+02 2.65904933e+04 4.72291856e+01
#  1.00000000e+01 1.87993902e+02 9.65951606e+04 7.87089236e+01
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=35 || lCount=83 || fCount=13
# [1.10000000e+01 1.68585160e+02 3.33691079e+04 8.42395292e+01
#  1.00000000e+01 1.67670666e+02 2.72427000e+04 8.06298912e+01
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=36 || lCount=84 || fCount=13
# [1.30000000e+01 1.29261771e+02 2.26506511e+03 7.53133512e+01
#  1.10000000e+01 2.05655832e+02 5.18239791e+04 4.89447947e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=37 || lCount=85 || fCount=13
# [1.10000000e+01 2.12852493e+02 2.28178907e+05 1.11094659e+02
#  1.10000000e+01 3.56051154e+02 1.33656796e+06 1.29963751e+03
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# PPG_data_info:./DataBase/Selected_PPG_wrist/210927_1.csv
# iCount=3 || jCount=0 || lCount=86 || fCount=13
# [9.00000000e+00 1.32110396e+02 2.24300414e+04 4.32210312e+01
#  9.00000000e+00 1.92511833e+02 1.43685485e+05 1.85453919e+02
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=1 || lCount=87 || fCount=13
# [9.00000000e+00 1.41261073e+02 2.64990230e+04 9.80872976e+01
#  9.00000000e+00 2.55931749e+02 4.10270202e+05 4.92952054e+02
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=2 || lCount=88 || fCount=13
# [9.00000000e+00 1.72264725e+02 5.10197583e+04 1.67273254e+02
#  9.00000000e+00 2.47120666e+02 4.88730883e+05 4.07392367e+02
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=3 || lCount=89 || fCount=13
# [1.00000000e+01 1.37497753e+02 4.67708133e+03 1.94251536e+02
#  1.00000000e+01 2.85363180e+02 6.98631471e+05 7.90479440e+02
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=4 || lCount=90 || fCount=13
# [1.00000000e+01 2.20365728e+02 2.74763829e+05 2.56782639e+02
#  1.00000000e+01 3.63672593e+02 1.64900021e+06 2.20607349e+03
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=5 || lCount=91 || fCount=13
# [9.00000000e+00 1.65109559e+02 7.64297868e+04 1.11429621e+02
#  1.10000000e+01 2.59387580e+02 5.80897772e+05 6.07611672e+02
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=6 || lCount=92 || fCount=13
# [1.00000000e+01 1.72922024e+02 1.02164596e+05 1.05036616e+02
#  1.00000000e+01 2.82652669e+02 8.24396354e+05 5.75865007e+02
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=7 || lCount=93 || fCount=13
# [1.10000000e+01 1.45558423e+02 3.00642734e+04 1.35282869e+02
#  7.00000000e+00 2.26559703e+02 1.17551523e+05 8.96109661e+02
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=8 || lCount=94 || fCount=13
# [9.00000000e+00 7.44221412e+01 2.75325387e+02 1.85633942e+01
#  1.10000000e+01 2.09982793e+02 2.17139122e+05 2.09314989e+02
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=9 || lCount=95 || fCount=13
# [1.10000000e+01 1.75711944e+02 9.68864775e+04 1.06224173e+02
#  1.00000000e+01 2.45806121e+02 6.21613352e+05 3.92500169e+02
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=10 || lCount=96 || fCount=13
# [5.00000000e+00 6.55805405e+01 9.63336686e+02 3.98252427e+01
#  1.00000000e+01 1.96300355e+02 1.85223450e+05 1.05698513e+02
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=11 || lCount=97 || fCount=13
# [1.00000000e+01 1.51580474e+02 1.40739436e+05 1.26764082e+02
#  1.00000000e+01 2.19841406e+02 3.29639403e+05 2.35074166e+02
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=12 || lCount=98 || fCount=13
# [9.00000000e+00 7.25834792e+01 3.72177037e+03 5.80286428e+00
#  9.00000000e+00 2.32649535e+02 2.58726302e+05 3.56938606e+02
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=13 || lCount=99 || fCount=13
# [9.00000000e+00 1.72728573e+02 5.34069914e+04 9.47091485e+01
#  9.00000000e+00 2.35005129e+02 2.30542101e+05 3.29799038e+02
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=14 || lCount=100 || fCount=13
# [1.00000000e+01 2.04575991e+02 1.45190940e+05 1.50200369e+02
#  1.00000000e+01 3.21518708e+02 1.11261114e+06 9.99756572e+02
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=15 || lCount=101 || fCount=13
# [1.00000000e+01 1.75140683e+02 8.36036923e+04 1.04294996e+02
#  1.00000000e+01 2.70958804e+02 4.45902164e+05 5.99876722e+02
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=16 || lCount=102 || fCount=13
# [8.00000000e+00 8.94958079e+01 1.39122555e+04 4.45130059e+01
#  1.00000000e+01 1.93848745e+02 1.29936500e+05 1.54383237e+02
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=17 || lCount=103 || fCount=13
# [1.00000000e+01 1.37597835e+02 2.62472070e+04 9.29919564e+01
#  1.00000000e+01 2.40993715e+02 2.69230670e+05 3.97453972e+02
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=18 || lCount=104 || fCount=13
# [1.00000000e+01 1.82873376e+02 1.93551026e+05 2.07758621e+02
#  1.00000000e+01 2.63163139e+02 7.78131529e+05 7.58883710e+02
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=19 || lCount=105 || fCount=13
# [1.00000000e+01 4.40842455e+01 8.90773970e+01 1.58648987e+00
#  9.00000000e+00 2.51944002e+02 3.80563344e+05 4.75819696e+02
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=20 || lCount=106 || fCount=13
# [9.00000000e+00 2.15912300e+02 3.34747295e+05 2.89088571e+02
#  1.00000000e+01 2.89214715e+02 9.75972564e+05 9.52712149e+02
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=21 || lCount=107 || fCount=13
# [9.00000000e+00 1.67046022e+02 1.38297552e+05 1.56186965e+02
#  9.00000000e+00 2.53747052e+02 5.33064418e+05 4.42394746e+02
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=22 || lCount=108 || fCount=13
# [9.00000000e+00 3.50718956e+01 1.88723219e+01 4.95550606e-01
#  1.00000000e+01 2.00230798e+02 2.40526762e+05 1.75820962e+02
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=23 || lCount=109 || fCount=13
# [1.10000000e+01 2.02737372e+02 2.35943999e+05 2.96665279e+02
#  9.00000000e+00 3.03869240e+02 9.77178184e+05 1.24468116e+03
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=24 || lCount=110 || fCount=13
# [1.00000000e+01 2.15620991e+02 2.78099949e+05 2.35391788e+02
#  1.00000000e+01 2.91716116e+02 7.82554913e+05 6.14137030e+02
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=25 || lCount=111 || fCount=13
# [1.00000000e+01 1.88920529e+02 9.44431084e+04 1.92599014e+02
#  1.00000000e+01 3.02623423e+02 8.46434729e+05 1.22156231e+03
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=26 || lCount=112 || fCount=13
# [9.00000000e+00 1.31548100e+02 3.36367688e+04 1.33155165e+02
#  1.00000000e+01 2.47871399e+02 4.40499123e+05 4.51023138e+02
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=27 || lCount=113 || fCount=13
# [1.60000000e+01 6.70040464e+01 3.40228998e+01 5.12611218e+00
#  1.10000000e+01 2.17916111e+02 2.45207082e+05 2.41647464e+02
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=28 || lCount=114 || fCount=13
# [1.00000000e+01 2.30904394e+02 2.62286405e+05 3.06982613e+02
#  1.00000000e+01 3.28335215e+02 1.46765075e+06 1.34562684e+03
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=29 || lCount=115 || fCount=13
# [9.00000000e+00 1.33790997e+02 4.10399466e+04 6.75886501e+01
#  1.10000000e+01 2.04368457e+02 2.16302514e+05 3.16065780e+02
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# iCount=3 || jCount=30 || lCount=116 || fCount=13
# [1.10000000e+01 1.40586988e+02 1.10014567e+04 9.15462252e+01
#  1.10000000e+01 2.09231080e+02 1.35169876e+05 2.83829890e+02
#  2.28329723e+00 1.08149380e+00 9.80000000e+01 2.40000000e+01
#  5.50000000e+00]
# PPG_data_info:./DataBase/Selected_PPG_wrist/210927_2.csv
# iCount=4 || jCount=0 || lCount=117 || fCount=13
# [9.00000000e+00 1.31957696e+02 2.90008792e+04 5.12354944e+01
#  8.00000000e+00 1.95991703e+02 1.44013117e+05 2.29905476e+02
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=1 || lCount=118 || fCount=13
# [9.00000000e+00 1.33742430e+02 1.92282812e+04 8.08095513e+01
#  9.00000000e+00 2.28235558e+02 2.54229640e+05 5.39358854e+02
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=2 || lCount=119 || fCount=13
# [9.00000000e+00 1.31835515e+02 2.69155241e+04 6.40126954e+01
#  9.00000000e+00 2.27791454e+02 1.98906299e+05 6.00314586e+02
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=3 || lCount=120 || fCount=13
# [1.00000000e+01 1.57960861e+02 6.26306535e+04 6.66144306e+01
#  1.00000000e+01 2.66972176e+02 6.05241890e+05 4.04328130e+02
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=4 || lCount=121 || fCount=13
# [9.00000000e+00 1.49495028e+02 3.93916624e+04 6.85748286e+01
#  9.00000000e+00 2.53129883e+02 4.05436036e+05 5.13120311e+02
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=5 || lCount=122 || fCount=13
# [9.00000000e+00 1.39253062e+02 3.12905624e+04 3.70716489e+01
#  9.00000000e+00 2.76439905e+02 5.31055500e+05 5.72244962e+02
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=6 || lCount=123 || fCount=13
# [9.00000000e+00 1.05185474e+02 4.89506851e+03 9.58929381e+01
#  9.00000000e+00 1.74879837e+02 1.08695165e+04 1.82149521e+03
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=7 || lCount=124 || fCount=13
# [1.00000000e+01 1.37244938e+02 3.78315255e+04 9.84794093e+01
#  9.00000000e+00 2.05064781e+02 2.47613479e+05 5.88977520e+02
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=8 || lCount=125 || fCount=13
# [9.00000000e+00 9.15212424e+01 1.19140625e+03 1.23398028e+01
#  1.00000000e+01 1.04030592e+02 3.13126008e+03 4.79286010e+01
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=9 || lCount=126 || fCount=13
# [9.00000000e+00 1.06299149e+02 1.47246075e+03 2.08426836e+02
#  9.00000000e+00 1.33509774e+02 3.97504929e+03 1.57005208e+03
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=10 || lCount=127 || fCount=13
# [9.00000000e+00 1.74430620e+02 2.79294244e+05 3.13380689e+02
#  9.00000000e+00 3.13756077e+02 2.80372550e+06 2.73933162e+03
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=11 || lCount=128 || fCount=13
# [7.00000000e+00 1.31632659e+02 4.03386560e+04 8.33316811e+01
#  7.00000000e+00 2.47669474e+02 7.39883233e+05 1.18369329e+03
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=12 || lCount=129 || fCount=13
# [8.00000000e+00 1.48050263e+02 5.31919083e+04 4.05989800e+02
#  8.00000000e+00 2.09013546e+02 1.99537945e+05 5.50174845e+03
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=13 || lCount=130 || fCount=13
# [9.00000000e+00 1.99336754e+02 1.52479850e+05 3.62915364e+02
#  9.00000000e+00 2.96460814e+02 9.13630703e+05 2.66031757e+03
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=14 || lCount=131 || fCount=13
# [1.00000000e+01 1.47960524e+02 5.54005471e+04 5.40142483e+01
#  1.00000000e+01 2.46548721e+02 7.56858969e+05 6.19413122e+02
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=15 || lCount=132 || fCount=13
# [9.00000000e+00 1.31433383e+02 6.00503544e+04 7.61915263e+01
#  7.00000000e+00 2.13498325e+02 4.72663982e+05 7.41808044e+02
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=16 || lCount=133 || fCount=13
# [1.00000000e+01 1.38314873e+02 3.17053251e+04 3.98147731e+01
#  1.00000000e+01 2.42838792e+02 3.21443686e+05 4.94734656e+02
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=17 || lCount=134 || fCount=13
# [9.00000000e+00 1.55926523e+02 4.74034285e+04 1.81845984e+02
#  1.00000000e+01 2.49095132e+02 3.49847379e+05 1.02965524e+03
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=18 || lCount=135 || fCount=13
# [1.00000000e+01 1.49128776e+02 4.96248003e+04 6.92094911e+01
#  1.00000000e+01 2.93405336e+02 6.46763499e+05 1.01660933e+03
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=19 || lCount=136 || fCount=13
# [9.00000000e+00 1.64824134e+02 5.39116327e+04 9.23239692e+01
#  9.00000000e+00 3.01048589e+02 8.01834473e+05 1.10994587e+03
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=20 || lCount=137 || fCount=13
# [9.00000000e+00 1.14618383e+02 2.67820473e+03 6.14900831e+01
#  9.00000000e+00 1.55742268e+02 1.76265729e+04 4.64600544e+02
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=21 || lCount=138 || fCount=13
# [9.00000000e+00 1.52534797e+02 3.49042876e+04 1.14021847e+02
#  9.00000000e+00 2.69005419e+02 1.77842148e+05 1.60279991e+03
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=22 || lCount=139 || fCount=13
# [8.00000000e+00 1.53259146e+02 7.34800388e+04 9.30743700e+01
#  1.10000000e+01 2.65477634e+02 5.77918619e+05 8.02624346e+02
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=23 || lCount=140 || fCount=13
# [8.00000000e+00 1.64255786e+02 6.76866575e+05 6.06900230e+02
#  4.00000000e+00 2.67868285e+02 5.97692011e+06 4.71193907e+03
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=24 || lCount=141 || fCount=13
# [8.00000000e+00 1.75036142e+02 8.56951440e+04 1.44003250e+02
#  1.00000000e+01 3.47527158e+02 8.66291231e+05 2.05435555e+03
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=25 || lCount=142 || fCount=13
# [1.40000000e+01 1.42336017e+02 2.21009061e+04 8.27823439e+01
#  9.00000000e+00 2.69789075e+02 5.14505163e+05 1.57737328e+03
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=26 || lCount=143 || fCount=13
# [1.10000000e+01 1.03527431e+02 4.89756172e+03 2.40957992e+01
#  8.00000000e+00 1.11373896e+02 3.38716731e+04 1.04998268e+02
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=27 || lCount=144 || fCount=13
# [7.00000000e+00 1.23641766e+02 2.90271968e+04 3.98810157e+01
#  7.00000000e+00 1.30549855e+02 6.18748955e+04 1.09423367e+02
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=28 || lCount=145 || fCount=13
# [1.30000000e+01 1.58533382e+02 7.43097509e+04 1.21640717e+02
#  1.10000000e+01 2.75045996e+02 9.14481164e+05 1.86206320e+03
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=29 || lCount=146 || fCount=13
# [1.00000000e+01 1.73448784e+02 5.36611229e+04 1.20658250e+02
#  1.00000000e+01 3.17398788e+02 7.09714628e+05 9.91686652e+02
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=30 || lCount=147 || fCount=13
# [1.00000000e+01 1.46840832e+02 5.29503969e+04 8.35212103e+01
#  1.00000000e+01 2.84431419e+02 8.95808600e+05 1.09434801e+03
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=4 || jCount=31 || lCount=148 || fCount=13
# [9.00000000e+00 1.52540381e+02 1.88848356e+04 9.86449724e+01
#  9.00000000e+00 2.47684938e+02 2.53404753e+05 7.68028860e+02
#  1.87902936e+00 1.17425987e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# PPG_data_info:./DataBase/Selected_PPG_wrist/210928_0.csv
# iCount=5 || jCount=0 || lCount=149 || fCount=13
# [9.00000000e+00 1.46804255e+02 6.40503225e+04 8.45808853e+01
#  1.00000000e+01 1.98412804e+02 2.68832911e+05 2.15296331e+02
#  1.72078308e+00 1.03295580e+00 9.60000000e+01 2.33000000e+01
#  6.00000000e+00]
# iCount=5 || jCount=1 || lCount=150 || fCount=13
# [1.10000000e+01 1.27602074e+02 2.44042485e+04 3.69306074e+01
#  1.10000000e+01 2.21383169e+02 2.45488926e+05 3.43076173e+02
#  1.72078308e+00 1.03295580e+00 9.60000000e+01 2.33000000e+01
#  6.00000000e+00]
# iCount=5 || jCount=2 || lCount=151 || fCount=13
# [9.00000000e+00 1.61087312e+02 2.30466575e+04 1.57427141e+02
#  9.00000000e+00 2.59922343e+02 2.50510667e+05 1.05635942e+03
#  1.72078308e+00 1.03295580e+00 9.60000000e+01 2.33000000e+01
#  6.00000000e+00]
# iCount=5 || jCount=3 || lCount=152 || fCount=13
# [9.00000000e+00 1.75965296e+02 5.01164903e+04 3.60993011e+02
#  9.00000000e+00 3.11502726e+02 4.60626275e+05 2.56077641e+03
#  1.72078308e+00 1.03295580e+00 9.60000000e+01 2.33000000e+01
#  6.00000000e+00]
# iCount=5 || jCount=4 || lCount=153 || fCount=13
# [9.00000000e+00 1.32899219e+02 4.51887776e+04 7.42787825e+01
#  1.00000000e+01 2.60857441e+02 5.68515002e+05 6.31300591e+02
#  1.72078308e+00 1.03295580e+00 9.60000000e+01 2.33000000e+01
#  6.00000000e+00]
# iCount=5 || jCount=5 || lCount=154 || fCount=13
# [1.20000000e+01 1.06098349e+02 8.64314796e+03 1.53628535e+01
#  1.00000000e+01 1.77426830e+02 6.41731206e+04 1.25582891e+02
#  1.72078308e+00 1.03295580e+00 9.60000000e+01 2.33000000e+01
#  6.00000000e+00]
# iCount=5 || jCount=6 || lCount=155 || fCount=13
# [1.00000000e+01 1.14577205e+02 6.93460475e+03 1.88689456e+01
#  1.00000000e+01 1.82959438e+02 8.39951620e+04 1.37916170e+02
#  1.72078308e+00 1.03295580e+00 9.60000000e+01 2.33000000e+01
#  6.00000000e+00]
# iCount=5 || jCount=7 || lCount=156 || fCount=13
# [1.00000000e+01 1.12956099e+02 1.43990489e+04 2.93027571e+01
#  1.10000000e+01 1.45374587e+02 5.88235929e+04 5.37201588e+01
#  1.72078308e+00 1.03295580e+00 9.60000000e+01 2.33000000e+01
#  6.00000000e+00]
# iCount=5 || jCount=8 || lCount=157 || fCount=13
# [1.00000000e+01 1.26132075e+02 1.58179163e+04 2.76440506e+01
#  1.00000000e+01 1.49888430e+02 3.52435552e+04 4.28938180e+01
#  1.72078308e+00 1.03295580e+00 9.60000000e+01 2.33000000e+01
#  6.00000000e+00]
# iCount=5 || jCount=9 || lCount=158 || fCount=13
# [1.00000000e+01 1.48323562e+02 8.64350356e+04 5.80064513e+01
#  1.00000000e+01 2.28498171e+02 4.46136929e+05 5.38135144e+02
#  1.72078308e+00 1.03295580e+00 9.60000000e+01 2.33000000e+01
#  6.00000000e+00]
# iCount=5 || jCount=10 || lCount=159 || fCount=13
# [1.00000000e+01 1.44986111e+02 1.19663863e+04 1.05882452e+02
#  1.20000000e+01 2.32695081e+02 1.28812750e+05 4.15217019e+02
#  1.72078308e+00 1.03295580e+00 9.60000000e+01 2.33000000e+01
#  6.00000000e+00]
# iCount=5 || jCount=11 || lCount=160 || fCount=13
# [1.00000000e+01 9.63968472e+01 6.52706963e+03 2.15030618e+01
#  1.10000000e+01 1.33581181e+02 3.54422642e+04 3.64255019e+01
#  1.72078308e+00 1.03295580e+00 9.60000000e+01 2.33000000e+01
#  6.00000000e+00]
# iCount=5 || jCount=12 || lCount=161 || fCount=13
# [7.00000000e+00 1.28708705e+02 1.24490086e+04 9.06822208e+01
#  1.00000000e+01 1.49183593e+02 1.61204988e+04 1.35584098e+02
#  1.72078308e+00 1.03295580e+00 9.60000000e+01 2.33000000e+01
#  6.00000000e+00]
# iCount=5 || jCount=13 || lCount=162 || fCount=13
# [6.00000000e+00 1.33824139e+02 9.62162995e+05 2.18027967e+02
#  6.00000000e+00 2.17720814e+02 4.33497880e+06 8.44617777e+02
#  1.72078308e+00 1.03295580e+00 9.60000000e+01 2.33000000e+01
#  6.00000000e+00]
# iCount=5 || jCount=14 || lCount=163 || fCount=13
# [8.00000000e+00 1.64198616e+02 3.45282660e+04 2.45268242e+02
#  1.00000000e+01 3.04705235e+02 4.98385410e+05 1.37135230e+03
#  1.72078308e+00 1.03295580e+00 9.60000000e+01 2.33000000e+01
#  6.00000000e+00]
# PPG_data_info:./DataBase/Selected_PPG_wrist/210928_1.csv
# iCount=6 || jCount=0 || lCount=164 || fCount=13
# [9.00000000e+00 3.88609188e+01 2.59213689e+02 2.09592020e+00
#  1.00000000e+01 5.70327225e+01 1.57848514e+03 3.49221207e+00
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# iCount=6 || jCount=1 || lCount=165 || fCount=13
# [1.00000000e+01 7.46056626e+01 1.65776355e+03 5.04802549e+00
#  1.00000000e+01 9.82843765e+01 8.74833590e+03 7.56157810e+00
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# iCount=6 || jCount=2 || lCount=166 || fCount=13
# [9.00000000e+00 8.00608490e+01 5.30010337e+03 7.68978965e+00
#  1.00000000e+01 8.54190577e+01 3.31593779e+03 6.74148041e+00
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# iCount=6 || jCount=3 || lCount=167 || fCount=13
# [1.00000000e+01 1.12693257e+02 1.48932280e+04 2.48719704e+01
#  1.00000000e+01 1.63434638e+02 7.10921997e+04 8.46170326e+01
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# iCount=6 || jCount=4 || lCount=168 || fCount=13
# [1.00000000e+01 9.60242970e+01 9.63331931e+03 1.36089507e+01
#  1.00000000e+01 1.37636290e+02 4.06638423e+04 5.33839673e+01
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# iCount=6 || jCount=5 || lCount=169 || fCount=13
# [1.10000000e+01 9.44615685e+01 7.87046170e+03 1.30227990e+01
#  1.10000000e+01 1.24322430e+02 2.77392268e+04 2.05431819e+01
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# iCount=6 || jCount=6 || lCount=170 || fCount=13
# [1.10000000e+01 9.47155406e+01 5.50740434e+03 1.73893571e+01
#  1.10000000e+01 1.23026689e+02 2.38512448e+04 3.27319135e+01
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# iCount=6 || jCount=7 || lCount=171 || fCount=13
# [1.30000000e+01 8.90568692e+01 3.67336180e+03 1.48189172e+01
#  1.00000000e+01 1.28539189e+02 2.31810499e+04 4.61943932e+01
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# iCount=6 || jCount=8 || lCount=172 || fCount=13
# [9.00000000e+00 1.16960401e+02 1.27406503e+04 4.12637495e+01
#  9.00000000e+00 1.30891672e+02 2.37308394e+04 8.94632310e+01
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# iCount=6 || jCount=9 || lCount=173 || fCount=13
# [1.60000000e+01 5.98588582e+01 1.00131626e+02 3.84666523e+00
#  1.00000000e+01 1.35691039e+02 2.63289881e+04 3.87221940e+01
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# iCount=6 || jCount=10 || lCount=174 || fCount=13
# [1.60000000e+01 5.00717688e+01 1.90805150e+02 1.17573671e+00
#  1.10000000e+01 1.34096864e+02 3.73902323e+04 5.51226721e+01
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# iCount=6 || jCount=11 || lCount=175 || fCount=13
# [1.10000000e+01 8.68168172e+01 2.89212979e+03 1.31152887e+01
#  1.00000000e+01 1.49649837e+02 2.56132418e+04 7.44456119e+01
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# iCount=6 || jCount=12 || lCount=176 || fCount=13
# [1.30000000e+01 5.00462678e+01 4.66512658e+01 1.54783290e+01
#  1.00000000e+01 1.41942008e+02 3.99050570e+04 7.89903553e+01
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# iCount=6 || jCount=13 || lCount=177 || fCount=13
# [1.00000000e+01 9.92225268e+01 2.14205549e+03 9.70135817e+00
#  1.00000000e+01 1.53639583e+02 2.41047102e+04 9.55243418e+01
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# iCount=6 || jCount=14 || lCount=178 || fCount=13
# [1.00000000e+01 1.31756997e+02 2.23371641e+04 6.60735610e+01
#  1.00000000e+01 1.79384825e+02 9.92750920e+04 1.21586920e+02
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# iCount=6 || jCount=15 || lCount=179 || fCount=13
# [1.00000000e+01 9.59798004e+01 4.44637658e+03 1.71555807e+01
#  1.00000000e+01 1.49593115e+02 3.66703293e+04 8.16455635e+01
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# iCount=6 || jCount=16 || lCount=180 || fCount=13
# [1.00000000e+01 1.29228042e+02 2.20209088e+04 4.72272039e+01
#  1.00000000e+01 1.64576269e+02 6.58384109e+04 9.43785397e+01
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# iCount=6 || jCount=17 || lCount=181 || fCount=13
# [1.00000000e+01 1.12174272e+02 5.51567403e+03 2.36968199e+01
#  1.00000000e+01 2.10723915e+02 1.29176039e+05 1.62301551e+02
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# iCount=6 || jCount=18 || lCount=182 || fCount=13
# [1.00000000e+01 7.35460926e+01 1.87859615e+03 4.99665794e+00
#  1.00000000e+01 1.76875300e+02 8.90265381e+04 1.28180494e+02
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# iCount=6 || jCount=19 || lCount=183 || fCount=13
# [1.00000000e+01 8.99696408e+01 5.07149821e+02 2.01716575e+01
#  1.70000000e+01 1.27074518e+02 1.52480117e+03 2.96301312e+02
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# iCount=6 || jCount=20 || lCount=184 || fCount=13
# [1.00000000e+01 1.40413736e+02 3.49102008e+04 3.29228683e+01
#  1.10000000e+01 1.65195608e+02 8.41226545e+04 1.01176086e+02
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# iCount=6 || jCount=21 || lCount=185 || fCount=13
# [1.10000000e+01 1.63888396e+02 2.19194426e+04 1.94096757e+02
#  1.10000000e+01 1.98780892e+02 7.66999034e+04 3.48803196e+02
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# iCount=6 || jCount=22 || lCount=186 || fCount=13
# [1.10000000e+01 1.28806021e+02 8.84576691e+03 3.61006567e+01
#  1.10000000e+01 1.85062795e+02 3.70680086e+04 1.33989885e+02
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# iCount=6 || jCount=23 || lCount=187 || fCount=13
# [1.10000000e+01 7.92799986e+01 1.26082260e+03 8.84082222e+00
#  8.00000000e+00 9.18830582e+01 1.70941605e+03 2.65403134e+01
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# iCount=6 || jCount=24 || lCount=188 || fCount=13
# [8.00000000e+00 9.76924008e+01 4.04202850e+03 2.39253889e+01
#  1.00000000e+01 1.78043821e+02 5.62929076e+04 1.23149186e+02
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# iCount=6 || jCount=25 || lCount=189 || fCount=13
# [1.40000000e+01 2.03968334e+02 1.48876332e+05 3.85797010e+02
#  1.20000000e+01 2.75031302e+02 5.03708819e+05 7.91554339e+02
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# iCount=6 || jCount=26 || lCount=190 || fCount=13
# [1.20000000e+01 1.66065739e+02 2.52187704e+04 9.15054951e+01
#  1.20000000e+01 2.53679445e+02 1.72578204e+05 2.91456245e+02
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# iCount=6 || jCount=27 || lCount=191 || fCount=13
# [1.40000000e+01 2.29808354e+02 8.29298900e+04 1.67467756e+02
#  1.40000000e+01 2.78513922e+02 1.56131628e+05 3.61195409e+02
#  1.82757814e+00 8.93573368e-01 9.70000000e+01 2.79000000e+01
#  5.30000000e+00]
# ...
# 707:	learn: 0.0144548	total: 1.35s	remaining: 557ms
# 708:	learn: 0.0144317	total: 1.35s	remaining: 555ms
# 709:	learn: 0.0144038	total: 1.35s	remaining: 553ms
# 710:	learn: 0.0143911	total: 1.35s	remaining: 551ms
# 711:	learn: 0.0143402	total: 1.36s	remaining: 549ms
# 712:	learn: 0.0143232	total: 1.36s	remaining: 547ms
# 713:	learn: 0.0143123	total: 1.36s	remaining: 545ms
# 714:	learn: 0.0142917	total: 1.36s	remaining: 543ms
# 715:	learn: 0.0142889	total: 1.36s	remaining: 541ms
# 716:	learn: 0.0142435	total: 1.37s	remaining: 539ms
# 717:	learn: 0.0142272	total: 1.37s	remaining: 538ms
# 718:	learn: 0.0141757	total: 1.37s	remaining: 536ms
# 719:	learn: 0.0141251	total: 1.37s	remaining: 534ms
# 720:	learn: 0.0141022	total: 1.37s	remaining: 532ms
# 721:	learn: 0.0140627	total: 1.38s	remaining: 530ms
# 722:	learn: 0.0140376	total: 1.38s	remaining: 528ms
# 723:	learn: 0.0140241	total: 1.38s	remaining: 526ms
# 724:	learn: 0.0139948	total: 1.38s	remaining: 524ms
# 725:	learn: 0.0139890	total: 1.38s	remaining: 522ms
# 726:	learn: 0.0139698	total: 1.39s	remaining: 520ms
# 727:	learn: 0.0139592	total: 1.39s	remaining: 518ms
# 728:	learn: 0.0139065	total: 1.39s	remaining: 517ms
# 729:	learn: 0.0138939	total: 1.39s	remaining: 515ms
# 730:	learn: 0.0138832	total: 1.39s	remaining: 513ms
# 731:	learn: 0.0138579	total: 1.4s	remaining: 511ms
# 732:	learn: 0.0138270	total: 1.4s	remaining: 509ms
# 733:	learn: 0.0138175	total: 1.4s	remaining: 507ms
# 734:	learn: 0.0137651	total: 1.4s	remaining: 505ms
# 735:	learn: 0.0137390	total: 1.4s	remaining: 503ms
# 736:	learn: 0.0136894	total: 1.41s	remaining: 501ms
# 737:	learn: 0.0136653	total: 1.41s	remaining: 500ms
# 738:	learn: 0.0136449	total: 1.41s	remaining: 498ms
# 739:	learn: 0.0136283	total: 1.41s	remaining: 496ms
# 740:	learn: 0.0136195	total: 1.41s	remaining: 494ms
# 741:	learn: 0.0135645	total: 1.41s	remaining: 492ms
# 742:	learn: 0.0135474	total: 1.42s	remaining: 490ms
# 743:	learn: 0.0135101	total: 1.42s	remaining: 488ms
# 744:	learn: 0.0134960	total: 1.42s	remaining: 486ms
# 745:	learn: 0.0134648	total: 1.42s	remaining: 484ms
# 746:	learn: 0.0134225	total: 1.42s	remaining: 482ms
# 747:	learn: 0.0133903	total: 1.43s	remaining: 480ms
# 748:	learn: 0.0133599	total: 1.43s	remaining: 479ms
# 749:	learn: 0.0133509	total: 1.43s	remaining: 477ms
# 750:	learn: 0.0133229	total: 1.43s	remaining: 475ms
# 751:	learn: 0.0132948	total: 1.43s	remaining: 473ms
# 752:	learn: 0.0132580	total: 1.44s	remaining: 471ms
# 753:	learn: 0.0132424	total: 1.44s	remaining: 469ms
# 754:	learn: 0.0132127	total: 1.44s	remaining: 467ms
# 755:	learn: 0.0132005	total: 1.44s	remaining: 465ms
# 756:	learn: 0.0131568	total: 1.44s	remaining: 463ms
# 757:	learn: 0.0131175	total: 1.44s	remaining: 461ms
# 758:	learn: 0.0131019	total: 1.45s	remaining: 459ms
# 759:	learn: 0.0130887	total: 1.45s	remaining: 457ms
# 760:	learn: 0.0130722	total: 1.45s	remaining: 455ms
# 761:	learn: 0.0130643	total: 1.45s	remaining: 453ms
# 762:	learn: 0.0130561	total: 1.45s	remaining: 452ms
# 763:	learn: 0.0130442	total: 1.46s	remaining: 450ms
# 764:	learn: 0.0130364	total: 1.46s	remaining: 448ms
# 765:	learn: 0.0130171	total: 1.46s	remaining: 446ms
# 766:	learn: 0.0129749	total: 1.46s	remaining: 444ms
# 767:	learn: 0.0129406	total: 1.46s	remaining: 442ms
# 768:	learn: 0.0129245	total: 1.46s	remaining: 440ms
# 769:	learn: 0.0129178	total: 1.47s	remaining: 438ms
# 770:	learn: 0.0128841	total: 1.47s	remaining: 436ms
# 771:	learn: 0.0128710	total: 1.47s	remaining: 434ms
# 772:	learn: 0.0128532	total: 1.47s	remaining: 432ms
# 773:	learn: 0.0128442	total: 1.47s	remaining: 430ms
# 774:	learn: 0.0128115	total: 1.48s	remaining: 429ms
# 775:	learn: 0.0127970	total: 1.48s	remaining: 427ms
# 776:	learn: 0.0127861	total: 1.48s	remaining: 425ms
# 777:	learn: 0.0127599	total: 1.48s	remaining: 423ms
# 778:	learn: 0.0127552	total: 1.48s	remaining: 421ms
# 779:	learn: 0.0127473	total: 1.49s	remaining: 419ms
# 780:	learn: 0.0127191	total: 1.49s	remaining: 417ms
# 781:	learn: 0.0127026	total: 1.49s	remaining: 415ms
# 782:	learn: 0.0126948	total: 1.49s	remaining: 413ms
# 783:	learn: 0.0126924	total: 1.49s	remaining: 411ms
# 784:	learn: 0.0126704	total: 1.5s	remaining: 409ms
# 785:	learn: 0.0126634	total: 1.5s	remaining: 408ms
# 786:	learn: 0.0126392	total: 1.5s	remaining: 406ms
# 787:	learn: 0.0126092	total: 1.5s	remaining: 404ms
# 788:	learn: 0.0126054	total: 1.5s	remaining: 402ms
# 789:	learn: 0.0125889	total: 1.5s	remaining: 400ms
# 790:	learn: 0.0125365	total: 1.5s	remaining: 398ms
# 791:	learn: 0.0124935	total: 1.51s	remaining: 396ms
# 792:	learn: 0.0124709	total: 1.51s	remaining: 394ms
# 793:	learn: 0.0124613	total: 1.51s	remaining: 392ms
# 794:	learn: 0.0124539	total: 1.51s	remaining: 390ms
# 795:	learn: 0.0124443	total: 1.51s	remaining: 388ms
# 796:	learn: 0.0124025	total: 1.52s	remaining: 386ms
# 797:	learn: 0.0123832	total: 1.52s	remaining: 385ms
# 798:	learn: 0.0123778	total: 1.52s	remaining: 383ms
# 799:	learn: 0.0123501	total: 1.52s	remaining: 381ms
# 800:	learn: 0.0123473	total: 1.52s	remaining: 379ms
# 801:	learn: 0.0123057	total: 1.53s	remaining: 377ms
# 802:	learn: 0.0122879	total: 1.53s	remaining: 375ms
# 803:	learn: 0.0122677	total: 1.53s	remaining: 373ms
# 804:	learn: 0.0122389	total: 1.53s	remaining: 371ms
# 805:	learn: 0.0122298	total: 1.53s	remaining: 369ms
# 806:	learn: 0.0122254	total: 1.54s	remaining: 367ms
# 807:	learn: 0.0122057	total: 1.54s	remaining: 365ms
# 808:	learn: 0.0121995	total: 1.54s	remaining: 364ms
# 809:	learn: 0.0121827	total: 1.54s	remaining: 362ms
# 810:	learn: 0.0121636	total: 1.54s	remaining: 360ms
# 811:	learn: 0.0121601	total: 1.54s	remaining: 358ms
# 812:	learn: 0.0121242	total: 1.55s	remaining: 356ms
# 813:	learn: 0.0121127	total: 1.55s	remaining: 354ms
# 814:	learn: 0.0120796	total: 1.55s	remaining: 352ms
# 815:	learn: 0.0120760	total: 1.55s	remaining: 350ms
# 816:	learn: 0.0120579	total: 1.55s	remaining: 348ms
# 817:	learn: 0.0120502	total: 1.56s	remaining: 346ms
# 818:	learn: 0.0120329	total: 1.56s	remaining: 344ms
# 819:	learn: 0.0120114	total: 1.56s	remaining: 343ms
# 820:	learn: 0.0119850	total: 1.56s	remaining: 341ms
# 821:	learn: 0.0119718	total: 1.56s	remaining: 339ms
# 822:	learn: 0.0119533	total: 1.57s	remaining: 337ms
# 823:	learn: 0.0119295	total: 1.57s	remaining: 335ms
# 824:	learn: 0.0119181	total: 1.57s	remaining: 333ms
# 825:	learn: 0.0119053	total: 1.57s	remaining: 331ms
# 826:	learn: 0.0118701	total: 1.57s	remaining: 329ms
# 827:	learn: 0.0118629	total: 1.58s	remaining: 327ms
# 828:	learn: 0.0118302	total: 1.58s	remaining: 326ms
# 829:	learn: 0.0118218	total: 1.58s	remaining: 324ms
# 830:	learn: 0.0117918	total: 1.58s	remaining: 322ms
# 831:	learn: 0.0117597	total: 1.58s	remaining: 320ms
# 832:	learn: 0.0117586	total: 1.58s	remaining: 318ms
# 833:	learn: 0.0117367	total: 1.59s	remaining: 316ms
# 834:	learn: 0.0117352	total: 1.59s	remaining: 314ms
# 835:	learn: 0.0117222	total: 1.59s	remaining: 312ms
# 836:	learn: 0.0117108	total: 1.59s	remaining: 310ms
# 837:	learn: 0.0116844	total: 1.59s	remaining: 308ms
# 838:	learn: 0.0116750	total: 1.6s	remaining: 306ms
# 839:	learn: 0.0116541	total: 1.6s	remaining: 304ms
# 840:	learn: 0.0116202	total: 1.6s	remaining: 303ms
# 841:	learn: 0.0115835	total: 1.6s	remaining: 301ms
# 842:	learn: 0.0115808	total: 1.6s	remaining: 299ms
# 843:	learn: 0.0115691	total: 1.61s	remaining: 297ms
# 844:	learn: 0.0115604	total: 1.61s	remaining: 295ms
# 845:	learn: 0.0115571	total: 1.61s	remaining: 293ms
# 846:	learn: 0.0115503	total: 1.61s	remaining: 291ms
# 847:	learn: 0.0115297	total: 1.61s	remaining: 289ms
# 848:	learn: 0.0115149	total: 1.61s	remaining: 287ms
# 849:	learn: 0.0115081	total: 1.62s	remaining: 285ms
# 850:	learn: 0.0115066	total: 1.62s	remaining: 283ms
# 851:	learn: 0.0114939	total: 1.62s	remaining: 282ms
# 852:	learn: 0.0114823	total: 1.62s	remaining: 280ms
# 853:	learn: 0.0114813	total: 1.62s	remaining: 278ms
# 854:	learn: 0.0114738	total: 1.63s	remaining: 276ms
# 855:	learn: 0.0114492	total: 1.63s	remaining: 274ms
# 856:	learn: 0.0114292	total: 1.63s	remaining: 272ms
# 857:	learn: 0.0114201	total: 1.63s	remaining: 270ms
# 858:	learn: 0.0114081	total: 1.63s	remaining: 268ms
# 859:	learn: 0.0113877	total: 1.64s	remaining: 266ms
# 860:	learn: 0.0113674	total: 1.64s	remaining: 264ms
# 861:	learn: 0.0113530	total: 1.64s	remaining: 263ms
# 862:	learn: 0.0113520	total: 1.64s	remaining: 261ms
# 863:	learn: 0.0113399	total: 1.64s	remaining: 259ms
# 864:	learn: 0.0113309	total: 1.64s	remaining: 257ms
# 865:	learn: 0.0113173	total: 1.65s	remaining: 255ms
# 866:	learn: 0.0113142	total: 1.65s	remaining: 253ms
# 867:	learn: 0.0112824	total: 1.65s	remaining: 251ms
# 868:	learn: 0.0112723	total: 1.65s	remaining: 249ms
# 869:	learn: 0.0112531	total: 1.65s	remaining: 247ms
# 870:	learn: 0.0112489	total: 1.66s	remaining: 245ms
# 871:	learn: 0.0112347	total: 1.66s	remaining: 243ms
# 872:	learn: 0.0112071	total: 1.66s	remaining: 242ms
# 873:	learn: 0.0112061	total: 1.66s	remaining: 240ms
# 874:	learn: 0.0112018	total: 1.66s	remaining: 238ms
# 875:	learn: 0.0111825	total: 1.67s	remaining: 236ms
# 876:	learn: 0.0111721	total: 1.67s	remaining: 234ms
# 877:	learn: 0.0111462	total: 1.67s	remaining: 232ms
# 878:	learn: 0.0111179	total: 1.67s	remaining: 230ms
# 879:	learn: 0.0110999	total: 1.67s	remaining: 228ms
# 880:	learn: 0.0110988	total: 1.67s	remaining: 226ms
# 881:	learn: 0.0110839	total: 1.68s	remaining: 224ms
# 882:	learn: 0.0110632	total: 1.68s	remaining: 222ms
# 883:	learn: 0.0110398	total: 1.68s	remaining: 221ms
# 884:	learn: 0.0110205	total: 1.68s	remaining: 219ms
# 885:	learn: 0.0110145	total: 1.68s	remaining: 217ms
# 886:	learn: 0.0110003	total: 1.69s	remaining: 215ms
# 887:	learn: 0.0109953	total: 1.69s	remaining: 213ms
# 888:	learn: 0.0109822	total: 1.69s	remaining: 211ms
# 889:	learn: 0.0109642	total: 1.69s	remaining: 209ms
# 890:	learn: 0.0109505	total: 1.69s	remaining: 207ms
# 891:	learn: 0.0109404	total: 1.7s	remaining: 205ms
# 892:	learn: 0.0109379	total: 1.7s	remaining: 203ms
# 893:	learn: 0.0109301	total: 1.7s	remaining: 201ms
# 894:	learn: 0.0109123	total: 1.7s	remaining: 200ms
# 895:	learn: 0.0109113	total: 1.7s	remaining: 198ms
# 896:	learn: 0.0108903	total: 1.7s	remaining: 196ms
# 897:	learn: 0.0108757	total: 1.71s	remaining: 194ms
# 898:	learn: 0.0108702	total: 1.71s	remaining: 192ms
# 899:	learn: 0.0108540	total: 1.71s	remaining: 190ms
# 900:	learn: 0.0108355	total: 1.71s	remaining: 188ms
# 901:	learn: 0.0108259	total: 1.72s	remaining: 186ms
# 902:	learn: 0.0108082	total: 1.72s	remaining: 184ms
# 903:	learn: 0.0107730	total: 1.72s	remaining: 183ms
# 904:	learn: 0.0107515	total: 1.72s	remaining: 181ms
# 905:	learn: 0.0107357	total: 1.72s	remaining: 179ms
# 906:	learn: 0.0107149	total: 1.73s	remaining: 177ms
# 907:	learn: 0.0107020	total: 1.73s	remaining: 175ms
# 908:	learn: 0.0106867	total: 1.73s	remaining: 173ms
# 909:	learn: 0.0106859	total: 1.73s	remaining: 171ms
# 910:	learn: 0.0106696	total: 1.73s	remaining: 169ms
# 911:	learn: 0.0106647	total: 1.74s	remaining: 167ms
# 912:	learn: 0.0106638	total: 1.74s	remaining: 166ms
# 913:	learn: 0.0106479	total: 1.74s	remaining: 164ms
# 914:	learn: 0.0106429	total: 1.74s	remaining: 162ms
# 915:	learn: 0.0106371	total: 1.74s	remaining: 160ms
# 916:	learn: 0.0106362	total: 1.75s	remaining: 158ms
# 917:	learn: 0.0106272	total: 1.75s	remaining: 156ms
# 918:	learn: 0.0106127	total: 1.75s	remaining: 154ms
# 919:	learn: 0.0106070	total: 1.75s	remaining: 152ms
# 920:	learn: 0.0105916	total: 1.75s	remaining: 150ms
# 921:	learn: 0.0105674	total: 1.75s	remaining: 148ms
# 922:	learn: 0.0105355	total: 1.76s	remaining: 147ms
# 923:	learn: 0.0105226	total: 1.76s	remaining: 145ms
# 924:	learn: 0.0105152	total: 1.76s	remaining: 143ms
# 925:	learn: 0.0105106	total: 1.76s	remaining: 141ms
# 926:	learn: 0.0104921	total: 1.76s	remaining: 139ms
# 927:	learn: 0.0104740	total: 1.77s	remaining: 137ms
# 928:	learn: 0.0104451	total: 1.77s	remaining: 135ms
# 929:	learn: 0.0104348	total: 1.77s	remaining: 133ms
# 930:	learn: 0.0104189	total: 1.77s	remaining: 131ms
# 931:	learn: 0.0104135	total: 1.77s	remaining: 129ms
# 932:	learn: 0.0104030	total: 1.78s	remaining: 128ms
# 933:	learn: 0.0103778	total: 1.78s	remaining: 126ms
# 934:	learn: 0.0103686	total: 1.78s	remaining: 124ms
# 935:	learn: 0.0103597	total: 1.78s	remaining: 122ms
# 936:	learn: 0.0103430	total: 1.78s	remaining: 120ms
# 937:	learn: 0.0103333	total: 1.79s	remaining: 118ms
# 938:	learn: 0.0103111	total: 1.79s	remaining: 116ms
# 939:	learn: 0.0102795	total: 1.79s	remaining: 114ms
# 940:	learn: 0.0102787	total: 1.79s	remaining: 112ms
# 941:	learn: 0.0102778	total: 1.79s	remaining: 110ms
# 942:	learn: 0.0102766	total: 1.79s	remaining: 109ms
# 943:	learn: 0.0102686	total: 1.8s	remaining: 107ms
# 944:	learn: 0.0102617	total: 1.8s	remaining: 105ms
# 945:	learn: 0.0102488	total: 1.8s	remaining: 103ms
# 946:	learn: 0.0102284	total: 1.8s	remaining: 101ms
# 947:	learn: 0.0102112	total: 1.8s	remaining: 99.1ms
# 948:	learn: 0.0101923	total: 1.81s	remaining: 97.2ms
# 949:	learn: 0.0101887	total: 1.81s	remaining: 95.3ms
# 950:	learn: 0.0101818	total: 1.81s	remaining: 93.4ms
# 951:	learn: 0.0101649	total: 1.81s	remaining: 91.5ms
# 952:	learn: 0.0101471	total: 1.81s	remaining: 89.6ms
# 953:	learn: 0.0101187	total: 1.82s	remaining: 87.6ms
# 954:	learn: 0.0101010	total: 1.82s	remaining: 85.7ms
# 955:	learn: 0.0100777	total: 1.82s	remaining: 83.8ms
# 956:	learn: 0.0100587	total: 1.82s	remaining: 81.9ms
# 957:	learn: 0.0100420	total: 1.82s	remaining: 80ms
# 958:	learn: 0.0100118	total: 1.83s	remaining: 78.1ms
# 959:	learn: 0.0099919	total: 1.83s	remaining: 76.2ms
# 960:	learn: 0.0099865	total: 1.83s	remaining: 74.3ms
# 961:	learn: 0.0099686	total: 1.83s	remaining: 72.4ms
# 962:	learn: 0.0099680	total: 1.83s	remaining: 70.5ms
# 963:	learn: 0.0099617	total: 1.84s	remaining: 68.6ms
# 964:	learn: 0.0099331	total: 1.84s	remaining: 66.7ms
# 965:	learn: 0.0099282	total: 1.84s	remaining: 64.8ms
# 966:	learn: 0.0099131	total: 1.84s	remaining: 62.9ms
# 967:	learn: 0.0098990	total: 1.84s	remaining: 61ms
# 968:	learn: 0.0098931	total: 1.85s	remaining: 59.1ms
# 969:	learn: 0.0098839	total: 1.85s	remaining: 57.2ms
# 970:	learn: 0.0098730	total: 1.85s	remaining: 55.3ms
# 971:	learn: 0.0098493	total: 1.85s	remaining: 53.4ms
# 972:	learn: 0.0098322	total: 1.85s	remaining: 51.5ms
# 973:	learn: 0.0098212	total: 1.86s	remaining: 49.6ms
# 974:	learn: 0.0098150	total: 1.86s	remaining: 47.7ms
# 975:	learn: 0.0098031	total: 1.86s	remaining: 45.8ms
# 976:	learn: 0.0097942	total: 1.86s	remaining: 43.8ms
# 977:	learn: 0.0097865	total: 1.86s	remaining: 41.9ms
# 978:	learn: 0.0097779	total: 1.87s	remaining: 40ms
# 979:	learn: 0.0097772	total: 1.87s	remaining: 38.1ms
# 980:	learn: 0.0097753	total: 1.87s	remaining: 36.2ms
# 981:	learn: 0.0097623	total: 1.87s	remaining: 34.3ms
# 982:	learn: 0.0097535	total: 1.87s	remaining: 32.4ms
# 983:	learn: 0.0097293	total: 1.88s	remaining: 30.5ms
# 984:	learn: 0.0097155	total: 1.88s	remaining: 28.6ms
# 985:	learn: 0.0096996	total: 1.88s	remaining: 26.7ms
# 986:	learn: 0.0096895	total: 1.88s	remaining: 24.8ms
# 987:	learn: 0.0096766	total: 1.88s	remaining: 22.9ms
# 988:	learn: 0.0096561	total: 1.89s	remaining: 21ms
# 989:	learn: 0.0096419	total: 1.89s	remaining: 19.1ms
# 990:	learn: 0.0096207	total: 1.89s	remaining: 17.2ms
# 991:	learn: 0.0096105	total: 1.89s	remaining: 15.3ms
# 992:	learn: 0.0095972	total: 1.89s	remaining: 13.3ms
# 993:	learn: 0.0095927	total: 1.9s	remaining: 11.4ms
# 994:	learn: 0.0095720	total: 1.9s	remaining: 9.54ms
# 995:	learn: 0.0095710	total: 1.9s	remaining: 7.63ms
# 996:	learn: 0.0095578	total: 1.9s	remaining: 5.72ms
# 997:	learn: 0.0095466	total: 1.9s	remaining: 3.82ms
# 998:	learn: 0.0095277	total: 1.91s	remaining: 1.91ms
# 999:	learn: 0.0095113	total: 1.91s	remaining: 0us
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] bagging_fraction is set=1, subsample=1.0 will be ignored. Current value: bagging_fraction=1
# [LightGBM] [Warning] bagging_freq is set=100, subsample_freq=0 will be ignored. Current value: bagging_freq=100
# c:\Users\RBM-WorkStation\AppData\Local\Programs\Python\Python39\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")

# %% [markdown]
# > Evaluation of __Test 2__

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'XG Boost',
    predictedValue = t2_results_xg,
    exactValue     = t2_e_results_xg
)
# Out:
# ############ HbA1c Evaluation Metrics of XG Boost Regression ############
# Diff STD  =  0.37868355341630255
# MSE       =  0.14370782198968618
# ME        =  0.017509664808000806
# MAD       =  0.27150630269731824
# RMSE      =  0.3790881454090673
# R2 score  =  0.8235250028352148
# Pearson R and p-value:  PearsonRResult(statistic=0.9119007443192294, pvalue=1.482274019173351e-11)
# ##################################################################################

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'Random Forest',
    predictedValue = t2_results_rf,
    exactValue     = t2_e_results_rf
)
# Out:
# ############ HbA1c Evaluation Metrics of Random Forest Regression ############
# Diff STD  =  0.5364183465358371
# MSE       =  0.2963747201021974
# ME        =  -0.09289821097284857
# MAD       =  0.4184501356774449
# RMSE      =  0.5444030860513167
# R2 score  =  0.6360481484890708
# Pearson R and p-value:  PearsonRResult(statistic=0.8062365691608457, pvalue=2.230543831986288e-07)
# ##################################################################################

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'Cat Boost',
    predictedValue = t2_results_cb,
    exactValue     = t2_e_results_cb
)
# Out:
# ############ HbA1c Evaluation Metrics of Cat Boost Regression ############
# Diff STD  =  0.33146022776503065
# MSE       =  0.11220763041271352
# ME        =  -0.0483916090109381
# MAD       =  0.26835569914835145
# RMSE      =  0.3349740742396544
# R2 score  =  0.8622076308388276
# Pearson R and p-value:  PearsonRResult(statistic=0.9444908614947329, pvalue=4.409988478865402e-14)
# ##################################################################################

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'Light GBM',
    predictedValue = t2_results_lg,
    exactValue     = t2_e_results_lg
)
# Out:
# ############ HbA1c Evaluation Metrics of Light GBM Regression ############
# Diff STD  =  0.48374434722823584
# MSE       =  0.24538438237056723
# ME        =  0.10665734337257435
# MAD       =  0.35393439237350927
# RMSE      =  0.49536287948388624
# R2 score  =  0.698664918975417
# Pearson R and p-value:  PearsonRResult(statistic=0.877806648991292, pvalue=8.539822487901127e-10)
# ##################################################################################

# %%
ltb.plot_importance(booster= lg)
plt.show()
