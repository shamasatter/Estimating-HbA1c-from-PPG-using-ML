# %% [markdown]
# >__ACK:__ *** This whole code is developed by __Shama Satter__ ***

# %% [markdown]
# # __Create environment for running AI program__

# %% [markdown]
# > __Install libraris__ https://pypi.org

# %%
# %pip install pandas
# %pip install heartpy
# %pip install tsfel
# %pip install librosa
# %pip install statsmodels
# %pip install lightgbm
# %pip install catboost
# %pip install xgboost

# %% [markdown]
# > __Import libraries and dependencies__

# %%
import pandas as pd
import numpy as np
import heartpy as hp
from   matplotlib import pyplot as plt
import tsfel
import scipy 
import sklearn as sk
from   sklearn.ensemble import RandomForestRegressor
import librosa
import csv
import pandas as pd
import os
import xgboost as xgb
import random
import statsmodels.regression
from   warnings import filterwarnings
import lightgbm as ltb
from   sklearn import metrics
import catboost as cab
from   sklearn.model_selection import GridSearchCV
import time
from   datetime import datetime
from   sklearn.metrics import mean_squared_error, accuracy_score
from   sklearn.metrics import r2_score
from   IPython.display import clear_output
from sklearn.model_selection import KFold

# %% [markdown]
# # __Data collection & preprocessing__

# %% [markdown]
# > Mount Gdrive

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %% [markdown]
# > Inserting Data

# %%
## PPG Data
# define parent directory of PPG files
# PPG_dataDirectory = 'gdrive/My Drive/Colab Notebooks/SCI#02/DataBase/data/'
PPG_dataDirectory = './DataBase/Selected_PPG_wrist/'
# PPG CSV filenames
PPG_data =  [   
            '210823_4.csv',   
            '210830_0.csv',   
            '210927_0.csv',             
            '210927_1.csv',             
            '210927_2.csv',            
            '210928_0.csv',                       
            '210928_1.csv',          
            '210929_0.csv',           
            '210930_0.csv',            
            '210930_1.csv',            
            '210930_2.csv',           
            '210930_3.csv',            
            '210930_4.csv',           
            '210930_5.csv',         
            '211001_0.csv',         
            '211001_1.csv', 
            '211001_2.csv',
            '211018_1.csv',
            '211018_2.csv',
            '211018_3.csv',
            '211018_4.csv',
            '211019_0.csv',
            '211026_0.csv',
            '211026_1.csv',
            '211026_2.csv',
            '211026_3.csv',
            '211115_0.csv',
            '211115_1.csv',         
            ]
# Assigning complete filename of PPG CSV data
PPG_csvData = []
for fileName in PPG_data:
    PPG_csvData.append(PPG_dataDirectory+fileName)


## HbA1c data
HbA1c_data  =   [ 
                8.4,5.4,7.6,5.5,5.4,6.0,5.3,6.3,5.7,4.9,5.6,5.5,5.2,5.2,5.5,5.8,5.7,5.6,5.5,5.7,5.6,7.4,6.2,7.0,6.3,5.3,8.2,6.7
                ]


## SpO2 data
SpO2_data   =   [ 96,97,97,98,97,96,97,97,96,96,97,95,95,98,97,95,97,97,97,97,97,96,97,96,97,98,97,97                
                ]


## Age data
Age_data    =   [ 
                34,25,63,26,25,63,30,27,25,34,
                35
                ]


## Gender data
Gender_data =   [ 
                'M','F','M','M','F','M','F','M','M','M',
                'M','M','F','F','M','M','M','M','M','M','M','M','M','M','M','M','M','M'
                ]


                
## BMI data
BMI_data    =   [ 
                28.71,23.6,28.71,24,23.6,23.3,27.9,25.8,25.82,19.71,22.72,33.96,20.64,22.04,25.26,20.6,20.4,33.3,26.4,22.2,30.1,28.71,19.6,25.8,29.1,32.8,30.4,21.7
                ]


print('*****************PPG_csvData******************')
print(PPG_csvData)
print('Data counted = '+ str(len(PPG_csvData)))
print('******************HbA1c_data******************')
print(HbA1c_data)
print('Data counted = '+ str(len(HbA1c_data)))
print('******************SpO2_data*******************')
print(SpO2_data)
print('Data counted = '+ str(len(SpO2_data)))
print('*******************Age_data*******************')
print(Age_data)
print('Data counted = '+ str(len(Age_data)))
print('*****************Gender_data******************')
print(Gender_data)
print('Data counted = '+ str(len(Gender_data)))


print('******************BMI_data********************')
print(BMI_data)
print('Data counted = '+ str(len(BMI_data)))
# Out:
# *****************PPG_csvData******************
# ['./DataBase/Selected_PPG_wrist/210823_4.csv', './DataBase/Selected_PPG_wrist/210830_0.csv', './DataBase/Selected_PPG_wrist/210927_0.csv', './DataBase/Selected_PPG_wrist/210927_1.csv', './DataBase/Selected_PPG_wrist/210927_2.csv', './DataBase/Selected_PPG_wrist/210928_0.csv', './DataBase/Selected_PPG_wrist/210928_1.csv', './DataBase/Selected_PPG_wrist/210929_0.csv', './DataBase/Selected_PPG_wrist/210930_0.csv', './DataBase/Selected_PPG_wrist/210930_1.csv', './DataBase/Selected_PPG_wrist/210930_2.csv', './DataBase/Selected_PPG_wrist/210930_3.csv', './DataBase/Selected_PPG_wrist/210930_4.csv', './DataBase/Selected_PPG_wrist/210930_5.csv', './DataBase/Selected_PPG_wrist/211001_0.csv', './DataBase/Selected_PPG_wrist/211001_1.csv', './DataBase/Selected_PPG_wrist/211001_2.csv', './DataBase/Selected_PPG_wrist/211018_1.csv', './DataBase/Selected_PPG_wrist/211018_2.csv', './DataBase/Selected_PPG_wrist/211018_3.csv', './DataBase/Selected_PPG_wrist/211018_4.csv', './DataBase/Selected_PPG_wrist/211019_0.csv', './DataBase/Selected_PPG_wrist/211026_0.csv', './DataBase/Selected_PPG_wrist/211026_1.csv', './DataBase/Selected_PPG_wrist/211026_2.csv', './DataBase/Selected_PPG_wrist/211026_3.csv', './DataBase/Selected_PPG_wrist/211115_0.csv', './DataBase/Selected_PPG_wrist/211115_1.csv']
# Data counted = 28
# ******************HbA1c_data******************
# [8.4, 5.4, 7.6, 5.5, 5.4, 6.0, 5.3, 6.3, 5.7, 4.9, 5.6, 5.5, 5.2, 5.2, 5.5, 5.8, 5.7, 5.6, 5.5, 5.7, 5.6, 7.4, 6.2, 7.0, 6.3, 5.3, 8.2, 6.7]
# Data counted = 28
# ******************SpO2_data*******************
# [96, 97, 97, 98, 97, 96, 97, 97, 96, 96, 97, 95, 95, 98, 97, 95, 97, 97, 97, 97, 97, 96, 97, 96, 97, 98, 97, 97]
# Data counted = 28
# *******************Age_data*******************
# [34, 25, 63, 26, 25, 63, 30, 27, 25, 34, 35]
# Data counted = 11
# *****************Gender_data******************
# ['M', 'F', 'M', 'M', 'F', 'M', 'F', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M']
# Data counted = 28
# ******************BMI_data********************
# [28.71, 23.6, 28.71, 24, 23.6, 23.3, 27.9, 25.8, 25.82, 19.71, 22.72, 33.96, 20.64, 22.04, 25.26, 20.6, 20.4, 33.3, 26.4, 22.2, 30.1, 28.71, 19.6, 25.8, 29.1, 32.8, 30.4, 21.7]
# Data counted = 28

# %% [markdown]
# > Making array

# %%
PPG_csvArray  = np.asarray(PPG_csvData)
HbA1c_Array   = np.asarray(HbA1c_data)
SpO2_Array    = np.asarray(SpO2_data)
Age_Array     = np.asarray(Age_data)
Gender_Array  = np.asarray(Gender_data)
BMI_Array     = np.asarray(BMI_data)

# %% [markdown]
# # __User Defined Functions and Algorithms__

# %% [markdown]
# > __Function 00:__ Visualize PPG signal

# %%
def visual_PPG(PPG, drawFigure=True):

    for i in range (0,len(PPG)):
        
        # Getting corresponding Combined PPG Data 
        dat    = pd.read_csv(PPG[i], delimiter=',', header=None)
        print('********************************')
        print('Index='+str(i)+' || '+str(PPG[i]))
        print('********************************')
        if (dat.shape[1] == 3):
           bs = dat.iloc[:,2]
           gs = dat.iloc[:,1]
           rs = dat.iloc[:,0]
        else:
           bs = dat.iloc[:,3]
           gs = dat.iloc[:,2]
           rs = dat.iloc[:,1]
    
        # Visualization **Don't mention inside the pseudo code**
        if drawFigure:
           plt.rcParams.update(plt.rcParamsDefault)
           plt.rcParams['font.size'] = '8'
           fig,axs = plt.subplots(3, figsize=(20, 5))
           axs[0].set(title='Visualization of Wrist PPG Signal')
           axs[0].plot(bs, color='blue', label='blue signal')
           axs[0].set(ylabel = ' ')
           axs[0].legend(loc=1)
           axs[0].grid(True)
           axs[1].plot(gs, color='green', label='green signal')
           axs[1].set(ylabel = ' ', xlabel = ' ')
           axs[1].legend(loc=1)
           axs[1].grid(True)
           axs[2].plot(rs, color='red', label='red signal')
           axs[2].set(ylabel = ' ', xlabel = ' ')
           axs[2].legend(loc=1)
           axs[2].grid(True)
           plt.show()
        
    # Return
    return

# %% [markdown]
# > __Function 01:__ BA_Plot

# %%
def bland_altman_plot(data1, data2):
    data1     = np.asarray(data1)
    data2     = np.asarray(data2)
    mean      = np.mean([data1, data2], axis=0)
    diff      = data1 - data2                   # Difference between data1 and data2
    md        = np.mean(diff)                   # Mean of the difference
    sd        = np.std(diff, axis=0)            # Standard deviation of the difference

    plt.scatter(mean, diff,   c = 'black')
    plt.axhline(md,           color='green', linestyle='--')
    plt.axhline(md + 1.96*sd, color='red',   linestyle='--')
    plt.axhline(md - 1.96*sd, color='red',   linestyle='--')
    plt.xlabel("Average of the two measures", fontsize = 14)
    plt.ylabel("Difference between the two measures", fontsize = 14)
    plt.title("Bland-Altman plot for estimated %HbA1c values", fontsize = 14)
    # plt.savefig('./Figure/RF_trans_BA_Plot.png', bbox_inches = "tight", transparent = True, dpi = 400)

# %% [markdown]
# > __Function 02:__ EGA_Plot

# %%
from matplotlib.patches import Circle, Wedge, Polygon, Path
from matplotlib.collections import PatchCollection

def error_grid_analysis(ref,est):
    fig, ax = plt.subplots()

    polygons = []

    A  = [[4.0,4.0],[5.7,4.0],[5.7,5.4],[7.2,6.5],[12.0,6.5],[12.0,12.0],[6.5,12.0],[6.5,7.2],[5.4,5.7],[4.0,5.7]]
    Bd = [[5.7,4.0],[5.7,5.4],[7.2,6.5],[12.0,6.5],[12.0,5.7],[6.5,5.7],[6.5,4.0]]
    Bu = [[4.0,5.7],[5.4,5.7],[6.5,7.2],[6.5,12.0],[5.7,12.0],[5.7,6.5],[4.0,6.5]]
    Cd = [[6.5,4.0],[6.5,5.7],[12.0,5.7],[12.0,4.0]]
    Cu = [[4.0,6.5],[5.7,6.5],[5.7,12.0],[4.0,12.0]]

    # print(np.asarray(A).shape)
    pA  = Polygon(np.asarray(A))
    pBd = Polygon(np.asarray(Bd))
    pBu = Polygon(np.asarray(Bu))
    pCd = Polygon(np.asarray(Cd))
    pCu = Polygon(np.asarray(Cu))

    polygons.append(pA)
    polygons.append(pBd)
    polygons.append(pBu)
    polygons.append(pCd)
    polygons.append(pCu)


    p = PatchCollection(polygons)
    p.set_color([[0,1,0,0.3],[1,1,0,0.3],[1,1,0,0.3],[1,0,0,0.3],[1,0,0,0.3]])
    ax.add_collection(p)



    plt.plot([4.0,12.0],[4.0,12.0])


    x = ref
    y = est

    sA = []
    sB = []
    sC = []
    for i in range(len(y)):
        sA.append(int(pA.contains_point ([x[i],y[i]]))*30)
        sB.append(int(pBd.contains_point([x[i],y[i]]) or pBu.contains_point([x[i],y[i]]))*30)
        sC.append(int(pCd.contains_point([x[i],y[i]]) or pCu.contains_point([x[i],y[i]]))*30)


    plt.scatter(x,y,s=sA,color=[0.227, 0.513, 0.282,1])
    plt.scatter(x,y,s=sB,color=[0.886, 0.654, 0.133,1])
    plt.scatter(x,y,s=sC,color=[0.941, 0, 0.098,1])

    lx = np.linspace(min(x), max(x), 100)
    z = np.polyfit(x, y, 1)
    p = np.poly1d(z)
    plt.plot(lx,p(lx))


    plt.text(10.5,9,'A',fontsize=26)
    plt.text(9,10.5,'A',fontsize=26)
    plt.text(10.5,5.94,'B',fontsize=26)
    plt.text(5.94,10.5,'B',fontsize=26)
    plt.text(10.5,4.7,'C',fontsize=26)
    plt.text(4.7,10.5,'C',fontsize=26)
    fig.set_figheight(8)
    fig.set_figwidth(8)
    plt.xlim([4.0,12.0])
    plt.ylim([4.0,12.0])
    plt.xlabel('HbA1c Invasive device (%NGSP)',fontsize=15)
    plt.ylabel('HbA1c Estimated (%NGSP)',fontsize=15)
    plt.title('Error Grid Analysis (EGA) for estimated %HbA1c values',fontsize=15)
    plt.show()

# %% [markdown]
# > __Function 03:__ Evaluation
# >> ACK: __Developed by Shama__. _To visualize performance and evaluate model_

# %%
def evaluation_metrics_including_BA_and_EGA_plot(modelName, predictedValue, exactValue):
    print('############ HbA1c Evaluation Metrics of ' + modelName + ' Regression ############')
    CVy = np.asarray(predictedValue)
    CVx = np.asarray(exactValue)
    print('Diff STD  = ',np.std(CVx-CVy))
    print('MSE       = ',np.sum((CVx-CVy)**2)/CVy.shape[0])
    print('ME        = ',np.sum((CVx-CVy))/CVy.shape[0])
    print('MAD       = ',np.sum(np.abs(CVx-CVy))/CVy.shape[0])
    print('RMSE      = ',np.sqrt(np.sum((CVx-CVy)**2)/CVy.shape[0]))
    print('R2 score  = ',r2_score(CVx,CVy))
    print('Pearson R and p-value: ',scipy.stats.pearsonr(CVx,CVy))
    print('##################################################################################\n')
    bland_altman_plot  (predictedValue, exactValue)
    error_grid_analysis(predictedValue, exactValue)

# %% [markdown]
# > __Algorithm 01:__ Baseline Dirft Removal by ()
# >> ACK: __Developed by Shama__. _This algorithm ()_

# %%
### Initialize Second Order Section
sos  = scipy.signal.butter(2, 8, fs=32, output='sos')  ###
sos1 = scipy.signal.butter(2, 0.5,btype='high', fs=36, output='sos') ###
def removing_baseline_drift (ppgSignal, showFigure='False'): 
   # Getting corresponding Combined PPG Data 
   dat   = pd.read_csv(ppgSignal, delimiter=',', header=None)
   if (dat.shape[1] == 3):
      bs = dat.iloc[:,2]
      gs = dat.iloc[:,1]
      rs = dat.iloc[:,0]
   else:
      bs = dat.iloc[:,3]
      gs = dat.iloc[:,2]
      rs = dat.iloc[:,1]
   fil_s_b = scipy.signal.sosfilt(sos, bs)[10:]
   fil_s_g = scipy.signal.sosfilt(sos, gs)[10:]
   fil_s_r = scipy.signal.sosfilt(sos, rs)[10:]

   fil_s_b1 = scipy.signal.sosfilt(sos1, fil_s_b)[110:] + np.mean(fil_s_b)
   fil_s_g1 = scipy.signal.sosfilt(sos1, fil_s_g)[110:] + np.mean(fil_s_g)
   fil_s_r1 = scipy.signal.sosfilt(sos1, fil_s_r)[110:] + np.mean(fil_s_r)
   
   ### Visualization
   if showFigure=='True':
      print('***************Blue**************')
      plt.rcParams.update(plt.rcParamsDefault)
      plt.rcParams['font.size'] = '9'
      fig,axs = plt.subplots(2, figsize=(20, 2.5))
      axs[0].set(title='Visualization of PPG Signal before and after filtering')
      axs[0].plot(pd.DataFrame(fil_s_b), color='blue', label='after first filtering')
      axs[0].set(ylabel = ' ', xlabel = ' ')
      axs[0].legend(loc=1)
      axs[0].grid(True)
      axs[1].plot(pd.DataFrame(fil_s_b1), color='blue', label='After 2nd filter and baseline_drift_removal')
      axs[1].set(ylabel = ' ', xlabel = ' ')
      axs[1].legend(loc=1)
      axs[1].grid(True)
      plt.show()

      print('***************Green**************')
      plt.rcParams.update(plt.rcParamsDefault)
      plt.rcParams['font.size'] = '9'
      fig,axs = plt.subplots(2, figsize=(20, 2.5))
      axs[0].set(title='Visualization of PPG Signal before and after filtering')
      axs[0].plot(pd.DataFrame(fil_s_g), color='green', label='after first filtering')
      axs[0].set(ylabel = ' ', xlabel = ' ')
      axs[0].legend(loc=1)
      axs[0].grid(True)
      axs[1].plot(pd.DataFrame(fil_s_g1), color='green', label='After 2nd filter and baseline_drift_removal')
      axs[1].set(ylabel = ' ', xlabel = ' ')
      axs[1].legend(loc=1)
      axs[1].grid(True)
      plt.show()
      
      print('***************Red**************')
      plt.rcParams.update(plt.rcParamsDefault)
      plt.rcParams['font.size'] = '9'
      fig,axs = plt.subplots(2, figsize=(20, 2.5))
      axs[0].set(title='Visualization of PPG Signal before and after filtering')
      axs[0].plot(pd.DataFrame(fil_s_r), color='red', label='after first filtering')
      axs[0].set(ylabel = ' ', xlabel = ' ')
      axs[0].legend(loc=1)
      axs[0].grid(True)
      axs[1].plot(pd.DataFrame(fil_s_r1), color='red', label='After 2nd filter and baseline_drift_removal')
      axs[1].set(ylabel = ' ', xlabel = ' ')
      axs[1].legend(loc=1)
      axs[1].grid(True)
      plt.show()

   ## Return outcome
   return(fil_s_r1, fil_s_g1, fil_s_b1)

# %% [markdown]
# >> Test Algorithm 01:

# %%
# for i in range(len(PPG_csvArray)):
#     print(f'**********PPG_info:{PPG_csvArray[i]}**********')
#     r,g,b = removing_baseline_drift(ppgSignal=PPG_csvArray[i], showFigure='True')

# %% [markdown]
# > __Algorithm 02:__ splitSignal into discrete segments

# %%
def splitSignal (individualSignal, horizonSize=50, windowSize=200):
    overallSignal  = []
    completeFlag   = 0
    for i in range (0, len(individualSignal), horizonSize):
        if i+windowSize < len(individualSignal): #Only consider sets with windowSize data
            splittedSignal = []
            for j in range(windowSize):
                splittedSignal.append(individualSignal[i+j])
            overallSignal.append(splittedSignal)
    x = np.array(overallSignal) 
    return (x)

# %% [markdown]
# >> Test algorithm 02

# %%
horizonSet = 7*5
windowSet  = 7*13
countData  = 0
for i in range(len(PPG_csvArray)):
    r,g,b = removing_baseline_drift(ppgSignal=PPG_csvArray[i], showFigure='False')
    r_ = splitSignal(individualSignal=r, horizonSize=horizonSet, windowSize=windowSet)
    print(r_.shape)
    countData += r_.shape[0]*r_.shape[1]
print(f'dCount={countData}')
### Plotting on the first one
pd.DataFrame(r_[0]).plot()
plt.show()
# Out:
# (25, 91)
# (94, 91)
# (97, 91)
# (81, 91)
# (83, 91)
# (39, 91)
# (90, 91)
# (91, 91)
# (65, 91)
# (77, 91)
# (56, 91)
# (53, 91)
# (87, 91)
# (89, 91)
# (73, 91)
# (89, 91)
# (98, 91)
# (47, 91)
# (81, 91)
# (73, 91)
# (92, 91)
# (84, 91)
# (96, 91)
# (116, 91)
# (66, 91)
# (54, 91)
# (130, 91)
# (102, 91)
# dCount=202748

# %% [markdown]
# > __Algorithm 03:__ Butter Low-pass Filter (Ignore this in SCI)

# %%
def butter_lowPass(cutoff, fs, order=5):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = scipy.signal.butter(order, normal_cutoff, btype='low', analog=False)
    return b, a

def butter_lowPass_filter(data, cutoff, fs, order=5):
    b, a = butter_lowPass(cutoff, fs, order=order)
    y = scipy.signal.lfilter(b, a, data)
    return y

# %% [markdown]
# >> Test Algorithm 03

# %%
print('Actual Splitted Signal')
pd.DataFrame(r_[0]).plot()
plt.show()
print('After applying mean function')
data = r_[0]-np.mean(r_[0])
pd.DataFrame(data).plot()
plt.show()
print('After applying filter')
filteredSignal_r = butter_lowPass_filter(
    data  = data, 
    cutoff= 8, 
    fs    = 32, 
    order = 6)
pd.DataFrame(filteredSignal_r).plot()
plt.show()
# Out:
# Actual Splitted Signal
# After applying mean function
# After applying filter

# %% [markdown]
# > __Algorithm 04:__ Determine AC_DC_from_Signal
# >> ACK: __Developed by Shama__. _This algorithm is developed to determine __r1__ and __r2__ which significantly improve the performance of the trained models_

# %%
def determine_ac_dc_from_PPG (Signal):
    uPeak =  scipy.signal.find_peaks(Signal)
    uPeak =  pd.DataFrame(uPeak[0])
    lPeak =  scipy.signal.find_peaks(-Signal)
    lPeak =  pd.DataFrame(lPeak[0])

    if (len(uPeak)<len(lPeak)):
        indexLength = len(uPeak)
    else:
        indexLength = len(lPeak)

    for index in range(indexLength):
        newValue_ac =  Signal[uPeak.iloc[index]] - Signal[lPeak.iloc[index]]
        newValue_dc =  Signal[lPeak.iloc[index]]
        if index ==0:
            allValue_ac = newValue_ac
            allValue_dc = newValue_dc
        else:
            allValue_ac =  np.append(allValue_ac,newValue_ac)
            allValue_dc =  np.append(allValue_dc,newValue_dc)

    meanValue_ac = np.mean(allValue_ac)
    meanValue_dc = np.mean(allValue_dc)

    return meanValue_ac,meanValue_dc

# %% [markdown]
# > __Algorithm 05:__ Kaiser–Teager Energy

# %%
def get_kaiser_teager_energy(x):
    x         = np.array(x)
    l         = len(x)
    squ       = x[1:l-1]**2
    oddi      = x[0:l-2]
    eveni     = x[2:l]
    ex        = squ - (oddi*eveni)
    kte       = np.zeros([l,])
    kte[0]    = ex[0]
    kte[-1]   = ex[-1]
    kte[1:-1] = ex
    return kte

# %% [markdown]
# > __Algorithm 06v1:__ Constructing Features Set _(Red, Green, Blue; Reflected, FeatureCount=[4+4+r1+r2]+[HbA1c]=11)_
# >> ACK: __Developed by Shama, Guided by Honorable Professor Kim__. _Significantly improve the performance_

# %%
def construct_feature_set_v1 (PPG, HbA1c, SpO2, BMI, samplingRate=32):
    # Initialization
    sr         = samplingRate
    l          = 0

    for i in range (0,len(PPG)):
        
        # Getting corresponding PPG Data
        # > __Algorithm 01:__ Baseline Dirft Removal by () 
        r,g,b = removing_baseline_drift(ppgSignal=PPG[i], showFigure='False')
        print('PPG_data_info:'+str(PPG[i]))

        # > __Algorithm 04:__ Determine AC_DC_from_Signal
        r_ac,r_dc = determine_ac_dc_from_PPG(r)
        g_ac,g_dc = determine_ac_dc_from_PPG(g)
        b_ac,b_dc = determine_ac_dc_from_PPG(b)

        # Calculate r1 & r2
        r1 = (g_ac/g_dc)/(r_ac/r_dc)
        r2 = (b_ac/b_dc)/(r_ac/r_dc)

        # > __Algorithm 02:__ Split_Signal
        r_sp = splitSignal(individualSignal=r, horizonSize=horizonSet, windowSize=windowSet)
        g_sp = splitSignal(individualSignal=g, horizonSize=horizonSet, windowSize=windowSet)
        b_sp = splitSignal(individualSignal=b, horizonSize=horizonSet, windowSize=windowSet)
        
        # Constructing Feature Set
        for j in range(len(r_sp)):  ### You can also use r_sp.shape[0]
            # Initialize frame
            featureFrame       = []
            
            # >>>>>>>>>>>>>>>>Red>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
            # > __Algorithm 03:__ Filter
            filteredSignal_r   = butter_lowPass_filter(
                data  = r_sp[j]-np.mean(r_sp[j]), 
                cutoff= 8, 
                fs    = sr, 
                order = 6
                )

            fqSignal_r, psdSignal_r    = scipy.signal.welch(
                x       = filteredSignal_r, 
                nperseg = len(filteredSignal_r) # Added to overcome error
                ) 


            # > __Algorithm 05:__ Kaiser–Teager Energy
            kteSignal_r            = get_kaiser_teager_energy(
                filteredSignal_r
                )



            # Insert Feature one by one
            # Add new feature (5)
            ar_coeffs_r, _r        = statsmodels.regression.linear_model.yule_walker(filteredSignal_r, order = 2)
            # featureFrame           = np.append(featureFrame,ar_coeffs_r)
            
            # Add new feature
            zcSignal_r             = tsfel.feature_extraction.features.zero_cross(filteredSignal_r)
            featureFrame           = np.append(featureFrame,zcSignal_r)
            
            # Add new feature
            skewSignal_r           = tsfel.feature_extraction.features.skewness(filteredSignal_r)
            # featureFrame           = np.append(featureFrame,skewSignal_r)
            
            # Add new feature
            absWavelength_r        = tsfel.feature_extraction.wavelet_abs_mean(filteredSignal_r)
            maWavelength_r         = np.mean(absWavelength_r)
            # featureFrame           = np.append(featureFrame,maWavelength_r)
            
            # Add new feature
            autocorr_r             = tsfel.feature_extraction.autocorr(filteredSignal_r)
            # featureFrame           = np.append(featureFrame,autocorr_r)
            
            # Add new feature
            kurtSpectral_r         = tsfel.feature_extraction.features.spectral_kurtosis(filteredSignal_r, sr)
            # featureFrame           = np.append(featureFrame,kurtSpectral_r)
            
            # Add new feature
            skewSpectral_r         = tsfel.feature_extraction.features.spectral_skewness(filteredSignal_r, sr)
            # featureFrame           = np.append(featureFrame,skewSpectral_r)
            
            # Add new feature
            sum_abs_diff_r         = tsfel.feature_extraction.features.sum_abs_diff(filteredSignal_r)
            featureFrame           = np.append(featureFrame,sum_abs_diff_r)
            
            # Add new feature
            kurtPSD_r              = scipy.stats.kurtosis(psdSignal_r)
            # featureFrame           = np.append(featureFrame,kurtPSD_r)
            
            # Add new feature
            varPSD_r               = np.var(psdSignal_r)
            featureFrame           = np.append(featureFrame,varPSD_r)
            
            # Add new feature
            meanPSD_r              = np.mean(psdSignal_r)
            # featureFrame           = np.append(featureFrame,meanPSD_r)
            
            # Add new feature
            skewKTE_r              = scipy.stats.skew(kteSignal_r)
            # featureFrame           = np.append(featureFrame,skewKTE_r)
            
            # Add new feature
            kurtKTE_r              = scipy.stats.kurtosis(kteSignal_r)
            # featureFrame           = np.append(featureFrame,kurtKTE_r)
            
            # Add new feature
            varKTE_r               = np.var(kteSignal_r)
            featureFrame           = np.append(featureFrame,varKTE_r)
            
            # Add new feature
            meanKTE_r              = np.mean(kteSignal_r)
            # featureFrame           = np.append(featureFrame,meanKTE_r)
            
            
            # >>>>>>>>>>>>>>>>Green>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
           
            # > __Algorithm 03:__ Butter Low-pass Filter
            filteredSignal_g = butter_lowPass_filter(
                data  = g_sp[j]-np.mean(g_sp[j]), 
                cutoff= 8, 
                fs    = sr, 
                order = 6
                )

            fqSignal_g, psdSignal_g    = scipy.signal.welch(
                x       = filteredSignal_g, 
                nperseg = len(filteredSignal_g) # Added to overcome error
                ) 
           
            # > __Algorithm 05:__ Kaiser–Teager Energy
            kteSignal_g            = get_kaiser_teager_energy(
                filteredSignal_g
                )
            
            
            # Insert Feature one by one
            # Add new feature
            ar_coeffs_g, _g        = statsmodels.regression.linear_model.yule_walker(filteredSignal_g, order = 2)
            # featureFrame           = np.append(featureFrame,ar_coeffs_g)
            
            # Add new feature
            zcSignal_g             = tsfel.feature_extraction.features.zero_cross(filteredSignal_g)
            featureFrame           = np.append(featureFrame,zcSignal_g)
            
            # Add new feature
            skewSignal_g           = tsfel.feature_extraction.features.skewness(filteredSignal_g)
            # featureFrame           = np.append(featureFrame,skewSignal_g)
            
            # Add new feature
            absWavelength_g        = tsfel.feature_extraction.wavelet_abs_mean(filteredSignal_g)
            maWavelength_g         = np.mean(absWavelength_g)
            # featureFrame           = np.append(featureFrame,maWavelength_g)
            
            # Add new feature
            autocorr_g             = tsfel.feature_extraction.autocorr(filteredSignal_g)
            # featureFrame           = np.append(featureFrame,autocorr_g)
            
            # Add new feature
            kurtSpectral_g         = tsfel.feature_extraction.features.spectral_kurtosis(filteredSignal_g, sr)
            # featureFrame           = np.append(featureFrame,kurtSpectral_g)
            
            # Add new feature
            skewSpectral_g         = tsfel.feature_extraction.features.spectral_skewness(filteredSignal_g, sr)
            # featureFrame           = np.append(featureFrame,skewSpectral_g)
            
            # Add new feature
            sum_abs_diff_g         = tsfel.feature_extraction.features.sum_abs_diff(filteredSignal_g)
            featureFrame           = np.append(featureFrame,sum_abs_diff_g)
            
            # Add new feature
            kurtPSD_g              = scipy.stats.kurtosis(psdSignal_g)
            # featureFrame           = np.append(featureFrame,kurtPSD_g)
            
            # Add new feature
            varPSD_g               = np.var(psdSignal_g)
            featureFrame           = np.append(featureFrame,varPSD_g)
            
            # Add new feature
            meanPSD_g              = np.mean(psdSignal_g)
            # featureFrame           = np.append(featureFrame,meanPSD_g)
            
            # Add new feature
            skewKTE_g              = scipy.stats.skew(kteSignal_g)
            # featureFrame           = np.append(featureFrame,skewKTE_g)
            
            # Add new feature
            kurtKTE_g              = scipy.stats.kurtosis(kteSignal_g)
            # featureFrame           = np.append(featureFrame,kurtKTE_g)
            
            # Add new feature
            varKTE_g               = np.var(kteSignal_g)
            featureFrame           = np.append(featureFrame,varKTE_g)
            
            # Add new feature
            meanKTE_g              = np.mean(kteSignal_g)
            # featureFrame           = np.append(featureFrame,meanKTE_g)


            # >>>>>>>>>>>>>>>>Add_r1_r2_as_features>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
            # filteredSignal_b = butter_lowPass_filter(
            #     data  = b_sp[j]-np.mean(b_sp[j]), 
            #     cutoff= 8, 
            #     fs    = sr, 
            #     order = 6
            #     )

            
            featureFrame           = np.append(featureFrame,r1)
            featureFrame           = np.append(featureFrame,r2)
            
            
            # >>>>>>>>>>>>>>>>Add_other_features>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
            # featureFrame           = np.append(featureFrame,SpO2[i])
            # featureFrame           = np.append(featureFrame,BMI[i])

            # >>>>>>>>>>>>>>> Add output feature 
            featureFrame           = np.append(featureFrame,HbA1c[i])

            ## Insert featureFrame into featureSet
            # Initialized feature set array 
            if l == 0:
                k = len(featureFrame)
                # print('kCount='+str(k))
                featureSet = np.empty([150000,k]) 
            # Save into featureSet
            featureSet[l][:k] = featureFrame
            # Length increased for next cycle
            l = l + 1


            # Checking outputs
            print(f'iCount={i} || jCount={j} || lCount={l} || fCount={len(featureFrame)}')
            print(featureFrame)

        # Check point    
        # print('iCount='+str(i))

    # Gather all
    print('**********************************************************************')
    print('*****************************Summary**********************************')    
    featureSet = featureSet[0:l][:]
    # Check for null
    featureSet = featureSet[~np.isnan(featureSet).any(axis=1)]
    print('**********************************************************************')
    return featureSet

# %% [markdown]
# > __Algorithm 06v2:__ Constructing Features Set _(Red, Green, Blue; Reflected, FeatureCount=[4+4+r1+r2+SpO2+BMI]+[HbA1c]=13)_
# >> ACK: __Developed by Shama, Guided by Honorable Professor Kim__. _Significantly improve the performance_

# %%
def construct_feature_set_v2 (PPG, HbA1c, SpO2, BMI, samplingRate=32):
    # Initialization
    sr         = samplingRate
    l          = 0

    for i in range (0,len(PPG)):
        
        # Getting corresponding PPG Data
        # > __Algorithm 01:__ Baseline Dirft Removal by () 
        r,g,b = removing_baseline_drift(ppgSignal=PPG[i], showFigure='False')
        print('PPG_data_info:'+str(PPG[i]))

        # > __Algorithm 04:__ Determine AC_DC_from_Signal
        r_ac,r_dc = determine_ac_dc_from_PPG(r)
        g_ac,g_dc = determine_ac_dc_from_PPG(g)
        b_ac,b_dc = determine_ac_dc_from_PPG(b)

        # Calculate r1 & r2
        r1 = (g_ac/g_dc)/(r_ac/r_dc)
        r2 = (b_ac/b_dc)/(r_ac/r_dc)

        # > __Algorithm 02:__ Split_Signal
        r_sp = splitSignal(individualSignal=r, horizonSize=horizonSet, windowSize=windowSet)
        g_sp = splitSignal(individualSignal=g, horizonSize=horizonSet, windowSize=windowSet)
        b_sp = splitSignal(individualSignal=b, horizonSize=horizonSet, windowSize=windowSet)
        
        # Constructing Feature Set
        for j in range(len(r_sp)):  ### You can also use r_sp.shape[0]
            # Initialize frame
            featureFrame       = []
            
            # >>>>>>>>>>>>>>>>Red>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
            # > __Algorithm 03:__ Filter
            filteredSignal_r   = butter_lowPass_filter(
                data  = r_sp[j]-np.mean(r_sp[j]), 
                cutoff= 8, 
                fs    = sr, 
                order = 6
                )

            fqSignal_r, psdSignal_r    = scipy.signal.welch(
                x       = filteredSignal_r, 
                nperseg = len(filteredSignal_r) # Added to overcome error
                ) 


            # > __Algorithm 05:__ Kaiser–Teager Energy
            kteSignal_r            = get_kaiser_teager_energy(
                filteredSignal_r
                )



            # Insert Feature one by one
            # Add new feature (5)
            ar_coeffs_r, _r        = statsmodels.regression.linear_model.yule_walker(filteredSignal_r, order = 2)
            # featureFrame           = np.append(featureFrame,ar_coeffs_r)
            
            # Add new feature
            zcSignal_r             = tsfel.feature_extraction.features.zero_cross(filteredSignal_r)
            featureFrame           = np.append(featureFrame,zcSignal_r)
            
            # Add new feature
            skewSignal_r           = tsfel.feature_extraction.features.skewness(filteredSignal_r)
            # featureFrame           = np.append(featureFrame,skewSignal_r)
            
            # Add new feature
            absWavelength_r        = tsfel.feature_extraction.wavelet_abs_mean(filteredSignal_r)
            maWavelength_r         = np.mean(absWavelength_r)
            # featureFrame           = np.append(featureFrame,maWavelength_r)
            
            # Add new feature
            autocorr_r             = tsfel.feature_extraction.autocorr(filteredSignal_r)
            # featureFrame           = np.append(featureFrame,autocorr_r)
            
            # Add new feature
            kurtSpectral_r         = tsfel.feature_extraction.features.spectral_kurtosis(filteredSignal_r, sr)
            # featureFrame           = np.append(featureFrame,kurtSpectral_r)
            
            # Add new feature
            skewSpectral_r         = tsfel.feature_extraction.features.spectral_skewness(filteredSignal_r, sr)
            # featureFrame           = np.append(featureFrame,skewSpectral_r)
            
            # Add new feature
            sum_abs_diff_r         = tsfel.feature_extraction.features.sum_abs_diff(filteredSignal_r)
            featureFrame           = np.append(featureFrame,sum_abs_diff_r)
            
            # Add new feature
            kurtPSD_r              = scipy.stats.kurtosis(psdSignal_r)
            # featureFrame           = np.append(featureFrame,kurtPSD_r)
            
            # Add new feature
            varPSD_r               = np.var(psdSignal_r)
            featureFrame           = np.append(featureFrame,varPSD_r)
            
            # Add new feature
            meanPSD_r              = np.mean(psdSignal_r)
            # featureFrame           = np.append(featureFrame,meanPSD_r)
            
            # Add new feature
            skewKTE_r              = scipy.stats.skew(kteSignal_r)
            # featureFrame           = np.append(featureFrame,skewKTE_r)
            
            # Add new feature
            kurtKTE_r              = scipy.stats.kurtosis(kteSignal_r)
            # featureFrame           = np.append(featureFrame,kurtKTE_r)
            
            # Add new feature
            varKTE_r               = np.var(kteSignal_r)
            featureFrame           = np.append(featureFrame,varKTE_r)
            
            # Add new feature
            meanKTE_r              = np.mean(kteSignal_r)
            # featureFrame           = np.append(featureFrame,meanKTE_r)
            
            
            # >>>>>>>>>>>>>>>>Green>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
           
            # > __Algorithm 03:__ Butter Low-pass Filter
            filteredSignal_g = butter_lowPass_filter(
                data  = g_sp[j]-np.mean(g_sp[j]), 
                cutoff= 8, 
                fs    = sr, 
                order = 6
                )

            fqSignal_g, psdSignal_g    = scipy.signal.welch(
                x       = filteredSignal_g, 
                nperseg = len(filteredSignal_g) # Added to overcome error
                ) 
           
            # > __Algorithm 05:__ Kaiser–Teager Energy
            kteSignal_g            = get_kaiser_teager_energy(
                filteredSignal_g
                )
            
            
            # Insert Feature one by one
            # Add new feature
            ar_coeffs_g, _g        = statsmodels.regression.linear_model.yule_walker(filteredSignal_g, order = 2)
            # featureFrame           = np.append(featureFrame,ar_coeffs_g)
            
            # Add new feature
            zcSignal_g             = tsfel.feature_extraction.features.zero_cross(filteredSignal_g)
            featureFrame           = np.append(featureFrame,zcSignal_g)
            
            # Add new feature
            skewSignal_g           = tsfel.feature_extraction.features.skewness(filteredSignal_g)
            # featureFrame           = np.append(featureFrame,skewSignal_g)
            
            # Add new feature
            absWavelength_g        = tsfel.feature_extraction.wavelet_abs_mean(filteredSignal_g)
            maWavelength_g         = np.mean(absWavelength_g)
            # featureFrame           = np.append(featureFrame,maWavelength_g)
            
            # Add new feature
            autocorr_g             = tsfel.feature_extraction.autocorr(filteredSignal_g)
            # featureFrame           = np.append(featureFrame,autocorr_g)
            
            # Add new feature
            kurtSpectral_g         = tsfel.feature_extraction.features.spectral_kurtosis(filteredSignal_g, sr)
            # featureFrame           = np.append(featureFrame,kurtSpectral_g)
            
            # Add new feature
            skewSpectral_g         = tsfel.feature_extraction.features.spectral_skewness(filteredSignal_g, sr)
            # featureFrame           = np.append(featureFrame,skewSpectral_g)
            
            # Add new feature
            sum_abs_diff_g         = tsfel.feature_extraction.features.sum_abs_diff(filteredSignal_g)
            featureFrame           = np.append(featureFrame,sum_abs_diff_g)
            
            # Add new feature
            kurtPSD_g              = scipy.stats.kurtosis(psdSignal_g)
            # featureFrame           = np.append(featureFrame,kurtPSD_g)
            
            # Add new feature
            varPSD_g               = np.var(psdSignal_g)
            featureFrame           = np.append(featureFrame,varPSD_g)
            
            # Add new feature
            meanPSD_g              = np.mean(psdSignal_g)
            # featureFrame           = np.append(featureFrame,meanPSD_g)
            
            # Add new feature
            skewKTE_g              = scipy.stats.skew(kteSignal_g)
            # featureFrame           = np.append(featureFrame,skewKTE_g)
            
            # Add new feature
            kurtKTE_g              = scipy.stats.kurtosis(kteSignal_g)
            # featureFrame           = np.append(featureFrame,kurtKTE_g)
            
            # Add new feature
            varKTE_g               = np.var(kteSignal_g)
            featureFrame           = np.append(featureFrame,varKTE_g)
            
            # Add new feature
            meanKTE_g              = np.mean(kteSignal_g)
            # featureFrame           = np.append(featureFrame,meanKTE_g)


            # >>>>>>>>>>>>>>>>Add_r1_r2_as_features>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
            
            featureFrame           = np.append(featureFrame,r1)
            featureFrame           = np.append(featureFrame,r2)
            
            
            # >>>>>>>>>>>>>>>>Add_other_features>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
            featureFrame           = np.append(featureFrame,SpO2[i])
            featureFrame           = np.append(featureFrame,BMI[i])

            # >>>>>>>>>>>>>>> Add output feature 
            featureFrame           = np.append(featureFrame,HbA1c[i])

            ## Insert featureFrame into featureSet
            # Initialized feature set array 
            if l == 0:
                k = len(featureFrame)
                # print('kCount='+str(k))
                featureSet = np.empty([150000,k]) 
            # Save into featureSet
            featureSet[l][:k] = featureFrame
            # Length increased for next cycle
            l = l + 1


            # Checking outputs
            print(f'iCount={i} || jCount={j} || lCount={l} || fCount={len(featureFrame)}')
            print(featureFrame)

        # Check point    
        # print('iCount='+str(i))

    # Gather all
    print('**********************************************************************')
    print('*****************************Summary**********************************')    
    featureSet = featureSet[0:l][:]
    # Check for null
    featureSet = featureSet[~np.isnan(featureSet).any(axis=1)]
    print('**********************************************************************')
    return featureSet

# %% [markdown]
# # __Main Function__

# %% [markdown]
# ## __Test 01:__

# %% [markdown]
# >  Utilizing __Algorithm 06v2:__ Constructing Features Set _(Red, Green, Blue; Reflected, FeatureCount=[4+4+r1+r2]+[HbA1c]=11)_

# %%
# Initialize
loo                = sk.model_selection.LeaveOneOut()
t1_scores          = []
t1_test_cases      = []
t1_train_cases     = []
countEpoch         = 0
percent            = 0.02
# XG Boost
t1_results_xg      = []
t1_e_results_xg    = []
# Random Forest
t1_results_rf      = []
t1_e_results_rf    = []
# Cat Boost
t1_results_cb      = []
t1_e_results_cb    = []
# Light GBM
t1_results_lg      = []
t1_e_results_lg    = []

for train_index, test_index in loo.split(PPG_csvArray):
    print('Epoch # '+str(countEpoch))
    countEpoch +=1

    X_train, X_test      = PPG_csvArray[train_index], PPG_csvArray[test_index]
    y_train, y_test      = HbA1c_Array [train_index], HbA1c_Array [test_index]
    sp_train, sp_test    = SpO2_Array  [train_index], SpO2_Array  [test_index]
    bmi_train, bmi_test  = BMI_Array   [train_index], BMI_Array   [test_index]
    
    
    # > __Algorithm 06v1:__ Constructing Features Set _(Red, Green, Blue; Reflected, FeatureCount=[4+4+r1+r2]+[HbA1c]=11)_
    print('*************************************************************')
    print('*********************Training Array Set**********************')
    print('*************************************************************')
    train_array = construct_feature_set_v1(
        PPG          = X_train,
        HbA1c        = y_train,
        SpO2         = sp_train,
        BMI          = bmi_train,
        samplingRate = 32
        )
    print('*************************************************************')
    print('*********************Testing Array Set***********************')
    print('*************************************************************')
    test_array  = construct_feature_set_v1(
        PPG          = X_test,
        HbA1c        = y_test,
        SpO2         = sp_test,
        BMI          = bmi_test,
        samplingRate = 32
        )
    
    feature_train, hba1c_train = train_array[:,:-1], train_array[:,-1]
    feature_test, hba1c_test   = test_array[:,:-1],  test_array[:,-1]
    
    train = np.sort(np.array(random.sample(range(feature_test.shape[0]), int(feature_test.shape[0] * percent))))
    if train.shape[0] == 0:
        feature_train, hba1c_train = np.append(feature_train, np.expand_dims(feature_test[0],axis=0), 0), np.append(hba1c_train, np.expand_dims(hba1c_test[0],axis=0), 0)
        # feature_test, hba1c_test = np.delete(feature_test, 0, axis = 0), np.delete(hba1c_test, 0, axis = 0)
    else:
        test = np.delete(np.arange(feature_test.shape[0]), train)

        feature_train, hba1c_train = np.append(feature_train, feature_test[train], 0), np.append(hba1c_train, hba1c_test[train], 0)
        feature_test, hba1c_test = np.delete(feature_test, train, axis = 0), np.delete(hba1c_test, train, axis = 0)
    
    feature_train, hba1c_train = sk.utils.shuffle(feature_train, hba1c_train, random_state=0)
    # print(feature_train.shape)
    # print(feature_test.shape)

    # XGboost
    xg = xgb.XGBRegressor(objective="reg:squarederror", random_state=42)
    xg.fit(feature_train, hba1c_train)
    t1_results_xg.append(np.nanmean(xg.predict(feature_test)))
    t1_e_results_xg.append(np.nanmean(hba1c_test))

    # Random Forest
    rf = RandomForestRegressor(random_state=42, n_estimators=1000, n_jobs=-1)
    rf.fit(feature_train, hba1c_train)
    t1_results_rf.append(np.nanmean(rf.predict(feature_test)))
    t1_e_results_rf.append(np.nanmean(hba1c_test))

    # Cat boost
    cb = cab.CatBoostRegressor()
    cb.fit(feature_train, hba1c_train)
    t1_results_cb.append(np.nanmean(cb.predict(feature_test)))
    t1_e_results_cb.append(np.nanmean(hba1c_test))

    # Light GBM
    # lg = ltb.LGBMRegressor(boosting_type='dart')
    lg = ltb.LGBMRegressor(
        application = 'regression',
        objective = 'root_mean_squared_error',
        boosting_type="dart",
        num_iterations = 3500,
        learning_rate = 0.05,
        num_leaves=150,
        tree_learner='feature',
        max_depth =10,
        min_data_in_leaf=7,
        bagging_fraction = 1,
        bagging_freq = 100,
        reg_sqrt='True',
        metric ='rmse',
        feature_fraction = 0.6,
        random_state=42
        ) 
    lg.fit(feature_train, hba1c_train)
    t1_results_lg.append(np.nanmean(lg.predict(feature_test)))
    t1_e_results_lg.append(np.nanmean(hba1c_test))



    t1_test_cases.append(X_test)
    t1_train_cases.append(X_train)

    clear_output(wait=True)
# Out:
# Epoch # 27
# *************************************************************
# *********************Training Array Set**********************
# *************************************************************
# PPG_data_info:./DataBase/Selected_PPG_wrist/210823_4.csv
# iCount=0 || jCount=0 || lCount=1 || fCount=11
# [7.00000000e+00 1.61312204e+02 4.10558183e+05 1.36127807e+02
#  7.00000000e+00 1.74190061e+02 5.03481979e+05 1.54951554e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=1 || lCount=2 || fCount=11
# [7.00000000e+00 1.91803315e+02 2.96738685e+05 1.90432848e+02
#  7.00000000e+00 2.02711545e+02 4.13354251e+05 1.97611040e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=2 || lCount=3 || fCount=11
# [7.00000000e+00 1.79943544e+02 3.82680075e+05 2.35377866e+02
#  7.00000000e+00 1.92379419e+02 4.64490018e+05 2.63663411e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=3 || lCount=4 || fCount=11
# [6.00000000e+00 1.72377749e+02 2.73144676e+05 1.33134886e+02
#  6.00000000e+00 1.76909105e+02 3.88045904e+05 1.38785164e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=4 || lCount=5 || fCount=11
# [7.00000000e+00 1.65683896e+02 3.79694533e+05 1.48109607e+02
#  7.00000000e+00 1.79250007e+02 4.22356425e+05 1.61181767e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=5 || lCount=6 || fCount=11
# [7.00000000e+00 1.62742490e+02 1.87012861e+05 1.06966438e+02
#  7.00000000e+00 1.75755137e+02 3.01513553e+05 1.15175021e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=6 || lCount=7 || fCount=11
# [7.00000000e+00 1.60025502e+02 2.72718163e+05 8.17170237e+01
#  6.00000000e+00 1.72146488e+02 3.89271296e+05 1.17528472e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=7 || lCount=8 || fCount=11
# [7.00000000e+00 1.66339438e+02 3.42903743e+05 9.52418406e+01
#  7.00000000e+00 1.82503072e+02 4.63742434e+05 1.64579204e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=8 || lCount=9 || fCount=11
# [7.00000000e+00 1.57764503e+02 2.19044274e+05 8.61038524e+01
#  7.00000000e+00 1.74142605e+02 3.36180653e+05 1.33201131e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=9 || lCount=10 || fCount=11
# [7.00000000e+00 1.71641184e+02 2.43282649e+05 1.22399177e+02
#  7.00000000e+00 1.78794843e+02 2.95162029e+05 1.31202785e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=10 || lCount=11 || fCount=11
# [7.00000000e+00 1.72014223e+02 4.21432720e+05 1.10751931e+02
#  7.00000000e+00 1.81407670e+02 5.11053625e+05 1.19541115e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=11 || lCount=12 || fCount=11
# [7.00000000e+00 1.67730274e+02 2.26760796e+05 9.96250628e+01
#  7.00000000e+00 1.81256444e+02 3.37824004e+05 1.03199110e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=12 || lCount=13 || fCount=11
# [7.00000000e+00 1.73291192e+02 4.50047062e+05 1.18550364e+02
#  7.00000000e+00 1.87022010e+02 5.57927017e+05 1.27455164e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=13 || lCount=14 || fCount=11
# [6.00000000e+00 1.70058097e+02 2.72924695e+05 1.22931421e+02
#  6.00000000e+00 1.83064413e+02 3.93325157e+05 1.27517168e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=14 || lCount=15 || fCount=11
# [7.00000000e+00 1.64476367e+02 3.39279705e+05 1.02753756e+02
#  7.00000000e+00 1.74333596e+02 4.39691110e+05 1.18154473e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=15 || lCount=16 || fCount=11
# [7.00000000e+00 1.78814075e+02 3.20770213e+05 1.33682623e+02
#  7.00000000e+00 1.86751014e+02 4.73468275e+05 1.53623186e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=16 || lCount=17 || fCount=11
# [6.00000000e+00 1.70293606e+02 1.90914991e+05 1.10503778e+02
#  6.00000000e+00 1.76980454e+02 2.88309766e+05 1.10792169e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=17 || lCount=18 || fCount=11
# [7.00000000e+00 1.51763040e+02 3.34748259e+05 8.03502233e+01
#  7.00000000e+00 1.64026892e+02 3.67380648e+05 8.17050394e+01
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=18 || lCount=19 || fCount=11
# [7.00000000e+00 1.62205810e+02 1.78928495e+05 1.16466324e+02
#  7.00000000e+00 1.68705979e+02 2.60216496e+05 1.03014440e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=19 || lCount=20 || fCount=11
# [7.00000000e+00 1.52600566e+02 2.12623979e+05 9.00601144e+01
#  7.00000000e+00 1.63812460e+02 2.67470371e+05 9.66400858e+01
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=20 || lCount=21 || fCount=11
# [7.00000000e+00 1.53820211e+02 3.62579914e+05 9.89692328e+01
#  7.00000000e+00 1.63437001e+02 3.79240369e+05 8.33044633e+01
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=21 || lCount=22 || fCount=11
# [7.00000000e+00 1.66742344e+02 1.81260751e+05 1.06686486e+02
#  7.00000000e+00 1.66939814e+02 2.68366792e+05 8.86314636e+01
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=22 || lCount=23 || fCount=11
# [7.00000000e+00 1.62495903e+02 3.49258991e+05 9.03064098e+01
#  7.00000000e+00 1.69922237e+02 3.17372615e+05 1.01617569e+02
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=23 || lCount=24 || fCount=11
# [7.00000000e+00 1.61069501e+02 2.68237266e+05 7.33247848e+01
#  7.00000000e+00 1.66327776e+02 3.29823572e+05 7.73548729e+01
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# iCount=0 || jCount=24 || lCount=25 || fCount=11
# [7.00000000e+00 1.56801034e+02 2.16108840e+05 9.03119669e+01
#  7.00000000e+00 1.66419610e+02 2.74075660e+05 9.15134329e+01
#  3.82517736e+00 1.56929855e+00 8.40000000e+00]
# PPG_data_info:./DataBase/Selected_PPG_wrist/210830_0.csv
# iCount=1 || jCount=0 || lCount=26 || fCount=11
# [6.00000000e+00 5.36622112e+01 1.20219822e+04 3.86968504e+00
#  6.00000000e+00 7.14115935e+01 3.69170680e+04 7.05572951e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=1 || lCount=27 || fCount=11
# [4.00000000e+00 5.68601351e+01 2.21110875e+03 6.76047459e+00
#  4.00000000e+00 7.50217028e+01 7.52117335e+03 1.33017721e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=2 || lCount=28 || fCount=11
# [7.00000000e+00 3.98799254e+01 5.39392214e+03 1.65279945e+00
#  5.00000000e+00 5.96249953e+01 2.00376580e+04 4.66805347e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=3 || lCount=29 || fCount=11
# [8.00000000e+00 4.62733001e+01 9.70010015e+02 1.99436675e+00
#  6.00000000e+00 6.48593713e+01 4.59385783e+03 9.17348134e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=4 || lCount=30 || fCount=11
# [9.00000000e+00 4.30171513e+01 4.53269586e+02 1.44548214e+00
#  7.00000000e+00 5.77469751e+01 1.84059958e+03 3.73371531e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=5 || lCount=31 || fCount=11
# [1.10000000e+01 3.91652777e+01 1.10397909e+02 6.93367343e-01
#  9.00000000e+00 5.05405968e+01 1.86595493e+03 1.60556123e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=6 || lCount=32 || fCount=11
# [7.00000000e+00 3.65622380e+01 5.23996227e+02 7.23637285e-01
#  7.00000000e+00 5.44938209e+01 2.37509861e+03 2.48402625e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=7 || lCount=33 || fCount=11
# [7.00000000e+00 4.29106682e+01 3.47425979e+02 1.56782149e+00
#  7.00000000e+00 6.47615141e+01 5.09205262e+03 6.13831554e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=8 || lCount=34 || fCount=11
# [7.00000000e+00 4.96083843e+01 1.55340224e+03 1.73390698e+00
#  7.00000000e+00 7.28182870e+01 9.40422508e+03 6.52668679e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=9 || lCount=35 || fCount=11
# [1.00000000e+01 5.23642562e+01 2.27729470e+03 1.71025087e+00
#  6.00000000e+00 7.07487109e+01 1.14073594e+04 6.46952243e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=10 || lCount=36 || fCount=11
# [1.10000000e+01 5.27519742e+01 4.48549404e+02 1.74530398e+00
#  7.00000000e+00 7.56919092e+01 8.84785581e+03 7.96458938e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=11 || lCount=37 || fCount=11
# [1.00000000e+01 5.03916361e+01 2.49908751e+03 1.53602041e+00
#  8.00000000e+00 7.39225591e+01 1.17602249e+04 5.98820247e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=12 || lCount=38 || fCount=11
# [6.00000000e+00 4.86840389e+01 4.64175802e+03 1.66677456e+00
#  6.00000000e+00 7.09336779e+01 2.25783180e+04 5.41057782e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=13 || lCount=39 || fCount=11
# [7.00000000e+00 5.22974244e+01 2.05916120e+03 1.76437438e+00
#  6.00000000e+00 7.50534446e+01 1.89150644e+04 6.40508584e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=14 || lCount=40 || fCount=11
# [8.00000000e+00 5.37169766e+01 1.21857257e+03 1.16513494e+00
#  6.00000000e+00 7.54197303e+01 1.14543069e+04 7.84904975e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=15 || lCount=41 || fCount=11
# [8.00000000e+00 5.41300516e+01 5.04148775e+03 1.16725707e+00
#  6.00000000e+00 7.23464861e+01 1.83716726e+04 6.11599491e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=16 || lCount=42 || fCount=11
# [6.00000000e+00 5.49527580e+01 2.99875882e+03 2.56728945e+00
#  6.00000000e+00 7.64256700e+01 1.28000106e+04 9.19181919e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=17 || lCount=43 || fCount=11
# [7.00000000e+00 4.82479728e+01 3.98817226e+02 1.63791415e+00
#  7.00000000e+00 6.90097213e+01 5.53895562e+03 5.78471798e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=18 || lCount=44 || fCount=11
# [6.00000000e+00 4.87580911e+01 1.63162589e+03 1.33762000e+00
#  6.00000000e+00 7.05295701e+01 1.09794344e+04 6.16267266e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=19 || lCount=45 || fCount=11
# [7.00000000e+00 5.52482139e+01 3.41261980e+03 2.23539030e+00
#  7.00000000e+00 8.06784014e+01 1.74539613e+04 9.19927671e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=20 || lCount=46 || fCount=11
# [1.10000000e+01 5.13498605e+01 9.73726639e+02 1.90535502e+00
#  7.00000000e+00 7.78892131e+01 9.51986332e+03 8.69431616e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=21 || lCount=47 || fCount=11
# [1.00000000e+01 4.86532523e+01 1.72263940e+03 1.64405575e+00
#  6.00000000e+00 6.98654784e+01 1.31615800e+04 7.36860032e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=22 || lCount=48 || fCount=11
# [7.00000000e+00 5.25053587e+01 1.22175931e+03 1.68934146e+00
#  7.00000000e+00 8.21765407e+01 8.53302431e+03 8.41217812e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=23 || lCount=49 || fCount=11
# [6.00000000e+00 4.96284877e+01 1.68822690e+03 1.48842298e+00
#  6.00000000e+00 7.97980989e+01 1.43846845e+04 9.75130850e+00
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=24 || lCount=50 || fCount=11
# [6.00000000e+00 5.70291953e+01 3.89229830e+03 2.71389664e+00
#  6.00000000e+00 8.48415621e+01 2.67601277e+04 1.11497125e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=25 || lCount=51 || fCount=11
# [7.00000000e+00 5.77924420e+01 4.74214394e+03 2.92942117e+00
#  7.00000000e+00 9.14179724e+01 2.29794885e+04 1.23870386e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=26 || lCount=52 || fCount=11
# [6.00000000e+00 5.62719403e+01 1.53131626e+03 2.65879994e+00
#  6.00000000e+00 8.32808643e+01 1.51879848e+04 1.08165517e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=27 || lCount=53 || fCount=11
# [7.00000000e+00 6.05271004e+01 9.90369224e+03 2.45445463e+00
#  7.00000000e+00 8.86557997e+01 4.31439283e+04 1.26564663e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=28 || lCount=54 || fCount=11
# [6.00000000e+00 6.32207845e+01 7.81505640e+03 3.45065824e+00
#  6.00000000e+00 9.02907627e+01 4.36728432e+04 1.51764851e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=29 || lCount=55 || fCount=11
# [6.00000000e+00 5.78469471e+01 2.35254381e+03 5.34546268e+00
#  6.00000000e+00 8.85064663e+01 2.38696034e+04 2.58375675e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=30 || lCount=56 || fCount=11
# [6.00000000e+00 5.22968838e+01 1.74535047e+03 2.58245101e+00
#  6.00000000e+00 8.21015657e+01 1.81072148e+04 1.21256514e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=31 || lCount=57 || fCount=11
# [7.00000000e+00 5.18055596e+01 4.45403434e+03 3.02333139e+00
#  7.00000000e+00 7.94483403e+01 2.07472641e+04 1.43516363e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=32 || lCount=58 || fCount=11
# [6.00000000e+00 5.52124001e+01 3.28110987e+03 3.46425860e+00
#  6.00000000e+00 8.14769479e+01 3.50997325e+04 1.69007515e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=33 || lCount=59 || fCount=11
# [7.00000000e+00 6.51847310e+01 1.55415973e+03 6.32637514e+00
#  7.00000000e+00 1.00549738e+02 1.59023391e+04 3.56023455e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=34 || lCount=60 || fCount=11
# [6.00000000e+00 6.15357177e+01 9.16157446e+03 4.94291567e+00
#  6.00000000e+00 9.34522697e+01 4.68869481e+04 2.44157374e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=35 || lCount=61 || fCount=11
# [7.00000000e+00 5.98220558e+01 4.62341686e+03 4.89065363e+00
#  6.00000000e+00 8.81823120e+01 4.28431384e+04 2.32066069e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=36 || lCount=62 || fCount=11
# [1.00000000e+01 5.66313770e+01 9.60818435e+02 2.37860904e+00
#  6.00000000e+00 8.69554717e+01 1.53724753e+04 1.75554816e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=37 || lCount=63 || fCount=11
# [8.00000000e+00 6.38988774e+01 6.47888244e+03 4.30680376e+00
#  6.00000000e+00 8.90602974e+01 3.18800275e+04 2.56609307e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=38 || lCount=64 || fCount=11
# [6.00000000e+00 7.02416069e+01 1.36234326e+04 4.25190978e+00
#  6.00000000e+00 9.90990114e+01 5.34042400e+04 2.18370063e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=39 || lCount=65 || fCount=11
# [6.00000000e+00 6.20451619e+01 3.86936212e+03 3.15221111e+00
#  6.00000000e+00 9.60389307e+01 3.36098916e+04 2.21746729e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=40 || lCount=66 || fCount=11
# [7.00000000e+00 6.15918038e+01 6.46611518e+03 3.81446051e+00
#  7.00000000e+00 9.91804733e+01 5.77628684e+04 2.82792113e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=41 || lCount=67 || fCount=11
# [6.00000000e+00 7.48397541e+01 1.58214215e+04 6.17310121e+00
#  6.00000000e+00 1.18212593e+02 9.25455068e+04 3.56989386e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=42 || lCount=68 || fCount=11
# [6.00000000e+00 7.76417365e+01 2.68644400e+04 8.82514122e+00
#  6.00000000e+00 1.23034580e+02 1.82147180e+05 5.05206162e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=43 || lCount=69 || fCount=11
# [6.00000000e+00 7.47913163e+01 9.04323453e+03 1.08929388e+01
#  6.00000000e+00 1.17883813e+02 8.12890482e+04 6.55680307e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=44 || lCount=70 || fCount=11
# [6.00000000e+00 6.77367802e+01 1.13680747e+04 7.21925311e+00
#  6.00000000e+00 1.01541009e+02 8.76493435e+04 4.48636328e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=45 || lCount=71 || fCount=11
# [6.00000000e+00 7.11767727e+01 1.49675140e+04 8.79181817e+00
#  6.00000000e+00 1.10976920e+02 8.45194611e+04 5.02779940e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=46 || lCount=72 || fCount=11
# [6.00000000e+00 6.60288217e+01 1.35407337e+04 5.77148469e+00
#  6.00000000e+00 1.08513243e+02 8.55987824e+04 3.77096185e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=47 || lCount=73 || fCount=11
# [6.00000000e+00 6.20460316e+01 5.90526823e+03 8.16550499e+00
#  6.00000000e+00 1.00257887e+02 5.61704745e+04 4.15557466e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=48 || lCount=74 || fCount=11
# [6.00000000e+00 6.60207371e+01 5.99516468e+03 5.27747099e+00
#  6.00000000e+00 1.07323057e+02 7.12927244e+04 4.30454584e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=49 || lCount=75 || fCount=11
# [6.00000000e+00 7.02986312e+01 8.62160331e+03 1.01268013e+01
#  6.00000000e+00 1.11083899e+02 8.07704997e+04 5.39027255e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=50 || lCount=76 || fCount=11
# [7.00000000e+00 7.49040875e+01 3.30467769e+04 9.36171522e+00
#  7.00000000e+00 1.16343692e+02 1.78858627e+05 5.06413659e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=51 || lCount=77 || fCount=11
# [6.00000000e+00 8.11922116e+01 1.81282054e+04 9.78877403e+00
#  6.00000000e+00 1.23144293e+02 1.18117906e+05 6.07837771e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=52 || lCount=78 || fCount=11
# [6.00000000e+00 7.38491806e+01 1.02530109e+04 7.56417016e+00
#  6.00000000e+00 1.16957058e+02 8.16341396e+04 6.80259145e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=53 || lCount=79 || fCount=11
# [6.00000000e+00 7.87528476e+01 1.62779105e+04 9.66889288e+00
#  6.00000000e+00 1.19467946e+02 9.77034152e+04 5.06661813e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=54 || lCount=80 || fCount=11
# [6.00000000e+00 7.59111338e+01 2.15384270e+04 9.87294046e+00
#  6.00000000e+00 1.19226960e+02 1.32958617e+05 5.23783930e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=55 || lCount=81 || fCount=11
# [7.00000000e+00 7.47798622e+01 1.60104485e+04 1.01631427e+01
#  7.00000000e+00 1.16617225e+02 1.39696503e+05 5.45648161e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=56 || lCount=82 || fCount=11
# [6.00000000e+00 7.58212908e+01 1.30429325e+04 9.10665159e+00
#  6.00000000e+00 1.22936321e+02 9.89215828e+04 6.20104283e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=57 || lCount=83 || fCount=11
# [6.00000000e+00 8.31845842e+01 2.71418346e+04 1.26987254e+01
#  6.00000000e+00 1.30665531e+02 1.51668234e+05 8.21779037e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=58 || lCount=84 || fCount=11
# [6.00000000e+00 8.54401102e+01 3.07243203e+04 1.23966811e+01
#  6.00000000e+00 1.32823190e+02 1.96779327e+05 7.48416900e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=59 || lCount=85 || fCount=11
# [6.00000000e+00 7.62937595e+01 1.04748430e+04 1.10355365e+01
#  6.00000000e+00 1.21463671e+02 7.72902192e+04 6.84318077e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=60 || lCount=86 || fCount=11
# [6.00000000e+00 7.79655244e+01 2.91773764e+04 9.57568832e+00
#  6.00000000e+00 1.24469817e+02 1.93169661e+05 5.64006824e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=61 || lCount=87 || fCount=11
# [7.00000000e+00 8.47067667e+01 1.52083353e+04 1.46242746e+01
#  7.00000000e+00 1.37854086e+02 9.86645823e+04 1.10946194e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=62 || lCount=88 || fCount=11
# [6.00000000e+00 7.59926071e+01 7.90131804e+03 1.34127879e+01
#  6.00000000e+00 1.26951009e+02 7.35865811e+04 8.52971053e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=63 || lCount=89 || fCount=11
# [7.00000000e+00 7.59638587e+01 1.81504130e+04 1.18652826e+01
#  7.00000000e+00 1.23256384e+02 1.44099291e+05 6.74597032e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=64 || lCount=90 || fCount=11
# [6.00000000e+00 8.42515118e+01 2.37580262e+04 1.88193231e+01
#  6.00000000e+00 1.34408369e+02 1.29273367e+05 9.78733753e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=65 || lCount=91 || fCount=11
# [7.00000000e+00 8.50029977e+01 2.20361070e+04 1.98480909e+01
#  7.00000000e+00 1.36578114e+02 1.46347345e+05 1.05491961e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=66 || lCount=92 || fCount=11
# [6.00000000e+00 8.23767215e+01 6.60286530e+03 1.30413695e+01
#  6.00000000e+00 1.29483860e+02 5.56651919e+04 9.39062414e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=67 || lCount=93 || fCount=11
# [7.00000000e+00 7.74674052e+01 2.57069081e+04 8.26305032e+00
#  7.00000000e+00 1.17202645e+02 1.08350415e+05 4.07418391e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=68 || lCount=94 || fCount=11
# [6.00000000e+00 8.51126197e+01 8.25199679e+03 1.58540927e+01
#  6.00000000e+00 1.24388473e+02 5.09890392e+04 6.72963725e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=69 || lCount=95 || fCount=11
# [7.00000000e+00 8.82641959e+01 1.51514488e+04 1.73645391e+01
#  7.00000000e+00 1.36931832e+02 1.32693608e+05 9.16421677e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=70 || lCount=96 || fCount=11
# [8.00000000e+00 9.08822930e+01 3.40923911e+04 1.86902824e+01
#  6.00000000e+00 1.41361934e+02 1.83212664e+05 9.67941121e+01
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=71 || lCount=97 || fCount=11
# [6.00000000e+00 8.95274154e+01 5.18810761e+04 2.04937910e+01
#  6.00000000e+00 1.35775523e+02 2.72944132e+05 1.05753139e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=72 || lCount=98 || fCount=11
# [6.00000000e+00 9.01938175e+01 2.19763720e+04 2.43970739e+01
#  6.00000000e+00 1.38573855e+02 1.74677356e+05 1.27937042e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=73 || lCount=99 || fCount=11
# [6.00000000e+00 8.64577718e+01 1.37958534e+04 2.50916218e+01
#  6.00000000e+00 1.33014318e+02 1.27921513e+05 1.51166627e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=74 || lCount=100 || fCount=11
# [6.00000000e+00 9.53542096e+01 5.45925394e+04 2.65844371e+01
#  6.00000000e+00 1.47398163e+02 3.09621021e+05 1.51078866e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=75 || lCount=101 || fCount=11
# [6.00000000e+00 9.51640126e+01 5.02363388e+04 2.33694445e+01
#  6.00000000e+00 1.45228517e+02 2.77130921e+05 1.20174462e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=76 || lCount=102 || fCount=11
# [6.00000000e+00 9.05591756e+01 3.60225737e+04 2.70416129e+01
#  7.00000000e+00 1.39490555e+02 2.38849838e+05 1.34005035e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=77 || lCount=103 || fCount=11
# [6.00000000e+00 9.14535594e+01 3.02843782e+04 2.56219878e+01
#  6.00000000e+00 1.46783817e+02 2.32419965e+05 1.38492691e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=78 || lCount=104 || fCount=11
# [6.00000000e+00 9.39691110e+01 4.06171009e+04 2.90297967e+01
#  6.00000000e+00 1.47600086e+02 2.39869529e+05 1.63879119e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=79 || lCount=105 || fCount=11
# [6.00000000e+00 9.96110405e+01 4.33832836e+04 3.31201595e+01
#  6.00000000e+00 1.53570259e+02 2.37790104e+05 1.86802933e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=80 || lCount=106 || fCount=11
# [6.00000000e+00 9.04922609e+01 4.38751972e+04 2.48408436e+01
#  6.00000000e+00 1.43155071e+02 2.99733958e+05 1.50737913e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=81 || lCount=107 || fCount=11
# [6.00000000e+00 9.12811123e+01 3.42232674e+04 2.44312076e+01
#  7.00000000e+00 1.47874017e+02 2.49585126e+05 1.54989213e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=82 || lCount=108 || fCount=11
# [6.00000000e+00 1.03141154e+02 6.70085852e+04 2.89593707e+01
#  6.00000000e+00 1.62340201e+02 3.91400815e+05 1.68533583e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=83 || lCount=109 || fCount=11
# [6.00000000e+00 1.03294076e+02 6.02803496e+04 4.23042523e+01
#  6.00000000e+00 1.62361013e+02 3.39675114e+05 2.84624142e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=84 || lCount=110 || fCount=11
# [6.00000000e+00 1.03622378e+02 3.26422640e+04 5.33303868e+01
#  6.00000000e+00 1.62613432e+02 2.59969613e+05 2.57175003e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=85 || lCount=111 || fCount=11
# [6.00000000e+00 1.00493190e+02 5.92578345e+04 3.38918006e+01
#  6.00000000e+00 1.55361129e+02 3.65534859e+05 1.77691460e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=86 || lCount=112 || fCount=11
# [6.00000000e+00 1.05846430e+02 7.64911856e+04 3.69354212e+01
#  6.00000000e+00 1.55935688e+02 4.06075406e+05 1.82740725e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=87 || lCount=113 || fCount=11
# [6.00000000e+00 1.03442908e+02 4.97528579e+04 3.43020595e+01
#  6.00000000e+00 1.63695570e+02 2.82270411e+05 2.00330008e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=88 || lCount=114 || fCount=11
# [6.00000000e+00 9.89898882e+01 4.54023527e+04 4.78733192e+01
#  6.00000000e+00 1.57299417e+02 3.64812475e+05 2.46774231e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=89 || lCount=115 || fCount=11
# [6.00000000e+00 1.05356288e+02 3.97039415e+04 4.48840516e+01
#  6.00000000e+00 1.70716965e+02 3.18301751e+05 3.59781422e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=90 || lCount=116 || fCount=11
# [6.00000000e+00 1.08540177e+02 7.28677129e+04 3.55489069e+01
#  6.00000000e+00 1.61774715e+02 4.08542791e+05 2.27449545e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=91 || lCount=117 || fCount=11
# [5.00000000e+00 1.05409002e+02 1.12914832e+05 3.38413094e+01
#  6.00000000e+00 1.55575699e+02 5.08832654e+05 2.21874930e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=92 || lCount=118 || fCount=11
# [6.00000000e+00 1.11242364e+02 6.14257366e+04 3.74909104e+01
#  6.00000000e+00 1.63010248e+02 3.87035543e+05 2.17455324e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# iCount=1 || jCount=93 || lCount=119 || fCount=11
# [6.00000000e+00 1.06310420e+02 4.70256543e+04 4.63723849e+01
#  6.00000000e+00 1.66415443e+02 3.17708656e+05 2.49184443e+02
#  3.46759814e+00 1.29776067e+00 5.40000000e+00]
# PPG_data_info:./DataBase/Selected_PPG_wrist/210927_0.csv
# iCount=2 || jCount=0 || lCount=120 || fCount=11
# [1.10000000e+01 6.83467371e+01 1.08422612e+03 4.39506632e+00
#  1.10000000e+01 9.83106175e+01 7.90890426e+03 1.47652844e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=1 || lCount=121 || fCount=11
# [1.30000000e+01 7.55110735e+01 6.25628990e+02 4.98448440e+00
#  1.20000000e+01 1.13288980e+02 7.14841395e+03 4.83718638e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=2 || lCount=122 || fCount=11
# [1.40000000e+01 1.04019294e+02 4.42348591e+03 1.66496997e+01
#  1.20000000e+01 1.76443322e+02 5.53104775e+04 1.32319190e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=3 || lCount=123 || fCount=11
# [1.10000000e+01 1.52350390e+02 4.04430300e+04 9.68716555e+01
#  1.10000000e+01 2.47901690e+02 2.25981969e+05 4.14581843e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=4 || lCount=124 || fCount=11
# [1.20000000e+01 1.27093435e+02 1.19484472e+04 1.08387240e+02
#  1.10000000e+01 2.40353315e+02 1.70847268e+05 3.92389460e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=5 || lCount=125 || fCount=11
# [1.20000000e+01 9.78764833e+01 1.58260123e+03 1.98850723e+01
#  1.20000000e+01 2.28256579e+02 1.30011333e+05 1.80191639e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=6 || lCount=126 || fCount=11
# [1.40000000e+01 8.42051526e+01 7.12986238e+03 1.24388513e+01
#  1.20000000e+01 2.31671965e+02 2.14060706e+05 1.81512257e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=7 || lCount=127 || fCount=11
# [1.60000000e+01 7.82655360e+01 5.40787594e+02 8.54455468e+00
#  1.20000000e+01 2.36278910e+02 1.47917260e+05 1.89905799e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=8 || lCount=128 || fCount=11
# [1.40000000e+01 6.65114370e+01 3.15556537e+02 2.79999770e+00
#  1.10000000e+01 2.20439994e+02 1.36575834e+05 1.81036078e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=9 || lCount=129 || fCount=11
# [1.30000000e+01 1.04840643e+02 1.92060881e+03 2.01515758e+01
#  1.10000000e+01 2.25450112e+02 1.06754261e+05 1.70181560e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=10 || lCount=130 || fCount=11
# [1.10000000e+01 1.39822451e+02 3.23449265e+04 3.98398038e+01
#  1.10000000e+01 2.32869702e+02 1.70655193e+05 1.68636496e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=11 || lCount=131 || fCount=11
# [1.10000000e+01 1.80298404e+02 7.19304409e+04 8.10282272e+01
#  1.10000000e+01 2.53085690e+02 2.94369871e+05 2.24845656e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=12 || lCount=132 || fCount=11
# [1.10000000e+01 1.99534398e+02 7.42166924e+04 1.11447784e+02
#  1.10000000e+01 2.72540518e+02 2.54188436e+05 3.07445299e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=13 || lCount=133 || fCount=11
# [1.10000000e+01 1.93649706e+02 9.23798304e+04 9.04337299e+01
#  1.20000000e+01 2.47517291e+02 2.87906390e+05 2.69096300e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=14 || lCount=134 || fCount=11
# [1.20000000e+01 1.99828891e+02 6.61250850e+04 1.09351953e+02
#  1.20000000e+01 2.51520013e+02 1.37224767e+05 2.78696275e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=15 || lCount=135 || fCount=11
# [1.10000000e+01 1.99002165e+02 7.65537606e+04 1.00992090e+02
#  1.10000000e+01 2.61989904e+02 2.54450308e+05 2.73935678e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=16 || lCount=136 || fCount=11
# [1.20000000e+01 2.00781633e+02 8.54302769e+04 1.13668884e+02
#  1.20000000e+01 3.02257069e+02 4.76102831e+05 3.64664456e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=17 || lCount=137 || fCount=11
# [1.10000000e+01 1.87835176e+02 7.09990337e+04 8.87713665e+01
#  1.10000000e+01 2.93695431e+02 4.31360539e+05 4.26505446e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=18 || lCount=138 || fCount=11
# [1.20000000e+01 1.68856349e+02 3.88098245e+04 8.32197441e+01
#  1.20000000e+01 2.79687973e+02 3.02598118e+05 4.14186869e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=19 || lCount=139 || fCount=11
# [1.10000000e+01 1.65783277e+02 2.59939453e+04 8.17042956e+01
#  1.10000000e+01 2.73240228e+02 2.40174264e+05 3.43621030e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=20 || lCount=140 || fCount=11
# [1.20000000e+01 1.48256313e+02 2.83455721e+04 4.47644608e+01
#  1.10000000e+01 2.26011755e+02 2.53376644e+05 2.13012241e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=21 || lCount=141 || fCount=11
# [1.10000000e+01 1.67222435e+02 3.12968714e+04 9.87538886e+01
#  1.10000000e+01 2.30005730e+02 7.62413775e+04 3.30413454e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=22 || lCount=142 || fCount=11
# [1.00000000e+01 1.82079815e+02 8.79946309e+04 8.41041388e+01
#  1.00000000e+01 2.30404471e+02 3.19107346e+05 2.38509372e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=23 || lCount=143 || fCount=11
# [1.10000000e+01 1.82959134e+02 7.92963118e+04 7.84645148e+01
#  1.10000000e+01 2.54069448e+02 3.51272752e+05 2.15649439e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=24 || lCount=144 || fCount=11
# [1.10000000e+01 2.03205785e+02 6.93712495e+04 1.20634472e+02
#  1.10000000e+01 2.57485662e+02 2.30649040e+05 2.27622578e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=25 || lCount=145 || fCount=11
# [1.20000000e+01 2.06497351e+02 2.01289189e+05 1.22920284e+02
#  1.10000000e+01 2.43165455e+02 2.39921463e+05 2.25320090e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=26 || lCount=146 || fCount=11
# [1.10000000e+01 2.18471698e+02 8.41361662e+04 1.84549564e+02
#  1.10000000e+01 2.39430840e+02 1.43858793e+05 2.00647627e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=27 || lCount=147 || fCount=11
# [1.10000000e+01 1.94742366e+02 6.20483496e+04 1.39441284e+02
#  1.10000000e+01 2.17922912e+02 1.41162122e+05 1.66138170e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=28 || lCount=148 || fCount=11
# [1.20000000e+01 1.96484211e+02 4.31992947e+04 1.13401646e+02
#  1.10000000e+01 2.08425099e+02 8.08292817e+04 1.40644048e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=29 || lCount=149 || fCount=11
# [1.20000000e+01 2.15700137e+02 1.25681476e+05 1.31579594e+02
#  1.20000000e+01 2.25233621e+02 1.25144528e+05 1.85353572e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=30 || lCount=150 || fCount=11
# [1.10000000e+01 1.98784674e+02 8.55202922e+04 1.27355640e+02
#  1.10000000e+01 2.48198603e+02 1.83498155e+05 2.35233905e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=31 || lCount=151 || fCount=11
# [1.20000000e+01 1.74015588e+02 2.35383986e+04 1.01191789e+02
#  1.20000000e+01 2.73448028e+02 3.67673545e+05 3.63194307e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=32 || lCount=152 || fCount=11
# [1.10000000e+01 1.67070388e+02 3.98897176e+04 6.70955605e+01
#  1.10000000e+01 2.81053850e+02 3.10087450e+05 3.99418392e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=33 || lCount=153 || fCount=11
# [1.20000000e+01 2.26325972e+02 1.18662551e+05 2.41376111e+02
#  1.20000000e+01 3.47853883e+02 5.57037130e+05 1.31752998e+03
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=34 || lCount=154 || fCount=11
# [1.10000000e+01 2.27104724e+02 2.49571492e+05 2.32226973e+02
#  1.10000000e+01 3.54155315e+02 1.66924626e+06 1.32689366e+03
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=35 || lCount=155 || fCount=11
# [1.20000000e+01 2.21029747e+02 6.70140230e+04 2.77969126e+02
#  1.20000000e+01 3.54579140e+02 6.45710763e+05 1.55182786e+03
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=36 || lCount=156 || fCount=11
# [1.30000000e+01 1.61894834e+02 5.00932332e+04 1.28846334e+02
#  1.10000000e+01 2.53014427e+02 2.69867487e+05 6.99741543e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=37 || lCount=157 || fCount=11
# [1.20000000e+01 1.14660575e+02 4.62509903e+03 1.38463612e+01
#  1.20000000e+01 1.86227792e+02 5.65026360e+04 1.56602355e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=38 || lCount=158 || fCount=11
# [1.10000000e+01 1.36175108e+02 1.25238035e+04 4.88968640e+01
#  1.10000000e+01 1.69615255e+02 4.81978286e+04 1.06315595e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=39 || lCount=159 || fCount=11
# [1.10000000e+01 1.75019035e+02 5.30919222e+04 7.12489500e+01
#  1.10000000e+01 1.71552444e+02 4.34976790e+04 9.98493635e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=40 || lCount=160 || fCount=11
# [1.20000000e+01 1.89571398e+02 8.31383735e+04 9.46053625e+01
#  1.10000000e+01 2.05683756e+02 6.04452010e+04 2.30832240e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=41 || lCount=161 || fCount=11
# [1.10000000e+01 1.74699087e+02 3.31447349e+04 1.15649729e+02
#  1.10000000e+01 2.21591794e+02 1.90204449e+05 3.16648992e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=42 || lCount=162 || fCount=11
# [1.20000000e+01 1.59285885e+02 1.89419247e+04 7.60573013e+01
#  1.10000000e+01 2.60741483e+02 2.25543873e+05 3.77500081e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=43 || lCount=163 || fCount=11
# [1.10000000e+01 1.93262331e+02 9.73449477e+04 1.49571920e+02
#  1.10000000e+01 2.94608582e+02 5.28325894e+05 6.73055997e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=44 || lCount=164 || fCount=11
# [1.20000000e+01 1.90815149e+02 1.02529830e+05 1.50947472e+02
#  1.10000000e+01 3.01012275e+02 6.32789347e+05 7.60605178e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=45 || lCount=165 || fCount=11
# [1.00000000e+01 1.83925363e+02 2.62544144e+04 1.81016940e+02
#  1.00000000e+01 2.87948290e+02 2.39413414e+05 9.60233597e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=46 || lCount=166 || fCount=11
# [4.00000000e+00 1.58915182e+02 1.71218314e+05 1.38842101e+02
#  9.00000000e+00 2.34925327e+02 4.89466486e+05 6.30733409e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=47 || lCount=167 || fCount=11
# [1.10000000e+01 1.70728130e+02 4.88416409e+04 1.35353822e+02
#  1.30000000e+01 2.38907265e+02 1.42851154e+05 3.87821529e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=48 || lCount=168 || fCount=11
# [1.10000000e+01 1.47175724e+02 2.77791015e+04 4.81325866e+01
#  1.10000000e+01 2.09232557e+02 1.11256986e+05 1.21153572e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=49 || lCount=169 || fCount=11
# [1.10000000e+01 1.41665288e+02 2.86410991e+04 4.07529481e+01
#  1.20000000e+01 2.12185032e+02 1.39012844e+05 1.75176345e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=50 || lCount=170 || fCount=11
# [1.10000000e+01 1.37720241e+02 1.72209491e+04 5.46251197e+01
#  1.10000000e+01 1.93529633e+02 9.20272875e+04 2.62801666e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=51 || lCount=171 || fCount=11
# [1.40000000e+01 1.11663227e+02 4.64598460e+03 1.43015175e+01
#  1.00000000e+01 1.43484837e+02 1.68891988e+04 7.75451047e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=52 || lCount=172 || fCount=11
# [9.00000000e+00 1.37957899e+02 8.57246900e+03 1.24885905e+02
#  9.00000000e+00 1.79473342e+02 4.18354574e+04 2.74596345e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=53 || lCount=173 || fCount=11
# [1.20000000e+01 1.48446614e+02 7.52346219e+04 8.65110794e+01
#  1.20000000e+01 2.31298134e+02 2.78195113e+05 3.05530043e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=54 || lCount=174 || fCount=11
# [1.10000000e+01 1.73938872e+02 2.97776806e+04 1.94683664e+02
#  1.10000000e+01 2.67387296e+02 2.45079330e+05 5.63622377e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=55 || lCount=175 || fCount=11
# [1.20000000e+01 1.91887004e+02 8.87196854e+04 1.49513051e+02
#  1.20000000e+01 2.79054531e+02 3.80251655e+05 4.89528232e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=56 || lCount=176 || fCount=11
# [1.10000000e+01 2.38584148e+02 2.05680293e+05 1.68941476e+02
#  1.10000000e+01 3.28659140e+02 7.91163060e+05 5.64982298e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=57 || lCount=177 || fCount=11
# [1.10000000e+01 2.26321572e+02 1.47285699e+05 2.08090588e+02
#  1.10000000e+01 3.00671418e+02 5.36160267e+05 7.41331258e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=58 || lCount=178 || fCount=11
# [1.10000000e+01 1.75525603e+02 3.90896377e+04 7.57900725e+01
#  1.10000000e+01 2.27440037e+02 9.04193534e+04 2.33747869e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=59 || lCount=179 || fCount=11
# [1.00000000e+01 1.21062157e+02 1.76326680e+04 2.54139708e+01
#  1.10000000e+01 1.71189311e+02 7.62772013e+04 8.88425632e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=60 || lCount=180 || fCount=11
# [1.10000000e+01 9.50550002e+01 1.55860500e+03 2.32850901e+01
#  1.10000000e+01 1.62233995e+02 2.89943220e+04 6.30998574e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=61 || lCount=181 || fCount=11
# [1.10000000e+01 8.64574154e+01 4.46112696e+02 2.92969527e+01
#  1.10000000e+01 1.73503318e+02 3.55350362e+04 1.53784559e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=62 || lCount=182 || fCount=11
# [1.00000000e+01 1.13915209e+02 1.61746156e+04 3.49040556e+01
#  1.10000000e+01 2.10843870e+02 1.91528730e+05 2.25821051e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=63 || lCount=183 || fCount=11
# [1.10000000e+01 1.49902195e+02 2.72971293e+04 4.06798479e+01
#  1.10000000e+01 2.13873642e+02 1.63285938e+05 2.09572554e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=64 || lCount=184 || fCount=11
# [1.10000000e+01 1.45942001e+02 4.73764350e+04 1.22190421e+02
#  1.10000000e+01 1.95727445e+02 1.27347134e+05 1.98953940e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=65 || lCount=185 || fCount=11
# [4.00000000e+00 1.10306293e+02 3.25049763e+04 1.22450827e+02
#  5.00000000e+00 1.40799574e+02 1.98843179e+05 1.76918094e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=66 || lCount=186 || fCount=11
# [1.20000000e+01 8.22033335e+01 1.22152035e+03 8.65369758e+00
#  7.00000000e+00 9.34178113e+01 7.87427726e+03 4.01515792e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=67 || lCount=187 || fCount=11
# [6.00000000e+00 1.32894751e+02 1.94755354e+04 1.61536036e+02
#  6.00000000e+00 1.53178317e+02 6.67158942e+04 5.94581180e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=68 || lCount=188 || fCount=11
# [4.00000000e+00 1.65872927e+02 4.60437816e+06 4.50144700e+02
#  4.00000000e+00 2.00680707e+02 1.47533901e+07 1.43115329e+03
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=69 || lCount=189 || fCount=11
# [4.00000000e+00 1.60617200e+02 2.90621552e+06 4.95832402e+02
#  2.00000000e+00 2.01894578e+02 9.52755685e+06 1.58086150e+03
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=70 || lCount=190 || fCount=11
# [8.00000000e+00 1.12436547e+02 8.18316382e+04 6.29433391e+02
#  4.00000000e+00 1.39263844e+02 3.22026239e+05 1.76362442e+03
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=71 || lCount=191 || fCount=11
# [1.00000000e+01 8.38301871e+01 5.54465485e+03 2.41597442e+01
#  8.00000000e+00 9.84389779e+01 2.41646472e+04 8.27505531e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=72 || lCount=192 || fCount=11
# [1.30000000e+01 8.25844027e+01 3.08480329e+03 8.72709801e+00
#  8.00000000e+00 8.37610966e+01 5.11600222e+03 3.54409753e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=73 || lCount=193 || fCount=11
# [1.60000000e+01 7.71524986e+01 1.30826828e+03 6.12520201e+00
#  8.00000000e+00 6.34323482e+01 7.75008097e+02 2.80505207e+00
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=74 || lCount=194 || fCount=11
# [1.30000000e+01 7.45743984e+01 1.43374066e+03 5.59572364e+00
#  1.30000000e+01 6.90208760e+01 7.13304251e+02 3.12537233e+00
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=75 || lCount=195 || fCount=11
# [1.10000000e+01 8.53871475e+01 1.45689662e+03 1.12915331e+01
#  1.20000000e+01 8.99299947e+01 6.39047371e+02 1.07583287e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=76 || lCount=196 || fCount=11
# [1.10000000e+01 8.27003053e+01 1.27015778e+03 6.82292978e+00
#  1.10000000e+01 1.05738321e+02 2.58899042e+03 1.38791155e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=77 || lCount=197 || fCount=11
# [1.20000000e+01 7.76095260e+01 1.59735612e+03 5.44991226e+00
#  1.10000000e+01 1.09155673e+02 7.20882947e+03 1.92775930e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=78 || lCount=198 || fCount=11
# [1.10000000e+01 7.63630904e+01 2.17828730e+03 4.55035438e+00
#  1.10000000e+01 1.20493186e+02 1.32326739e+04 2.82413510e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=79 || lCount=199 || fCount=11
# [1.10000000e+01 8.12403584e+01 1.92987583e+03 5.95653253e+00
#  1.00000000e+01 1.12349577e+02 1.46071220e+04 2.09633727e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=80 || lCount=200 || fCount=11
# [1.30000000e+01 8.34669061e+01 2.78501785e+03 5.11273020e+00
#  1.10000000e+01 1.00202688e+02 5.26351870e+03 1.73274242e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=81 || lCount=201 || fCount=11
# [1.30000000e+01 8.72874830e+01 8.88292669e+02 8.11966321e+00
#  1.30000000e+01 1.04794444e+02 4.80594528e+03 1.30462679e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=82 || lCount=202 || fCount=11
# [1.20000000e+01 7.63182675e+01 1.23247304e+03 3.29161475e+00
#  1.10000000e+01 9.70296758e+01 5.50431405e+03 8.72439929e+00
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=83 || lCount=203 || fCount=11
# [1.10000000e+01 9.93665875e+01 5.46168040e+03 2.47095560e+01
#  9.00000000e+00 1.21449886e+02 1.78027544e+04 5.26217237e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=84 || lCount=204 || fCount=11
# [1.10000000e+01 1.39559467e+02 3.95721389e+04 7.18329953e+01
#  9.00000000e+00 1.87899105e+02 1.15271412e+05 2.27300730e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=85 || lCount=205 || fCount=11
# [1.00000000e+01 1.39175729e+02 5.40286619e+04 7.79370793e+01
#  1.00000000e+01 2.25704626e+02 1.88302313e+05 2.76507948e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=86 || lCount=206 || fCount=11
# [1.10000000e+01 1.25972871e+02 8.01680919e+03 5.70175046e+01
#  1.10000000e+01 1.99691918e+02 1.56546495e+05 2.52556506e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=87 || lCount=207 || fCount=11
# [1.10000000e+01 1.31447634e+02 3.16071787e+04 3.71970853e+01
#  1.00000000e+01 2.01907261e+02 7.20174093e+04 2.21201891e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=88 || lCount=208 || fCount=11
# [1.10000000e+01 1.47265610e+02 4.39301664e+04 3.95227651e+01
#  1.10000000e+01 1.75764379e+02 1.22114994e+05 7.21726961e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=89 || lCount=209 || fCount=11
# [1.10000000e+01 1.53522972e+02 1.79561083e+04 7.04081394e+01
#  1.10000000e+01 1.96608307e+02 9.08319561e+04 1.01998807e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=90 || lCount=210 || fCount=11
# [1.10000000e+01 1.48212037e+02 5.14808336e+04 8.49040793e+01
#  1.10000000e+01 1.73888398e+02 1.08900886e+05 9.12280231e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=91 || lCount=211 || fCount=11
# [1.10000000e+01 1.68585160e+02 3.33691079e+04 8.42395292e+01
#  1.00000000e+01 1.67670666e+02 2.72427000e+04 8.06298912e+01
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=92 || lCount=212 || fCount=11
# [1.10000000e+01 1.64168428e+02 5.94982227e+04 5.67669306e+01
#  1.10000000e+01 1.92473072e+02 1.43061664e+05 2.66151595e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=93 || lCount=213 || fCount=11
# [1.60000000e+01 1.31423001e+02 2.29984258e+04 5.80853748e+01
#  1.10000000e+01 1.98225216e+02 1.58322735e+05 2.66188333e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=94 || lCount=214 || fCount=11
# [1.60000000e+01 1.15690786e+02 1.48307851e+03 3.76808286e+01
#  1.10000000e+01 1.90032805e+02 4.16937442e+04 2.73837285e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=95 || lCount=215 || fCount=11
# [1.10000000e+01 1.47582989e+02 4.56585178e+04 8.21440596e+01
#  1.10000000e+01 2.38685926e+02 2.32738748e+05 4.46133102e+02
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# iCount=2 || jCount=96 || lCount=216 || fCount=11
# [1.10000000e+01 2.11040980e+02 1.91913144e+05 1.19691198e+02
#  1.10000000e+01 3.52547748e+02 9.94431361e+05 1.30228370e+03
#  1.62557644e+00 1.09338065e+00 7.60000000e+00]
# PPG_data_info:./DataBase/Selected_PPG_wrist/210927_1.csv
# iCount=3 || jCount=0 || lCount=217 || fCount=11
# [9.00000000e+00 1.32110396e+02 2.24300414e+04 4.32210312e+01
#  9.00000000e+00 1.92511833e+02 1.43685485e+05 1.85453919e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=1 || lCount=218 || fCount=11
# [9.00000000e+00 1.30469482e+02 2.64247300e+04 7.22637712e+01
#  9.00000000e+00 2.26218839e+02 3.02832746e+05 3.91351546e+02
#  2.28329723e+00 1.08149380e+00 5.50000000e+00]
# iCount=3 || jCount=2 || lCount=219 || fCount=11
# [9.00000000e+00 1.24281128e+02 1.59268344e+04 4.19040021e+01
#  9.00000000e+00 2.42202127e+02 3.71451563e+05 3.55256458e+02
# ...
# 707:	learn: 0.0164297	total: 1.75s	remaining: 721ms
# 708:	learn: 0.0164050	total: 1.75s	remaining: 719ms
# 709:	learn: 0.0163848	total: 1.75s	remaining: 716ms
# 710:	learn: 0.0163618	total: 1.76s	remaining: 714ms
# 711:	learn: 0.0163443	total: 1.76s	remaining: 712ms
# 712:	learn: 0.0163282	total: 1.76s	remaining: 709ms
# 713:	learn: 0.0163022	total: 1.76s	remaining: 707ms
# 714:	learn: 0.0162822	total: 1.77s	remaining: 704ms
# 715:	learn: 0.0162731	total: 1.77s	remaining: 702ms
# 716:	learn: 0.0162549	total: 1.77s	remaining: 699ms
# 717:	learn: 0.0162451	total: 1.77s	remaining: 697ms
# 718:	learn: 0.0162096	total: 1.78s	remaining: 694ms
# 719:	learn: 0.0161965	total: 1.78s	remaining: 692ms
# 720:	learn: 0.0161670	total: 1.78s	remaining: 689ms
# 721:	learn: 0.0161592	total: 1.78s	remaining: 687ms
# 722:	learn: 0.0161580	total: 1.78s	remaining: 684ms
# 723:	learn: 0.0161437	total: 1.79s	remaining: 682ms
# 724:	learn: 0.0161231	total: 1.79s	remaining: 679ms
# 725:	learn: 0.0161043	total: 1.79s	remaining: 677ms
# 726:	learn: 0.0160888	total: 1.79s	remaining: 674ms
# 727:	learn: 0.0160664	total: 1.8s	remaining: 672ms
# 728:	learn: 0.0160445	total: 1.8s	remaining: 669ms
# 729:	learn: 0.0160265	total: 1.8s	remaining: 667ms
# 730:	learn: 0.0160061	total: 1.8s	remaining: 664ms
# 731:	learn: 0.0159879	total: 1.81s	remaining: 662ms
# 732:	learn: 0.0159550	total: 1.81s	remaining: 659ms
# 733:	learn: 0.0159403	total: 1.81s	remaining: 657ms
# 734:	learn: 0.0159071	total: 1.81s	remaining: 654ms
# 735:	learn: 0.0158844	total: 1.82s	remaining: 652ms
# 736:	learn: 0.0158691	total: 1.82s	remaining: 649ms
# 737:	learn: 0.0158465	total: 1.82s	remaining: 647ms
# 738:	learn: 0.0158303	total: 1.82s	remaining: 644ms
# 739:	learn: 0.0158198	total: 1.83s	remaining: 642ms
# 740:	learn: 0.0158129	total: 1.83s	remaining: 640ms
# 741:	learn: 0.0157997	total: 1.83s	remaining: 637ms
# 742:	learn: 0.0157743	total: 1.83s	remaining: 635ms
# 743:	learn: 0.0157568	total: 1.84s	remaining: 632ms
# 744:	learn: 0.0157403	total: 1.84s	remaining: 630ms
# 745:	learn: 0.0157197	total: 1.84s	remaining: 627ms
# 746:	learn: 0.0156920	total: 1.84s	remaining: 625ms
# 747:	learn: 0.0156848	total: 1.85s	remaining: 622ms
# 748:	learn: 0.0156666	total: 1.85s	remaining: 620ms
# 749:	learn: 0.0156470	total: 1.85s	remaining: 617ms
# 750:	learn: 0.0156222	total: 1.85s	remaining: 615ms
# 751:	learn: 0.0155929	total: 1.86s	remaining: 612ms
# 752:	learn: 0.0155873	total: 1.86s	remaining: 610ms
# 753:	learn: 0.0155786	total: 1.86s	remaining: 607ms
# 754:	learn: 0.0155398	total: 1.86s	remaining: 605ms
# 755:	learn: 0.0155311	total: 1.86s	remaining: 602ms
# 756:	learn: 0.0155276	total: 1.87s	remaining: 600ms
# 757:	learn: 0.0155134	total: 1.87s	remaining: 597ms
# 758:	learn: 0.0155016	total: 1.87s	remaining: 595ms
# 759:	learn: 0.0154808	total: 1.88s	remaining: 592ms
# 760:	learn: 0.0154611	total: 1.88s	remaining: 590ms
# 761:	learn: 0.0154477	total: 1.88s	remaining: 587ms
# 762:	learn: 0.0154329	total: 1.88s	remaining: 585ms
# 763:	learn: 0.0154123	total: 1.89s	remaining: 582ms
# 764:	learn: 0.0153996	total: 1.89s	remaining: 580ms
# 765:	learn: 0.0153873	total: 1.89s	remaining: 577ms
# 766:	learn: 0.0153630	total: 1.89s	remaining: 575ms
# 767:	learn: 0.0153413	total: 1.9s	remaining: 573ms
# 768:	learn: 0.0153242	total: 1.9s	remaining: 570ms
# 769:	learn: 0.0153034	total: 1.9s	remaining: 568ms
# 770:	learn: 0.0152881	total: 1.9s	remaining: 565ms
# 771:	learn: 0.0152777	total: 1.91s	remaining: 563ms
# 772:	learn: 0.0152583	total: 1.91s	remaining: 560ms
# 773:	learn: 0.0152371	total: 1.91s	remaining: 558ms
# 774:	learn: 0.0152288	total: 1.91s	remaining: 555ms
# 775:	learn: 0.0151922	total: 1.92s	remaining: 553ms
# 776:	learn: 0.0151767	total: 1.92s	remaining: 550ms
# 777:	learn: 0.0151659	total: 1.92s	remaining: 548ms
# 778:	learn: 0.0151441	total: 1.92s	remaining: 545ms
# 779:	learn: 0.0151353	total: 1.92s	remaining: 543ms
# 780:	learn: 0.0151281	total: 1.93s	remaining: 540ms
# 781:	learn: 0.0150997	total: 1.93s	remaining: 538ms
# 782:	learn: 0.0150732	total: 1.93s	remaining: 535ms
# 783:	learn: 0.0150658	total: 1.93s	remaining: 533ms
# 784:	learn: 0.0150412	total: 1.94s	remaining: 530ms
# 785:	learn: 0.0150234	total: 1.94s	remaining: 528ms
# 786:	learn: 0.0150056	total: 1.94s	remaining: 526ms
# 787:	learn: 0.0149804	total: 1.94s	remaining: 523ms
# 788:	learn: 0.0149562	total: 1.95s	remaining: 521ms
# 789:	learn: 0.0149466	total: 1.95s	remaining: 518ms
# 790:	learn: 0.0149164	total: 1.95s	remaining: 516ms
# 791:	learn: 0.0148967	total: 1.95s	remaining: 513ms
# 792:	learn: 0.0148613	total: 1.96s	remaining: 511ms
# 793:	learn: 0.0148523	total: 1.96s	remaining: 508ms
# 794:	learn: 0.0148438	total: 1.96s	remaining: 506ms
# 795:	learn: 0.0148322	total: 1.96s	remaining: 503ms
# 796:	learn: 0.0148107	total: 1.97s	remaining: 501ms
# 797:	learn: 0.0147967	total: 1.97s	remaining: 499ms
# 798:	learn: 0.0147616	total: 1.97s	remaining: 496ms
# 799:	learn: 0.0147469	total: 1.97s	remaining: 493ms
# 800:	learn: 0.0147424	total: 1.98s	remaining: 491ms
# 801:	learn: 0.0147041	total: 1.98s	remaining: 489ms
# 802:	learn: 0.0146830	total: 1.98s	remaining: 486ms
# 803:	learn: 0.0146733	total: 1.98s	remaining: 484ms
# 804:	learn: 0.0146644	total: 1.99s	remaining: 481ms
# 805:	learn: 0.0146329	total: 1.99s	remaining: 479ms
# 806:	learn: 0.0146276	total: 1.99s	remaining: 476ms
# 807:	learn: 0.0146216	total: 1.99s	remaining: 474ms
# 808:	learn: 0.0146008	total: 2s	remaining: 471ms
# 809:	learn: 0.0145881	total: 2s	remaining: 469ms
# 810:	learn: 0.0145655	total: 2s	remaining: 466ms
# 811:	learn: 0.0145450	total: 2s	remaining: 464ms
# 812:	learn: 0.0145208	total: 2s	remaining: 461ms
# 813:	learn: 0.0145041	total: 2.01s	remaining: 459ms
# 814:	learn: 0.0144717	total: 2.01s	remaining: 457ms
# 815:	learn: 0.0144593	total: 2.01s	remaining: 454ms
# 816:	learn: 0.0144493	total: 2.02s	remaining: 452ms
# 817:	learn: 0.0144387	total: 2.02s	remaining: 449ms
# 818:	learn: 0.0144172	total: 2.02s	remaining: 447ms
# 819:	learn: 0.0143889	total: 2.02s	remaining: 444ms
# 820:	learn: 0.0143729	total: 2.02s	remaining: 442ms
# 821:	learn: 0.0143532	total: 2.03s	remaining: 439ms
# 822:	learn: 0.0143288	total: 2.03s	remaining: 437ms
# 823:	learn: 0.0143214	total: 2.03s	remaining: 434ms
# 824:	learn: 0.0143136	total: 2.04s	remaining: 432ms
# 825:	learn: 0.0142975	total: 2.04s	remaining: 429ms
# 826:	learn: 0.0142915	total: 2.04s	remaining: 427ms
# 827:	learn: 0.0142755	total: 2.04s	remaining: 424ms
# 828:	learn: 0.0142589	total: 2.04s	remaining: 422ms
# 829:	learn: 0.0142425	total: 2.05s	remaining: 419ms
# 830:	learn: 0.0142088	total: 2.05s	remaining: 417ms
# 831:	learn: 0.0141801	total: 2.05s	remaining: 414ms
# 832:	learn: 0.0141678	total: 2.05s	remaining: 412ms
# 833:	learn: 0.0141535	total: 2.06s	remaining: 410ms
# 834:	learn: 0.0141322	total: 2.06s	remaining: 407ms
# 835:	learn: 0.0141162	total: 2.06s	remaining: 405ms
# 836:	learn: 0.0141056	total: 2.06s	remaining: 402ms
# 837:	learn: 0.0140931	total: 2.07s	remaining: 400ms
# 838:	learn: 0.0140676	total: 2.07s	remaining: 397ms
# 839:	learn: 0.0140576	total: 2.07s	remaining: 395ms
# 840:	learn: 0.0140283	total: 2.07s	remaining: 392ms
# 841:	learn: 0.0140225	total: 2.08s	remaining: 390ms
# 842:	learn: 0.0140061	total: 2.08s	remaining: 387ms
# 843:	learn: 0.0139795	total: 2.08s	remaining: 385ms
# 844:	learn: 0.0139541	total: 2.08s	remaining: 382ms
# 845:	learn: 0.0139346	total: 2.09s	remaining: 380ms
# 846:	learn: 0.0139178	total: 2.09s	remaining: 377ms
# 847:	learn: 0.0138988	total: 2.09s	remaining: 375ms
# 848:	learn: 0.0138935	total: 2.09s	remaining: 372ms
# 849:	learn: 0.0138851	total: 2.1s	remaining: 370ms
# 850:	learn: 0.0138592	total: 2.1s	remaining: 368ms
# 851:	learn: 0.0138443	total: 2.1s	remaining: 365ms
# 852:	learn: 0.0138156	total: 2.1s	remaining: 363ms
# 853:	learn: 0.0137935	total: 2.11s	remaining: 360ms
# 854:	learn: 0.0137796	total: 2.11s	remaining: 358ms
# 855:	learn: 0.0137660	total: 2.11s	remaining: 355ms
# 856:	learn: 0.0137445	total: 2.11s	remaining: 353ms
# 857:	learn: 0.0137343	total: 2.12s	remaining: 350ms
# 858:	learn: 0.0137159	total: 2.12s	remaining: 348ms
# 859:	learn: 0.0137003	total: 2.12s	remaining: 345ms
# 860:	learn: 0.0136803	total: 2.12s	remaining: 343ms
# 861:	learn: 0.0136617	total: 2.13s	remaining: 340ms
# 862:	learn: 0.0136462	total: 2.13s	remaining: 338ms
# 863:	learn: 0.0136394	total: 2.13s	remaining: 335ms
# 864:	learn: 0.0136230	total: 2.13s	remaining: 333ms
# 865:	learn: 0.0136029	total: 2.13s	remaining: 330ms
# 866:	learn: 0.0135921	total: 2.14s	remaining: 328ms
# 867:	learn: 0.0135813	total: 2.14s	remaining: 326ms
# 868:	learn: 0.0135586	total: 2.14s	remaining: 323ms
# 869:	learn: 0.0135505	total: 2.15s	remaining: 321ms
# 870:	learn: 0.0135358	total: 2.15s	remaining: 318ms
# 871:	learn: 0.0135216	total: 2.15s	remaining: 316ms
# 872:	learn: 0.0135182	total: 2.15s	remaining: 313ms
# 873:	learn: 0.0135115	total: 2.16s	remaining: 311ms
# 874:	learn: 0.0135036	total: 2.16s	remaining: 308ms
# 875:	learn: 0.0134722	total: 2.16s	remaining: 306ms
# 876:	learn: 0.0134555	total: 2.16s	remaining: 303ms
# 877:	learn: 0.0134430	total: 2.17s	remaining: 301ms
# 878:	learn: 0.0134339	total: 2.17s	remaining: 298ms
# 879:	learn: 0.0134145	total: 2.17s	remaining: 296ms
# 880:	learn: 0.0133989	total: 2.17s	remaining: 293ms
# 881:	learn: 0.0133848	total: 2.17s	remaining: 291ms
# 882:	learn: 0.0133667	total: 2.18s	remaining: 289ms
# 883:	learn: 0.0133540	total: 2.18s	remaining: 286ms
# 884:	learn: 0.0133423	total: 2.18s	remaining: 284ms
# 885:	learn: 0.0133194	total: 2.19s	remaining: 281ms
# 886:	learn: 0.0133070	total: 2.19s	remaining: 279ms
# 887:	learn: 0.0132852	total: 2.19s	remaining: 276ms
# 888:	learn: 0.0132739	total: 2.19s	remaining: 274ms
# 889:	learn: 0.0132558	total: 2.2s	remaining: 271ms
# 890:	learn: 0.0132472	total: 2.2s	remaining: 269ms
# 891:	learn: 0.0132414	total: 2.2s	remaining: 267ms
# 892:	learn: 0.0132346	total: 2.2s	remaining: 264ms
# 893:	learn: 0.0132276	total: 2.21s	remaining: 262ms
# 894:	learn: 0.0132076	total: 2.21s	remaining: 259ms
# 895:	learn: 0.0132021	total: 2.21s	remaining: 257ms
# 896:	learn: 0.0131898	total: 2.21s	remaining: 254ms
# 897:	learn: 0.0131771	total: 2.22s	remaining: 252ms
# 898:	learn: 0.0131639	total: 2.22s	remaining: 249ms
# 899:	learn: 0.0131540	total: 2.22s	remaining: 247ms
# 900:	learn: 0.0131491	total: 2.22s	remaining: 244ms
# 901:	learn: 0.0131299	total: 2.23s	remaining: 242ms
# 902:	learn: 0.0131084	total: 2.23s	remaining: 240ms
# 903:	learn: 0.0130896	total: 2.23s	remaining: 237ms
# 904:	learn: 0.0130783	total: 2.23s	remaining: 235ms
# 905:	learn: 0.0130752	total: 2.24s	remaining: 232ms
# 906:	learn: 0.0130629	total: 2.24s	remaining: 230ms
# 907:	learn: 0.0130492	total: 2.24s	remaining: 227ms
# 908:	learn: 0.0130349	total: 2.24s	remaining: 225ms
# 909:	learn: 0.0130139	total: 2.25s	remaining: 222ms
# 910:	learn: 0.0130070	total: 2.25s	remaining: 220ms
# 911:	learn: 0.0129902	total: 2.25s	remaining: 217ms
# 912:	learn: 0.0129843	total: 2.25s	remaining: 215ms
# 913:	learn: 0.0129793	total: 2.26s	remaining: 212ms
# 914:	learn: 0.0129708	total: 2.26s	remaining: 210ms
# 915:	learn: 0.0129529	total: 2.26s	remaining: 207ms
# 916:	learn: 0.0129420	total: 2.26s	remaining: 205ms
# 917:	learn: 0.0129383	total: 2.27s	remaining: 202ms
# 918:	learn: 0.0129286	total: 2.27s	remaining: 200ms
# 919:	learn: 0.0129124	total: 2.27s	remaining: 198ms
# 920:	learn: 0.0129096	total: 2.27s	remaining: 195ms
# 921:	learn: 0.0128932	total: 2.28s	remaining: 193ms
# 922:	learn: 0.0128801	total: 2.28s	remaining: 190ms
# 923:	learn: 0.0128713	total: 2.28s	remaining: 188ms
# 924:	learn: 0.0128561	total: 2.28s	remaining: 185ms
# 925:	learn: 0.0128409	total: 2.29s	remaining: 183ms
# 926:	learn: 0.0128254	total: 2.29s	remaining: 180ms
# 927:	learn: 0.0128153	total: 2.29s	remaining: 178ms
# 928:	learn: 0.0127963	total: 2.29s	remaining: 175ms
# 929:	learn: 0.0127880	total: 2.3s	remaining: 173ms
# 930:	learn: 0.0127695	total: 2.3s	remaining: 170ms
# 931:	learn: 0.0127503	total: 2.3s	remaining: 168ms
# 932:	learn: 0.0127396	total: 2.3s	remaining: 165ms
# 933:	learn: 0.0127185	total: 2.31s	remaining: 163ms
# 934:	learn: 0.0127062	total: 2.31s	remaining: 161ms
# 935:	learn: 0.0126928	total: 2.31s	remaining: 158ms
# 936:	learn: 0.0126894	total: 2.31s	remaining: 156ms
# 937:	learn: 0.0126800	total: 2.32s	remaining: 153ms
# 938:	learn: 0.0126696	total: 2.32s	remaining: 151ms
# 939:	learn: 0.0126674	total: 2.32s	remaining: 148ms
# 940:	learn: 0.0126580	total: 2.32s	remaining: 146ms
# 941:	learn: 0.0126552	total: 2.33s	remaining: 143ms
# 942:	learn: 0.0126378	total: 2.33s	remaining: 141ms
# 943:	learn: 0.0126256	total: 2.33s	remaining: 138ms
# 944:	learn: 0.0126150	total: 2.33s	remaining: 136ms
# 945:	learn: 0.0125988	total: 2.34s	remaining: 133ms
# 946:	learn: 0.0125819	total: 2.34s	remaining: 131ms
# 947:	learn: 0.0125691	total: 2.34s	remaining: 129ms
# 948:	learn: 0.0125609	total: 2.35s	remaining: 126ms
# 949:	learn: 0.0125455	total: 2.35s	remaining: 124ms
# 950:	learn: 0.0125339	total: 2.35s	remaining: 121ms
# 951:	learn: 0.0125281	total: 2.35s	remaining: 119ms
# 952:	learn: 0.0125043	total: 2.35s	remaining: 116ms
# 953:	learn: 0.0125000	total: 2.36s	remaining: 114ms
# 954:	learn: 0.0124880	total: 2.36s	remaining: 111ms
# 955:	learn: 0.0124765	total: 2.36s	remaining: 109ms
# 956:	learn: 0.0124647	total: 2.36s	remaining: 106ms
# 957:	learn: 0.0124536	total: 2.37s	remaining: 104ms
# 958:	learn: 0.0124473	total: 2.37s	remaining: 101ms
# 959:	learn: 0.0124305	total: 2.37s	remaining: 98.9ms
# 960:	learn: 0.0124146	total: 2.37s	remaining: 96.4ms
# 961:	learn: 0.0124044	total: 2.38s	remaining: 93.9ms
# 962:	learn: 0.0123885	total: 2.38s	remaining: 91.4ms
# 963:	learn: 0.0123769	total: 2.38s	remaining: 89ms
# 964:	learn: 0.0123682	total: 2.38s	remaining: 86.5ms
# 965:	learn: 0.0123504	total: 2.39s	remaining: 84ms
# 966:	learn: 0.0123413	total: 2.39s	remaining: 81.6ms
# 967:	learn: 0.0123376	total: 2.39s	remaining: 79.1ms
# 968:	learn: 0.0123272	total: 2.4s	remaining: 76.6ms
# 969:	learn: 0.0123159	total: 2.4s	remaining: 74.2ms
# 970:	learn: 0.0123079	total: 2.4s	remaining: 71.7ms
# 971:	learn: 0.0122946	total: 2.4s	remaining: 69.2ms
# 972:	learn: 0.0122754	total: 2.4s	remaining: 66.8ms
# 973:	learn: 0.0122537	total: 2.41s	remaining: 64.3ms
# 974:	learn: 0.0122360	total: 2.41s	remaining: 61.8ms
# 975:	learn: 0.0122160	total: 2.41s	remaining: 59.3ms
# 976:	learn: 0.0121973	total: 2.42s	remaining: 56.9ms
# 977:	learn: 0.0121954	total: 2.42s	remaining: 54.4ms
# 978:	learn: 0.0121866	total: 2.42s	remaining: 51.9ms
# 979:	learn: 0.0121828	total: 2.42s	remaining: 49.5ms
# 980:	learn: 0.0121503	total: 2.43s	remaining: 47ms
# 981:	learn: 0.0121417	total: 2.43s	remaining: 44.5ms
# 982:	learn: 0.0121389	total: 2.43s	remaining: 42ms
# 983:	learn: 0.0121333	total: 2.43s	remaining: 39.6ms
# 984:	learn: 0.0121226	total: 2.44s	remaining: 37.1ms
# 985:	learn: 0.0121137	total: 2.44s	remaining: 34.6ms
# 986:	learn: 0.0121083	total: 2.44s	remaining: 32.1ms
# 987:	learn: 0.0120997	total: 2.44s	remaining: 29.7ms
# 988:	learn: 0.0120895	total: 2.45s	remaining: 27.2ms
# 989:	learn: 0.0120878	total: 2.45s	remaining: 24.7ms
# 990:	learn: 0.0120819	total: 2.45s	remaining: 22.3ms
# 991:	learn: 0.0120658	total: 2.45s	remaining: 19.8ms
# 992:	learn: 0.0120564	total: 2.46s	remaining: 17.3ms
# 993:	learn: 0.0120476	total: 2.46s	remaining: 14.8ms
# 994:	learn: 0.0120405	total: 2.46s	remaining: 12.4ms
# 995:	learn: 0.0120292	total: 2.46s	remaining: 9.9ms
# 996:	learn: 0.0120246	total: 2.47s	remaining: 7.42ms
# 997:	learn: 0.0120069	total: 2.47s	remaining: 4.95ms
# 998:	learn: 0.0119909	total: 2.47s	remaining: 2.47ms
# 999:	learn: 0.0119740	total: 2.48s	remaining: 0us
# c:\Users\RBM-WorkStation\AppData\Local\Programs\Python\Python39\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] bagging_fraction is set=1, subsample=1.0 will be ignored. Current value: bagging_fraction=1
# [LightGBM] [Warning] bagging_freq is set=100, subsample_freq=0 will be ignored. Current value: bagging_freq=100

# %% [markdown]
# > Evaluation of __Test 1__

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'XG Boost',
    predictedValue = t1_results_xg,
    exactValue     = t1_e_results_xg
)
# Out:
# ############ HbA1c Evaluation Metrics of XG Boost Regression ############
# Diff STD  =  0.37473289047392044
# MSE       =  0.14098074545424916
# ME        =  -0.023579784802027888
# MAD       =  0.22697612558092398
# RMSE      =  0.3754740276693571
# R2 score  =  0.8268738868221555
# Pearson R and p-value:  PearsonRResult(statistic=0.9136692187348733, pvalue=1.1505127367332726e-11)
# ##################################################################################

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'Random Forest',
    predictedValue = t1_results_rf,
    exactValue     = t1_e_results_rf
)
# Out:
# ############ HbA1c Evaluation Metrics of Random Forest Regression ############
# Diff STD  =  0.6401605474279066
# MSE       =  0.4109817713681002
# ME        =  -0.03429642670750337
# MAD       =  0.5040558680611884
# RMSE      =  0.64107859999231
# R2 score  =  0.4953092606039965
# Pearson R and p-value:  PearsonRResult(statistic=0.7286788875299768, pvalue=1.0977289225865126e-05)
# ##################################################################################

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'Cat Boost',
    predictedValue = t1_results_cb,
    exactValue     = t1_e_results_cb
)
# Out:
# ############ HbA1c Evaluation Metrics of Cat Boost Regression ############
# Diff STD  =  0.5250180255644078
# MSE       =  0.2784550120191538
# ME        =  -0.05301966476322389
# MAD       =  0.4095102344353481
# RMSE      =  0.5276883663860269
# R2 score  =  0.6580537734395054
# Pearson R and p-value:  PearsonRResult(statistic=0.8295480920559882, pvalue=4.8522954330689394e-08)
# ##################################################################################

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'Light GBM',
    predictedValue = t1_results_lg,
    exactValue     = t1_e_results_lg
)
# Out:
# ############ HbA1c Evaluation Metrics of Light GBM Regression ############
# Diff STD  =  0.682179266351421
# MSE       =  0.49091569299261345
# ME        =  0.1598347319979315
# MAD       =  0.4891906399784453
# RMSE      =  0.7006537611349941
# R2 score  =  0.39714940822610323
# Pearson R and p-value:  PearsonRResult(statistic=0.6927623896239404, pvalue=4.3963719135427686e-05)
# ##################################################################################

# %%
ltb.plot_importance(booster= lg)
plt.show()

# %% [markdown]
# ## __Test 02:__

# %% [markdown]
# >  Utilizing __Algorithm 06v2:__ Constructing Features Set _(Red, Green, Blue; Reflected, FeatureCount=4+4+r1+r2+SpO2+BMI=13)_

# %%
# Initialize
loo                = sk.model_selection.LeaveOneOut()
t2_scores          = []
t2_test_cases      = []
t2_train_cases     = []
countEpoch         = 0
percent            = 0.02
# XG Boost
t2_results_xg      = []
t2_e_results_xg    = []
# Random Forest
t2_results_rf      = []
t2_e_results_rf    = []
# Cat Boost
t2_results_cb      = []
t2_e_results_cb    = []
# Light GBM
t2_results_lg      = []
t2_e_results_lg    = []

for train_index, test_index in loo.split(PPG_csvArray):
    print('Epoch # '+str(countEpoch))
    countEpoch +=1

    X_train, X_test      = PPG_csvArray[train_index], PPG_csvArray[test_index]
    y_train, y_test      = HbA1c_Array [train_index], HbA1c_Array [test_index]
    sp_train, sp_test    = SpO2_Array  [train_index], SpO2_Array  [test_index]
    bmi_train, bmi_test  = BMI_Array   [train_index], BMI_Array   [test_index]
    
    
    # > __Algorithm 06v2:__ Constructing Features Set _(Red, Green, Blue; Reflected, FeatureCount=4+4+r1+r2+SpO2+BMI=13)_
    print('*************************************************************')
    print('*********************Training Array Set**********************')
    print('*************************************************************')
    train_array = construct_feature_set_v2(
        PPG          = X_train,
        HbA1c        = y_train,
        SpO2         = sp_train,
        BMI          = bmi_train,
        samplingRate = 32
        )
    print('*************************************************************')
    print('*********************Testing Array Set***********************')
    print('*************************************************************')
    test_array  = construct_feature_set_v2(
        PPG          = X_test,
        HbA1c        = y_test,
        SpO2         = sp_test,
        BMI          = bmi_test,
        samplingRate = 32
        )
    
    feature_train, hba1c_train = train_array[:,:-1], train_array[:,-1]
    feature_test, hba1c_test   = test_array[:,:-1],  test_array[:,-1]
    
    train = np.sort(np.array(random.sample(range(feature_test.shape[0]), int(feature_test.shape[0] * percent))))
    if train.shape[0] == 0:
        feature_train, hba1c_train = np.append(feature_train, np.expand_dims(feature_test[0],axis=0), 0), np.append(hba1c_train, np.expand_dims(hba1c_test[0],axis=0), 0)
        # feature_test, hba1c_test = np.delete(feature_test, 0, axis = 0), np.delete(hba1c_test, 0, axis = 0)
    else:
        test = np.delete(np.arange(feature_test.shape[0]), train)

        feature_train, hba1c_train = np.append(feature_train, feature_test[train], 0), np.append(hba1c_train, hba1c_test[train], 0)
        feature_test, hba1c_test = np.delete(feature_test, train, axis = 0), np.delete(hba1c_test, train, axis = 0)
    
    feature_train, hba1c_train = sk.utils.shuffle(feature_train, hba1c_train, random_state=0)
    # print(feature_train.shape)
    # print(feature_test.shape)

    # XGboost
    xg = xgb.XGBRegressor(objective="reg:squarederror", random_state=42)
    xg.fit(feature_train, hba1c_train)
    t2_results_xg.append(np.nanmean(xg.predict(feature_test)))
    t2_e_results_xg.append(np.nanmean(hba1c_test))

    # Random Forest
    rf = RandomForestRegressor(random_state=42, n_estimators=1000, n_jobs=-1)
    rf.fit(feature_train, hba1c_train)
    t2_results_rf.append(np.nanmean(rf.predict(feature_test)))
    t2_e_results_rf.append(np.nanmean(hba1c_test))

    # Cat boost
    cb = cab.CatBoostRegressor()
    cb.fit(feature_train, hba1c_train)
    t2_results_cb.append(np.nanmean(cb.predict(feature_test)))
    t2_e_results_cb.append(np.nanmean(hba1c_test))

    # Light GBM
    # lg = ltb.LGBMRegressor(boosting_type='dart')
    lg = ltb.LGBMRegressor(
        application = 'regression',
        objective = 'root_mean_squared_error',
        boosting_type="dart",
        num_iterations = 3500,
        learning_rate = 0.05,
        num_leaves=150,
        tree_learner='feature',
        max_depth =10,
        min_data_in_leaf=7,
        bagging_fraction = 1,
        bagging_freq = 100,
        reg_sqrt='True',
        metric ='rmse',
        feature_fraction = 0.6,
        random_state=42
        ) 
    lg.fit(feature_train, hba1c_train)
    t2_results_lg.append(np.nanmean(lg.predict(feature_test)))
    t2_e_results_lg.append(np.nanmean(hba1c_test))



    t2_test_cases.append(X_test)
    t2_train_cases.append(X_train)

    clear_output(wait=True)
# Out:
# Epoch # 27
# *************************************************************
# *********************Training Array Set**********************
# *************************************************************
# PPG_data_info:./DataBase/Selected_PPG_wrist/210823_4.csv
# iCount=0 || jCount=0 || lCount=1 || fCount=13
# [7.00000000e+00 1.61312204e+02 4.10558183e+05 1.36127807e+02
#  7.00000000e+00 1.74190061e+02 5.03481979e+05 1.54951554e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=1 || lCount=2 || fCount=13
# [7.00000000e+00 1.91803315e+02 2.96738685e+05 1.90432848e+02
#  7.00000000e+00 2.02711545e+02 4.13354251e+05 1.97611040e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=2 || lCount=3 || fCount=13
# [7.00000000e+00 1.79943544e+02 3.82680075e+05 2.35377866e+02
#  7.00000000e+00 1.92379419e+02 4.64490018e+05 2.63663411e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=3 || lCount=4 || fCount=13
# [6.00000000e+00 1.72377749e+02 2.73144676e+05 1.33134886e+02
#  6.00000000e+00 1.76909105e+02 3.88045904e+05 1.38785164e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=4 || lCount=5 || fCount=13
# [7.00000000e+00 1.65683896e+02 3.79694533e+05 1.48109607e+02
#  7.00000000e+00 1.79250007e+02 4.22356425e+05 1.61181767e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=5 || lCount=6 || fCount=13
# [7.00000000e+00 1.62742490e+02 1.87012861e+05 1.06966438e+02
#  7.00000000e+00 1.75755137e+02 3.01513553e+05 1.15175021e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=6 || lCount=7 || fCount=13
# [7.00000000e+00 1.60025502e+02 2.72718163e+05 8.17170237e+01
#  6.00000000e+00 1.72146488e+02 3.89271296e+05 1.17528472e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=7 || lCount=8 || fCount=13
# [7.00000000e+00 1.66339438e+02 3.42903743e+05 9.52418406e+01
#  7.00000000e+00 1.82503072e+02 4.63742434e+05 1.64579204e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=8 || lCount=9 || fCount=13
# [7.00000000e+00 1.57764503e+02 2.19044274e+05 8.61038524e+01
#  7.00000000e+00 1.74142605e+02 3.36180653e+05 1.33201131e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=9 || lCount=10 || fCount=13
# [7.00000000e+00 1.71641184e+02 2.43282649e+05 1.22399177e+02
#  7.00000000e+00 1.78794843e+02 2.95162029e+05 1.31202785e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=10 || lCount=11 || fCount=13
# [7.00000000e+00 1.72014223e+02 4.21432720e+05 1.10751931e+02
#  7.00000000e+00 1.81407670e+02 5.11053625e+05 1.19541115e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=11 || lCount=12 || fCount=13
# [7.00000000e+00 1.67730274e+02 2.26760796e+05 9.96250628e+01
#  7.00000000e+00 1.81256444e+02 3.37824004e+05 1.03199110e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=12 || lCount=13 || fCount=13
# [7.00000000e+00 1.73291192e+02 4.50047062e+05 1.18550364e+02
#  7.00000000e+00 1.87022010e+02 5.57927017e+05 1.27455164e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=13 || lCount=14 || fCount=13
# [6.00000000e+00 1.70058097e+02 2.72924695e+05 1.22931421e+02
#  6.00000000e+00 1.83064413e+02 3.93325157e+05 1.27517168e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=14 || lCount=15 || fCount=13
# [7.00000000e+00 1.64476367e+02 3.39279705e+05 1.02753756e+02
#  7.00000000e+00 1.74333596e+02 4.39691110e+05 1.18154473e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=15 || lCount=16 || fCount=13
# [7.00000000e+00 1.78814075e+02 3.20770213e+05 1.33682623e+02
#  7.00000000e+00 1.86751014e+02 4.73468275e+05 1.53623186e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=16 || lCount=17 || fCount=13
# [6.00000000e+00 1.70293606e+02 1.90914991e+05 1.10503778e+02
#  6.00000000e+00 1.76980454e+02 2.88309766e+05 1.10792169e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=17 || lCount=18 || fCount=13
# [7.00000000e+00 1.51763040e+02 3.34748259e+05 8.03502233e+01
#  7.00000000e+00 1.64026892e+02 3.67380648e+05 8.17050394e+01
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=18 || lCount=19 || fCount=13
# [7.00000000e+00 1.62205810e+02 1.78928495e+05 1.16466324e+02
#  7.00000000e+00 1.68705979e+02 2.60216496e+05 1.03014440e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=19 || lCount=20 || fCount=13
# [7.00000000e+00 1.52600566e+02 2.12623979e+05 9.00601144e+01
#  7.00000000e+00 1.63812460e+02 2.67470371e+05 9.66400858e+01
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=20 || lCount=21 || fCount=13
# [7.00000000e+00 1.53820211e+02 3.62579914e+05 9.89692328e+01
#  7.00000000e+00 1.63437001e+02 3.79240369e+05 8.33044633e+01
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=21 || lCount=22 || fCount=13
# [7.00000000e+00 1.66742344e+02 1.81260751e+05 1.06686486e+02
#  7.00000000e+00 1.66939814e+02 2.68366792e+05 8.86314636e+01
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=22 || lCount=23 || fCount=13
# [7.00000000e+00 1.62495903e+02 3.49258991e+05 9.03064098e+01
#  7.00000000e+00 1.69922237e+02 3.17372615e+05 1.01617569e+02
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=23 || lCount=24 || fCount=13
# [7.00000000e+00 1.61069501e+02 2.68237266e+05 7.33247848e+01
#  7.00000000e+00 1.66327776e+02 3.29823572e+05 7.73548729e+01
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=24 || lCount=25 || fCount=13
# [7.00000000e+00 1.56801034e+02 2.16108840e+05 9.03119669e+01
#  7.00000000e+00 1.66419610e+02 2.74075660e+05 9.15134329e+01
#  3.82517736e+00 1.56929855e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# PPG_data_info:./DataBase/Selected_PPG_wrist/210830_0.csv
# iCount=1 || jCount=0 || lCount=26 || fCount=13
# [6.00000000e+00 5.36622112e+01 1.20219822e+04 3.86968504e+00
#  6.00000000e+00 7.14115935e+01 3.69170680e+04 7.05572951e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=1 || lCount=27 || fCount=13
# [4.00000000e+00 5.68601351e+01 2.21110875e+03 6.76047459e+00
#  4.00000000e+00 7.50217028e+01 7.52117335e+03 1.33017721e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=2 || lCount=28 || fCount=13
# [7.00000000e+00 3.98799254e+01 5.39392214e+03 1.65279945e+00
#  5.00000000e+00 5.96249953e+01 2.00376580e+04 4.66805347e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=3 || lCount=29 || fCount=13
# [8.00000000e+00 4.62733001e+01 9.70010015e+02 1.99436675e+00
#  6.00000000e+00 6.48593713e+01 4.59385783e+03 9.17348134e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=4 || lCount=30 || fCount=13
# [9.00000000e+00 4.30171513e+01 4.53269586e+02 1.44548214e+00
#  7.00000000e+00 5.77469751e+01 1.84059958e+03 3.73371531e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=5 || lCount=31 || fCount=13
# [1.10000000e+01 3.91652777e+01 1.10397909e+02 6.93367343e-01
#  9.00000000e+00 5.05405968e+01 1.86595493e+03 1.60556123e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=6 || lCount=32 || fCount=13
# [7.00000000e+00 3.65622380e+01 5.23996227e+02 7.23637285e-01
#  7.00000000e+00 5.44938209e+01 2.37509861e+03 2.48402625e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=7 || lCount=33 || fCount=13
# [7.00000000e+00 4.29106682e+01 3.47425979e+02 1.56782149e+00
#  7.00000000e+00 6.47615141e+01 5.09205262e+03 6.13831554e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=8 || lCount=34 || fCount=13
# [7.00000000e+00 4.96083843e+01 1.55340224e+03 1.73390698e+00
#  7.00000000e+00 7.28182870e+01 9.40422508e+03 6.52668679e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=9 || lCount=35 || fCount=13
# [1.00000000e+01 5.23642562e+01 2.27729470e+03 1.71025087e+00
#  6.00000000e+00 7.07487109e+01 1.14073594e+04 6.46952243e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=10 || lCount=36 || fCount=13
# [1.10000000e+01 5.27519742e+01 4.48549404e+02 1.74530398e+00
#  7.00000000e+00 7.56919092e+01 8.84785581e+03 7.96458938e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=11 || lCount=37 || fCount=13
# [1.00000000e+01 5.03916361e+01 2.49908751e+03 1.53602041e+00
#  8.00000000e+00 7.39225591e+01 1.17602249e+04 5.98820247e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=12 || lCount=38 || fCount=13
# [6.00000000e+00 4.86840389e+01 4.64175802e+03 1.66677456e+00
#  6.00000000e+00 7.09336779e+01 2.25783180e+04 5.41057782e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=13 || lCount=39 || fCount=13
# [7.00000000e+00 5.22974244e+01 2.05916120e+03 1.76437438e+00
#  6.00000000e+00 7.50534446e+01 1.89150644e+04 6.40508584e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=14 || lCount=40 || fCount=13
# [8.00000000e+00 5.37169766e+01 1.21857257e+03 1.16513494e+00
#  6.00000000e+00 7.54197303e+01 1.14543069e+04 7.84904975e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=15 || lCount=41 || fCount=13
# [8.00000000e+00 5.41300516e+01 5.04148775e+03 1.16725707e+00
#  6.00000000e+00 7.23464861e+01 1.83716726e+04 6.11599491e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=16 || lCount=42 || fCount=13
# [6.00000000e+00 5.49527580e+01 2.99875882e+03 2.56728945e+00
#  6.00000000e+00 7.64256700e+01 1.28000106e+04 9.19181919e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=17 || lCount=43 || fCount=13
# [7.00000000e+00 4.82479728e+01 3.98817226e+02 1.63791415e+00
#  7.00000000e+00 6.90097213e+01 5.53895562e+03 5.78471798e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=18 || lCount=44 || fCount=13
# [6.00000000e+00 4.87580911e+01 1.63162589e+03 1.33762000e+00
#  6.00000000e+00 7.05295701e+01 1.09794344e+04 6.16267266e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=19 || lCount=45 || fCount=13
# [7.00000000e+00 5.52482139e+01 3.41261980e+03 2.23539030e+00
#  7.00000000e+00 8.06784014e+01 1.74539613e+04 9.19927671e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=20 || lCount=46 || fCount=13
# [1.10000000e+01 5.13498605e+01 9.73726639e+02 1.90535502e+00
#  7.00000000e+00 7.78892131e+01 9.51986332e+03 8.69431616e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=21 || lCount=47 || fCount=13
# [1.00000000e+01 4.86532523e+01 1.72263940e+03 1.64405575e+00
#  6.00000000e+00 6.98654784e+01 1.31615800e+04 7.36860032e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=22 || lCount=48 || fCount=13
# [7.00000000e+00 5.25053587e+01 1.22175931e+03 1.68934146e+00
#  7.00000000e+00 8.21765407e+01 8.53302431e+03 8.41217812e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=23 || lCount=49 || fCount=13
# [6.00000000e+00 4.96284877e+01 1.68822690e+03 1.48842298e+00
#  6.00000000e+00 7.97980989e+01 1.43846845e+04 9.75130850e+00
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=24 || lCount=50 || fCount=13
# [6.00000000e+00 5.70291953e+01 3.89229830e+03 2.71389664e+00
#  6.00000000e+00 8.48415621e+01 2.67601277e+04 1.11497125e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=25 || lCount=51 || fCount=13
# [7.00000000e+00 5.77924420e+01 4.74214394e+03 2.92942117e+00
#  7.00000000e+00 9.14179724e+01 2.29794885e+04 1.23870386e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=26 || lCount=52 || fCount=13
# [6.00000000e+00 5.62719403e+01 1.53131626e+03 2.65879994e+00
#  6.00000000e+00 8.32808643e+01 1.51879848e+04 1.08165517e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=27 || lCount=53 || fCount=13
# [7.00000000e+00 6.05271004e+01 9.90369224e+03 2.45445463e+00
#  7.00000000e+00 8.86557997e+01 4.31439283e+04 1.26564663e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=28 || lCount=54 || fCount=13
# [6.00000000e+00 6.32207845e+01 7.81505640e+03 3.45065824e+00
#  6.00000000e+00 9.02907627e+01 4.36728432e+04 1.51764851e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=29 || lCount=55 || fCount=13
# [6.00000000e+00 5.78469471e+01 2.35254381e+03 5.34546268e+00
#  6.00000000e+00 8.85064663e+01 2.38696034e+04 2.58375675e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=30 || lCount=56 || fCount=13
# [6.00000000e+00 5.22968838e+01 1.74535047e+03 2.58245101e+00
#  6.00000000e+00 8.21015657e+01 1.81072148e+04 1.21256514e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=31 || lCount=57 || fCount=13
# [7.00000000e+00 5.18055596e+01 4.45403434e+03 3.02333139e+00
#  7.00000000e+00 7.94483403e+01 2.07472641e+04 1.43516363e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=32 || lCount=58 || fCount=13
# [6.00000000e+00 5.52124001e+01 3.28110987e+03 3.46425860e+00
#  6.00000000e+00 8.14769479e+01 3.50997325e+04 1.69007515e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=33 || lCount=59 || fCount=13
# [7.00000000e+00 6.51847310e+01 1.55415973e+03 6.32637514e+00
#  7.00000000e+00 1.00549738e+02 1.59023391e+04 3.56023455e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=34 || lCount=60 || fCount=13
# [6.00000000e+00 6.15357177e+01 9.16157446e+03 4.94291567e+00
#  6.00000000e+00 9.34522697e+01 4.68869481e+04 2.44157374e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=35 || lCount=61 || fCount=13
# [7.00000000e+00 5.98220558e+01 4.62341686e+03 4.89065363e+00
#  6.00000000e+00 8.81823120e+01 4.28431384e+04 2.32066069e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=36 || lCount=62 || fCount=13
# [1.00000000e+01 5.66313770e+01 9.60818435e+02 2.37860904e+00
#  6.00000000e+00 8.69554717e+01 1.53724753e+04 1.75554816e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=37 || lCount=63 || fCount=13
# [8.00000000e+00 6.38988774e+01 6.47888244e+03 4.30680376e+00
#  6.00000000e+00 8.90602974e+01 3.18800275e+04 2.56609307e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=38 || lCount=64 || fCount=13
# [6.00000000e+00 7.02416069e+01 1.36234326e+04 4.25190978e+00
#  6.00000000e+00 9.90990114e+01 5.34042400e+04 2.18370063e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=39 || lCount=65 || fCount=13
# [6.00000000e+00 6.20451619e+01 3.86936212e+03 3.15221111e+00
#  6.00000000e+00 9.60389307e+01 3.36098916e+04 2.21746729e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=40 || lCount=66 || fCount=13
# [7.00000000e+00 6.15918038e+01 6.46611518e+03 3.81446051e+00
#  7.00000000e+00 9.91804733e+01 5.77628684e+04 2.82792113e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=41 || lCount=67 || fCount=13
# [6.00000000e+00 7.48397541e+01 1.58214215e+04 6.17310121e+00
#  6.00000000e+00 1.18212593e+02 9.25455068e+04 3.56989386e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=42 || lCount=68 || fCount=13
# [6.00000000e+00 7.76417365e+01 2.68644400e+04 8.82514122e+00
#  6.00000000e+00 1.23034580e+02 1.82147180e+05 5.05206162e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=43 || lCount=69 || fCount=13
# [6.00000000e+00 7.47913163e+01 9.04323453e+03 1.08929388e+01
#  6.00000000e+00 1.17883813e+02 8.12890482e+04 6.55680307e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=44 || lCount=70 || fCount=13
# [6.00000000e+00 6.77367802e+01 1.13680747e+04 7.21925311e+00
#  6.00000000e+00 1.01541009e+02 8.76493435e+04 4.48636328e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=45 || lCount=71 || fCount=13
# [6.00000000e+00 7.11767727e+01 1.49675140e+04 8.79181817e+00
#  6.00000000e+00 1.10976920e+02 8.45194611e+04 5.02779940e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=46 || lCount=72 || fCount=13
# [6.00000000e+00 6.60288217e+01 1.35407337e+04 5.77148469e+00
#  6.00000000e+00 1.08513243e+02 8.55987824e+04 3.77096185e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=47 || lCount=73 || fCount=13
# [6.00000000e+00 6.20460316e+01 5.90526823e+03 8.16550499e+00
#  6.00000000e+00 1.00257887e+02 5.61704745e+04 4.15557466e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=48 || lCount=74 || fCount=13
# [6.00000000e+00 6.60207371e+01 5.99516468e+03 5.27747099e+00
#  6.00000000e+00 1.07323057e+02 7.12927244e+04 4.30454584e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=49 || lCount=75 || fCount=13
# [6.00000000e+00 7.02986312e+01 8.62160331e+03 1.01268013e+01
#  6.00000000e+00 1.11083899e+02 8.07704997e+04 5.39027255e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=50 || lCount=76 || fCount=13
# [7.00000000e+00 7.49040875e+01 3.30467769e+04 9.36171522e+00
#  7.00000000e+00 1.16343692e+02 1.78858627e+05 5.06413659e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=51 || lCount=77 || fCount=13
# [6.00000000e+00 8.11922116e+01 1.81282054e+04 9.78877403e+00
#  6.00000000e+00 1.23144293e+02 1.18117906e+05 6.07837771e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=52 || lCount=78 || fCount=13
# [6.00000000e+00 7.38491806e+01 1.02530109e+04 7.56417016e+00
#  6.00000000e+00 1.16957058e+02 8.16341396e+04 6.80259145e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=53 || lCount=79 || fCount=13
# [6.00000000e+00 7.87528476e+01 1.62779105e+04 9.66889288e+00
#  6.00000000e+00 1.19467946e+02 9.77034152e+04 5.06661813e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=54 || lCount=80 || fCount=13
# [6.00000000e+00 7.59111338e+01 2.15384270e+04 9.87294046e+00
#  6.00000000e+00 1.19226960e+02 1.32958617e+05 5.23783930e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=55 || lCount=81 || fCount=13
# [7.00000000e+00 7.47798622e+01 1.60104485e+04 1.01631427e+01
#  7.00000000e+00 1.16617225e+02 1.39696503e+05 5.45648161e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=56 || lCount=82 || fCount=13
# [6.00000000e+00 7.58212908e+01 1.30429325e+04 9.10665159e+00
#  6.00000000e+00 1.22936321e+02 9.89215828e+04 6.20104283e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=57 || lCount=83 || fCount=13
# [6.00000000e+00 8.31845842e+01 2.71418346e+04 1.26987254e+01
#  6.00000000e+00 1.30665531e+02 1.51668234e+05 8.21779037e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=58 || lCount=84 || fCount=13
# [6.00000000e+00 8.54401102e+01 3.07243203e+04 1.23966811e+01
#  6.00000000e+00 1.32823190e+02 1.96779327e+05 7.48416900e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=59 || lCount=85 || fCount=13
# [6.00000000e+00 7.62937595e+01 1.04748430e+04 1.10355365e+01
#  6.00000000e+00 1.21463671e+02 7.72902192e+04 6.84318077e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=60 || lCount=86 || fCount=13
# [6.00000000e+00 7.79655244e+01 2.91773764e+04 9.57568832e+00
#  6.00000000e+00 1.24469817e+02 1.93169661e+05 5.64006824e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=61 || lCount=87 || fCount=13
# [7.00000000e+00 8.47067667e+01 1.52083353e+04 1.46242746e+01
#  7.00000000e+00 1.37854086e+02 9.86645823e+04 1.10946194e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=62 || lCount=88 || fCount=13
# [6.00000000e+00 7.59926071e+01 7.90131804e+03 1.34127879e+01
#  6.00000000e+00 1.26951009e+02 7.35865811e+04 8.52971053e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=63 || lCount=89 || fCount=13
# [7.00000000e+00 7.59638587e+01 1.81504130e+04 1.18652826e+01
#  7.00000000e+00 1.23256384e+02 1.44099291e+05 6.74597032e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=64 || lCount=90 || fCount=13
# [6.00000000e+00 8.42515118e+01 2.37580262e+04 1.88193231e+01
#  6.00000000e+00 1.34408369e+02 1.29273367e+05 9.78733753e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=65 || lCount=91 || fCount=13
# [7.00000000e+00 8.50029977e+01 2.20361070e+04 1.98480909e+01
#  7.00000000e+00 1.36578114e+02 1.46347345e+05 1.05491961e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=66 || lCount=92 || fCount=13
# [6.00000000e+00 8.23767215e+01 6.60286530e+03 1.30413695e+01
#  6.00000000e+00 1.29483860e+02 5.56651919e+04 9.39062414e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=67 || lCount=93 || fCount=13
# [7.00000000e+00 7.74674052e+01 2.57069081e+04 8.26305032e+00
#  7.00000000e+00 1.17202645e+02 1.08350415e+05 4.07418391e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=68 || lCount=94 || fCount=13
# [6.00000000e+00 8.51126197e+01 8.25199679e+03 1.58540927e+01
#  6.00000000e+00 1.24388473e+02 5.09890392e+04 6.72963725e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=69 || lCount=95 || fCount=13
# [7.00000000e+00 8.82641959e+01 1.51514488e+04 1.73645391e+01
#  7.00000000e+00 1.36931832e+02 1.32693608e+05 9.16421677e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=70 || lCount=96 || fCount=13
# [8.00000000e+00 9.08822930e+01 3.40923911e+04 1.86902824e+01
#  6.00000000e+00 1.41361934e+02 1.83212664e+05 9.67941121e+01
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=71 || lCount=97 || fCount=13
# [6.00000000e+00 8.95274154e+01 5.18810761e+04 2.04937910e+01
#  6.00000000e+00 1.35775523e+02 2.72944132e+05 1.05753139e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=72 || lCount=98 || fCount=13
# [6.00000000e+00 9.01938175e+01 2.19763720e+04 2.43970739e+01
#  6.00000000e+00 1.38573855e+02 1.74677356e+05 1.27937042e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=73 || lCount=99 || fCount=13
# [6.00000000e+00 8.64577718e+01 1.37958534e+04 2.50916218e+01
#  6.00000000e+00 1.33014318e+02 1.27921513e+05 1.51166627e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=74 || lCount=100 || fCount=13
# [6.00000000e+00 9.53542096e+01 5.45925394e+04 2.65844371e+01
#  6.00000000e+00 1.47398163e+02 3.09621021e+05 1.51078866e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=75 || lCount=101 || fCount=13
# [6.00000000e+00 9.51640126e+01 5.02363388e+04 2.33694445e+01
#  6.00000000e+00 1.45228517e+02 2.77130921e+05 1.20174462e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=76 || lCount=102 || fCount=13
# [6.00000000e+00 9.05591756e+01 3.60225737e+04 2.70416129e+01
#  7.00000000e+00 1.39490555e+02 2.38849838e+05 1.34005035e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=77 || lCount=103 || fCount=13
# [6.00000000e+00 9.14535594e+01 3.02843782e+04 2.56219878e+01
#  6.00000000e+00 1.46783817e+02 2.32419965e+05 1.38492691e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=78 || lCount=104 || fCount=13
# [6.00000000e+00 9.39691110e+01 4.06171009e+04 2.90297967e+01
#  6.00000000e+00 1.47600086e+02 2.39869529e+05 1.63879119e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=79 || lCount=105 || fCount=13
# [6.00000000e+00 9.96110405e+01 4.33832836e+04 3.31201595e+01
#  6.00000000e+00 1.53570259e+02 2.37790104e+05 1.86802933e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=80 || lCount=106 || fCount=13
# [6.00000000e+00 9.04922609e+01 4.38751972e+04 2.48408436e+01
#  6.00000000e+00 1.43155071e+02 2.99733958e+05 1.50737913e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=81 || lCount=107 || fCount=13
# [6.00000000e+00 9.12811123e+01 3.42232674e+04 2.44312076e+01
#  7.00000000e+00 1.47874017e+02 2.49585126e+05 1.54989213e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=82 || lCount=108 || fCount=13
# [6.00000000e+00 1.03141154e+02 6.70085852e+04 2.89593707e+01
#  6.00000000e+00 1.62340201e+02 3.91400815e+05 1.68533583e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=83 || lCount=109 || fCount=13
# [6.00000000e+00 1.03294076e+02 6.02803496e+04 4.23042523e+01
#  6.00000000e+00 1.62361013e+02 3.39675114e+05 2.84624142e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=84 || lCount=110 || fCount=13
# [6.00000000e+00 1.03622378e+02 3.26422640e+04 5.33303868e+01
#  6.00000000e+00 1.62613432e+02 2.59969613e+05 2.57175003e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=85 || lCount=111 || fCount=13
# [6.00000000e+00 1.00493190e+02 5.92578345e+04 3.38918006e+01
#  6.00000000e+00 1.55361129e+02 3.65534859e+05 1.77691460e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=86 || lCount=112 || fCount=13
# [6.00000000e+00 1.05846430e+02 7.64911856e+04 3.69354212e+01
#  6.00000000e+00 1.55935688e+02 4.06075406e+05 1.82740725e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=87 || lCount=113 || fCount=13
# [6.00000000e+00 1.03442908e+02 4.97528579e+04 3.43020595e+01
#  6.00000000e+00 1.63695570e+02 2.82270411e+05 2.00330008e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=88 || lCount=114 || fCount=13
# [6.00000000e+00 9.89898882e+01 4.54023527e+04 4.78733192e+01
#  6.00000000e+00 1.57299417e+02 3.64812475e+05 2.46774231e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=89 || lCount=115 || fCount=13
# [6.00000000e+00 1.05356288e+02 3.97039415e+04 4.48840516e+01
#  6.00000000e+00 1.70716965e+02 3.18301751e+05 3.59781422e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=90 || lCount=116 || fCount=13
# [6.00000000e+00 1.08540177e+02 7.28677129e+04 3.55489069e+01
#  6.00000000e+00 1.61774715e+02 4.08542791e+05 2.27449545e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=91 || lCount=117 || fCount=13
# [5.00000000e+00 1.05409002e+02 1.12914832e+05 3.38413094e+01
#  6.00000000e+00 1.55575699e+02 5.08832654e+05 2.21874930e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=92 || lCount=118 || fCount=13
# [6.00000000e+00 1.11242364e+02 6.14257366e+04 3.74909104e+01
#  6.00000000e+00 1.63010248e+02 3.87035543e+05 2.17455324e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=93 || lCount=119 || fCount=13
# [6.00000000e+00 1.06310420e+02 4.70256543e+04 4.63723849e+01
#  6.00000000e+00 1.66415443e+02 3.17708656e+05 2.49184443e+02
#  3.46759814e+00 1.29776067e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# PPG_data_info:./DataBase/Selected_PPG_wrist/210927_0.csv
# iCount=2 || jCount=0 || lCount=120 || fCount=13
# [1.10000000e+01 6.83467371e+01 1.08422612e+03 4.39506632e+00
#  1.10000000e+01 9.83106175e+01 7.90890426e+03 1.47652844e+01
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=1 || lCount=121 || fCount=13
# [1.30000000e+01 7.55110735e+01 6.25628990e+02 4.98448440e+00
#  1.20000000e+01 1.13288980e+02 7.14841395e+03 4.83718638e+01
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=2 || lCount=122 || fCount=13
# [1.40000000e+01 1.04019294e+02 4.42348591e+03 1.66496997e+01
#  1.20000000e+01 1.76443322e+02 5.53104775e+04 1.32319190e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=3 || lCount=123 || fCount=13
# [1.10000000e+01 1.52350390e+02 4.04430300e+04 9.68716555e+01
#  1.10000000e+01 2.47901690e+02 2.25981969e+05 4.14581843e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=4 || lCount=124 || fCount=13
# [1.20000000e+01 1.27093435e+02 1.19484472e+04 1.08387240e+02
#  1.10000000e+01 2.40353315e+02 1.70847268e+05 3.92389460e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=5 || lCount=125 || fCount=13
# [1.20000000e+01 9.78764833e+01 1.58260123e+03 1.98850723e+01
#  1.20000000e+01 2.28256579e+02 1.30011333e+05 1.80191639e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=6 || lCount=126 || fCount=13
# [1.40000000e+01 8.42051526e+01 7.12986238e+03 1.24388513e+01
#  1.20000000e+01 2.31671965e+02 2.14060706e+05 1.81512257e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=7 || lCount=127 || fCount=13
# [1.60000000e+01 7.82655360e+01 5.40787594e+02 8.54455468e+00
#  1.20000000e+01 2.36278910e+02 1.47917260e+05 1.89905799e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=8 || lCount=128 || fCount=13
# [1.40000000e+01 6.65114370e+01 3.15556537e+02 2.79999770e+00
#  1.10000000e+01 2.20439994e+02 1.36575834e+05 1.81036078e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=9 || lCount=129 || fCount=13
# [1.30000000e+01 1.04840643e+02 1.92060881e+03 2.01515758e+01
#  1.10000000e+01 2.25450112e+02 1.06754261e+05 1.70181560e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=10 || lCount=130 || fCount=13
# [1.10000000e+01 1.39822451e+02 3.23449265e+04 3.98398038e+01
#  1.10000000e+01 2.32869702e+02 1.70655193e+05 1.68636496e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=11 || lCount=131 || fCount=13
# [1.10000000e+01 1.80298404e+02 7.19304409e+04 8.10282272e+01
#  1.10000000e+01 2.53085690e+02 2.94369871e+05 2.24845656e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=12 || lCount=132 || fCount=13
# [1.10000000e+01 1.99534398e+02 7.42166924e+04 1.11447784e+02
#  1.10000000e+01 2.72540518e+02 2.54188436e+05 3.07445299e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=13 || lCount=133 || fCount=13
# [1.10000000e+01 1.93649706e+02 9.23798304e+04 9.04337299e+01
#  1.20000000e+01 2.47517291e+02 2.87906390e+05 2.69096300e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=14 || lCount=134 || fCount=13
# [1.20000000e+01 1.99828891e+02 6.61250850e+04 1.09351953e+02
#  1.20000000e+01 2.51520013e+02 1.37224767e+05 2.78696275e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=15 || lCount=135 || fCount=13
# [1.10000000e+01 1.99002165e+02 7.65537606e+04 1.00992090e+02
#  1.10000000e+01 2.61989904e+02 2.54450308e+05 2.73935678e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=16 || lCount=136 || fCount=13
# [1.20000000e+01 2.00781633e+02 8.54302769e+04 1.13668884e+02
#  1.20000000e+01 3.02257069e+02 4.76102831e+05 3.64664456e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=17 || lCount=137 || fCount=13
# [1.10000000e+01 1.87835176e+02 7.09990337e+04 8.87713665e+01
#  1.10000000e+01 2.93695431e+02 4.31360539e+05 4.26505446e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=18 || lCount=138 || fCount=13
# [1.20000000e+01 1.68856349e+02 3.88098245e+04 8.32197441e+01
#  1.20000000e+01 2.79687973e+02 3.02598118e+05 4.14186869e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=19 || lCount=139 || fCount=13
# [1.10000000e+01 1.65783277e+02 2.59939453e+04 8.17042956e+01
#  1.10000000e+01 2.73240228e+02 2.40174264e+05 3.43621030e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=20 || lCount=140 || fCount=13
# [1.20000000e+01 1.48256313e+02 2.83455721e+04 4.47644608e+01
#  1.10000000e+01 2.26011755e+02 2.53376644e+05 2.13012241e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=21 || lCount=141 || fCount=13
# [1.10000000e+01 1.67222435e+02 3.12968714e+04 9.87538886e+01
#  1.10000000e+01 2.30005730e+02 7.62413775e+04 3.30413454e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=22 || lCount=142 || fCount=13
# [1.00000000e+01 1.82079815e+02 8.79946309e+04 8.41041388e+01
#  1.00000000e+01 2.30404471e+02 3.19107346e+05 2.38509372e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=23 || lCount=143 || fCount=13
# [1.10000000e+01 1.82959134e+02 7.92963118e+04 7.84645148e+01
#  1.10000000e+01 2.54069448e+02 3.51272752e+05 2.15649439e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=24 || lCount=144 || fCount=13
# [1.10000000e+01 2.03205785e+02 6.93712495e+04 1.20634472e+02
#  1.10000000e+01 2.57485662e+02 2.30649040e+05 2.27622578e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=25 || lCount=145 || fCount=13
# [1.20000000e+01 2.06497351e+02 2.01289189e+05 1.22920284e+02
#  1.10000000e+01 2.43165455e+02 2.39921463e+05 2.25320090e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=26 || lCount=146 || fCount=13
# [1.10000000e+01 2.18471698e+02 8.41361662e+04 1.84549564e+02
#  1.10000000e+01 2.39430840e+02 1.43858793e+05 2.00647627e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=27 || lCount=147 || fCount=13
# [1.10000000e+01 1.94742366e+02 6.20483496e+04 1.39441284e+02
#  1.10000000e+01 2.17922912e+02 1.41162122e+05 1.66138170e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=28 || lCount=148 || fCount=13
# [1.20000000e+01 1.96484211e+02 4.31992947e+04 1.13401646e+02
#  1.10000000e+01 2.08425099e+02 8.08292817e+04 1.40644048e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=29 || lCount=149 || fCount=13
# [1.20000000e+01 2.15700137e+02 1.25681476e+05 1.31579594e+02
#  1.20000000e+01 2.25233621e+02 1.25144528e+05 1.85353572e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=30 || lCount=150 || fCount=13
# [1.10000000e+01 1.98784674e+02 8.55202922e+04 1.27355640e+02
#  1.10000000e+01 2.48198603e+02 1.83498155e+05 2.35233905e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=31 || lCount=151 || fCount=13
# [1.20000000e+01 1.74015588e+02 2.35383986e+04 1.01191789e+02
#  1.20000000e+01 2.73448028e+02 3.67673545e+05 3.63194307e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=32 || lCount=152 || fCount=13
# [1.10000000e+01 1.67070388e+02 3.98897176e+04 6.70955605e+01
#  1.10000000e+01 2.81053850e+02 3.10087450e+05 3.99418392e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=33 || lCount=153 || fCount=13
# [1.20000000e+01 2.26325972e+02 1.18662551e+05 2.41376111e+02
#  1.20000000e+01 3.47853883e+02 5.57037130e+05 1.31752998e+03
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=34 || lCount=154 || fCount=13
# [1.10000000e+01 2.27104724e+02 2.49571492e+05 2.32226973e+02
#  1.10000000e+01 3.54155315e+02 1.66924626e+06 1.32689366e+03
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=35 || lCount=155 || fCount=13
# [1.20000000e+01 2.21029747e+02 6.70140230e+04 2.77969126e+02
#  1.20000000e+01 3.54579140e+02 6.45710763e+05 1.55182786e+03
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=36 || lCount=156 || fCount=13
# [1.30000000e+01 1.61894834e+02 5.00932332e+04 1.28846334e+02
#  1.10000000e+01 2.53014427e+02 2.69867487e+05 6.99741543e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=37 || lCount=157 || fCount=13
# [1.20000000e+01 1.14660575e+02 4.62509903e+03 1.38463612e+01
#  1.20000000e+01 1.86227792e+02 5.65026360e+04 1.56602355e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=38 || lCount=158 || fCount=13
# [1.10000000e+01 1.36175108e+02 1.25238035e+04 4.88968640e+01
#  1.10000000e+01 1.69615255e+02 4.81978286e+04 1.06315595e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=39 || lCount=159 || fCount=13
# [1.10000000e+01 1.75019035e+02 5.30919222e+04 7.12489500e+01
#  1.10000000e+01 1.71552444e+02 4.34976790e+04 9.98493635e+01
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=40 || lCount=160 || fCount=13
# [1.20000000e+01 1.89571398e+02 8.31383735e+04 9.46053625e+01
#  1.10000000e+01 2.05683756e+02 6.04452010e+04 2.30832240e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=41 || lCount=161 || fCount=13
# [1.10000000e+01 1.74699087e+02 3.31447349e+04 1.15649729e+02
#  1.10000000e+01 2.21591794e+02 1.90204449e+05 3.16648992e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=42 || lCount=162 || fCount=13
# [1.20000000e+01 1.59285885e+02 1.89419247e+04 7.60573013e+01
#  1.10000000e+01 2.60741483e+02 2.25543873e+05 3.77500081e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=43 || lCount=163 || fCount=13
# [1.10000000e+01 1.93262331e+02 9.73449477e+04 1.49571920e+02
#  1.10000000e+01 2.94608582e+02 5.28325894e+05 6.73055997e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=44 || lCount=164 || fCount=13
# [1.20000000e+01 1.90815149e+02 1.02529830e+05 1.50947472e+02
#  1.10000000e+01 3.01012275e+02 6.32789347e+05 7.60605178e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=45 || lCount=165 || fCount=13
# [1.00000000e+01 1.83925363e+02 2.62544144e+04 1.81016940e+02
#  1.00000000e+01 2.87948290e+02 2.39413414e+05 9.60233597e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=46 || lCount=166 || fCount=13
# [4.00000000e+00 1.58915182e+02 1.71218314e+05 1.38842101e+02
#  9.00000000e+00 2.34925327e+02 4.89466486e+05 6.30733409e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=47 || lCount=167 || fCount=13
# [1.10000000e+01 1.70728130e+02 4.88416409e+04 1.35353822e+02
#  1.30000000e+01 2.38907265e+02 1.42851154e+05 3.87821529e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=48 || lCount=168 || fCount=13
# [1.10000000e+01 1.47175724e+02 2.77791015e+04 4.81325866e+01
#  1.10000000e+01 2.09232557e+02 1.11256986e+05 1.21153572e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=49 || lCount=169 || fCount=13
# [1.10000000e+01 1.41665288e+02 2.86410991e+04 4.07529481e+01
#  1.20000000e+01 2.12185032e+02 1.39012844e+05 1.75176345e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=50 || lCount=170 || fCount=13
# [1.10000000e+01 1.37720241e+02 1.72209491e+04 5.46251197e+01
#  1.10000000e+01 1.93529633e+02 9.20272875e+04 2.62801666e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=51 || lCount=171 || fCount=13
# [1.40000000e+01 1.11663227e+02 4.64598460e+03 1.43015175e+01
#  1.00000000e+01 1.43484837e+02 1.68891988e+04 7.75451047e+01
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=52 || lCount=172 || fCount=13
# [9.00000000e+00 1.37957899e+02 8.57246900e+03 1.24885905e+02
#  9.00000000e+00 1.79473342e+02 4.18354574e+04 2.74596345e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=53 || lCount=173 || fCount=13
# [1.20000000e+01 1.48446614e+02 7.52346219e+04 8.65110794e+01
#  1.20000000e+01 2.31298134e+02 2.78195113e+05 3.05530043e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=54 || lCount=174 || fCount=13
# [1.10000000e+01 1.73938872e+02 2.97776806e+04 1.94683664e+02
#  1.10000000e+01 2.67387296e+02 2.45079330e+05 5.63622377e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=55 || lCount=175 || fCount=13
# [1.20000000e+01 1.91887004e+02 8.87196854e+04 1.49513051e+02
#  1.20000000e+01 2.79054531e+02 3.80251655e+05 4.89528232e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=56 || lCount=176 || fCount=13
# [1.10000000e+01 2.38584148e+02 2.05680293e+05 1.68941476e+02
#  1.10000000e+01 3.28659140e+02 7.91163060e+05 5.64982298e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=57 || lCount=177 || fCount=13
# [1.10000000e+01 2.26321572e+02 1.47285699e+05 2.08090588e+02
#  1.10000000e+01 3.00671418e+02 5.36160267e+05 7.41331258e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=58 || lCount=178 || fCount=13
# [1.10000000e+01 1.75525603e+02 3.90896377e+04 7.57900725e+01
#  1.10000000e+01 2.27440037e+02 9.04193534e+04 2.33747869e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=59 || lCount=179 || fCount=13
# [1.00000000e+01 1.21062157e+02 1.76326680e+04 2.54139708e+01
#  1.10000000e+01 1.71189311e+02 7.62772013e+04 8.88425632e+01
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=60 || lCount=180 || fCount=13
# [1.10000000e+01 9.50550002e+01 1.55860500e+03 2.32850901e+01
#  1.10000000e+01 1.62233995e+02 2.89943220e+04 6.30998574e+01
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=61 || lCount=181 || fCount=13
# [1.10000000e+01 8.64574154e+01 4.46112696e+02 2.92969527e+01
#  1.10000000e+01 1.73503318e+02 3.55350362e+04 1.53784559e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=62 || lCount=182 || fCount=13
# [1.00000000e+01 1.13915209e+02 1.61746156e+04 3.49040556e+01
#  1.10000000e+01 2.10843870e+02 1.91528730e+05 2.25821051e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=63 || lCount=183 || fCount=13
# [1.10000000e+01 1.49902195e+02 2.72971293e+04 4.06798479e+01
#  1.10000000e+01 2.13873642e+02 1.63285938e+05 2.09572554e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=64 || lCount=184 || fCount=13
# [1.10000000e+01 1.45942001e+02 4.73764350e+04 1.22190421e+02
#  1.10000000e+01 1.95727445e+02 1.27347134e+05 1.98953940e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=65 || lCount=185 || fCount=13
# [4.00000000e+00 1.10306293e+02 3.25049763e+04 1.22450827e+02
#  5.00000000e+00 1.40799574e+02 1.98843179e+05 1.76918094e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=66 || lCount=186 || fCount=13
# [1.20000000e+01 8.22033335e+01 1.22152035e+03 8.65369758e+00
#  7.00000000e+00 9.34178113e+01 7.87427726e+03 4.01515792e+01
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=67 || lCount=187 || fCount=13
# [6.00000000e+00 1.32894751e+02 1.94755354e+04 1.61536036e+02
#  6.00000000e+00 1.53178317e+02 6.67158942e+04 5.94581180e+02
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=68 || lCount=188 || fCount=13
# [4.00000000e+00 1.65872927e+02 4.60437816e+06 4.50144700e+02
#  4.00000000e+00 2.00680707e+02 1.47533901e+07 1.43115329e+03
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=69 || lCount=189 || fCount=13
# [4.00000000e+00 1.60617200e+02 2.90621552e+06 4.95832402e+02
#  2.00000000e+00 2.01894578e+02 9.52755685e+06 1.58086150e+03
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=70 || lCount=190 || fCount=13
# [8.00000000e+00 1.12436547e+02 8.18316382e+04 6.29433391e+02
#  4.00000000e+00 1.39263844e+02 3.22026239e+05 1.76362442e+03
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=71 || lCount=191 || fCount=13
# [1.00000000e+01 8.38301871e+01 5.54465485e+03 2.41597442e+01
#  8.00000000e+00 9.84389779e+01 2.41646472e+04 8.27505531e+01
#  1.62557644e+00 1.09338065e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=72 || lCount=192 || fCount=13
# [1.30000000e+01 8.25844027e+01 3.08480329e+03 8.72709801e+00
#  8.00000000e+00 8.37610966e+01 5.11600222e+03 3.54409753e+01
# ...
# 707:	learn: 0.0086347	total: 1.84s	remaining: 757ms
# 708:	learn: 0.0086299	total: 1.84s	remaining: 755ms
# 709:	learn: 0.0086085	total: 1.84s	remaining: 752ms
# 710:	learn: 0.0086016	total: 1.84s	remaining: 749ms
# 711:	learn: 0.0085824	total: 1.85s	remaining: 747ms
# 712:	learn: 0.0085718	total: 1.85s	remaining: 744ms
# 713:	learn: 0.0085587	total: 1.85s	remaining: 742ms
# 714:	learn: 0.0085475	total: 1.85s	remaining: 739ms
# 715:	learn: 0.0085313	total: 1.86s	remaining: 737ms
# 716:	learn: 0.0085250	total: 1.86s	remaining: 734ms
# 717:	learn: 0.0085115	total: 1.86s	remaining: 732ms
# 718:	learn: 0.0084940	total: 1.86s	remaining: 729ms
# 719:	learn: 0.0084896	total: 1.87s	remaining: 727ms
# 720:	learn: 0.0084846	total: 1.87s	remaining: 724ms
# 721:	learn: 0.0084674	total: 1.87s	remaining: 721ms
# 722:	learn: 0.0084543	total: 1.88s	remaining: 719ms
# 723:	learn: 0.0084454	total: 1.88s	remaining: 716ms
# 724:	learn: 0.0084415	total: 1.88s	remaining: 713ms
# 725:	learn: 0.0084221	total: 1.88s	remaining: 711ms
# 726:	learn: 0.0084108	total: 1.89s	remaining: 708ms
# 727:	learn: 0.0083934	total: 1.89s	remaining: 706ms
# 728:	learn: 0.0083826	total: 1.89s	remaining: 703ms
# 729:	learn: 0.0083672	total: 1.89s	remaining: 701ms
# 730:	learn: 0.0083493	total: 1.9s	remaining: 698ms
# 731:	learn: 0.0083410	total: 1.9s	remaining: 695ms
# 732:	learn: 0.0083269	total: 1.9s	remaining: 693ms
# 733:	learn: 0.0083205	total: 1.9s	remaining: 690ms
# 734:	learn: 0.0083031	total: 1.91s	remaining: 688ms
# 735:	learn: 0.0082928	total: 1.91s	remaining: 685ms
# 736:	learn: 0.0082883	total: 1.91s	remaining: 683ms
# 737:	learn: 0.0082712	total: 1.92s	remaining: 680ms
# 738:	learn: 0.0082674	total: 1.92s	remaining: 678ms
# 739:	learn: 0.0082567	total: 1.92s	remaining: 675ms
# 740:	learn: 0.0082380	total: 1.92s	remaining: 673ms
# 741:	learn: 0.0082188	total: 1.93s	remaining: 670ms
# 742:	learn: 0.0082146	total: 1.93s	remaining: 668ms
# 743:	learn: 0.0081985	total: 1.93s	remaining: 665ms
# 744:	learn: 0.0081933	total: 1.94s	remaining: 662ms
# 745:	learn: 0.0081755	total: 1.94s	remaining: 660ms
# 746:	learn: 0.0081628	total: 1.94s	remaining: 657ms
# 747:	learn: 0.0081528	total: 1.94s	remaining: 655ms
# 748:	learn: 0.0081422	total: 1.95s	remaining: 652ms
# 749:	learn: 0.0081307	total: 1.95s	remaining: 649ms
# 750:	learn: 0.0081251	total: 1.95s	remaining: 647ms
# 751:	learn: 0.0081129	total: 1.95s	remaining: 644ms
# 752:	learn: 0.0080994	total: 1.96s	remaining: 642ms
# 753:	learn: 0.0080910	total: 1.96s	remaining: 639ms
# 754:	learn: 0.0080787	total: 1.96s	remaining: 637ms
# 755:	learn: 0.0080731	total: 1.97s	remaining: 634ms
# 756:	learn: 0.0080562	total: 1.97s	remaining: 632ms
# 757:	learn: 0.0080527	total: 1.97s	remaining: 629ms
# 758:	learn: 0.0080488	total: 1.97s	remaining: 626ms
# 759:	learn: 0.0080383	total: 1.98s	remaining: 624ms
# 760:	learn: 0.0080264	total: 1.98s	remaining: 621ms
# 761:	learn: 0.0080099	total: 1.98s	remaining: 619ms
# 762:	learn: 0.0079945	total: 1.98s	remaining: 616ms
# 763:	learn: 0.0079840	total: 1.99s	remaining: 613ms
# 764:	learn: 0.0079716	total: 1.99s	remaining: 611ms
# 765:	learn: 0.0079605	total: 1.99s	remaining: 608ms
# 766:	learn: 0.0079502	total: 1.99s	remaining: 606ms
# 767:	learn: 0.0079365	total: 2s	remaining: 603ms
# 768:	learn: 0.0079232	total: 2s	remaining: 600ms
# 769:	learn: 0.0079086	total: 2s	remaining: 598ms
# 770:	learn: 0.0078937	total: 2s	remaining: 595ms
# 771:	learn: 0.0078827	total: 2.01s	remaining: 593ms
# 772:	learn: 0.0078615	total: 2.01s	remaining: 590ms
# 773:	learn: 0.0078584	total: 2.01s	remaining: 587ms
# 774:	learn: 0.0078457	total: 2.01s	remaining: 585ms
# 775:	learn: 0.0078278	total: 2.02s	remaining: 582ms
# 776:	learn: 0.0078183	total: 2.02s	remaining: 580ms
# 777:	learn: 0.0078147	total: 2.02s	remaining: 577ms
# 778:	learn: 0.0078022	total: 2.02s	remaining: 574ms
# 779:	learn: 0.0077922	total: 2.03s	remaining: 572ms
# 780:	learn: 0.0077869	total: 2.03s	remaining: 569ms
# 781:	learn: 0.0077751	total: 2.03s	remaining: 566ms
# 782:	learn: 0.0077621	total: 2.04s	remaining: 564ms
# 783:	learn: 0.0077558	total: 2.04s	remaining: 561ms
# 784:	learn: 0.0077444	total: 2.04s	remaining: 559ms
# 785:	learn: 0.0077330	total: 2.04s	remaining: 556ms
# 786:	learn: 0.0077226	total: 2.04s	remaining: 553ms
# 787:	learn: 0.0077151	total: 2.05s	remaining: 551ms
# 788:	learn: 0.0077024	total: 2.05s	remaining: 548ms
# 789:	learn: 0.0076985	total: 2.05s	remaining: 546ms
# 790:	learn: 0.0076933	total: 2.05s	remaining: 543ms
# 791:	learn: 0.0076732	total: 2.06s	remaining: 540ms
# 792:	learn: 0.0076673	total: 2.06s	remaining: 538ms
# 793:	learn: 0.0076532	total: 2.06s	remaining: 535ms
# 794:	learn: 0.0076392	total: 2.06s	remaining: 532ms
# 795:	learn: 0.0076252	total: 2.07s	remaining: 530ms
# 796:	learn: 0.0076157	total: 2.07s	remaining: 527ms
# 797:	learn: 0.0076129	total: 2.07s	remaining: 525ms
# 798:	learn: 0.0075979	total: 2.07s	remaining: 522ms
# 799:	learn: 0.0075924	total: 2.08s	remaining: 519ms
# 800:	learn: 0.0075830	total: 2.08s	remaining: 517ms
# 801:	learn: 0.0075756	total: 2.08s	remaining: 514ms
# 802:	learn: 0.0075669	total: 2.08s	remaining: 511ms
# 803:	learn: 0.0075574	total: 2.09s	remaining: 509ms
# 804:	learn: 0.0075538	total: 2.09s	remaining: 506ms
# 805:	learn: 0.0075492	total: 2.09s	remaining: 504ms
# 806:	learn: 0.0075394	total: 2.09s	remaining: 501ms
# 807:	learn: 0.0075319	total: 2.11s	remaining: 501ms
# 808:	learn: 0.0075255	total: 2.11s	remaining: 498ms
# 809:	learn: 0.0075107	total: 2.11s	remaining: 495ms
# 810:	learn: 0.0075058	total: 2.11s	remaining: 493ms
# 811:	learn: 0.0074992	total: 2.12s	remaining: 490ms
# 812:	learn: 0.0074908	total: 2.12s	remaining: 488ms
# 813:	learn: 0.0074795	total: 2.12s	remaining: 485ms
# 814:	learn: 0.0074750	total: 2.12s	remaining: 482ms
# 815:	learn: 0.0074630	total: 2.13s	remaining: 480ms
# 816:	learn: 0.0074491	total: 2.13s	remaining: 477ms
# 817:	learn: 0.0074423	total: 2.13s	remaining: 474ms
# 818:	learn: 0.0074285	total: 2.13s	remaining: 472ms
# 819:	learn: 0.0074155	total: 2.14s	remaining: 469ms
# 820:	learn: 0.0074077	total: 2.14s	remaining: 467ms
# 821:	learn: 0.0073987	total: 2.14s	remaining: 464ms
# 822:	learn: 0.0073921	total: 2.14s	remaining: 461ms
# 823:	learn: 0.0073872	total: 2.15s	remaining: 459ms
# 824:	learn: 0.0073848	total: 2.15s	remaining: 456ms
# 825:	learn: 0.0073810	total: 2.15s	remaining: 453ms
# 826:	learn: 0.0073737	total: 2.15s	remaining: 451ms
# 827:	learn: 0.0073647	total: 2.16s	remaining: 448ms
# 828:	learn: 0.0073565	total: 2.16s	remaining: 445ms
# 829:	learn: 0.0073494	total: 2.16s	remaining: 443ms
# 830:	learn: 0.0073404	total: 2.16s	remaining: 440ms
# 831:	learn: 0.0073344	total: 2.17s	remaining: 438ms
# 832:	learn: 0.0073244	total: 2.17s	remaining: 435ms
# 833:	learn: 0.0073194	total: 2.17s	remaining: 432ms
# 834:	learn: 0.0073130	total: 2.17s	remaining: 430ms
# 835:	learn: 0.0073034	total: 2.18s	remaining: 427ms
# 836:	learn: 0.0072962	total: 2.18s	remaining: 425ms
# 837:	learn: 0.0072897	total: 2.18s	remaining: 422ms
# 838:	learn: 0.0072782	total: 2.19s	remaining: 419ms
# 839:	learn: 0.0072662	total: 2.19s	remaining: 417ms
# 840:	learn: 0.0072595	total: 2.19s	remaining: 414ms
# 841:	learn: 0.0072544	total: 2.19s	remaining: 412ms
# 842:	learn: 0.0072460	total: 2.19s	remaining: 409ms
# 843:	learn: 0.0072413	total: 2.2s	remaining: 406ms
# 844:	learn: 0.0072384	total: 2.2s	remaining: 404ms
# 845:	learn: 0.0072335	total: 2.2s	remaining: 401ms
# 846:	learn: 0.0072216	total: 2.21s	remaining: 399ms
# 847:	learn: 0.0072130	total: 2.21s	remaining: 396ms
# 848:	learn: 0.0071979	total: 2.21s	remaining: 393ms
# 849:	learn: 0.0071918	total: 2.21s	remaining: 391ms
# 850:	learn: 0.0071895	total: 2.22s	remaining: 388ms
# 851:	learn: 0.0071739	total: 2.22s	remaining: 386ms
# 852:	learn: 0.0071642	total: 2.22s	remaining: 383ms
# 853:	learn: 0.0071574	total: 2.22s	remaining: 380ms
# 854:	learn: 0.0071486	total: 2.23s	remaining: 378ms
# 855:	learn: 0.0071410	total: 2.23s	remaining: 375ms
# 856:	learn: 0.0071342	total: 2.23s	remaining: 372ms
# 857:	learn: 0.0071298	total: 2.23s	remaining: 370ms
# 858:	learn: 0.0071246	total: 2.24s	remaining: 367ms
# 859:	learn: 0.0071138	total: 2.24s	remaining: 365ms
# 860:	learn: 0.0071055	total: 2.24s	remaining: 362ms
# 861:	learn: 0.0070995	total: 2.25s	remaining: 359ms
# 862:	learn: 0.0070925	total: 2.25s	remaining: 357ms
# 863:	learn: 0.0070817	total: 2.25s	remaining: 354ms
# 864:	learn: 0.0070746	total: 2.25s	remaining: 352ms
# 865:	learn: 0.0070703	total: 2.25s	remaining: 349ms
# 866:	learn: 0.0070661	total: 2.26s	remaining: 346ms
# 867:	learn: 0.0070507	total: 2.26s	remaining: 344ms
# 868:	learn: 0.0070483	total: 2.26s	remaining: 341ms
# 869:	learn: 0.0070412	total: 2.27s	remaining: 339ms
# 870:	learn: 0.0070372	total: 2.27s	remaining: 336ms
# 871:	learn: 0.0070276	total: 2.27s	remaining: 333ms
# 872:	learn: 0.0070229	total: 2.27s	remaining: 331ms
# 873:	learn: 0.0070139	total: 2.28s	remaining: 328ms
# 874:	learn: 0.0070027	total: 2.28s	remaining: 326ms
# 875:	learn: 0.0069975	total: 2.28s	remaining: 323ms
# 876:	learn: 0.0069827	total: 2.29s	remaining: 320ms
# 877:	learn: 0.0069764	total: 2.29s	remaining: 318ms
# 878:	learn: 0.0069732	total: 2.29s	remaining: 315ms
# 879:	learn: 0.0069551	total: 2.29s	remaining: 313ms
# 880:	learn: 0.0069497	total: 2.29s	remaining: 310ms
# 881:	learn: 0.0069461	total: 2.3s	remaining: 307ms
# 882:	learn: 0.0069403	total: 2.3s	remaining: 305ms
# 883:	learn: 0.0069336	total: 2.3s	remaining: 302ms
# 884:	learn: 0.0069264	total: 2.31s	remaining: 300ms
# 885:	learn: 0.0069228	total: 2.31s	remaining: 297ms
# 886:	learn: 0.0069092	total: 2.31s	remaining: 294ms
# 887:	learn: 0.0068992	total: 2.31s	remaining: 292ms
# 888:	learn: 0.0068892	total: 2.31s	remaining: 289ms
# 889:	learn: 0.0068865	total: 2.32s	remaining: 286ms
# 890:	learn: 0.0068751	total: 2.32s	remaining: 284ms
# 891:	learn: 0.0068678	total: 2.32s	remaining: 281ms
# 892:	learn: 0.0068630	total: 2.33s	remaining: 279ms
# 893:	learn: 0.0068615	total: 2.33s	remaining: 276ms
# 894:	learn: 0.0068534	total: 2.33s	remaining: 273ms
# 895:	learn: 0.0068487	total: 2.33s	remaining: 271ms
# 896:	learn: 0.0068465	total: 2.33s	remaining: 268ms
# 897:	learn: 0.0068394	total: 2.34s	remaining: 266ms
# 898:	learn: 0.0068340	total: 2.34s	remaining: 263ms
# 899:	learn: 0.0068287	total: 2.34s	remaining: 260ms
# 900:	learn: 0.0068185	total: 2.35s	remaining: 258ms
# 901:	learn: 0.0068064	total: 2.35s	remaining: 255ms
# 902:	learn: 0.0067964	total: 2.35s	remaining: 253ms
# 903:	learn: 0.0067909	total: 2.35s	remaining: 250ms
# 904:	learn: 0.0067834	total: 2.36s	remaining: 247ms
# 905:	learn: 0.0067742	total: 2.36s	remaining: 245ms
# 906:	learn: 0.0067710	total: 2.36s	remaining: 242ms
# 907:	learn: 0.0067648	total: 2.36s	remaining: 240ms
# 908:	learn: 0.0067522	total: 2.37s	remaining: 237ms
# 909:	learn: 0.0067434	total: 2.37s	remaining: 234ms
# 910:	learn: 0.0067349	total: 2.37s	remaining: 232ms
# 911:	learn: 0.0067254	total: 2.37s	remaining: 229ms
# 912:	learn: 0.0067157	total: 2.38s	remaining: 226ms
# 913:	learn: 0.0067035	total: 2.38s	remaining: 224ms
# 914:	learn: 0.0067021	total: 2.38s	remaining: 221ms
# 915:	learn: 0.0066967	total: 2.38s	remaining: 219ms
# 916:	learn: 0.0066803	total: 2.39s	remaining: 216ms
# 917:	learn: 0.0066773	total: 2.39s	remaining: 213ms
# 918:	learn: 0.0066699	total: 2.39s	remaining: 211ms
# 919:	learn: 0.0066613	total: 2.39s	remaining: 208ms
# 920:	learn: 0.0066545	total: 2.4s	remaining: 206ms
# 921:	learn: 0.0066476	total: 2.4s	remaining: 203ms
# 922:	learn: 0.0066368	total: 2.4s	remaining: 200ms
# 923:	learn: 0.0066326	total: 2.4s	remaining: 198ms
# 924:	learn: 0.0066316	total: 2.41s	remaining: 195ms
# 925:	learn: 0.0066288	total: 2.41s	remaining: 193ms
# 926:	learn: 0.0066212	total: 2.41s	remaining: 190ms
# 927:	learn: 0.0066159	total: 2.41s	remaining: 187ms
# 928:	learn: 0.0066150	total: 2.42s	remaining: 185ms
# 929:	learn: 0.0066103	total: 2.42s	remaining: 182ms
# 930:	learn: 0.0066054	total: 2.42s	remaining: 180ms
# 931:	learn: 0.0065976	total: 2.42s	remaining: 177ms
# 932:	learn: 0.0065886	total: 2.43s	remaining: 174ms
# 933:	learn: 0.0065834	total: 2.43s	remaining: 172ms
# 934:	learn: 0.0065791	total: 2.43s	remaining: 169ms
# 935:	learn: 0.0065727	total: 2.44s	remaining: 167ms
# 936:	learn: 0.0065691	total: 2.44s	remaining: 164ms
# 937:	learn: 0.0065505	total: 2.44s	remaining: 161ms
# 938:	learn: 0.0065435	total: 2.44s	remaining: 159ms
# 939:	learn: 0.0065409	total: 2.44s	remaining: 156ms
# 940:	learn: 0.0065371	total: 2.45s	remaining: 154ms
# 941:	learn: 0.0065268	total: 2.45s	remaining: 151ms
# 942:	learn: 0.0065218	total: 2.45s	remaining: 148ms
# 943:	learn: 0.0065082	total: 2.46s	remaining: 146ms
# 944:	learn: 0.0065042	total: 2.46s	remaining: 143ms
# 945:	learn: 0.0065022	total: 2.46s	remaining: 140ms
# 946:	learn: 0.0064981	total: 2.46s	remaining: 138ms
# 947:	learn: 0.0064955	total: 2.47s	remaining: 135ms
# 948:	learn: 0.0064881	total: 2.47s	remaining: 133ms
# 949:	learn: 0.0064790	total: 2.47s	remaining: 130ms
# 950:	learn: 0.0064749	total: 2.47s	remaining: 127ms
# 951:	learn: 0.0064677	total: 2.48s	remaining: 125ms
# 952:	learn: 0.0064576	total: 2.48s	remaining: 122ms
# 953:	learn: 0.0064512	total: 2.48s	remaining: 120ms
# 954:	learn: 0.0064411	total: 2.48s	remaining: 117ms
# 955:	learn: 0.0064353	total: 2.49s	remaining: 114ms
# 956:	learn: 0.0064315	total: 2.49s	remaining: 112ms
# 957:	learn: 0.0064292	total: 2.49s	remaining: 109ms
# 958:	learn: 0.0064194	total: 2.5s	remaining: 107ms
# 959:	learn: 0.0064140	total: 2.5s	remaining: 104ms
# 960:	learn: 0.0064020	total: 2.5s	remaining: 101ms
# 961:	learn: 0.0063931	total: 2.5s	remaining: 98.9ms
# 962:	learn: 0.0063812	total: 2.5s	remaining: 96.3ms
# 963:	learn: 0.0063761	total: 2.51s	remaining: 93.7ms
# 964:	learn: 0.0063726	total: 2.51s	remaining: 91.1ms
# 965:	learn: 0.0063698	total: 2.51s	remaining: 88.5ms
# 966:	learn: 0.0063598	total: 2.52s	remaining: 85.9ms
# 967:	learn: 0.0063547	total: 2.52s	remaining: 83.3ms
# 968:	learn: 0.0063502	total: 2.52s	remaining: 80.7ms
# 969:	learn: 0.0063423	total: 2.52s	remaining: 78ms
# 970:	learn: 0.0063345	total: 2.52s	remaining: 75.4ms
# 971:	learn: 0.0063322	total: 2.53s	remaining: 72.8ms
# 972:	learn: 0.0063225	total: 2.53s	remaining: 70.2ms
# 973:	learn: 0.0063117	total: 2.53s	remaining: 67.6ms
# 974:	learn: 0.0063044	total: 2.54s	remaining: 65ms
# 975:	learn: 0.0062982	total: 2.54s	remaining: 62.4ms
# 976:	learn: 0.0062925	total: 2.54s	remaining: 59.8ms
# 977:	learn: 0.0062809	total: 2.54s	remaining: 57.2ms
# 978:	learn: 0.0062740	total: 2.55s	remaining: 54.6ms
# 979:	learn: 0.0062669	total: 2.55s	remaining: 52ms
# 980:	learn: 0.0062589	total: 2.55s	remaining: 49.4ms
# 981:	learn: 0.0062552	total: 2.55s	remaining: 46.8ms
# 982:	learn: 0.0062464	total: 2.56s	remaining: 44.2ms
# 983:	learn: 0.0062436	total: 2.56s	remaining: 41.6ms
# 984:	learn: 0.0062382	total: 2.56s	remaining: 39ms
# 985:	learn: 0.0062297	total: 2.56s	remaining: 36.4ms
# 986:	learn: 0.0062215	total: 2.57s	remaining: 33.8ms
# 987:	learn: 0.0062140	total: 2.57s	remaining: 31.2ms
# 988:	learn: 0.0062033	total: 2.57s	remaining: 28.6ms
# 989:	learn: 0.0061951	total: 2.57s	remaining: 26ms
# 990:	learn: 0.0061941	total: 2.58s	remaining: 23.4ms
# 991:	learn: 0.0061893	total: 2.58s	remaining: 20.8ms
# 992:	learn: 0.0061858	total: 2.58s	remaining: 18.2ms
# 993:	learn: 0.0061772	total: 2.58s	remaining: 15.6ms
# 994:	learn: 0.0061675	total: 2.59s	remaining: 13ms
# 995:	learn: 0.0061609	total: 2.59s	remaining: 10.4ms
# 996:	learn: 0.0061575	total: 2.59s	remaining: 7.81ms
# 997:	learn: 0.0061507	total: 2.6s	remaining: 5.21ms
# 998:	learn: 0.0061458	total: 2.6s	remaining: 2.6ms
# 999:	learn: 0.0061395	total: 2.6s	remaining: 0us
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] bagging_fraction is set=1, subsample=1.0 will be ignored. Current value: bagging_fraction=1
# [LightGBM] [Warning] bagging_freq is set=100, subsample_freq=0 will be ignored. Current value: bagging_freq=100
# c:\Users\RBM-WorkStation\AppData\Local\Programs\Python\Python39\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")

# %% [markdown]
# > Evaluation of __Test 2__

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'XG Boost',
    predictedValue = t2_results_xg,
    exactValue     = t2_e_results_xg
)
# Out:
# ############ HbA1c Evaluation Metrics of XG Boost Regression ############
# Diff STD  =  0.36379424968015844
# MSE       =  0.13246512967072072
# ME        =  -0.010902915682111245
# MAD       =  0.2439468792506625
# RMSE      =  0.3639575932313004
# R2 score  =  0.8373311691777563
# Pearson R and p-value:  PearsonRResult(statistic=0.9187397025280967, pvalue=5.39375672721449e-12)
# ##################################################################################

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'Random Forest',
    predictedValue = t2_results_rf,
    exactValue     = t2_e_results_rf
)
# Out:
# ############ HbA1c Evaluation Metrics of Random Forest Regression ############
# Diff STD  =  0.517880214248492
# MSE       =  0.2750923256042077
# ME        =  -0.0830205353761573
# MAD       =  0.36970309010303176
# RMSE      =  0.5244924457074741
# R2 score  =  0.6621831942833218
# Pearson R and p-value:  PearsonRResult(statistic=0.822063699719589, pvalue=8.109070265272012e-08)
# ##################################################################################

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'Cat Boost',
    predictedValue = t2_results_cb,
    exactValue     = t2_e_results_cb
)
# Out:
# ############ HbA1c Evaluation Metrics of Cat Boost Regression ############
# Diff STD  =  0.3241788275472866
# MSE       =  0.10769818730560154
# ME        =  -0.05105169023321527
# MAD       =  0.2322931303345032
# RMSE      =  0.32817401985166583
# R2 score  =  0.8677452831984844
# Pearson R and p-value:  PearsonRResult(statistic=0.9399445077560417, pvalue=1.1956365369566545e-13)
# ##################################################################################

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'Light GBM',
    predictedValue = t2_results_lg,
    exactValue     = t2_e_results_lg
)
# Out:
# ############ HbA1c Evaluation Metrics of Light GBM Regression ############
# Diff STD  =  0.5131950261878714
# MSE       =  0.27009099499253786
# ME        =  0.0819869507212448
# MAD       =  0.3652163076603599
# RMSE      =  0.519702794866968
# R2 score  =  0.6683248906314715
# Pearson R and p-value:  PearsonRResult(statistic=0.8483553125276642, pvalue=1.1879750507062638e-08)
# ##################################################################################

# %%
ltb.plot_importance(booster= lg)
plt.show()
