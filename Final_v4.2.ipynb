# %% [markdown]
# >__ACK:__ *** This whole code is developed by __Shama Satter__ ***

# %% [markdown]
# # __Create environment for running AI program__

# %% [markdown]
# > __Install libraris__ https://pypi.org

# %%
# %pip install --upgrade pip
# %pip install --user --upgrade pandas
# %pip install --user --upgrade heartpy
# %pip install --user --upgrade tsfel
# %pip install --user --upgrade librosa
# %pip install --user --upgrade statsmodels
# %pip install --user --upgrade lightgbm
# %pip install --user --upgrade catboost
# %pip install --user --upgrade xgboost
# Out:
# Requirement already satisfied: pip in c:\users\shama\anaconda3\envs\py39==env6\lib\site-packages (23.0.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in c:\users\shama\appdata\roaming\python\python39\site-packages (1.5.3)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\shama\appdata\roaming\python\python39\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\shama\appdata\roaming\python\python39\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shama\appdata\roaming\python\python39\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\shama\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: heartpy in c:\users\shama\appdata\roaming\python\python39\site-packages (1.2.7)
# Requirement already satisfied: scipy in c:\users\shama\appdata\roaming\python\python39\site-packages (from heartpy) (1.10.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\shama\appdata\roaming\python\python39\site-packages (from heartpy) (1.23.5)
# Requirement already satisfied: matplotlib in c:\users\shama\appdata\roaming\python\python39\site-packages (from heartpy) (3.7.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\shama\appdata\roaming\python\python39\site-packages (from matplotlib->heartpy) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from matplotlib->heartpy) (5.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shama\appdata\roaming\python\python39\site-packages (from matplotlib->heartpy) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from matplotlib->heartpy) (4.39.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from matplotlib->heartpy) (22.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\shama\appdata\roaming\python\python39\site-packages (from matplotlib->heartpy) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from matplotlib->heartpy) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shama\appdata\roaming\python\python39\site-packages (from matplotlib->heartpy) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shama\appdata\roaming\python\python39\site-packages (from matplotlib->heartpy) (1.4.4)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from importlib-resources>=3.2.0->matplotlib->heartpy) (3.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\shama\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib->heartpy) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tsfel in c:\users\shama\appdata\roaming\python\python39\site-packages (0.1.5)
# Requirement already satisfied: ipython>=7.4.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from tsfel) (8.7.0)
# Requirement already satisfied: gspread>=3.1.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from tsfel) (5.7.2)
# Requirement already satisfied: scipy>=1.7.3 in c:\users\shama\appdata\roaming\python\python39\site-packages (from tsfel) (1.10.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\shama\appdata\roaming\python\python39\site-packages (from tsfel) (1.23.5)
# Requirement already satisfied: oauth2client>=4.1.3 in c:\users\shama\appdata\roaming\python\python39\site-packages (from tsfel) (4.1.3)
# Requirement already satisfied: pandas>=1.5.3 in c:\users\shama\appdata\roaming\python\python39\site-packages (from tsfel) (1.5.3)
# Requirement already satisfied: Sphinx>=1.8.5 in c:\users\shama\appdata\roaming\python\python39\site-packages (from tsfel) (6.1.3)
# Requirement already satisfied: setuptools>=47.1.1 in c:\users\shama\anaconda3\envs\py39==env6\lib\site-packages (from tsfel) (65.6.3)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in c:\users\shama\appdata\roaming\python\python39\site-packages (from gspread>=3.1.0->tsfel) (1.0.0)
# Requirement already satisfied: google-auth>=1.12.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from gspread>=3.1.0->tsfel) (2.16.2)
# Requirement already satisfied: backcall in c:\users\shama\appdata\roaming\python\python39\site-packages (from ipython>=7.4.0->tsfel) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\shama\appdata\roaming\python\python39\site-packages (from ipython>=7.4.0->tsfel) (0.18.2)
# Requirement already satisfied: pickleshare in c:\users\shama\appdata\roaming\python\python39\site-packages (from ipython>=7.4.0->tsfel) (0.7.5)
# Requirement already satisfied: decorator in c:\users\shama\appdata\roaming\python\python39\site-packages (from ipython>=7.4.0->tsfel) (5.1.1)
# Requirement already satisfied: traitlets>=5 in c:\users\shama\appdata\roaming\python\python39\site-packages (from ipython>=7.4.0->tsfel) (5.8.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from ipython>=7.4.0->tsfel) (2.13.0)
# Requirement already satisfied: stack-data in c:\users\shama\appdata\roaming\python\python39\site-packages (from ipython>=7.4.0->tsfel) (0.6.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in c:\users\shama\appdata\roaming\python\python39\site-packages (from ipython>=7.4.0->tsfel) (3.0.36)
# Requirement already satisfied: matplotlib-inline in c:\users\shama\appdata\roaming\python\python39\site-packages (from ipython>=7.4.0->tsfel) (0.1.6)
# Requirement already satisfied: colorama in c:\users\shama\appdata\roaming\python\python39\site-packages (from ipython>=7.4.0->tsfel) (0.4.6)
# Requirement already satisfied: rsa>=3.1.4 in c:\users\shama\appdata\roaming\python\python39\site-packages (from oauth2client>=4.1.3->tsfel) (4.9)
# Requirement already satisfied: httplib2>=0.9.1 in c:\users\shama\appdata\roaming\python\python39\site-packages (from oauth2client>=4.1.3->tsfel) (0.21.0)
# Requirement already satisfied: pyasn1>=0.1.7 in c:\users\shama\appdata\roaming\python\python39\site-packages (from oauth2client>=4.1.3->tsfel) (0.4.8)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in c:\users\shama\appdata\roaming\python\python39\site-packages (from oauth2client>=4.1.3->tsfel) (0.2.8)
# Requirement already satisfied: six>=1.6.1 in c:\users\shama\appdata\roaming\python\python39\site-packages (from oauth2client>=4.1.3->tsfel) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\shama\appdata\roaming\python\python39\site-packages (from pandas>=1.5.3->tsfel) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shama\appdata\roaming\python\python39\site-packages (from pandas>=1.5.3->tsfel) (2022.7.1)
# Requirement already satisfied: sphinxcontrib-devhelp in c:\users\shama\appdata\roaming\python\python39\site-packages (from Sphinx>=1.8.5->tsfel) (1.0.2)
# Requirement already satisfied: sphinxcontrib-jsmath in c:\users\shama\appdata\roaming\python\python39\site-packages (from Sphinx>=1.8.5->tsfel) (1.0.1)
# Requirement already satisfied: imagesize>=1.3 in c:\users\shama\appdata\roaming\python\python39\site-packages (from Sphinx>=1.8.5->tsfel) (1.4.1)
# Requirement already satisfied: sphinxcontrib-applehelp in c:\users\shama\appdata\roaming\python\python39\site-packages (from Sphinx>=1.8.5->tsfel) (1.0.4)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from Sphinx>=1.8.5->tsfel) (3.1.2)
# Requirement already satisfied: requests>=2.25.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from Sphinx>=1.8.5->tsfel) (2.28.2)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in c:\users\shama\appdata\roaming\python\python39\site-packages (from Sphinx>=1.8.5->tsfel) (1.1.5)
# Requirement already satisfied: packaging>=21.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from Sphinx>=1.8.5->tsfel) (22.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in c:\users\shama\appdata\roaming\python\python39\site-packages (from Sphinx>=1.8.5->tsfel) (0.7.13)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from Sphinx>=1.8.5->tsfel) (2.0.1)
# Requirement already satisfied: importlib-metadata>=4.8 in c:\users\shama\appdata\roaming\python\python39\site-packages (from Sphinx>=1.8.5->tsfel) (6.0.0)
# Requirement already satisfied: babel>=2.9 in c:\users\shama\appdata\roaming\python\python39\site-packages (from Sphinx>=1.8.5->tsfel) (2.12.1)
# Requirement already satisfied: sphinxcontrib-qthelp in c:\users\shama\appdata\roaming\python\python39\site-packages (from Sphinx>=1.8.5->tsfel) (1.0.3)
# Requirement already satisfied: docutils<0.20,>=0.18 in c:\users\shama\appdata\roaming\python\python39\site-packages (from Sphinx>=1.8.5->tsfel) (0.19)
# Requirement already satisfied: snowballstemmer>=2.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from Sphinx>=1.8.5->tsfel) (2.2.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from google-auth>=1.12.0->gspread>=3.1.0->tsfel) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from google-auth-oauthlib>=0.4.1->gspread>=3.1.0->tsfel) (1.3.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\shama\appdata\roaming\python\python39\site-packages (from httplib2>=0.9.1->oauth2client>=4.1.3->tsfel) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in c:\users\shama\appdata\roaming\python\python39\site-packages (from importlib-metadata>=4.8->Sphinx>=1.8.5->tsfel) (3.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from jedi>=0.16->ipython>=7.4.0->tsfel) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from Jinja2>=3.0->Sphinx>=1.8.5->tsfel) (2.1.2)
# Requirement already satisfied: wcwidth in c:\users\shama\appdata\roaming\python\python39\site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython>=7.4.0->tsfel) (0.2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shama\appdata\roaming\python\python39\site-packages (from requests>=2.25.0->Sphinx>=1.8.5->tsfel) (3.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\shama\appdata\roaming\python\python39\site-packages (from requests>=2.25.0->Sphinx>=1.8.5->tsfel) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shama\anaconda3\envs\py39==env6\lib\site-packages (from requests>=2.25.0->Sphinx>=1.8.5->tsfel) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shama\appdata\roaming\python\python39\site-packages (from requests>=2.25.0->Sphinx>=1.8.5->tsfel) (3.4)
# Requirement already satisfied: executing>=1.2.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from stack-data->ipython>=7.4.0->tsfel) (1.2.0)
# Requirement already satisfied: pure-eval in c:\users\shama\appdata\roaming\python\python39\site-packages (from stack-data->ipython>=7.4.0->tsfel) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from stack-data->ipython>=7.4.0->tsfel) (2.2.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.1.0->tsfel) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: librosa in c:\users\shama\appdata\roaming\python\python39\site-packages (0.10.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: scipy>=1.2.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from librosa) (1.10.1)
# Requirement already satisfied: pooch>=1.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from librosa) (1.7.0)
# Requirement already satisfied: joblib>=0.14 in c:\users\shama\appdata\roaming\python\python39\site-packages (from librosa) (1.2.0)
# Requirement already satisfied: msgpack>=1.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from librosa) (1.0.5)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\shama\appdata\roaming\python\python39\site-packages (from librosa) (0.1)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\shama\appdata\roaming\python\python39\site-packages (from librosa) (1.23.5)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\shama\appdata\roaming\python\python39\site-packages (from librosa) (4.5.0)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\shama\appdata\roaming\python\python39\site-packages (from librosa) (0.3.4)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\shama\appdata\roaming\python\python39\site-packages (from librosa) (3.0.0)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\shama\appdata\roaming\python\python39\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from librosa) (1.2.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from librosa) (0.56.4)
# Requirement already satisfied: setuptools in c:\users\shama\anaconda3\envs\py39==env6\lib\site-packages (from numba>=0.51.0->librosa) (65.6.3)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from numba>=0.51.0->librosa) (0.39.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from pooch>=1.0->librosa) (22.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from pooch>=1.0->librosa) (2.28.2)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from pooch>=1.0->librosa) (2.6.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from scikit-learn>=0.20.0->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\shama\appdata\roaming\python\python39\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\shama\appdata\roaming\python\python39\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shama\appdata\roaming\python\python39\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shama\appdata\roaming\python\python39\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shama\anaconda3\envs\py39==env6\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2022.12.7)
# Requirement already satisfied: statsmodels in c:\users\shama\appdata\roaming\python\python39\site-packages (0.13.5)
# Requirement already satisfied: pandas>=0.25 in c:\users\shama\appdata\roaming\python\python39\site-packages (from statsmodels) (1.5.3)
# Requirement already satisfied: packaging>=21.3 in c:\users\shama\appdata\roaming\python\python39\site-packages (from statsmodels) (22.0)
# Requirement already satisfied: scipy>=1.3 in c:\users\shama\appdata\roaming\python\python39\site-packages (from statsmodels) (1.10.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\shama\appdata\roaming\python\python39\site-packages (from statsmodels) (1.23.5)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\shama\appdata\roaming\python\python39\site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\shama\appdata\roaming\python\python39\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shama\appdata\roaming\python\python39\site-packages (from pandas>=0.25->statsmodels) (2022.7.1)
# Requirement already satisfied: six in c:\users\shama\appdata\roaming\python\python39\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: lightgbm in c:\users\shama\appdata\roaming\python\python39\site-packages (3.3.5)
# Requirement already satisfied: numpy in c:\users\shama\appdata\roaming\python\python39\site-packages (from lightgbm) (1.23.5)
# Requirement already satisfied: scipy in c:\users\shama\appdata\roaming\python\python39\site-packages (from lightgbm) (1.10.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from lightgbm) (1.2.1)
# Requirement already satisfied: wheel in c:\users\shama\anaconda3\envs\py39==env6\lib\site-packages (from lightgbm) (0.38.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\shama\appdata\roaming\python\python39\site-packages (from scikit-learn!=0.22.0->lightgbm) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from scikit-learn!=0.22.0->lightgbm) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: catboost in c:\users\shama\appdata\roaming\python\python39\site-packages (1.1.1)
# Requirement already satisfied: graphviz in c:\users\shama\appdata\roaming\python\python39\site-packages (from catboost) (0.20.1)
# Requirement already satisfied: six in c:\users\shama\appdata\roaming\python\python39\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in c:\users\shama\appdata\roaming\python\python39\site-packages (from catboost) (1.10.1)
# Requirement already satisfied: plotly in c:\users\shama\appdata\roaming\python\python39\site-packages (from catboost) (5.13.1)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from catboost) (1.23.5)
# Requirement already satisfied: matplotlib in c:\users\shama\appdata\roaming\python\python39\site-packages (from catboost) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\shama\appdata\roaming\python\python39\site-packages (from pandas>=0.24.0->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shama\appdata\roaming\python\python39\site-packages (from pandas>=0.24.0->catboost) (2022.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shama\appdata\roaming\python\python39\site-packages (from matplotlib->catboost) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from matplotlib->catboost) (22.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from matplotlib->catboost) (5.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from matplotlib->catboost) (4.39.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\shama\appdata\roaming\python\python39\site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\shama\appdata\roaming\python\python39\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shama\appdata\roaming\python\python39\site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from plotly->catboost) (8.2.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\shama\appdata\roaming\python\python39\site-packages (from importlib-resources>=3.2.0->matplotlib->catboost) (3.15.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: xgboost in c:\users\shama\appdata\roaming\python\python39\site-packages (1.7.4)
# Requirement already satisfied: scipy in c:\users\shama\appdata\roaming\python\python39\site-packages (from xgboost) (1.10.1)
# Requirement already satisfied: numpy in c:\users\shama\appdata\roaming\python\python39\site-packages (from xgboost) (1.23.5)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# > __Import libraries and dependencies__

# %%
import pandas as pd
import numpy as np
import heartpy as hp
from   matplotlib import pyplot as plt
import tsfel
import scipy 
import sklearn as sk
from   sklearn.ensemble import RandomForestRegressor
#import librosa
import csv
import pandas as pd
import os
import xgboost as xgb
import random
import statsmodels.regression
from   warnings import filterwarnings
import lightgbm as ltb
from   sklearn import metrics
import catboost as cab
from   sklearn.model_selection import GridSearchCV
import time
from   datetime import datetime
from   sklearn.metrics import mean_squared_error, accuracy_score
from   sklearn.metrics import r2_score
from   IPython.display import clear_output
from sklearn.model_selection import KFold

# %% [markdown]
# # __Data collection & preprocessing__

# %% [markdown]
# > Mount Gdrive

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %% [markdown]
# > Inserting Data

# %%
PPG_dataDirectory = 'E:\OneDrive - KookminUNIV\KMU==Lab\MCSP==Research-Papers\SCI-02\Software\ProgrammingCodes\DataBase\data(mod)\\'

# %%
PPG_data =  [   
            '1_turja_0120_2023(356)_hb5.3_sp98.csv',   
            '2_thk_0125_2023.csv',   
            'kdk_356_0227.csv',             
            '4_shama_0125_2023.csv',             
            '5_jho_1_0125_2023.csv',            
            'khj_123_0228_2023.csv',                       
            'JKY_356_7.4.csv',          
            'youngsu_bang_245_0208_2023.csv',                   
            ]

# %%
filePath = 'E:\OneDrive - KookminUNIV\KMU==Lab\MCSP==Research-Papers\SCI-02\Software\ProgrammingCodes\DataBase\data(mod)\\1_turja_0120_2023(356)_hb5.3_sp98.csv'
filePath

#THis is how code works. You have to check each output. When ther is any numerical value at first. System can't identify right info. That is not the right path.
#  You didn't even add '\' in your code
# TO solve this I used '\\' as it is getting 1 in next
# Out:
# 'E:\\OneDrive - KookminUNIV\\KMU==Lab\\MCSP==Research-Papers\\SCI-02\\Software\\ProgrammingCodes\\DataBase\\data(mod)\\1_turja_0120_2023(356)_hb5.3_sp98.csv'

# %%
dat    = pd.read_csv(filePath, delimiter=',', header=None)

# %%
dat
# Out:
#          0     1     2
# 0     4856  4812  4760
# 1     4856  4812  4756
# 2     4856  4812  4764
# 3     4856  4816  4764
# 4     4860  4816  4764
# ...    ...   ...   ...
# 4278  4596  4464  4436
# 4279  4596  4464  4432
# 4280  4596  4464  4436
# 4281  4600  4468  4436
# 4282  4600  4472  4440
#
# [4283 rows x 3 columns]

# %%
## PPG Data
# define parent directory of PPG files
# PPG_dataDirectory = 'gdrive/My Drive/Colab Notebooks/SCI#02/DataBase/data/'
PPG_dataDirectory = 'E:\OneDrive - KookminUNIV\KMU==Lab\MCSP==Research-Papers\SCI-02\Software\ProgrammingCodes\DataBase\data(mod)\\'
# PPG CSV filenames
PPG_data =  [   
            '1_turja_0120_2023(356)_hb5.3_sp98.csv',   
            '2_thk_0125_2023.csv',   
            'kdk_356_0227.csv',             
            '4_shama_0125_2023.csv',             
            '5_jho_1_0125_2023.csv',            
            'khj_123_0228_2023.csv',                       
            'JKY_356_7.4.csv',          
            'youngsu_bang_245_0208_2023.csv',                   
            ]
# Assigning complete filename of PPG CSV data
PPG_csvData = []
for fileName in PPG_data:
    PPG_csvData.append(PPG_dataDirectory+fileName) # The fileName was a variable in previous code


## HbA1c data
HbA1c_data  =   [ 
                5.3,5.5,5.7,5.6,6.4,7.0,7.4,7.6,
                ]


## SpO2 data
SpO2_data   =   [ 99,96,98,98,97,97,96,96,               
                ]


## Age data
Age_data    =   [ 
                25,34,65,27,55,58,55,56,
            
                ]


## Gender data
Gender_data =   [ 
                'M','M','M','F','M','M','M',
                'M',
                ]


                
## BMI data
BMI_data    =   [ 
                26.7,26.4,22.2,26.4,25.4,21.7,26,28.71,
                ]


print('*****************PPG_csvData******************')
print(PPG_csvData)
print('Data counted = '+ str(len(PPG_csvData)))
print('******************HbA1c_data******************')
print(HbA1c_data)
print('Data counted = '+ str(len(HbA1c_data)))
print('******************SpO2_data*******************')
print(SpO2_data)
print('Data counted = '+ str(len(SpO2_data)))
print('*******************Age_data*******************')
print(Age_data)
print('Data counted = '+ str(len(Age_data)))
print('*****************Gender_data******************')
print(Gender_data)
print('Data counted = '+ str(len(Gender_data)))


print('******************BMI_data********************')
print(BMI_data)
print('Data counted = '+ str(len(BMI_data)))
# Out:
# *****************PPG_csvData******************
# ['E:\\OneDrive - KookminUNIV\\KMU==Lab\\MCSP==Research-Papers\\SCI-02\\Software\\ProgrammingCodes\\DataBase\\data(mod)\\1_turja_0120_2023(356)_hb5.3_sp98.csv', 'E:\\OneDrive - KookminUNIV\\KMU==Lab\\MCSP==Research-Papers\\SCI-02\\Software\\ProgrammingCodes\\DataBase\\data(mod)\\2_thk_0125_2023.csv', 'E:\\OneDrive - KookminUNIV\\KMU==Lab\\MCSP==Research-Papers\\SCI-02\\Software\\ProgrammingCodes\\DataBase\\data(mod)\\kdk_356_0227.csv', 'E:\\OneDrive - KookminUNIV\\KMU==Lab\\MCSP==Research-Papers\\SCI-02\\Software\\ProgrammingCodes\\DataBase\\data(mod)\\4_shama_0125_2023.csv', 'E:\\OneDrive - KookminUNIV\\KMU==Lab\\MCSP==Research-Papers\\SCI-02\\Software\\ProgrammingCodes\\DataBase\\data(mod)\\5_jho_1_0125_2023.csv', 'E:\\OneDrive - KookminUNIV\\KMU==Lab\\MCSP==Research-Papers\\SCI-02\\Software\\ProgrammingCodes\\DataBase\\data(mod)\\khj_123_0228_2023.csv', 'E:\\OneDrive - KookminUNIV\\KMU==Lab\\MCSP==Research-Papers\\SCI-02\\Software\\ProgrammingCodes\\DataBase\\data(mod)\\JKY_356_7.4.csv', 'E:\\OneDrive - KookminUNIV\\KMU==Lab\\MCSP==Research-Papers\\SCI-02\\Software\\ProgrammingCodes\\DataBase\\data(mod)\\youngsu_bang_245_0208_2023.csv']
# Data counted = 8
# ******************HbA1c_data******************
# [5.3, 5.5, 5.7, 5.6, 6.4, 7.0, 7.4, 7.6]
# Data counted = 8
# ******************SpO2_data*******************
# [99, 96, 98, 98, 97, 97, 96, 96]
# Data counted = 8
# *******************Age_data*******************
# [25, 34, 65, 27, 55, 58, 55, 56]
# Data counted = 8
# *****************Gender_data******************
# ['M', 'M', 'M', 'F', 'M', 'M', 'M', 'M']
# Data counted = 8
# ******************BMI_data********************
# [26.7, 26.4, 22.2, 26.4, 25.4, 21.7, 26, 28.71]
# Data counted = 8

# %% [markdown]
# > Making array

# %%
PPG_csvArray  = np.asarray(PPG_csvData)
HbA1c_Array   = np.asarray(HbA1c_data)
SpO2_Array    = np.asarray(SpO2_data)
Age_Array     = np.asarray(Age_data)
Gender_Array  = np.asarray(Gender_data)
BMI_Array     = np.asarray(BMI_data)

# %% [markdown]
# # __User Defined Functions and Algorithms__

# %% [markdown]
# > __Function 00:__ Visualize PPG signal

# %%
def visual_PPG(PPG, drawFigure=True):

    for i in range (0,len(PPG)):
        
        # Getting corresponding Combined PPG Data 
        dat    = pd.read_csv(PPG[i], delimiter=',', header=None)
        print('********************************')
        print('Index='+str(i)+' || '+str(PPG[i]))
        print('********************************')
        if (dat.shape[1] == 3):
           bs = dat.iloc[:,2]
           gs = dat.iloc[:,1]
           rs = dat.iloc[:,0]
        else:
           bs = dat.iloc[:,3]
           gs = dat.iloc[:,2]
           rs = dat.iloc[:,1]
    
        # Visualization **Don't mention inside the pseudo code**
        if drawFigure:
           plt.rcParams.update(plt.rcParamsDefault)
           plt.rcParams['font.size'] = '8'
           fig,axs = plt.subplots(3, figsize=(20, 5))
           axs[0].set(title='Visualization of Wrist PPG Signal')
           axs[0].plot(bs, color='blue', label='blue signal')
           axs[0].set(ylabel = ' ')
           axs[0].legend(loc=1)
           axs[0].grid(True)
           axs[1].plot(gs, color='green', label='green signal')
           axs[1].set(ylabel = ' ', xlabel = ' ')
           axs[1].legend(loc=1)
           axs[1].grid(True)
           axs[2].plot(rs, color='red', label='red signal')
           axs[2].set(ylabel = ' ', xlabel = ' ')
           axs[2].legend(loc=1)
           axs[2].grid(True)
           plt.show()
        
    # Return
    return

# %% [markdown]
# > __Function 01:__ BA_Plot

# %%
def bland_altman_plot(data1, data2):
    data1     = np.asarray(data1)
    data2     = np.asarray(data2)
    mean      = np.mean([data1, data2], axis=0)
    diff      = data1 - data2                   # Difference between data1 and data2
    md        = np.mean(diff)                   # Mean of the difference
    sd        = np.std(diff, axis=0)            # Standard deviation of the difference

    plt.scatter(mean, diff,   c = 'black')
    plt.axhline(md,           color='green', linestyle='--')
    plt.axhline(md + 1.96*sd, color='red',   linestyle='--')
    plt.axhline(md - 1.96*sd, color='red',   linestyle='--')
    plt.xlabel("Average of the two measures", fontsize = 14)
    plt.ylabel("Difference between the two measures", fontsize = 14)
    plt.title("Bland-Altman plot for estimated %HbA1c values", fontsize = 14)
    # plt.savefig('./Figure/RF_trans_BA_Plot.png', bbox_inches = "tight", transparent = True, dpi = 400)

# %% [markdown]
# > __Function 02:__ EGA_Plot

# %%
from matplotlib.patches import Circle, Wedge, Polygon, Path
from matplotlib.collections import PatchCollection

def error_grid_analysis(ref,est):
    fig, ax = plt.subplots()

    polygons = []

    A  = [[4.0,4.0],[5.7,4.0],[5.7,5.4],[7.2,6.5],[12.0,6.5],[12.0,12.0],[6.5,12.0],[6.5,7.2],[5.4,5.7],[4.0,5.7]]
    Bd = [[5.7,4.0],[5.7,5.4],[7.2,6.5],[12.0,6.5],[12.0,5.7],[6.5,5.7],[6.5,4.0]]
    Bu = [[4.0,5.7],[5.4,5.7],[6.5,7.2],[6.5,12.0],[5.7,12.0],[5.7,6.5],[4.0,6.5]]
    Cd = [[6.5,4.0],[6.5,5.7],[12.0,5.7],[12.0,4.0]]
    Cu = [[4.0,6.5],[5.7,6.5],[5.7,12.0],[4.0,12.0]]

    # print(np.asarray(A).shape)
    pA  = Polygon(np.asarray(A))
    pBd = Polygon(np.asarray(Bd))
    pBu = Polygon(np.asarray(Bu))
    pCd = Polygon(np.asarray(Cd))
    pCu = Polygon(np.asarray(Cu))

    polygons.append(pA)
    polygons.append(pBd)
    polygons.append(pBu)
    polygons.append(pCd)
    polygons.append(pCu)


    p = PatchCollection(polygons)
    p.set_color([[0,1,0,0.3],[1,1,0,0.3],[1,1,0,0.3],[1,0,0,0.3],[1,0,0,0.3]])
    ax.add_collection(p)



    plt.plot([4.0,12.0],[4.0,12.0])


    x = ref
    y = est

    sA = []
    sB = []
    sC = []
    for i in range(len(y)):
        sA.append(int(pA.contains_point ([x[i],y[i]]))*30)
        sB.append(int(pBd.contains_point([x[i],y[i]]) or pBu.contains_point([x[i],y[i]]))*30)
        sC.append(int(pCd.contains_point([x[i],y[i]]) or pCu.contains_point([x[i],y[i]]))*30)


    plt.scatter(x,y,s=sA,color=[0.227, 0.513, 0.282,1])
    plt.scatter(x,y,s=sB,color=[0.886, 0.654, 0.133,1])
    plt.scatter(x,y,s=sC,color=[0.941, 0, 0.098,1])

    lx = np.linspace(min(x), max(x), 100)
    z = np.polyfit(x, y, 1)
    p = np.poly1d(z)
    plt.plot(lx,p(lx))


    plt.text(10.5,9,'A',fontsize=26)
    plt.text(9,10.5,'A',fontsize=26)
    plt.text(10.5,5.94,'B',fontsize=26)
    plt.text(5.94,10.5,'B',fontsize=26)
    plt.text(10.5,4.7,'C',fontsize=26)
    plt.text(4.7,10.5,'C',fontsize=26)
    fig.set_figheight(8)
    fig.set_figwidth(8)
    plt.xlim([4.0,12.0])
    plt.ylim([4.0,12.0])
    plt.xlabel('HbA1c Invasive device (%NGSP)',fontsize=15)
    plt.ylabel('HbA1c Estimated (%NGSP)',fontsize=15)
    plt.title('Error Grid Analysis (EGA) for estimated %HbA1c values',fontsize=15)
    plt.show()

# %% [markdown]
# > __Function 03:__ Evaluation
# >> ACK: __Developed by Shama__. _To visualize performance and evaluate model_

# %%
def evaluation_metrics_including_BA_and_EGA_plot(modelName, predictedValue, exactValue):
    print('############ HbA1c Evaluation Metrics of ' + modelName + ' Regression ############')
    CVy = np.asarray(predictedValue)
    CVx = np.asarray(exactValue)
    print('Diff STD  = ',np.std(CVx-CVy))
    print('MSE       = ',np.sum((CVx-CVy)**2)/CVy.shape[0])
    print('ME        = ',np.sum((CVx-CVy))/CVy.shape[0])
    print('MAD       = ',np.sum(np.abs(CVx-CVy))/CVy.shape[0])
    print('RMSE      = ',np.sqrt(np.sum((CVx-CVy)**2)/CVy.shape[0]))
    print('R2 score  = ',r2_score(CVx,CVy))
    print('Pearson R and p-value: ',scipy.stats.pearsonr(CVx,CVy))
    print('##################################################################################\n')
    bland_altman_plot  (predictedValue, exactValue)
    error_grid_analysis(predictedValue, exactValue)

# %% [markdown]
# > __Algorithm 01:__ Baseline Dirft Removal by ()
# >> ACK: __Developed by Shama__. _This algorithm ()_
# >> 1. https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.butter.html
# >> 2. https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.lfilter.html

# %%
### Initialize Second Order Section
sos  = scipy.signal.butter(N=2, Wn=8.0, btype='low',  fs=32, output='sos')  ### The sampling frequency of the digital system(‘fs’).second-order sections (‘sos’)
sos1 = scipy.signal.butter(N=2, Wn=0.5, btype='high', fs=32, output='sos')  ###
def removing_baseline_drift (ppgSignal, showFigure='False'): 
   # Getting corresponding Combined PPG Data 
   dat   = pd.read_csv(ppgSignal, delimiter=',', header=None)
    
   bs = dat.iloc[:,2]
   gs = dat.iloc[:,1]
   rs = dat.iloc[:,0]
  
   fil_s_b = scipy.signal.sosfilt(sos, bs)[10:]
   fil_s_g = scipy.signal.sosfilt(sos, gs)[10:]
   fil_s_r = scipy.signal.sosfilt(sos, rs)[10:]

   fil_s_b1 = scipy.signal.sosfilt(sos1, fil_s_b)[110:] + np.mean(fil_s_b)
   fil_s_g1 = scipy.signal.sosfilt(sos1, fil_s_g)[110:] + np.mean(fil_s_g)
   fil_s_r1 = scipy.signal.sosfilt(sos1, fil_s_r)[110:] + np.mean(fil_s_r)
   
   ### Visualization
   if showFigure=='True':
      print('***************Blue**************')
      plt.rcParams.update(plt.rcParamsDefault)
      plt.rcParams['font.size'] = '9'
      fig,axs = plt.subplots(2, figsize=(20, 2.5))
      axs[0].set(title='Visualization of PPG Signal before and after filtering')
      axs[0].plot(pd.DataFrame(fil_s_b), color='blue', label='after first filtering')
      axs[0].set(ylabel = ' ', xlabel = ' ')
      axs[0].legend(loc=1)
      axs[0].grid(True)
      axs[1].plot(pd.DataFrame(fil_s_b1), color='blue', label='After 2nd filter and baseline_drift_removal')
      axs[1].set(ylabel = ' ', xlabel = ' ')
      axs[1].legend(loc=1)
      axs[1].grid(True)
      plt.show()

      print('***************Green**************')
      plt.rcParams.update(plt.rcParamsDefault)
      plt.rcParams['font.size'] = '9'
      fig,axs = plt.subplots(2, figsize=(20, 2.5))
      axs[0].set(title='Visualization of PPG Signal before and after filtering')
      axs[0].plot(pd.DataFrame(fil_s_g), color='green', label='after first filtering')
      axs[0].set(ylabel = ' ', xlabel = ' ')
      axs[0].legend(loc=1)
      axs[0].grid(True)
      axs[1].plot(pd.DataFrame(fil_s_g1), color='green', label='After 2nd filter and baseline_drift_removal')
      axs[1].set(ylabel = ' ', xlabel = ' ')
      axs[1].legend(loc=1)
      axs[1].grid(True)
      plt.show()
      
      print('***************Red**************')
      plt.rcParams.update(plt.rcParamsDefault)
      plt.rcParams['font.size'] = '9'
      fig,axs = plt.subplots(2, figsize=(20, 2.5))
      axs[0].set(title='Visualization of PPG Signal before and after filtering')
      axs[0].plot(pd.DataFrame(fil_s_r), color='red', label='after first filtering')
      axs[0].set(ylabel = ' ', xlabel = ' ')
      axs[0].legend(loc=1)
      axs[0].grid(True)
      axs[1].plot(pd.DataFrame(fil_s_r1), color='red', label='After 2nd filter and baseline_drift_removal')
      axs[1].set(ylabel = ' ', xlabel = ' ')
      axs[1].legend(loc=1)
      axs[1].grid(True)
      plt.show()

   ## Return outcome
   return(fil_s_r1, fil_s_g1, fil_s_b1)

# %% [markdown]
# >> Test Algorithm 01:

# %%
# for i in range(len(PPG_csvArray)):
#     print(f'**********PPG_info:{PPG_csvArray[i]}**********')
#     r,g,b = removing_baseline_drift(ppgSignal=PPG_csvArray[i], showFigure='True')

# %% [markdown]
# > __Algorithm 02:__ splitSignal into discrete segments

# %%
def splitSignal (individualSignal, horizonSize=50, windowSize=200):
    overallSignal  = []
    completeFlag   = 0
    for i in range (0, len(individualSignal), horizonSize):
        if i+windowSize < len(individualSignal): #Only consider sets with windowSize data
            splittedSignal = []
            for j in range(windowSize):
                splittedSignal.append(individualSignal[i+j])
            overallSignal.append(splittedSignal)
    x = np.array(overallSignal) 
    return (x)

# %% [markdown]
# >> Test algorithm 02

# %%
horizonSet = 32
windowSet  = 200
countData  = 0
for i in range(len(PPG_csvArray)):
    r,g,b = removing_baseline_drift(ppgSignal=PPG_csvArray[i], showFigure='False')
    r_ = splitSignal(individualSignal=r, horizonSize=horizonSet, windowSize=windowSet)
    print(r_.shape)
    countData += r_.shape[0]*r_.shape[1]
print(f'dCount={countData}')
### Plotting on the first one
pd.DataFrame(r_[0]).plot()
plt.show()
# Out:
# (124, 200)
# (157, 200)
# (231, 200)
# (420, 200)
# (169, 200)
# (292, 200)
# (252, 200)
# (316, 200)
# dCount=392200

# %% [markdown]
# > __Algorithm 03:__ Butter BandPass Filter (Include this in SCI)
# >> 1. https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.butter.html
# >> 2. https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.lfilter.html
# >> 3. https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.sosfilt.html#scipy.signal.sosfilt

# %%
def butter_filter(xArray, cutoffFreq=8, samplingFreq=24, filterOrder=2, filterType='low'):
    nyquistFreq  = 0.5 * samplingFreq
    criticalFreq = cutoffFreq/nyquistFreq
    # Butterworth digital and analog filter design.
    if filterType == 'band':
        sos = scipy.signal.butter(N=filterOrder, Wn=[0.1, criticalFreq], btype='bandpass', analog=False, output='sos')
    elif filterType == 'low':
        sos = scipy.signal.butter(N=filterOrder, Wn=criticalFreq,        btype='lowpass',  analog=False, output='sos')
    elif filterType == 'high':
        sos = scipy.signal.butter(N=filterOrder, Wn=criticalFreq,        btype='highpass', analog=False, output='sos')
    # Filter data along one-dimension with an IIR or FIR filter.
    y = scipy.signal.sosfilt(sos=sos, x=xArray)
    return y

# %% [markdown]
# >> Test Algorithm 03

# %%
print('Actual Splitted Signal')
pd.DataFrame(r_[0]).plot()
plt.show()
print('After applying mean function')
data = r_[0]-np.mean(r_[0])
pd.DataFrame(data).plot()
plt.show()
print('After applying filter')
filteredSignal_lp = butter_filter(xArray=data, cutoffFreq=8, samplingFreq=32, filterOrder=2, filterType='low')
filteredSignal_bp = butter_filter(xArray=data, cutoffFreq=8, samplingFreq=32, filterOrder=2, filterType='band')
filteredSignal_hp = butter_filter(xArray=data, cutoffFreq=8, samplingFreq=32, filterOrder=2, filterType='high')
pd.DataFrame(filteredSignal_lp).plot()
pd.DataFrame(filteredSignal_bp).plot()
pd.DataFrame(filteredSignal_hp).plot()
plt.show()
# Out:
# Actual Splitted Signal
# After applying mean function
# After applying filter

# %% [markdown]
# > __Algorithm 04:__ Determine AC_DC_from_Signal __(I have replaced with a new algorithm)__
# >> ACK: __Developed by Shama__. _This algorithm is developed to determine __r1__ and __r2__ which significantly improve the performance of the trained models_

# %%
# def determine_ac_dc_from_PPG (Signal):
#     uPeak =  scipy.signal.find_peaks(Signal)
#     uPeak =  pd.DataFrame(uPeak[0])
#     lPeak =  scipy.signal.find_peaks(-Signal)
#     lPeak =  pd.DataFrame(lPeak[0])

#     if (len(uPeak)<len(lPeak)):
#         indexLength = len(uPeak)
#     else:
#         indexLength = len(lPeak)

#     for index in range(indexLength):
#         newValue_ac =  Signal[uPeak.iloc[index]] - Signal[lPeak.iloc[index]]
#         newValue_dc =  Signal[lPeak.iloc[index]]
#         if index ==0:
#             allValue_ac = newValue_ac
#             allValue_dc = newValue_dc
#         else:
#             allValue_ac =  np.append(allValue_ac,newValue_ac)
#             allValue_dc =  np.append(allValue_dc,newValue_dc)

#     meanValue_ac = np.mean(allValue_ac)
#     meanValue_dc = np.mean(allValue_dc)

#     return meanValue_ac,meanValue_dc

# %% [markdown]
# > __Algorithm 04:__ Determine AC_DC_from_PPG (new developed)
# >> ACK: __Developed by Shama__. _This algorithm is developed to determine __r1__ and __r2__ which significantly improve the performance of the trained models_

# %%
def determine_ac_dc_from_PPG (Signal, showFigure='False'):
    maxArray = []
    minArray = []
    p2pPanDF = pd.DataFrame({'index':[], 'value':[]})
    midValue = np.mean(Signal)
    maxValue = midValue
    minValue = midValue
    maxIndex = 0
    minIndex = 0

    for i in range(len(Signal)):
        nowValue = Signal[i]
        if (nowValue>midValue):
            if (minValue<midValue and minIndex>0):
                p2pPanDF = pd.concat([p2pPanDF, pd.DataFrame({'index':[minIndex], 'value':[minValue]})], ignore_index=True, sort=False)
                minArray = np.append(minArray, minValue)
                minValue = midValue
            if (nowValue>maxValue):
                maxValue = nowValue
                maxIndex = i
        if (nowValue<midValue):
            if (maxValue>midValue and maxIndex>0):
                p2pPanDF = pd.concat([p2pPanDF, pd.DataFrame({'index':[maxIndex], 'value':[maxValue]})], ignore_index=True, sort=False)
                maxArray = np.append(maxArray, maxValue)
                maxValue = midValue
            if (nowValue<minValue):
                minValue = nowValue
                minIndex = i

    ## Calculate AC and DC
    acSignal = np.mean(maxArray) - np.mean(minArray)
    dcSignal = np.mean(minArray)

    ## Show Figure
    if (showFigure=='True'):
        plt.rcParams.update(plt.rcParamsDefault)
        plt.rcParams['font.size'] = '9'
        plt.figure(figsize=(21, 3))
        plt.title(f'***Analyze AC and DC Characteristics in a PPG Signal*** \n AC={acSignal} and DC={dcSignal} \n Total Peaks={len(maxArray)}(mean={np.mean(maxArray)}) and Valley={len(minArray)}(mean={np.mean(minArray)})', y=1, loc='center')
        plt.xlabel('Sample Count')
        plt.ylabel(' ')
        for i in range(len(Signal)):
            plt.plot(i, midValue,          '.', color='green')
            plt.plot(i, np.mean(maxArray), '.', color='blue')
            plt.plot(i, np.mean(minArray), '.', color='cyan')
        plt.plot(Signal, color='gray')
        plt.plot(p2pPanDF.values[:,0], p2pPanDF.values[:,1], 'x', color='red')
        plt.grid(True)
        plt.show()

    return acSignal, dcSignal, maxArray,minArray,p2pPanDF

# %% [markdown]
# >> Only to develop algorithm

# %%
# def determine_ac_dc_from_PPG (Signal):
#     maxArray = []
#     minArray = []
#     midValue = np.mean(Signal)
#     maxValue = midValue
#     minValue = midValue
#     maxIndex = 0
#     minIndex = 0

#     for i in range(len(Signal)):
#         nowValue = Signal[i]
#         if (nowValue>midValue):
#             if (minValue<midValue and minIndex>0):
#                 minArray = np.append(minArray, minValue)
#                 minValue = midValue
#             if (nowValue>maxValue):
#                 maxValue = nowValue
#                 maxIndex = i
#         if (nowValue<midValue):
#             if (maxValue>midValue and maxIndex>0):
#                 maxArray = np.append(maxArray, maxValue)
#                 maxValue = midValue
#             if (nowValue<minValue):
#                 minValue = nowValue
#                 minIndex = i

#     ## Calculate AC and DC
#     acSignal = np.mean(maxArray) - np.mean(minArray)
#     dcSignal = np.mean(minArray)

#     return acSignal, dcSignal

# %% [markdown]
# > Test with Algorithm 4

# %%
r,g,b = removing_baseline_drift(ppgSignal=PPG_csvArray[1], showFigure='False')

# %%
ac, dc, u, l, df = determine_ac_dc_from_PPG(r, showFigure='True')
ac, dc, u, l, df = determine_ac_dc_from_PPG(g, showFigure='True')
ac, dc, u, l, df = determine_ac_dc_from_PPG(b, showFigure='True')

# %% [markdown]
# > __Algorithm 05:__ Kaiser–Teager Energy

# %%
def get_kaiser_teager_energy(x):
    x         = np.array(x)
    l         = len(x)
    squ       = x[1:l-1]**2
    oddi      = x[0:l-2]
    eveni     = x[2:l]
    ex        = squ - (oddi*eveni)
    kte       = np.zeros([l,])
    kte[0]    = ex[0]
    kte[-1]   = ex[-1]
    kte[1:-1] = ex
    return kte

# %% [markdown]
# > __Algorithm 06v1:__ Constructing Features Set _(Red, Green, Blue; Reflected, FeatureCount=[4+4+r1+r2]+[HbA1c]=11)_
# >> ACK: __Developed by Shama, Guided by Honorable Professor Kim__. _Significantly improve the performance_

# %%
def construct_feature_set_v1 (PPG, HbA1c, SpO2, BMI, samplingRate=32):
    # Initialization
    sr         = samplingRate
    l          = 0

    for i in range (0,len(PPG)):
        
        # Getting corresponding PPG Data
        # > __Algorithm 01:__ Baseline Dirft Removal by () 
        r,g,b = removing_baseline_drift(ppgSignal=PPG[i], showFigure='False')
        print('PPG_data_info:'+str(PPG[i]))

        # > __Algorithm 04:__ Determine AC_DC_from_Signal
        r_ac,r_dc,r_pk,r_vy,r_df = determine_ac_dc_from_PPG(r)
        g_ac,g_dc,g_pk,g_vy,g_df = determine_ac_dc_from_PPG(g)
        b_ac,b_dc,b_pk,b_vy,b_df = determine_ac_dc_from_PPG(b)

        # Calculate r1 & r2
        r1 = (g_ac/g_dc)/(r_ac/r_dc)
        r2 = (b_ac/b_dc)/(r_ac/r_dc)

        # > __Algorithm 02:__ Split_Signal
        r_sp = splitSignal(individualSignal=r, horizonSize=horizonSet, windowSize=windowSet)
        g_sp = splitSignal(individualSignal=g, horizonSize=horizonSet, windowSize=windowSet)
        b_sp = splitSignal(individualSignal=b, horizonSize=horizonSet, windowSize=windowSet)
        
        # Constructing Feature Set
        for j in range(len(r_sp)):  ### You can also use r_sp.shape[0]
            # Initialize frame
            featureFrame       = []
            
            # >>>>>>>>>>>>>>>>Red>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
            # > __Algorithm 03:__ Filter
            filteredSignal_r = butter_filter(xArray=r_sp[j]-np.mean(r_sp[j]), cutoffFreq=8, samplingFreq=sr, filterOrder=2, filterType='low')

            fqSignal_r, psdSignal_r    = scipy.signal.welch(
                x       = filteredSignal_r, 
                nperseg = len(filteredSignal_r) # Added to overcome error
                ) 


            # > __Algorithm 05:__ Kaiser–Teager Energy
            kteSignal_r            = get_kaiser_teager_energy(
                filteredSignal_r
                )



            # Insert Feature one by one
            # Add new feature (5)
            ar_coeffs_r, _r        = statsmodels.regression.linear_model.yule_walker(filteredSignal_r, order = 2)
            # featureFrame           = np.append(featureFrame,ar_coeffs_r)
            
            # Add new feature
            zcSignal_r             = tsfel.feature_extraction.features.zero_cross(filteredSignal_r)
            #featureFrame           = np.append(featureFrame,zcSignal_r)
            
            # Add new feature
            skewSignal_r           = tsfel.feature_extraction.features.skewness(filteredSignal_r)
            # featureFrame           = np.append(featureFrame,skewSignal_r)
            
            # Add new feature
            absWavelength_r        = tsfel.feature_extraction.wavelet_abs_mean(filteredSignal_r)
            maWavelength_r         = np.mean(absWavelength_r)
            # featureFrame           = np.append(featureFrame,maWavelength_r)
            
            # Add new feature
            autocorr_r             = tsfel.feature_extraction.autocorr(filteredSignal_r)
            featureFrame           = np.append(featureFrame,autocorr_r)
            
            # Add new feature
            kurtSpectral_r         = tsfel.feature_extraction.features.spectral_kurtosis(filteredSignal_r, sr)
            # featureFrame           = np.append(featureFrame,kurtSpectral_r)
            
            # Add new feature
            skewSpectral_r         = tsfel.feature_extraction.features.spectral_skewness(filteredSignal_r, sr)
            # featureFrame           = np.append(featureFrame,skewSpectral_r)
            
            # Add new feature
            sum_abs_diff_r         = tsfel.feature_extraction.features.sum_abs_diff(filteredSignal_r)
            featureFrame           = np.append(featureFrame,sum_abs_diff_r)
            
            # Add new feature
            kurtPSD_r              = scipy.stats.kurtosis(psdSignal_r)
            # featureFrame           = np.append(featureFrame,kurtPSD_r)
            
            # Add new feature
            varPSD_r               = np.var(psdSignal_r)
            #featureFrame           = np.append(featureFrame,varPSD_r)
            
            # Add new feature
            meanPSD_r              = np.mean(psdSignal_r)
            # featureFrame           = np.append(featureFrame,meanPSD_r)
            
            # Add new feature
            skewKTE_r              = scipy.stats.skew(kteSignal_r)
            # featureFrame           = np.append(featureFrame,skewKTE_r)
            
            # Add new feature
            kurtKTE_r              = scipy.stats.kurtosis(kteSignal_r)
            # featureFrame           = np.append(featureFrame,kurtKTE_r)
            
            # Add new feature
            varKTE_r               = np.var(kteSignal_r)
            featureFrame           = np.append(featureFrame,varKTE_r)
            
            # Add new feature
            meanKTE_r              = np.mean(kteSignal_r)
            featureFrame           = np.append(featureFrame,meanKTE_r)
            
            
            # >>>>>>>>>>>>>>>>Green>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
           
            # > __Algorithm 03:__ Butter Low-pass Filter
            filteredSignal_g = butter_filter(xArray=g_sp[j]-np.mean(g_sp[j]), cutoffFreq=8, samplingFreq=sr, filterOrder=2, filterType='low')


            fqSignal_g, psdSignal_g    = scipy.signal.welch(
                x       = filteredSignal_g, 
                nperseg = len(filteredSignal_g) # Added to overcome error
                ) 
           
            # > __Algorithm 05:__ Kaiser–Teager Energy
            kteSignal_g            = get_kaiser_teager_energy(
                filteredSignal_g
                )
            
            
            # Insert Feature one by one
            # Add new feature
            ar_coeffs_g, _g        = statsmodels.regression.linear_model.yule_walker(filteredSignal_g, order = 2)
            # featureFrame           = np.append(featureFrame,ar_coeffs_g)
            
            # Add new feature
            zcSignal_g             = tsfel.feature_extraction.features.zero_cross(filteredSignal_g)
            #featureFrame           = np.append(featureFrame,zcSignal_g)
            
            # Add new feature
            skewSignal_g           = tsfel.feature_extraction.features.skewness(filteredSignal_g)
            # featureFrame           = np.append(featureFrame,skewSignal_g)
            
            # Add new feature
            absWavelength_g        = tsfel.feature_extraction.wavelet_abs_mean(filteredSignal_g)
            maWavelength_g         = np.mean(absWavelength_g)
            # featureFrame           = np.append(featureFrame,maWavelength_g)
            
            # Add new feature
            autocorr_g             = tsfel.feature_extraction.autocorr(filteredSignal_g)
            featureFrame           = np.append(featureFrame,autocorr_g)
            
            # Add new feature
            kurtSpectral_g         = tsfel.feature_extraction.features.spectral_kurtosis(filteredSignal_g, sr)
            # featureFrame           = np.append(featureFrame,kurtSpectral_g)
            
            # Add new feature
            skewSpectral_g         = tsfel.feature_extraction.features.spectral_skewness(filteredSignal_g, sr)
            # featureFrame           = np.append(featureFrame,skewSpectral_g)
            
            # Add new feature
            sum_abs_diff_g         = tsfel.feature_extraction.features.sum_abs_diff(filteredSignal_g)
            featureFrame           = np.append(featureFrame,sum_abs_diff_g)
            
            # Add new feature
            kurtPSD_g              = scipy.stats.kurtosis(psdSignal_g)
            # featureFrame           = np.append(featureFrame,kurtPSD_g)
            
            # Add new feature
            varPSD_g               = np.var(psdSignal_g)
            featureFrame           = np.append(featureFrame,varPSD_g)
            
            # Add new feature
            meanPSD_g              = np.mean(psdSignal_g)
            # featureFrame           = np.append(featureFrame,meanPSD_g)
            
            # Add new feature
            skewKTE_g              = scipy.stats.skew(kteSignal_g)
            # featureFrame           = np.append(featureFrame,skewKTE_g)
            
            # Add new feature
            kurtKTE_g              = scipy.stats.kurtosis(kteSignal_g)
            # featureFrame           = np.append(featureFrame,kurtKTE_g)
            
            # Add new feature
            varKTE_g               = np.var(kteSignal_g)
            #featureFrame           = np.append(featureFrame,varKTE_g)
            
            # Add new feature
            meanKTE_g              = np.mean(kteSignal_g)
            featureFrame           = np.append(featureFrame,meanKTE_g)


             # >>>>>>>>>>>>>>>>Blue>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

            # > __Algorithm 03:__ Butter Low-pass Filter
            filteredSignal_b = butter_filter(xArray=b_sp[j]-np.mean(b_sp[j]), cutoffFreq=8, samplingFreq=sr, filterOrder=2, filterType='low')

            fqSignal_b, psdSignal_b    = scipy.signal.welch(
                x       = filteredSignal_b, 
                nperseg = len(filteredSignal_b) # Added to overcome error
                ) 
           
            # > __Algorithm 05:__ Kaiser–Teager Energy
            kteSignal_b            = get_kaiser_teager_energy(
                filteredSignal_b
                )
            # Insert Feature one by one
            # Add new feature
            ar_coeffs_b, _b        = statsmodels.regression.linear_model.yule_walker(filteredSignal_b, order = 2)
            #featureFrame           = np.append(featureFrame,ar_coeffs_b)
            
            # Add new feature
            zcSignal_b             = tsfel.feature_extraction.features.zero_cross(filteredSignal_b)
            featureFrame           = np.append(featureFrame,zcSignal_b)
            
            # Add new feature
            skewSignal_b           = tsfel.feature_extraction.features.skewness(filteredSignal_b)
            #featureFrame           = np.append(featureFrame,skewSignal_b)
            
            # Add new feature
            absWavelength_b        = tsfel.feature_extraction.wavelet_abs_mean(filteredSignal_b)
            maWavelength_b         = np.mean(absWavelength_b)
            #featureFrame           = np.append(featureFrame,maWavelength_b)
            
            # Add new feature
            autocorr_b             = tsfel.feature_extraction.autocorr(filteredSignal_b)
            featureFrame           = np.append(featureFrame,autocorr_b)
            
            # Add new feature
            kurtSpectral_b         = tsfel.feature_extraction.features.spectral_kurtosis(filteredSignal_b, sr)
            #featureFrame           = np.append(featureFrame,kurtSpectral_b)

            # Add new feature
            skewSpectral_b         = tsfel.feature_extraction.features.spectral_skewness(filteredSignal_b, sr)
            #featureFrame           = np.append(featureFrame,skewSpectral_b)
            
            # Add new feature
            sum_abs_diff_b         = tsfel.feature_extraction.features.sum_abs_diff(filteredSignal_b)
            featureFrame           = np.append(featureFrame,sum_abs_diff_b)
            
            # Add new feature
            kurtPSD_b              = scipy.stats.kurtosis(psdSignal_b)
            #featureFrame           = np.append(featureFrame,kurtPSD_b)
            
            # Add new feature
            varPSD_b               = np.var(psdSignal_b)
            #featureFrame           = np.append(featureFrame,varPSD_b)
            
            # Add new feature
            meanPSD_b              = np.mean(psdSignal_b)
            #featureFrame           = np.append(featureFrame,meanPSD_b)
            
            # Add new feature
            skewKTE_b              = scipy.stats.skew(kteSignal_b)
            #featureFrame           = np.append(featureFrame,skewKTE_b)
            
            # Add new feature
            kurtKTE_b              = scipy.stats.kurtosis(kteSignal_b)
            #featureFrame           = np.append(featureFrame,kurtKTE_b)
            
            # Add new feature
            varKTE_b               = np.var(kteSignal_b)
            #featureFrame           = np.append(featureFrame,varKTE_b)
            
            # Add new feature
            meanKTE_b              = np.mean(kteSignal_b)
            featureFrame           = np.append(featureFrame,meanKTE_b)

            # >>>>>>>>>>>>>>>>Add_r1_r2_as_features>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
            # filteredSignal_b = butter_lowPass_filter(
            #     data  = b_sp[j]-np.mean(b_sp[j]), 
            #     cutoff= 8, 
            #     fs    = sr, 
            #     order = 6
            #     )

            
            #featureFrame           = np.append(featureFrame,r1)
            #featureFrame           = np.append(featureFrame,r2)
            
            
            # >>>>>>>>>>>>>>>>Add_other_features>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
            featureFrame           = np.append(featureFrame,SpO2[i])
            featureFrame           = np.append(featureFrame,BMI[i])

            # >>>>>>>>>>>>>>> Add output feature 
            featureFrame           = np.append(featureFrame,HbA1c[i])

            ## Insert featureFrame into featureSet
            # Initialized feature set array 
            if l == 0:
                k = len(featureFrame)
                # print('kCount='+str(k))
                featureSet = np.empty([150000,k]) 
            # Save into featureSet
            featureSet[l][:k] = featureFrame
            # Length increased for next cycle
            l = l + 1


            # Checking outputs
            print(f'iCount={i} || jCount={j} || lCount={l} || fCount={len(featureFrame)}')
            print(featureFrame)

        # Check point    
        # print('iCount='+str(i))

    # Gather all
    print('**********************************************************************')
    print('*****************************Summary**********************************')    
    featureSet = featureSet[0:l][:]
    # Check for null
    featureSet = featureSet[~np.isnan(featureSet).any(axis=1)]
    print('**********************************************************************')
    return featureSet

# %% [markdown]
# # __Main Function__

# %% [markdown]
# ## __Test 01:__

# %% [markdown]
# >  Utilizing __Algorithm 06v1:__ Constructing Features Set _(Red, Green, Blue; Reflected, FeatureCount=[4+4+r1+r2]+[HbA1c]=11)_

# %%
# Initialize
loo                = sk.model_selection.LeaveOneOut()
t1_scores          = []
t1_test_cases      = []
t1_train_cases     = []
countEpoch         = 0
percent            = 0.02
# XG Boost
t1_results_xg      = []
t1_e_results_xg    = []
# Random Forest
t1_results_rf      = []
t1_e_results_rf    = []
# Cat Boost
t1_results_cb      = []
t1_e_results_cb    = []
# Light GBM
t1_results_lg      = []
t1_e_results_lg    = []

for train_index, test_index in loo.split(PPG_csvArray):
    print('Epoch # '+str(countEpoch))
    countEpoch +=1

    X_train, X_test      = PPG_csvArray[train_index], PPG_csvArray[test_index]
    y_train, y_test      = HbA1c_Array [train_index], HbA1c_Array [test_index]
    sp_train, sp_test    = SpO2_Array  [train_index], SpO2_Array  [test_index]
    bmi_train, bmi_test  = BMI_Array   [train_index], BMI_Array   [test_index]
    
    
    # > __Algorithm 06v1:__ Constructing Features Set _(Red, Green, Blue; Reflected, FeatureCount=[4+4+r1+r2]+[HbA1c]=11)_
    print('*************************************************************')
    print('*********************Training Array Set**********************')
    print('*************************************************************')
    train_array = construct_feature_set_v1(
        PPG          = X_train,
        HbA1c        = y_train,
        SpO2         = sp_train,
        BMI          = bmi_train,
        samplingRate = 24
        )
    print('*************************************************************')
    print('*********************Testing Array Set***********************')
    print('*************************************************************')
    test_array  = construct_feature_set_v1(
        PPG          = X_test,
        HbA1c        = y_test,
        SpO2         = sp_test,
        BMI          = bmi_test,
        samplingRate = 24
        )
    
    feature_train, hba1c_train = train_array[:,:-1], train_array[:,-1]
    feature_test, hba1c_test   = test_array[:,:-1],  test_array[:,-1]
    
    train = np.sort(np.array(random.sample(range(feature_test.shape[0]), int(feature_test.shape[0] * percent))))
    if train.shape[0] == 0:
        feature_train, hba1c_train = np.append(feature_train, np.expand_dims(feature_test[0],axis=0), 0), np.append(hba1c_train, np.expand_dims(hba1c_test[0],axis=0), 0)
        # feature_test, hba1c_test = np.delete(feature_test, 0, axis = 0), np.delete(hba1c_test, 0, axis = 0)
    else:
        test = np.delete(np.arange(feature_test.shape[0]), train)

        feature_train, hba1c_train = np.append(feature_train, feature_test[train], 0), np.append(hba1c_train, hba1c_test[train], 0)
        feature_test, hba1c_test = np.delete(feature_test, train, axis = 0), np.delete(hba1c_test, train, axis = 0)
    
    feature_train, hba1c_train = sk.utils.shuffle(feature_train, hba1c_train, random_state=0)
    # print(feature_train.shape)
    # print(feature_test.shape)

    # XGboost
    xg = xgb.XGBRegressor(objective="reg:squarederror", random_state=42, n_estimators=2000, eta=0.05, subsample=0.5, colsample_bytree=0.5)
    xg.fit(feature_train, hba1c_train)
    t1_results_xg.append(np.nanmean(xg.predict(feature_test)))
    t1_e_results_xg.append(np.nanmean(hba1c_test))

    # Random Forest
    rf = RandomForestRegressor(random_state=42, n_estimators=1000, n_jobs=-1)
    rf.fit(feature_train, hba1c_train)
    t1_results_rf.append(np.nanmean(rf.predict(feature_test)))
    t1_e_results_rf.append(np.nanmean(hba1c_test))

    # Cat boost
    cb = cab.CatBoostRegressor(depth=3, l2_leaf_reg=5)
    cb.fit(feature_train, hba1c_train)
    t1_results_cb.append(np.nanmean(cb.predict(feature_test)))
    t1_e_results_cb.append(np.nanmean(hba1c_test))

    # Light GBM
    lg = ltb.LGBMRegressor(
    application='regression',
    objective='root_mean_squared_error',
    boosting_type='gbdt',
    learning_rate=0.05,
    num_leaves=31,
    max_depth=-1,
    min_data_in_leaf=5,
    metric='rmse',
    feature_fraction=0.8,
    bagging_fraction=0.8,
    bagging_freq=5,
    random_state=42,
    n_estimators=500
    )
    lg.fit(feature_train, hba1c_train)
    t1_results_lg.append(np.nanmean(lg.predict(feature_test)))
    t1_e_results_lg.append(np.nanmean(hba1c_test))



    t1_test_cases.append(X_test)
    t1_train_cases.append(X_train)

    clear_output(wait=True)
# Out:
# Epoch # 7
# *************************************************************
# *********************Training Array Set**********************
# *************************************************************
# PPG_data_info:E:\OneDrive - KookminUNIV\KMU==Lab\MCSP==Research-Papers\SCI-02\Software\ProgrammingCodes\DataBase\data(mod)\1_turja_0120_2023(356)_hb5.3_sp98.csv
# iCount=0 || jCount=0 || lCount=1 || fCount=15
# [4.24569539e+03 2.30931592e+02 4.13017321e+01 3.20040169e+00
#  4.02187360e+04 4.44772702e+02 7.09277088e+06 1.61623389e+01
#  1.00000000e+01 1.78823340e+04 3.48766282e+02 9.30978423e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=1 || lCount=2 || fCount=15
# [4.29232360e+03 2.18225463e+02 3.87572596e+01 2.87157229e+00
#  4.44009207e+04 4.43845975e+02 6.77923762e+06 1.72256696e+01
#  9.00000000e+00 1.95769617e+04 3.51833695e+02 9.96399588e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=2 || lCount=3 || fCount=15
# [4.14995249e+03 2.15593755e+02 3.99563195e+01 2.75682234e+00
#  4.12007335e+04 4.07258845e+02 6.74386390e+06 1.47602731e+01
#  1.10000000e+01 1.85528907e+04 3.33946496e+02 8.69759060e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=3 || lCount=4 || fCount=15
# [3.80704154e+03 2.08552645e+02 3.86732642e+01 2.74479357e+00
#  3.90378270e+04 4.14938899e+02 6.59994386e+06 1.75043460e+01
#  9.00000000e+00 1.74538010e+04 3.48551492e+02 9.91676842e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=4 || lCount=5 || fCount=15
# [3.51977565e+03 2.16044085e+02 3.68898809e+01 3.00120756e+00
#  3.76518781e+04 4.22657280e+02 5.07880451e+06 1.73847387e+01
#  1.00000000e+01 1.68621051e+04 3.60474749e+02 1.03133054e+01
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=5 || lCount=6 || fCount=15
# [3.38198234e+03 2.18612706e+02 3.84126329e+01 3.05088323e+00
#  3.87351324e+04 4.02067692e+02 4.03124291e+06 1.62198650e+01
#  9.00000000e+00 1.71547921e+04 3.61752981e+02 9.95375296e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=6 || lCount=7 || fCount=15
# [3.31459489e+03 2.28961579e+02 4.13771903e+01 3.13628518e+00
#  3.41565864e+04 4.04195468e+02 3.65627189e+06 1.47939580e+01
#  1.00000000e+01 1.56402048e+04 3.51897071e+02 9.23950334e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=7 || lCount=8 || fCount=15
# [3.04593967e+03 2.36180277e+02 4.31460237e+01 3.19924536e+00
#  3.26759794e+04 4.06416653e+02 3.92347971e+06 1.40841139e+01
#  1.20000000e+01 1.50091063e+04 3.53884275e+02 8.65378503e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=8 || lCount=9 || fCount=15
# [2.92995867e+03 2.44004860e+02 4.95877963e+01 3.50941956e+00
#  3.18488663e+04 4.33993605e+02 4.34818218e+06 1.64826619e+01
#  1.20000000e+01 1.44011334e+04 3.63600582e+02 9.89926136e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=9 || lCount=10 || fCount=15
# [2.84445487e+03 2.40375489e+02 4.50196061e+01 3.29679959e+00
#  3.38510273e+04 4.34304370e+02 3.64702647e+06 1.63525500e+01
#  1.20000000e+01 1.50616394e+04 3.49572399e+02 9.16158887e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=10 || lCount=11 || fCount=15
# [2.89208384e+03 2.33556571e+02 4.26430353e+01 3.17729355e+00
#  3.47657645e+04 4.36254078e+02 3.29338553e+06 1.57849038e+01
#  1.00000000e+01 1.52701968e+04 3.55563187e+02 9.41223504e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=11 || lCount=12 || fCount=15
# [3.29855533e+03 2.26235230e+02 5.01144094e+01 3.16613356e+00
#  3.63555027e+04 4.50489664e+02 3.48611680e+06 1.84676400e+01
#  1.00000000e+01 1.59374274e+04 3.47235116e+02 9.94292509e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=12 || lCount=13 || fCount=15
# [2.97861048e+03 2.28934712e+02 3.88347178e+01 3.04063136e+00
#  3.28583800e+04 4.36391043e+02 4.34061281e+06 1.65223008e+01
#  1.00000000e+01 1.44579664e+04 3.40796962e+02 9.30040033e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=13 || lCount=14 || fCount=15
# [3.14559972e+03 2.20261823e+02 3.82834503e+01 2.71894857e+00
#  3.30551353e+04 4.22278666e+02 4.64161826e+06 1.52903741e+01
#  1.00000000e+01 1.44499144e+04 3.23284385e+02 8.38340730e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=14 || lCount=15 || fCount=15
# [2.97371095e+03 2.04265395e+02 2.75901017e+01 2.42511290e+00
#  3.30705020e+04 4.14706780e+02 3.60608471e+06 1.42046502e+01
#  1.00000000e+01 1.41383484e+04 3.08021005e+02 7.52724783e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=15 || lCount=16 || fCount=15
# [2.91266030e+03 2.00506003e+02 3.09722883e+01 2.43652464e+00
#  3.33646024e+04 4.00851399e+02 3.04237852e+06 1.36659403e+01
#  1.20000000e+01 1.44446081e+04 3.09550805e+02 7.81535651e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=16 || lCount=17 || fCount=15
# [2.86401219e+03 2.07499157e+02 3.15771798e+01 2.51733592e+00
#  3.33497775e+04 4.01631167e+02 3.15575807e+06 1.53048096e+01
#  1.10000000e+01 1.41249612e+04 2.89416945e+02 7.47054614e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=17 || lCount=18 || fCount=15
# [2.33697300e+03 2.12022190e+02 2.83703061e+01 2.62654417e+00
#  3.06398509e+04 4.22958386e+02 3.97188552e+06 1.56071480e+01
#  1.00000000e+01 1.28434165e+04 3.02845984e+02 7.73606213e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=18 || lCount=19 || fCount=15
# [2.21063858e+03 2.07225699e+02 2.39927221e+01 2.59399069e+00
#  3.08550313e+04 4.17730509e+02 4.39179279e+06 1.51924648e+01
#  1.00000000e+01 1.24802802e+04 2.95413875e+02 7.17306928e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=19 || lCount=20 || fCount=15
# [2.41239065e+03 2.03110875e+02 2.63279613e+01 2.50885163e+00
#  3.51175280e+04 4.16875759e+02 3.57446898e+06 1.52723478e+01
#  9.00000000e+00 1.45320635e+04 2.92587974e+02 7.14708636e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=20 || lCount=21 || fCount=15
# [2.13720854e+03 2.17509662e+02 2.52071869e+01 2.67957766e+00
#  3.24799508e+04 4.31344156e+02 3.04408964e+06 1.60412529e+01
#  1.00000000e+01 1.32178387e+04 3.14905626e+02 7.52253581e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=21 || lCount=22 || fCount=15
# [2.08681253e+03 2.31074071e+02 3.05885104e+01 3.11744084e+00
#  3.51505629e+04 4.33895689e+02 3.26433909e+06 1.77832944e+01
#  9.00000000e+00 1.37300419e+04 3.14494552e+02 8.41293456e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=22 || lCount=23 || fCount=15
# [1.91104692e+03 2.34310706e+02 3.06236518e+01 3.19368874e+00
#  3.24984872e+04 4.45427024e+02 4.17810058e+06 1.76313494e+01
#  1.00000000e+01 1.26411513e+04 3.27692117e+02 8.24628065e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=23 || lCount=24 || fCount=15
# [1.99624949e+03 2.27700255e+02 2.90060178e+01 3.00263799e+00
#  3.39481677e+04 4.32751418e+02 4.55916526e+06 1.68255710e+01
#  9.00000000e+00 1.35029692e+04 3.20967112e+02 7.54934588e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=24 || lCount=25 || fCount=15
# [2.16021246e+03 2.28642761e+02 3.05276270e+01 3.03974586e+00
#  3.55207214e+04 4.46025854e+02 3.89256649e+06 1.70748989e+01
#  1.00000000e+01 1.48303836e+04 3.34490423e+02 8.35962032e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=25 || lCount=26 || fCount=15
# [2.28230686e+03 2.27676370e+02 3.60768423e+01 3.19733617e+00
#  3.57798181e+04 4.66619385e+02 3.47689259e+06 2.11252933e+01
#  1.00000000e+01 1.47844280e+04 3.53714855e+02 1.08728880e+01
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=26 || lCount=27 || fCount=15
# [2.11755077e+03 2.14348020e+02 2.78790133e+01 2.83693531e+00
#  3.56715120e+04 4.44538971e+02 3.99898664e+06 1.77562166e+01
#  1.20000000e+01 1.44415942e+04 3.31128059e+02 8.80685267e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=27 || lCount=28 || fCount=15
# [2.18616983e+03 1.95517746e+02 2.25508295e+01 2.42706751e+00
#  3.47150675e+04 4.35824969e+02 4.68024267e+06 1.71881947e+01
#  1.00000000e+01 1.42043493e+04 3.26481416e+02 8.32349010e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=28 || lCount=29 || fCount=15
# [2.25494491e+03 1.94307467e+02 2.40473272e+01 2.43184629e+00
#  3.33558101e+04 4.26577319e+02 4.70445809e+06 1.56958941e+01
#  1.00000000e+01 1.41184099e+04 3.32987866e+02 8.65050980e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=29 || lCount=30 || fCount=15
# [2.43355485e+03 2.00814026e+02 2.62070806e+01 2.66820638e+00
#  3.20963866e+04 4.17863312e+02 3.75817325e+06 1.55585789e+01
#  1.00000000e+01 1.38349842e+04 3.34990046e+02 9.33642312e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=30 || lCount=31 || fCount=15
# [2.41334049e+03 1.90407577e+02 2.57752870e+01 2.25968231e+00
#  3.14033804e+04 4.02398823e+02 2.80330185e+06 1.54696657e+01
#  9.00000000e+00 1.29733994e+04 3.22558568e+02 8.25022173e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=31 || lCount=32 || fCount=15
# [2.37696970e+03 1.99922103e+02 2.87858282e+01 2.69950461e+00
#  2.98731218e+04 4.30943543e+02 2.45991453e+06 1.60967744e+01
#  1.00000000e+01 1.22627688e+04 3.32862464e+02 8.83546432e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=32 || lCount=33 || fCount=15
# [2.40350410e+03 2.03572512e+02 2.54451712e+01 2.61058637e+00
#  2.99036402e+04 4.22672801e+02 2.62748073e+06 1.41866784e+01
#  9.00000000e+00 1.23225226e+04 3.38358352e+02 7.80844553e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=33 || lCount=34 || fCount=15
# [2.53614430e+03 2.19059274e+02 2.78350531e+01 2.87498929e+00
#  2.78685272e+04 4.11457342e+02 3.00112656e+06 1.31190082e+01
#  1.20000000e+01 1.22394580e+04 3.43734713e+02 7.95075523e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=34 || lCount=35 || fCount=15
# [2.48604251e+03 2.12223000e+02 2.82241699e+01 2.74250461e+00
#  2.60592517e+04 3.87147270e+02 2.90370112e+06 1.26220554e+01
#  1.10000000e+01 1.13286388e+04 3.33357231e+02 7.60769109e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=35 || lCount=36 || fCount=15
# [2.54631106e+03 2.16825694e+02 2.70100033e+01 2.85249411e+00
#  2.72838595e+04 4.01715632e+02 2.28174854e+06 1.25357102e+01
#  1.00000000e+01 1.17131983e+04 3.41582576e+02 7.59494036e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=36 || lCount=37 || fCount=15
# [2.81753360e+03 2.17056988e+02 2.72223637e+01 2.89219046e+00
#  3.06569692e+04 4.05972530e+02 1.74956470e+06 1.39107113e+01
#  9.00000000e+00 1.37730813e+04 3.45896121e+02 8.22276675e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=37 || lCount=38 || fCount=15
# [2.62165253e+03 2.13376390e+02 2.70236044e+01 2.96756739e+00
#  2.70168714e+04 3.81381220e+02 1.69212681e+06 1.21149553e+01
#  1.40000000e+01 1.23824030e+04 3.40661757e+02 7.62174591e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=38 || lCount=39 || fCount=15
# [3.06349337e+03 2.09387552e+02 3.06593200e+01 2.97621958e+00
#  2.91368915e+04 3.77128528e+02 2.67352878e+06 1.33082805e+01
#  1.10000000e+01 1.34490191e+04 3.41171188e+02 8.58370442e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=39 || lCount=40 || fCount=15
# [3.31751215e+03 2.17077287e+02 5.11362535e+01 3.23275296e+00
#  3.22281429e+04 4.12994888e+02 3.84656600e+06 1.52328638e+01
#  1.00000000e+01 1.44560028e+04 3.48509525e+02 9.20736897e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=40 || lCount=41 || fCount=15
# [3.78025202e+03 2.11569437e+02 4.87260702e+01 3.03704247e+00
#  3.55500116e+04 4.14593986e+02 4.45645028e+06 1.37628284e+01
#  9.00000000e+00 1.57006696e+04 3.42069425e+02 8.17296456e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=41 || lCount=42 || fCount=15
# [3.88781857e+03 2.14495472e+02 6.52939982e+01 3.45212658e+00
#  3.53846661e+04 4.19484341e+02 4.89084443e+06 1.43825757e+01
#  1.00000000e+01 1.57940167e+04 3.39741144e+02 8.45165936e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=42 || lCount=43 || fCount=15
# [4.05284320e+03 2.26931412e+02 8.56059316e+01 3.92857334e+00
#  3.59401118e+04 4.35330303e+02 4.32272688e+06 1.89423985e+01
#  9.00000000e+00 1.57307315e+04 3.46599509e+02 1.05612188e+01
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=43 || lCount=44 || fCount=15
# [4.52149985e+03 2.38202511e+02 7.86005294e+01 3.69796618e+00
#  3.84763282e+04 4.58906226e+02 3.59600138e+06 1.65118772e+01
#  1.00000000e+01 1.68472481e+04 3.41657508e+02 8.35729946e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=44 || lCount=45 || fCount=15
# [4.51781922e+03 2.42780393e+02 9.24250602e+01 4.10481915e+00
#  3.96378550e+04 4.67077765e+02 4.42776953e+06 1.83414138e+01
#  1.00000000e+01 1.76830286e+04 3.52679932e+02 9.92344945e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=45 || lCount=46 || fCount=15
# [4.47619207e+03 2.35906338e+02 8.08150485e+01 3.98052500e+00
#  3.99870659e+04 4.66869481e+02 5.86957691e+06 1.98296102e+01
#  1.00000000e+01 1.78603976e+04 3.48874691e+02 1.01820168e+01
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=46 || lCount=47 || fCount=15
# [4.23874199e+03 2.43671499e+02 7.00768239e+01 3.72246677e+00
#  3.89555142e+04 4.59824540e+02 6.52418453e+06 1.82801273e+01
#  1.00000000e+01 1.73595795e+04 3.41562658e+02 9.07954322e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=47 || lCount=48 || fCount=15
# [5.00441947e+03 2.66551307e+02 9.77275536e+01 4.51272106e+00
#  4.43659929e+04 4.80084094e+02 6.23047155e+06 2.00318857e+01
#  1.00000000e+01 1.98180760e+04 3.39882998e+02 9.14035588e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=48 || lCount=49 || fCount=15
# [5.13958180e+03 2.71288580e+02 9.00126941e+01 4.32573947e+00
#  4.68933310e+04 4.81631895e+02 6.22208894e+06 2.02061218e+01
#  1.00000000e+01 2.08233095e+04 3.46172710e+02 9.79335375e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=49 || lCount=50 || fCount=15
# [4.83399601e+03 2.62321295e+02 7.92911759e+01 4.16607234e+00
#  4.57699887e+04 4.57762116e+02 7.35576837e+06 1.91789371e+01
#  9.00000000e+00 2.01287817e+04 3.38397866e+02 9.73391229e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=50 || lCount=51 || fCount=15
# [4.87183026e+03 2.54493512e+02 7.16458063e+01 3.71923430e+00
#  4.33941452e+04 4.30836129e+02 8.11310332e+06 1.57848375e+01
#  9.00000000e+00 1.91628901e+04 3.21821359e+02 7.83789792e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=51 || lCount=52 || fCount=15
# [4.68512437e+03 2.56706265e+02 7.20012257e+01 3.94098142e+00
#  4.19292148e+04 4.43740189e+02 7.31569665e+06 1.88517246e+01
#  9.00000000e+00 1.84323806e+04 3.31922697e+02 9.52045131e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=52 || lCount=53 || fCount=15
# [4.54607477e+03 2.58965816e+02 6.43034993e+01 3.79484182e+00
#  4.06724621e+04 4.43564532e+02 5.58727291e+06 1.74935605e+01
#  1.00000000e+01 1.79898395e+04 3.38457516e+02 8.94588172e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=53 || lCount=54 || fCount=15
# [4.26387043e+03 2.52357959e+02 7.01169014e+01 3.76099866e+00
#  4.11265354e+04 4.35884367e+02 4.10205108e+06 1.87024285e+01
#  9.00000000e+00 1.75945845e+04 3.40045370e+02 9.43513206e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=54 || lCount=55 || fCount=15
# [3.59273730e+03 2.38930712e+02 4.20741379e+01 3.12282464e+00
#  3.47744186e+04 4.30013339e+02 3.91201423e+06 1.58563827e+01
#  1.00000000e+01 1.48624281e+04 3.40251297e+02 8.45459603e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=55 || lCount=56 || fCount=15
# [4.12718006e+03 2.30924896e+02 4.60927602e+01 3.12906072e+00
#  3.96111235e+04 4.25393428e+02 4.57486050e+06 1.54287193e+01
#  1.00000000e+01 1.67429436e+04 3.27333450e+02 7.66921970e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=56 || lCount=57 || fCount=15
# [4.13182577e+03 2.29555001e+02 4.95506937e+01 3.21472918e+00
#  3.94754539e+04 4.37289517e+02 5.96713725e+06 1.70740088e+01
#  1.00000000e+01 1.61964072e+04 3.36993355e+02 8.29334373e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=57 || lCount=58 || fCount=15
# [4.09993120e+03 2.26196119e+02 4.85215649e+01 3.16837865e+00
#  3.98947059e+04 4.26579296e+02 7.23630427e+06 1.57575722e+01
#  9.00000000e+00 1.59059803e+04 3.15463172e+02 7.33835470e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=58 || lCount=59 || fCount=15
# [4.02087595e+03 2.26008648e+02 5.24495061e+01 3.38258665e+00
#  3.92251310e+04 4.38104260e+02 6.61674171e+06 1.71530977e+01
#  1.00000000e+01 1.53177371e+04 3.16763321e+02 7.44877846e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=59 || lCount=60 || fCount=15
# [4.63978079e+03 2.25864823e+02 6.03850232e+01 3.34023342e+00
#  4.17981296e+04 4.34922620e+02 4.99035803e+06 1.88278005e+01
#  9.00000000e+00 1.69457979e+04 3.19433599e+02 8.29190632e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=60 || lCount=61 || fCount=15
# [4.75090902e+03 2.32420537e+02 6.30612470e+01 3.54386106e+00
#  4.20478002e+04 4.52422569e+02 4.88828442e+06 1.76067527e+01
#  1.00000000e+01 1.72290665e+04 3.39255005e+02 8.44105499e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=61 || lCount=62 || fCount=15
# [5.11060503e+03 2.31059045e+02 6.20913865e+01 3.42347297e+00
#  4.48001254e+04 4.44055530e+02 5.77955952e+06 1.81523647e+01
#  9.00000000e+00 1.86439653e+04 3.37799883e+02 9.11397342e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=62 || lCount=63 || fCount=15
# [4.49396897e+03 2.17027158e+02 5.66237284e+01 3.00286208e+00
#  3.95925214e+04 4.17969857e+02 7.20424496e+06 1.48867443e+01
#  1.00000000e+01 1.66322647e+04 3.18601958e+02 7.61254018e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=63 || lCount=64 || fCount=15
# [5.15130095e+03 2.28064940e+02 6.55312824e+01 3.49295992e+00
#  4.19586532e+04 4.22422811e+02 7.73617270e+06 1.65695548e+01
#  9.00000000e+00 1.80166158e+04 3.30468202e+02 8.55773569e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=64 || lCount=65 || fCount=15
# [4.97691724e+03 2.11915289e+02 5.52564369e+01 3.05874384e+00
#  4.21619788e+04 4.33644792e+02 6.77403862e+06 1.60804178e+01
#  1.00000000e+01 1.78024663e+04 3.20428030e+02 7.61026792e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=65 || lCount=66 || fCount=15
# [4.95269615e+03 2.20515838e+02 5.52464497e+01 3.48402950e+00
#  4.22328873e+04 4.23137109e+02 5.26960702e+06 1.72627457e+01
#  9.00000000e+00 1.78613281e+04 3.19798765e+02 8.23765872e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=66 || lCount=67 || fCount=15
# [4.46205528e+03 2.05767081e+02 4.13635470e+01 2.99057429e+00
#  3.68191068e+04 4.02998044e+02 4.18886905e+06 1.43272623e+01
#  1.00000000e+01 1.53252639e+04 3.00140136e+02 6.75323829e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=67 || lCount=68 || fCount=15
# [4.06592620e+03 2.20419024e+02 5.78899046e+01 3.41660538e+00
#  3.58900610e+04 4.14361964e+02 4.03378949e+06 1.79751232e+01
#  9.00000000e+00 1.42048031e+04 2.98332076e+02 7.41985087e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=68 || lCount=69 || fCount=15
# [3.93159050e+03 2.46829069e+02 5.46905907e+01 3.76302972e+00
#  3.35963898e+04 4.32349758e+02 4.25200192e+06 1.64376769e+01
#  1.00000000e+01 1.31610601e+04 3.16491921e+02 7.08164402e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=69 || lCount=70 || fCount=15
# [3.48213095e+03 2.44255459e+02 5.04365132e+01 3.73917558e+00
#  3.12067433e+04 4.17699844e+02 4.07406773e+06 1.52750970e+01
#  9.00000000e+00 1.20455314e+04 3.01445707e+02 6.73704244e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=70 || lCount=71 || fCount=15
# [3.51748929e+03 2.57303474e+02 6.21163531e+01 3.83572595e+00
#  3.08479231e+04 4.25046785e+02 3.08575485e+06 1.50052521e+01
#  1.00000000e+01 1.20226877e+04 3.13414566e+02 6.88213745e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=71 || lCount=72 || fCount=15
# [3.33998259e+03 2.54375849e+02 6.13051075e+01 3.96250974e+00
#  3.14846609e+04 4.35928464e+02 2.14036254e+06 1.78259153e+01
#  1.00000000e+01 1.23325252e+04 3.18851964e+02 7.51053846e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=72 || lCount=73 || fCount=15
# [3.21279837e+03 2.69512287e+02 6.46429749e+01 4.18646964e+00
#  3.22160908e+04 4.38660636e+02 2.28518302e+06 1.63144666e+01
#  1.00000000e+01 1.25087665e+04 3.16624080e+02 7.46270774e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=73 || lCount=74 || fCount=15
# [2.97068062e+03 2.62743807e+02 5.27870551e+01 4.01968550e+00
#  3.23688319e+04 4.40229090e+02 3.37798894e+06 1.65006458e+01
#  1.00000000e+01 1.26641139e+04 3.16224153e+02 7.39851292e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=74 || lCount=75 || fCount=15
# [2.74673877e+03 2.36397151e+02 4.04802753e+01 3.40889913e+00
#  3.29206143e+04 4.26969369e+02 4.63940552e+06 1.53473098e+01
#  1.00000000e+01 1.30102456e+04 3.07154441e+02 7.15315522e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=75 || lCount=76 || fCount=15
# [2.67849069e+03 2.28545400e+02 4.09046520e+01 3.26083312e+00
#  3.20723771e+04 4.06893539e+02 4.71116093e+06 1.46388053e+01
#  9.00000000e+00 1.28019008e+04 3.06786305e+02 6.76626773e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=76 || lCount=77 || fCount=15
# [2.77564375e+03 2.40703110e+02 5.13906720e+01 3.59767181e+00
#  3.40013003e+04 4.17031079e+02 3.83520523e+06 1.62891082e+01
#  9.00000000e+00 1.30849143e+04 3.07153244e+02 7.45795634e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=77 || lCount=78 || fCount=15
# [2.67510831e+03 2.31413427e+02 3.30224338e+01 3.12680083e+00
#  3.38904162e+04 4.25117662e+02 3.04719714e+06 1.52925199e+01
#  9.00000000e+00 1.28258039e+04 3.02194317e+02 6.89441816e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=78 || lCount=79 || fCount=15
# [2.69555762e+03 2.11986029e+02 3.00398741e+01 2.76347238e+00
#  3.24796287e+04 4.14369451e+02 2.92288240e+06 1.60359510e+01
#  9.00000000e+00 1.24407305e+04 2.93243413e+02 7.08575389e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=79 || lCount=80 || fCount=15
# [2.94742941e+03 2.12711198e+02 4.18129192e+01 3.03281060e+00
#  3.02855200e+04 4.05385383e+02 3.00263501e+06 1.43212779e+01
#  1.00000000e+01 1.19964137e+04 2.96963672e+02 7.03764299e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=80 || lCount=81 || fCount=15
# [3.55663190e+03 2.16639794e+02 4.43325879e+01 3.14101935e+00
#  3.24686542e+04 4.02481336e+02 2.86624099e+06 1.53406397e+01
#  9.00000000e+00 1.35705061e+04 3.01320380e+02 8.08488476e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=81 || lCount=82 || fCount=15
# [4.56250937e+03 2.30672877e+02 4.66203440e+01 3.44238701e+00
#  3.62488662e+04 4.43826488e+02 3.51380620e+06 1.64183186e+01
#  1.00000000e+01 1.59860117e+04 3.19781103e+02 8.14590894e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=82 || lCount=83 || fCount=15
# [4.58262041e+03 2.27558393e+02 5.03347806e+01 3.47476164e+00
#  3.72223058e+04 4.33896317e+02 5.10937266e+06 1.60823494e+01
#  9.00000000e+00 1.64309810e+04 3.22651855e+02 8.32680206e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=83 || lCount=84 || fCount=15
# [4.32916044e+03 2.33605083e+02 5.35061143e+01 3.74164406e+00
#  3.57659022e+04 4.52736335e+02 6.50712076e+06 1.76464726e+01
#  1.00000000e+01 1.56472458e+04 3.49641117e+02 9.19750505e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=84 || lCount=85 || fCount=15
# [4.21847882e+03 2.38234861e+02 5.22380214e+01 3.67051632e+00
#  3.54890763e+04 4.43351531e+02 6.11501608e+06 1.75932311e+01
#  1.00000000e+01 1.54325088e+04 3.51821135e+02 9.49579271e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=85 || lCount=86 || fCount=15
# [4.29634031e+03 2.39122460e+02 4.99832605e+01 3.65442361e+00
#  3.49538865e+04 4.38747218e+02 3.87019258e+06 1.63530463e+01
#  1.00000000e+01 1.52589749e+04 3.47410108e+02 8.64865704e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=86 || lCount=87 || fCount=15
# [3.81205736e+03 2.33251601e+02 4.12195576e+01 3.38311221e+00
#  3.46503382e+04 4.36573699e+02 2.50296673e+06 1.68952003e+01
#  1.00000000e+01 1.49916418e+04 3.58115994e+02 9.32159912e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=87 || lCount=88 || fCount=15
# [3.66154881e+03 2.15494318e+02 4.38017978e+01 3.13228693e+00
#  3.39571190e+04 4.01710887e+02 2.57994614e+06 1.54949717e+01
#  9.00000000e+00 1.40856675e+04 3.27577862e+02 8.01230307e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=88 || lCount=89 || fCount=15
# [2.88997289e+03 1.99788123e+02 2.68464369e+01 2.43380369e+00
#  2.76490350e+04 3.88198690e+02 3.65080783e+06 1.24939845e+01
#  1.00000000e+01 1.13863530e+04 3.09850509e+02 6.55892398e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=89 || lCount=90 || fCount=15
# [3.24718414e+03 1.90873620e+02 3.00600820e+01 2.42399145e+00
#  2.85292237e+04 3.65158205e+02 3.70231191e+06 1.37131105e+01
#  9.00000000e+00 1.20351082e+04 2.95673570e+02 6.59516069e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=90 || lCount=91 || fCount=15
# [3.56049349e+03 1.86755049e+02 2.90506803e+01 2.16378031e+00
#  3.01089526e+04 3.86918583e+02 2.59750360e+06 1.30554248e+01
#  1.00000000e+01 1.28968646e+04 3.05279339e+02 6.55000488e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=91 || lCount=92 || fCount=15
# [3.45713394e+03 1.90978287e+02 3.81358407e+01 2.60113607e+00
#  3.04466224e+04 3.93349901e+02 2.22058689e+06 1.38545309e+01
#  9.00000000e+00 1.30030563e+04 3.27668995e+02 8.14704245e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=92 || lCount=93 || fCount=15
# [3.29646045e+03 1.93140591e+02 2.98964363e+01 2.52289251e+00
#  2.72603298e+04 3.77115668e+02 2.34513303e+06 1.20811918e+01
#  1.00000000e+01 1.13926658e+04 3.09013688e+02 6.75387039e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=93 || lCount=94 || fCount=15
# [2.94191430e+03 2.07621668e+02 3.08045398e+01 2.90643683e+00
#  2.38896830e+04 3.97528702e+02 2.50548148e+06 1.38500744e+01
#  1.20000000e+01 1.00411610e+04 3.24625586e+02 7.62803744e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=94 || lCount=95 || fCount=15
# [3.27970301e+03 2.24817368e+02 3.91480321e+01 3.22027677e+00
#  2.49304556e+04 4.10359655e+02 2.04630705e+06 1.23727597e+01
#  1.10000000e+01 1.08817809e+04 3.42659981e+02 7.43189986e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=95 || lCount=96 || fCount=15
# [3.10840990e+03 2.36186927e+02 6.43066080e+01 3.84749340e+00
#  2.52494027e+04 4.34233831e+02 1.62529505e+06 1.51460429e+01
#  1.20000000e+01 1.07696640e+04 3.55112157e+02 8.81573271e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=96 || lCount=97 || fCount=15
# [3.12550203e+03 2.42070305e+02 3.80570070e+01 3.68124097e+00
#  2.59887269e+04 4.26935973e+02 1.56150190e+06 1.39766785e+01
#  1.10000000e+01 1.07573272e+04 3.54656793e+02 8.23523049e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=97 || lCount=98 || fCount=15
# [3.03763262e+03 2.48812951e+02 3.75027397e+01 3.58803889e+00
#  2.38842982e+04 4.15863991e+02 1.75754198e+06 1.29485574e+01
#  1.20000000e+01 9.95949407e+03 3.47149178e+02 7.33602045e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=98 || lCount=99 || fCount=15
# [3.05228941e+03 2.39195864e+02 3.88851579e+01 3.47719922e+00
#  2.53708557e+04 4.05777112e+02 2.24110458e+06 1.28750226e+01
#  1.10000000e+01 1.04174962e+04 3.41727320e+02 7.48087130e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=99 || lCount=100 || fCount=15
# [3.13619158e+03 2.25917392e+02 3.19738354e+01 3.08703086e+00
#  2.77144647e+04 4.14264336e+02 2.76835675e+06 1.34860952e+01
#  1.00000000e+01 1.11143232e+04 3.45740813e+02 7.37313006e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=100 || lCount=101 || fCount=15
# [3.55985113e+03 2.28596985e+02 3.02963823e+01 3.24229094e+00
#  3.16983541e+04 4.33866504e+02 3.09841998e+06 1.55365041e+01
#  1.00000000e+01 1.28612500e+04 3.61245178e+02 8.45733007e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=101 || lCount=102 || fCount=15
# [4.39409174e+03 2.33751354e+02 3.91388124e+01 3.52264161e+00
#  3.85153839e+04 4.44247521e+02 3.97105590e+06 1.71994843e+01
#  1.20000000e+01 1.63000113e+04 3.74466136e+02 9.66059398e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=102 || lCount=103 || fCount=15
# [4.52667196e+03 2.27540611e+02 3.71370118e+01 3.60244964e+00
#  4.05476357e+04 4.70005637e+02 5.68668948e+06 2.08963853e+01
#  1.00000000e+01 1.71567174e+04 3.77150825e+02 1.08383252e+01
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=103 || lCount=104 || fCount=15
# [4.52822568e+03 2.21145808e+02 3.82448979e+01 3.48089508e+00
#  4.18927056e+04 4.77277457e+02 8.09608493e+06 2.03307553e+01
#  1.00000000e+01 1.77135841e+04 3.71095303e+02 1.04822588e+01
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=104 || lCount=105 || fCount=15
# [4.64131958e+03 2.22952549e+02 4.68887954e+01 3.68452584e+00
#  4.30213069e+04 4.83531680e+02 8.63747447e+06 2.07448901e+01
#  1.00000000e+01 1.83867494e+04 3.68907487e+02 1.06704157e+01
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=105 || lCount=106 || fCount=15
# [4.43581804e+03 2.23443258e+02 4.23869525e+01 3.59537745e+00
#  4.33510159e+04 4.86767115e+02 6.72246838e+06 2.07489317e+01
#  1.00000000e+01 1.80397772e+04 3.58328479e+02 9.72683401e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=106 || lCount=107 || fCount=15
# [4.01329395e+03 2.04412772e+02 3.82089276e+01 3.04631051e+00
#  4.34692669e+04 4.61399426e+02 5.05225273e+06 1.88661632e+01
#  1.00000000e+01 1.78008718e+04 3.31995839e+02 9.13841386e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=107 || lCount=108 || fCount=15
# [3.48456529e+03 2.20685234e+02 5.03838220e+01 3.57496171e+00
#  4.07828833e+04 4.79772332e+02 4.68384786e+06 2.32749078e+01
#  1.00000000e+01 1.61775571e+04 3.36415438e+02 9.85783748e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=108 || lCount=109 || fCount=15
# [3.50508425e+03 2.25435447e+02 4.18128644e+01 3.45522424e+00
#  4.04734840e+04 4.65730542e+02 5.46941228e+06 1.92236992e+01
#  1.00000000e+01 1.64042828e+04 3.26498249e+02 8.66839906e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=109 || lCount=110 || fCount=15
# [3.44589977e+03 2.23550448e+02 3.58146273e+01 3.16274354e+00
#  4.10884120e+04 4.68926997e+02 6.65742622e+06 1.92006720e+01
#  1.00000000e+01 1.68627640e+04 3.36705455e+02 9.17768363e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=110 || lCount=111 || fCount=15
# [4.32291651e+03 2.31844664e+02 5.04263796e+01 3.43748899e+00
#  4.62491740e+04 4.77123162e+02 7.25605043e+06 2.04305947e+01
#  9.00000000e+00 1.89568598e+04 3.41550762e+02 9.52934165e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=111 || lCount=112 || fCount=15
# [4.12685613e+03 2.23158864e+02 3.89290971e+01 2.84304588e+00
#  4.46020164e+04 4.64202427e+02 7.47154901e+06 1.86255593e+01
#  1.00000000e+01 1.82185451e+04 3.29607087e+02 8.88011562e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=112 || lCount=113 || fCount=15
# [4.14920213e+03 2.22788714e+02 4.10760593e+01 2.94043931e+00
#  4.12616084e+04 4.57116345e+02 7.48080374e+06 1.94929654e+01
#  9.00000000e+00 1.69619893e+04 3.20397879e+02 9.02455025e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=113 || lCount=114 || fCount=15
# [4.14329520e+03 2.17730163e+02 3.63281880e+01 2.81193471e+00
#  4.01626929e+04 4.61831506e+02 6.38263819e+06 1.83939809e+01
#  1.20000000e+01 1.64341490e+04 3.26187914e+02 8.62794148e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=114 || lCount=115 || fCount=15
# [4.32345129e+03 2.23630915e+02 4.39275556e+01 3.03341366e+00
#  3.90246280e+04 4.68492891e+02 4.40902786e+06 1.96127848e+01
#  1.20000000e+01 1.59994472e+04 3.31401424e+02 9.13643647e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=115 || lCount=116 || fCount=15
# [4.37054641e+03 2.24988474e+02 4.80442983e+01 3.12268605e+00
#  3.83865681e+04 4.57078140e+02 3.37274506e+06 1.75901887e+01
#  1.20000000e+01 1.52753744e+04 3.24825309e+02 8.04347047e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=116 || lCount=117 || fCount=15
# [3.95716385e+03 2.23867244e+02 7.17168626e+01 3.48164909e+00
#  3.82601973e+04 4.54133604e+02 3.92298170e+06 1.97820779e+01
#  1.20000000e+01 1.50156419e+04 3.32670433e+02 9.63265162e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=117 || lCount=118 || fCount=15
# [3.95201324e+03 2.17305911e+02 4.41759076e+01 3.02552131e+00
#  3.87834755e+04 4.46103955e+02 5.30100946e+06 1.75019693e+01
#  1.10000000e+01 1.51789127e+04 3.24494806e+02 8.07154468e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=118 || lCount=119 || fCount=15
# [3.94270352e+03 2.20906736e+02 4.69401165e+01 3.20982992e+00
#  3.91577559e+04 4.43813591e+02 6.93677876e+06 1.78440094e+01
#  1.20000000e+01 1.53090786e+04 3.32833410e+02 8.62239193e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=119 || lCount=120 || fCount=15
# [3.95858753e+03 2.22027869e+02 4.66568897e+01 3.26241588e+00
#  4.02283754e+04 4.45376869e+02 6.86938093e+06 1.82933375e+01
#  1.20000000e+01 1.59046766e+04 3.43624828e+02 8.96656094e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=120 || lCount=121 || fCount=15
# [3.35720832e+03 2.09718125e+02 4.09163501e+01 3.01343370e+00
#  3.81665947e+04 4.23718408e+02 5.21961934e+06 1.64883461e+01
#  9.00000000e+00 1.46770114e+04 3.22727511e+02 8.04842430e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=121 || lCount=122 || fCount=15
# [2.64646080e+03 1.99453074e+02 2.10498579e+01 2.39934914e+00
#  3.11900730e+04 3.99633501e+02 3.48287294e+06 1.39861615e+01
#  1.00000000e+01 1.21213469e+04 3.12503432e+02 7.29529913e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=122 || lCount=123 || fCount=15
# [2.25351331e+03 1.88383045e+02 1.88324871e+01 2.26359307e+00
#  2.70898134e+04 3.72298095e+02 2.31232300e+06 1.40880885e+01
#  1.30000000e+01 1.03609631e+04 2.97153019e+02 7.20769016e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# iCount=0 || jCount=123 || lCount=124 || fCount=15
# [1.97230751e+03 1.94524569e+02 1.82144202e+01 2.32255656e+00
#  2.35379184e+04 3.78134517e+02 1.35841818e+06 1.29341643e+01
#  1.80000000e+01 9.08808100e+03 3.06310790e+02 6.79694625e+00
#  9.90000000e+01 2.67000000e+01 5.30000000e+00]
# PPG_data_info:E:\OneDrive - KookminUNIV\KMU==Lab\MCSP==Research-Papers\SCI-02\Software\ProgrammingCodes\DataBase\data(mod)\2_thk_0125_2023.csv
# iCount=1 || jCount=0 || lCount=125 || fCount=15
# [3.47273263e+03 2.81096567e+02 6.91344712e+01 4.94955496e+00
#  2.30043209e+04 5.21567268e+02 1.07632279e+06 1.96505827e+01
#  1.80000000e+01 1.76043097e+04 4.89506516e+02 1.71193543e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=1 || lCount=126 || fCount=15
# [3.04903259e+03 2.74273547e+02 4.70721161e+01 4.44230830e+00
#  2.17985340e+04 5.06845796e+02 8.81019734e+05 1.90007930e+01
#  1.80000000e+01 1.63756181e+04 4.74084201e+02 1.58072544e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=2 || lCount=127 || fCount=15
# [2.77055274e+03 2.64538567e+02 3.66917747e+01 4.00579615e+00
#  2.00398902e+04 4.83933344e+02 8.85433081e+05 1.57765625e+01
#  2.10000000e+01 1.50650784e+04 4.64247306e+02 1.37974834e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=3 || lCount=128 || fCount=15
# [2.71573864e+03 2.58918030e+02 3.43848406e+01 3.91724900e+00
#  2.05087881e+04 4.79770991e+02 1.12869251e+06 1.59958198e+01
#  1.80000000e+01 1.49893785e+04 4.56564990e+02 1.37669951e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=4 || lCount=129 || fCount=15
# [2.64749364e+03 2.57256976e+02 3.55643240e+01 3.92307731e+00
#  2.21208229e+04 5.07534302e+02 1.38720667e+06 1.82317571e+01
#  2.00000000e+01 1.56711803e+04 4.80370070e+02 1.51691103e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=5 || lCount=130 || fCount=15
# [2.88917813e+03 2.46922752e+02 3.36179405e+01 3.75414282e+00
#  2.37417749e+04 5.08341151e+02 1.52450182e+06 1.78282754e+01
#  1.60000000e+01 1.70361085e+04 4.82818463e+02 1.50224554e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=6 || lCount=131 || fCount=15
# [2.95597848e+03 2.55258508e+02 3.52087621e+01 4.09937938e+00
#  2.49913718e+04 5.17988941e+02 1.72767545e+06 2.02400559e+01
#  1.80000000e+01 1.76477601e+04 4.85206625e+02 1.64731244e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=7 || lCount=132 || fCount=15
# [3.45832807e+03 2.53555062e+02 3.62610627e+01 4.15258745e+00
#  2.72702149e+04 5.38539063e+02 2.15148750e+06 2.29797825e+01
#  1.80000000e+01 1.98081768e+04 5.11469206e+02 1.88791070e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=8 || lCount=133 || fCount=15
# [3.48648016e+03 2.48791150e+02 3.84616135e+01 4.13598903e+00
#  2.64389358e+04 5.31590357e+02 2.72702916e+06 2.04168746e+01
#  1.90000000e+01 1.91559724e+04 4.88898596e+02 1.64947089e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=9 || lCount=134 || fCount=15
# [3.52871596e+03 2.49548029e+02 4.36913646e+01 4.22500513e+00
#  2.73621534e+04 5.32068435e+02 2.91651920e+06 2.07312029e+01
#  1.80000000e+01 1.96089344e+04 4.93168381e+02 1.65386512e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=10 || lCount=135 || fCount=15
# [3.48101772e+03 2.52463316e+02 4.37522073e+01 4.32564710e+00
#  2.72407551e+04 5.30209515e+02 2.51539336e+06 2.10862988e+01
#  1.50000000e+01 1.95722729e+04 4.87674519e+02 1.65440414e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=11 || lCount=136 || fCount=15
# [3.41144778e+03 2.55168062e+02 4.41684152e+01 4.36639916e+00
#  2.68104449e+04 5.49677770e+02 2.03319435e+06 2.26210424e+01
#  1.50000000e+01 1.89391643e+04 4.89180941e+02 1.68551653e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=12 || lCount=137 || fCount=15
# [3.71593896e+03 2.49109651e+02 4.68849738e+01 4.11350366e+00
#  2.83983728e+04 5.67850158e+02 1.80975434e+06 2.30438953e+01
#  1.50000000e+01 2.03813214e+04 5.06013905e+02 1.73752139e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=13 || lCount=138 || fCount=15
# [3.45178037e+03 2.53465574e+02 5.09001130e+01 4.24045626e+00
#  2.62649905e+04 5.42313703e+02 1.99692982e+06 2.18883410e+01
#  1.50000000e+01 1.87378984e+04 4.86551248e+02 1.64611690e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=14 || lCount=139 || fCount=15
# [3.33152315e+03 2.61930256e+02 5.52247376e+01 4.11478349e+00
#  2.62444549e+04 5.25283867e+02 2.29457229e+06 2.06961523e+01
#  1.50000000e+01 1.84580390e+04 4.72762095e+02 1.55234061e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=15 || lCount=140 || fCount=15
# [3.43461795e+03 2.69439663e+02 5.59199546e+01 4.31048014e+00
#  2.69165475e+04 5.34345500e+02 2.32229405e+06 2.11585530e+01
#  1.70000000e+01 1.92053893e+04 4.81018912e+02 1.62870799e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=16 || lCount=141 || fCount=15
# [3.58854820e+03 2.74196694e+02 6.00344113e+01 4.42994873e+00
#  2.80047341e+04 5.43210988e+02 2.23185601e+06 2.15315351e+01
#  1.60000000e+01 2.00961908e+04 4.85412460e+02 1.68245251e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=17 || lCount=142 || fCount=15
# [3.95210516e+03 2.79739218e+02 6.21526870e+01 4.71559315e+00
#  2.95313350e+04 5.46032096e+02 2.48814597e+06 2.28668685e+01
#  1.40000000e+01 2.15345250e+04 4.97356490e+02 1.85856231e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=18 || lCount=143 || fCount=15
# [3.26585220e+03 2.79061008e+02 5.56128450e+01 4.42278554e+00
#  2.66165776e+04 5.10766522e+02 2.52087422e+06 1.90929316e+01
#  1.50000000e+01 1.88998365e+04 4.64013300e+02 1.53393844e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=19 || lCount=144 || fCount=15
# [3.18090902e+03 2.74754729e+02 4.90207592e+01 4.29742013e+00
#  2.67761858e+04 5.31302977e+02 2.31222140e+06 2.05402132e+01
#  1.60000000e+01 1.89679648e+04 4.83553627e+02 1.67679334e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=20 || lCount=145 || fCount=15
# [3.07557848e+03 2.66836576e+02 4.01205311e+01 4.22584352e+00
#  2.72289490e+04 5.33692281e+02 2.18713721e+06 2.11390911e+01
#  1.40000000e+01 1.88444031e+04 4.79365755e+02 1.64634955e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=21 || lCount=146 || fCount=15
# [3.14070402e+03 2.62699398e+02 4.22729214e+01 4.04028156e+00
#  2.74247856e+04 5.27313779e+02 2.31851901e+06 1.99343603e+01
#  1.40000000e+01 1.87622664e+04 4.76246156e+02 1.53407052e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=22 || lCount=147 || fCount=15
# [3.24534420e+03 2.55229898e+02 4.05576265e+01 3.93237336e+00
#  2.73681831e+04 5.22637334e+02 2.66293706e+06 2.01270499e+01
#  1.30000000e+01 1.85934986e+04 4.66454541e+02 1.49897999e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=23 || lCount=148 || fCount=15
# [3.33034207e+03 2.63953866e+02 4.35465610e+01 4.21354589e+00
#  2.66900601e+04 5.31844546e+02 2.91644858e+06 2.10775515e+01
#  1.40000000e+01 1.86285110e+04 4.88299658e+02 1.63012803e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=24 || lCount=149 || fCount=15
# [3.28780607e+03 2.58019008e+02 4.70502235e+01 4.15964457e+00
#  2.77571283e+04 5.36304169e+02 2.63747881e+06 2.29199619e+01
#  1.40000000e+01 1.91104362e+04 4.90758227e+02 1.74665040e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=25 || lCount=150 || fCount=15
# [3.25918208e+03 2.51322700e+02 4.32416592e+01 3.84855334e+00
#  2.81223454e+04 5.33567849e+02 2.09008318e+06 2.23945819e+01
#  1.40000000e+01 1.95880342e+04 4.90083801e+02 1.70577569e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=26 || lCount=151 || fCount=15
# [3.20318841e+03 2.52177399e+02 4.87098008e+01 4.16307117e+00
#  2.68538022e+04 5.32566040e+02 1.94373100e+06 2.20735611e+01
#  1.50000000e+01 1.90775856e+04 5.02671376e+02 1.81832086e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=27 || lCount=152 || fCount=15
# [3.45285217e+03 2.55301536e+02 6.20402416e+01 4.74464089e+00
#  2.81557168e+04 5.32373915e+02 2.15499821e+06 2.42056902e+01
#  1.60000000e+01 2.00853668e+04 4.97320712e+02 1.92026584e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=28 || lCount=153 || fCount=15
# [3.29350652e+03 2.54997645e+02 5.88377538e+01 4.43438862e+00
#  2.61555161e+04 5.27565948e+02 2.38469643e+06 2.18728205e+01
#  1.70000000e+01 1.90262755e+04 4.91124946e+02 1.82187557e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=29 || lCount=154 || fCount=15
# [3.33845896e+03 2.60380291e+02 7.12747797e+01 4.49237768e+00
#  2.69123354e+04 5.26519736e+02 2.47210177e+06 2.02866169e+01
#  1.60000000e+01 1.95353230e+04 4.88709599e+02 1.73564606e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=30 || lCount=155 || fCount=15
# [3.64386318e+03 2.63237675e+02 6.10517205e+01 4.62342376e+00
#  2.84065385e+04 5.38674965e+02 2.58131372e+06 2.15574068e+01
#  1.40000000e+01 2.08316809e+04 4.97886189e+02 1.83987406e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=31 || lCount=156 || fCount=15
# [3.57789136e+03 2.59190665e+02 5.88772535e+01 4.45398867e+00
#  2.83067672e+04 5.30853988e+02 2.73303588e+06 2.11539397e+01
#  1.60000000e+01 2.00914174e+04 4.80076015e+02 1.74732719e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=32 || lCount=157 || fCount=15
# [3.60081132e+03 2.71283948e+02 5.73205587e+01 4.70184501e+00
#  2.78961922e+04 5.53344376e+02 2.85788532e+06 2.25870507e+01
#  1.50000000e+01 1.99091572e+04 4.85370993e+02 1.83931237e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=33 || lCount=158 || fCount=15
# [3.63073753e+03 2.70131982e+02 5.98318128e+01 4.75584152e+00
#  2.86127279e+04 5.44839291e+02 2.81024445e+06 2.13900441e+01
#  1.40000000e+01 2.01878065e+04 4.75903838e+02 1.72895671e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=34 || lCount=159 || fCount=15
# [3.77203565e+03 2.76847087e+02 6.63066399e+01 4.90536047e+00
#  2.95480711e+04 5.53216468e+02 2.64206253e+06 2.38715180e+01
#  1.60000000e+01 2.07852314e+04 4.87638800e+02 1.85922550e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=35 || lCount=160 || fCount=15
# [3.82390141e+03 2.75573555e+02 6.25350002e+01 4.62417198e+00
#  2.93957631e+04 5.46310512e+02 2.66309898e+06 2.12230453e+01
#  1.40000000e+01 2.11737872e+04 4.91547943e+02 1.74841159e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=36 || lCount=161 || fCount=15
# [3.44798525e+03 2.67265468e+02 6.16866485e+01 4.46166151e+00
#  2.73244464e+04 5.31067099e+02 2.89256395e+06 1.99763904e+01
#  1.50000000e+01 1.93101826e+04 4.71581454e+02 1.61226194e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=37 || lCount=162 || fCount=15
# [3.53359928e+03 2.61452002e+02 6.22580800e+01 4.44403494e+00
#  2.79590762e+04 5.38952976e+02 2.83344192e+06 2.12851672e+01
#  1.40000000e+01 2.01948279e+04 4.76474926e+02 1.70894681e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=38 || lCount=163 || fCount=15
# [3.40064207e+03 2.57375405e+02 5.94379601e+01 4.04459631e+00
#  2.72442577e+04 5.31615757e+02 2.42084451e+06 1.95934822e+01
#  1.40000000e+01 1.93667796e+04 4.66841058e+02 1.52397037e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=39 || lCount=164 || fCount=15
# [3.35509442e+03 2.57409402e+02 6.63371114e+01 4.38661260e+00
#  2.62386235e+04 5.30923054e+02 2.13026388e+06 2.06954101e+01
#  1.40000000e+01 1.90018012e+04 4.66724027e+02 1.63830857e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=40 || lCount=165 || fCount=15
# [3.25362993e+03 2.50915836e+02 6.24191841e+01 4.48200862e+00
#  2.57740646e+04 5.32860299e+02 2.00159688e+06 2.01454053e+01
#  1.40000000e+01 1.86188115e+04 4.73826304e+02 1.68395107e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=41 || lCount=166 || fCount=15
# [3.16199918e+03 2.60489163e+02 5.90957724e+01 4.92328083e+00
#  2.65640163e+04 5.40619941e+02 2.07227353e+06 2.36022019e+01
#  1.60000000e+01 1.89595821e+04 4.84214029e+02 1.95329846e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=42 || lCount=167 || fCount=15
# [3.04954531e+03 2.52943002e+02 4.03561809e+01 4.18629997e+00
#  2.58211392e+04 5.21756346e+02 2.38816155e+06 1.98513366e+01
#  1.60000000e+01 1.83777969e+04 4.66440559e+02 1.63769064e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=43 || lCount=168 || fCount=15
# [3.48766688e+03 2.69941349e+02 4.93995819e+01 4.74705815e+00
#  2.64674328e+04 5.43322693e+02 2.71330631e+06 2.11511648e+01
#  1.70000000e+01 1.94389563e+04 4.89778816e+02 1.75980702e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=44 || lCount=169 || fCount=15
# [3.78652282e+03 2.67123520e+02 5.63115335e+01 4.84403718e+00
#  2.78291165e+04 5.21127043e+02 2.74550773e+06 2.03387711e+01
#  1.60000000e+01 2.08821577e+04 4.78755917e+02 1.76601015e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=45 || lCount=170 || fCount=15
# [4.14935937e+03 2.75064076e+02 5.95479645e+01 4.96809616e+00
#  3.17803107e+04 5.52453019e+02 2.96653405e+06 2.37104084e+01
#  1.60000000e+01 2.43487016e+04 5.14620459e+02 2.00339235e+01
#  9.60000000e+01 2.64000000e+01 5.50000000e+00]
# iCount=1 || jCount=46 || lCount=171 || fCount=15
# [4.30571319e+03 2.76187169e+02 6.19338907e+01 5.09673221e+00
#  3.14687502e+04 5.43297334e+02 3.52472253e+06 2.40379843e+01
# ...
# 705:	learn: 0.0164678	total: 328ms	remaining: 136ms
# 706:	learn: 0.0164638	total: 328ms	remaining: 136ms
# 707:	learn: 0.0164434	total: 329ms	remaining: 136ms
# 708:	learn: 0.0164421	total: 329ms	remaining: 135ms
# 709:	learn: 0.0164350	total: 329ms	remaining: 135ms
# 710:	learn: 0.0164261	total: 330ms	remaining: 134ms
# 711:	learn: 0.0164189	total: 330ms	remaining: 134ms
# 712:	learn: 0.0164132	total: 331ms	remaining: 133ms
# 713:	learn: 0.0163952	total: 331ms	remaining: 133ms
# 714:	learn: 0.0163801	total: 332ms	remaining: 132ms
# 715:	learn: 0.0163788	total: 332ms	remaining: 132ms
# 716:	learn: 0.0163644	total: 333ms	remaining: 131ms
# 717:	learn: 0.0163375	total: 333ms	remaining: 131ms
# 718:	learn: 0.0163362	total: 333ms	remaining: 130ms
# 719:	learn: 0.0163207	total: 334ms	remaining: 130ms
# 720:	learn: 0.0163105	total: 334ms	remaining: 129ms
# 721:	learn: 0.0163038	total: 335ms	remaining: 129ms
# 722:	learn: 0.0163017	total: 335ms	remaining: 129ms
# 723:	learn: 0.0162875	total: 336ms	remaining: 128ms
# 724:	learn: 0.0162660	total: 337ms	remaining: 128ms
# 725:	learn: 0.0162418	total: 337ms	remaining: 127ms
# 726:	learn: 0.0162223	total: 338ms	remaining: 127ms
# 727:	learn: 0.0162116	total: 338ms	remaining: 126ms
# 728:	learn: 0.0161933	total: 339ms	remaining: 126ms
# 729:	learn: 0.0161751	total: 339ms	remaining: 125ms
# 730:	learn: 0.0161530	total: 340ms	remaining: 125ms
# 731:	learn: 0.0161435	total: 340ms	remaining: 125ms
# 732:	learn: 0.0161369	total: 341ms	remaining: 124ms
# 733:	learn: 0.0161211	total: 341ms	remaining: 124ms
# 734:	learn: 0.0161147	total: 341ms	remaining: 123ms
# 735:	learn: 0.0161078	total: 342ms	remaining: 123ms
# 736:	learn: 0.0161015	total: 342ms	remaining: 122ms
# 737:	learn: 0.0160826	total: 343ms	remaining: 122ms
# 738:	learn: 0.0160613	total: 343ms	remaining: 121ms
# 739:	learn: 0.0160167	total: 344ms	remaining: 121ms
# 740:	learn: 0.0159899	total: 344ms	remaining: 120ms
# 741:	learn: 0.0159766	total: 345ms	remaining: 120ms
# 742:	learn: 0.0159675	total: 345ms	remaining: 119ms
# 743:	learn: 0.0159526	total: 346ms	remaining: 119ms
# 744:	learn: 0.0159421	total: 346ms	remaining: 119ms
# 745:	learn: 0.0158503	total: 347ms	remaining: 118ms
# 746:	learn: 0.0158329	total: 347ms	remaining: 118ms
# 747:	learn: 0.0158108	total: 348ms	remaining: 117ms
# 748:	learn: 0.0157940	total: 349ms	remaining: 117ms
# 749:	learn: 0.0157058	total: 349ms	remaining: 116ms
# 750:	learn: 0.0156923	total: 349ms	remaining: 116ms
# 751:	learn: 0.0156777	total: 350ms	remaining: 115ms
# 752:	learn: 0.0156765	total: 350ms	remaining: 115ms
# 753:	learn: 0.0156649	total: 351ms	remaining: 115ms
# 754:	learn: 0.0156597	total: 352ms	remaining: 114ms
# 755:	learn: 0.0156392	total: 352ms	remaining: 114ms
# 756:	learn: 0.0155973	total: 353ms	remaining: 113ms
# 757:	learn: 0.0155502	total: 353ms	remaining: 113ms
# 758:	learn: 0.0155301	total: 354ms	remaining: 112ms
# 759:	learn: 0.0154904	total: 354ms	remaining: 112ms
# 760:	learn: 0.0154712	total: 355ms	remaining: 111ms
# 761:	learn: 0.0154675	total: 355ms	remaining: 111ms
# 762:	learn: 0.0154532	total: 356ms	remaining: 110ms
# 763:	learn: 0.0154377	total: 356ms	remaining: 110ms
# 764:	learn: 0.0154180	total: 356ms	remaining: 109ms
# 765:	learn: 0.0153994	total: 357ms	remaining: 109ms
# 766:	learn: 0.0153917	total: 357ms	remaining: 109ms
# 767:	learn: 0.0153836	total: 358ms	remaining: 108ms
# 768:	learn: 0.0153696	total: 358ms	remaining: 108ms
# 769:	learn: 0.0153293	total: 359ms	remaining: 107ms
# 770:	learn: 0.0153219	total: 359ms	remaining: 107ms
# 771:	learn: 0.0153068	total: 360ms	remaining: 106ms
# 772:	learn: 0.0152683	total: 360ms	remaining: 106ms
# 773:	learn: 0.0152531	total: 361ms	remaining: 105ms
# 774:	learn: 0.0152160	total: 361ms	remaining: 105ms
# 775:	learn: 0.0151936	total: 362ms	remaining: 105ms
# 776:	learn: 0.0151834	total: 362ms	remaining: 104ms
# 777:	learn: 0.0151705	total: 363ms	remaining: 104ms
# 778:	learn: 0.0151528	total: 363ms	remaining: 103ms
# 779:	learn: 0.0151360	total: 364ms	remaining: 103ms
# 780:	learn: 0.0151247	total: 364ms	remaining: 102ms
# 781:	learn: 0.0151109	total: 365ms	remaining: 102ms
# 782:	learn: 0.0150993	total: 365ms	remaining: 101ms
# 783:	learn: 0.0150789	total: 366ms	remaining: 101ms
# 784:	learn: 0.0150683	total: 367ms	remaining: 100ms
# 785:	learn: 0.0150571	total: 368ms	remaining: 100ms
# 786:	learn: 0.0149759	total: 369ms	remaining: 99.8ms
# 787:	learn: 0.0149565	total: 369ms	remaining: 99.3ms
# 788:	learn: 0.0149347	total: 370ms	remaining: 98.9ms
# 789:	learn: 0.0149235	total: 370ms	remaining: 98.4ms
# 790:	learn: 0.0149086	total: 371ms	remaining: 97.9ms
# 791:	learn: 0.0148942	total: 371ms	remaining: 97.5ms
# 792:	learn: 0.0148834	total: 372ms	remaining: 97ms
# 793:	learn: 0.0148585	total: 372ms	remaining: 96.6ms
# 794:	learn: 0.0148486	total: 373ms	remaining: 96.1ms
# 795:	learn: 0.0148069	total: 373ms	remaining: 95.6ms
# 796:	learn: 0.0147899	total: 373ms	remaining: 95.1ms
# 797:	learn: 0.0147800	total: 374ms	remaining: 94.7ms
# 798:	learn: 0.0147674	total: 374ms	remaining: 94.2ms
# 799:	learn: 0.0147544	total: 375ms	remaining: 93.7ms
# 800:	learn: 0.0147418	total: 375ms	remaining: 93.2ms
# 801:	learn: 0.0147318	total: 376ms	remaining: 92.7ms
# 802:	learn: 0.0146546	total: 376ms	remaining: 92.3ms
# 803:	learn: 0.0146379	total: 377ms	remaining: 91.8ms
# 804:	learn: 0.0146147	total: 377ms	remaining: 91.3ms
# 805:	learn: 0.0145816	total: 377ms	remaining: 90.8ms
# 806:	learn: 0.0145420	total: 378ms	remaining: 90.4ms
# 807:	learn: 0.0145321	total: 378ms	remaining: 89.9ms
# 808:	learn: 0.0145151	total: 379ms	remaining: 89.4ms
# 809:	learn: 0.0145030	total: 379ms	remaining: 88.9ms
# 810:	learn: 0.0144890	total: 380ms	remaining: 88.5ms
# 811:	learn: 0.0144765	total: 380ms	remaining: 88ms
# 812:	learn: 0.0144580	total: 380ms	remaining: 87.5ms
# 813:	learn: 0.0144532	total: 381ms	remaining: 87.1ms
# 814:	learn: 0.0144405	total: 382ms	remaining: 86.6ms
# 815:	learn: 0.0144243	total: 382ms	remaining: 86.2ms
# 816:	learn: 0.0144060	total: 383ms	remaining: 85.7ms
# 817:	learn: 0.0143991	total: 383ms	remaining: 85.3ms
# 818:	learn: 0.0143262	total: 384ms	remaining: 84.8ms
# 819:	learn: 0.0143084	total: 384ms	remaining: 84.4ms
# 820:	learn: 0.0143016	total: 385ms	remaining: 83.9ms
# 821:	learn: 0.0142677	total: 385ms	remaining: 83.4ms
# 822:	learn: 0.0142508	total: 386ms	remaining: 83ms
# 823:	learn: 0.0142338	total: 386ms	remaining: 82.5ms
# 824:	learn: 0.0142221	total: 387ms	remaining: 82ms
# 825:	learn: 0.0142068	total: 387ms	remaining: 81.6ms
# 826:	learn: 0.0141905	total: 388ms	remaining: 81.1ms
# 827:	learn: 0.0141733	total: 388ms	remaining: 80.6ms
# 828:	learn: 0.0141687	total: 389ms	remaining: 80.2ms
# 829:	learn: 0.0141670	total: 389ms	remaining: 79.7ms
# 830:	learn: 0.0141506	total: 390ms	remaining: 79.3ms
# 831:	learn: 0.0141501	total: 390ms	remaining: 78.8ms
# 832:	learn: 0.0141480	total: 391ms	remaining: 78.3ms
# 833:	learn: 0.0141338	total: 391ms	remaining: 77.8ms
# 834:	learn: 0.0141220	total: 392ms	remaining: 77.4ms
# 835:	learn: 0.0141046	total: 392ms	remaining: 76.9ms
# 836:	learn: 0.0140990	total: 393ms	remaining: 76.4ms
# 837:	learn: 0.0140820	total: 393ms	remaining: 76ms
# 838:	learn: 0.0140714	total: 418ms	remaining: 80.2ms
# 839:	learn: 0.0140601	total: 419ms	remaining: 79.8ms
# 840:	learn: 0.0140513	total: 420ms	remaining: 79.4ms
# 841:	learn: 0.0140344	total: 421ms	remaining: 78.9ms
# 842:	learn: 0.0139984	total: 421ms	remaining: 78.4ms
# 843:	learn: 0.0139857	total: 422ms	remaining: 77.9ms
# 844:	learn: 0.0139696	total: 422ms	remaining: 77.4ms
# 845:	learn: 0.0139534	total: 423ms	remaining: 76.9ms
# 846:	learn: 0.0139407	total: 423ms	remaining: 76.4ms
# 847:	learn: 0.0139317	total: 423ms	remaining: 75.9ms
# 848:	learn: 0.0139119	total: 424ms	remaining: 75.4ms
# 849:	learn: 0.0138901	total: 425ms	remaining: 74.9ms
# 850:	learn: 0.0138723	total: 425ms	remaining: 74.5ms
# 851:	learn: 0.0138556	total: 426ms	remaining: 74ms
# 852:	learn: 0.0138412	total: 426ms	remaining: 73.5ms
# 853:	learn: 0.0138378	total: 427ms	remaining: 73ms
# 854:	learn: 0.0138286	total: 427ms	remaining: 72.5ms
# 855:	learn: 0.0138084	total: 428ms	remaining: 72ms
# 856:	learn: 0.0137947	total: 429ms	remaining: 71.7ms
# 857:	learn: 0.0137756	total: 430ms	remaining: 71.2ms
# 858:	learn: 0.0137592	total: 431ms	remaining: 70.7ms
# 859:	learn: 0.0137412	total: 431ms	remaining: 70.2ms
# 860:	learn: 0.0136757	total: 432ms	remaining: 69.7ms
# 861:	learn: 0.0136640	total: 432ms	remaining: 69.2ms
# 862:	learn: 0.0136530	total: 433ms	remaining: 68.7ms
# 863:	learn: 0.0136214	total: 433ms	remaining: 68.2ms
# 864:	learn: 0.0136012	total: 434ms	remaining: 67.7ms
# 865:	learn: 0.0135958	total: 434ms	remaining: 67.2ms
# 866:	learn: 0.0135826	total: 435ms	remaining: 66.7ms
# 867:	learn: 0.0135711	total: 435ms	remaining: 66.2ms
# 868:	learn: 0.0135586	total: 436ms	remaining: 65.7ms
# 869:	learn: 0.0135487	total: 436ms	remaining: 65.2ms
# 870:	learn: 0.0135381	total: 437ms	remaining: 64.7ms
# 871:	learn: 0.0135299	total: 437ms	remaining: 64.1ms
# 872:	learn: 0.0135144	total: 437ms	remaining: 63.6ms
# 873:	learn: 0.0134509	total: 438ms	remaining: 63.1ms
# 874:	learn: 0.0134369	total: 438ms	remaining: 62.6ms
# 875:	learn: 0.0134199	total: 439ms	remaining: 62.1ms
# 876:	learn: 0.0134094	total: 439ms	remaining: 61.6ms
# 877:	learn: 0.0133990	total: 440ms	remaining: 61.1ms
# 878:	learn: 0.0133928	total: 440ms	remaining: 60.6ms
# 879:	learn: 0.0133789	total: 440ms	remaining: 60.1ms
# 880:	learn: 0.0133669	total: 441ms	remaining: 59.6ms
# 881:	learn: 0.0133571	total: 441ms	remaining: 59ms
# 882:	learn: 0.0133434	total: 442ms	remaining: 58.5ms
# 883:	learn: 0.0133333	total: 442ms	remaining: 58ms
# 884:	learn: 0.0133006	total: 443ms	remaining: 57.5ms
# 885:	learn: 0.0132896	total: 443ms	remaining: 57ms
# 886:	learn: 0.0132773	total: 443ms	remaining: 56.5ms
# 887:	learn: 0.0132669	total: 444ms	remaining: 56ms
# 888:	learn: 0.0132532	total: 445ms	remaining: 55.5ms
# 889:	learn: 0.0132472	total: 445ms	remaining: 55ms
# 890:	learn: 0.0131885	total: 446ms	remaining: 54.5ms
# 891:	learn: 0.0131666	total: 446ms	remaining: 54ms
# 892:	learn: 0.0131538	total: 447ms	remaining: 53.5ms
# 893:	learn: 0.0131526	total: 447ms	remaining: 53ms
# 894:	learn: 0.0131369	total: 448ms	remaining: 52.5ms
# 895:	learn: 0.0131271	total: 448ms	remaining: 52ms
# 896:	learn: 0.0130711	total: 449ms	remaining: 51.5ms
# 897:	learn: 0.0130695	total: 449ms	remaining: 51ms
# 898:	learn: 0.0130679	total: 450ms	remaining: 50.5ms
# 899:	learn: 0.0130501	total: 450ms	remaining: 50ms
# 900:	learn: 0.0130374	total: 450ms	remaining: 49.5ms
# 901:	learn: 0.0130315	total: 451ms	remaining: 49ms
# 902:	learn: 0.0130212	total: 451ms	remaining: 48.5ms
# 903:	learn: 0.0129676	total: 452ms	remaining: 48ms
# 904:	learn: 0.0129445	total: 452ms	remaining: 47.5ms
# 905:	learn: 0.0129433	total: 453ms	remaining: 47ms
# 906:	learn: 0.0129420	total: 453ms	remaining: 46.4ms
# 907:	learn: 0.0129254	total: 453ms	remaining: 45.9ms
# 908:	learn: 0.0129159	total: 454ms	remaining: 45.4ms
# 909:	learn: 0.0129143	total: 454ms	remaining: 44.9ms
# 910:	learn: 0.0128963	total: 455ms	remaining: 44.4ms
# 911:	learn: 0.0128855	total: 455ms	remaining: 43.9ms
# 912:	learn: 0.0128822	total: 455ms	remaining: 43.4ms
# 913:	learn: 0.0128810	total: 456ms	remaining: 42.9ms
# 914:	learn: 0.0128797	total: 456ms	remaining: 42.4ms
# 915:	learn: 0.0128782	total: 457ms	remaining: 41.9ms
# 916:	learn: 0.0128646	total: 457ms	remaining: 41.4ms
# 917:	learn: 0.0128591	total: 458ms	remaining: 40.9ms
# 918:	learn: 0.0128497	total: 458ms	remaining: 40.4ms
# 919:	learn: 0.0128416	total: 458ms	remaining: 39.9ms
# 920:	learn: 0.0128361	total: 459ms	remaining: 39.4ms
# 921:	learn: 0.0128311	total: 460ms	remaining: 38.9ms
# 922:	learn: 0.0128260	total: 460ms	remaining: 38.4ms
# 923:	learn: 0.0128176	total: 460ms	remaining: 37.9ms
# 924:	learn: 0.0128124	total: 461ms	remaining: 37.4ms
# 925:	learn: 0.0128113	total: 461ms	remaining: 36.9ms
# 926:	learn: 0.0128101	total: 462ms	remaining: 36.4ms
# 927:	learn: 0.0128003	total: 462ms	remaining: 35.8ms
# 928:	learn: 0.0127906	total: 463ms	remaining: 35.4ms
# 929:	learn: 0.0127901	total: 463ms	remaining: 34.9ms
# 930:	learn: 0.0127802	total: 464ms	remaining: 34.4ms
# 931:	learn: 0.0127730	total: 464ms	remaining: 33.9ms
# 932:	learn: 0.0127725	total: 464ms	remaining: 33.3ms
# 933:	learn: 0.0127512	total: 465ms	remaining: 32.8ms
# 934:	learn: 0.0127497	total: 465ms	remaining: 32.3ms
# 935:	learn: 0.0127423	total: 466ms	remaining: 31.8ms
# 936:	learn: 0.0127409	total: 466ms	remaining: 31.3ms
# 937:	learn: 0.0127315	total: 467ms	remaining: 30.8ms
# 938:	learn: 0.0127182	total: 467ms	remaining: 30.3ms
# 939:	learn: 0.0127135	total: 467ms	remaining: 29.8ms
# 940:	learn: 0.0127064	total: 468ms	remaining: 29.3ms
# 941:	learn: 0.0126863	total: 468ms	remaining: 28.8ms
# 942:	learn: 0.0126318	total: 469ms	remaining: 28.3ms
# 943:	learn: 0.0126246	total: 469ms	remaining: 27.8ms
# 944:	learn: 0.0126177	total: 469ms	remaining: 27.3ms
# 945:	learn: 0.0125746	total: 470ms	remaining: 26.8ms
# 946:	learn: 0.0125741	total: 470ms	remaining: 26.3ms
# 947:	learn: 0.0125651	total: 471ms	remaining: 25.8ms
# 948:	learn: 0.0125526	total: 471ms	remaining: 25.3ms
# 949:	learn: 0.0125403	total: 472ms	remaining: 24.8ms
# 950:	learn: 0.0125392	total: 472ms	remaining: 24.3ms
# 951:	learn: 0.0125278	total: 473ms	remaining: 23.8ms
# 952:	learn: 0.0125192	total: 473ms	remaining: 23.3ms
# 953:	learn: 0.0125179	total: 474ms	remaining: 22.8ms
# 954:	learn: 0.0125135	total: 474ms	remaining: 22.3ms
# 955:	learn: 0.0125130	total: 475ms	remaining: 21.8ms
# 956:	learn: 0.0125125	total: 475ms	remaining: 21.3ms
# 957:	learn: 0.0125120	total: 475ms	remaining: 20.8ms
# 958:	learn: 0.0125028	total: 476ms	remaining: 20.3ms
# 959:	learn: 0.0124721	total: 476ms	remaining: 19.8ms
# 960:	learn: 0.0124710	total: 477ms	remaining: 19.3ms
# 961:	learn: 0.0124705	total: 477ms	remaining: 18.8ms
# 962:	learn: 0.0124700	total: 477ms	remaining: 18.3ms
# 963:	learn: 0.0124696	total: 478ms	remaining: 17.9ms
# 964:	learn: 0.0124691	total: 479ms	remaining: 17.4ms
# 965:	learn: 0.0124545	total: 479ms	remaining: 16.9ms
# 966:	learn: 0.0124540	total: 480ms	remaining: 16.4ms
# 967:	learn: 0.0124462	total: 480ms	remaining: 15.9ms
# 968:	learn: 0.0124457	total: 481ms	remaining: 15.4ms
# 969:	learn: 0.0124447	total: 481ms	remaining: 14.9ms
# 970:	learn: 0.0124437	total: 482ms	remaining: 14.4ms
# 971:	learn: 0.0124357	total: 482ms	remaining: 13.9ms
# 972:	learn: 0.0124315	total: 482ms	remaining: 13.4ms
# 973:	learn: 0.0124311	total: 483ms	remaining: 12.9ms
# 974:	learn: 0.0124216	total: 483ms	remaining: 12.4ms
# 975:	learn: 0.0124212	total: 484ms	remaining: 11.9ms
# 976:	learn: 0.0124207	total: 484ms	remaining: 11.4ms
# 977:	learn: 0.0124197	total: 485ms	remaining: 10.9ms
# 978:	learn: 0.0124063	total: 485ms	remaining: 10.4ms
# 979:	learn: 0.0123946	total: 485ms	remaining: 9.91ms
# 980:	learn: 0.0123880	total: 486ms	remaining: 9.41ms
# 981:	learn: 0.0123694	total: 486ms	remaining: 8.91ms
# 982:	learn: 0.0123685	total: 487ms	remaining: 8.42ms
# 983:	learn: 0.0123621	total: 487ms	remaining: 7.92ms
# 984:	learn: 0.0123108	total: 488ms	remaining: 7.43ms
# 985:	learn: 0.0122981	total: 488ms	remaining: 6.93ms
# 986:	learn: 0.0122971	total: 489ms	remaining: 6.43ms
# 987:	learn: 0.0122896	total: 489ms	remaining: 5.94ms
# 988:	learn: 0.0122826	total: 490ms	remaining: 5.44ms
# 989:	learn: 0.0122725	total: 490ms	remaining: 4.95ms
# 990:	learn: 0.0122647	total: 491ms	remaining: 4.46ms
# 991:	learn: 0.0122642	total: 491ms	remaining: 3.96ms
# 992:	learn: 0.0122351	total: 492ms	remaining: 3.46ms
# 993:	learn: 0.0122158	total: 492ms	remaining: 2.97ms
# 994:	learn: 0.0122047	total: 493ms	remaining: 2.47ms
# 995:	learn: 0.0121967	total: 493ms	remaining: 1.98ms
# 996:	learn: 0.0121834	total: 493ms	remaining: 1.48ms
# 997:	learn: 0.0121771	total: 494ms	remaining: 989us
# 998:	learn: 0.0121708	total: 494ms	remaining: 494us
# 999:	learn: 0.0121636	total: 495ms	remaining: 0us
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5

# %% [markdown]
# > Evaluation of __Test 1__

# %% [markdown]
# RGB with bmi and spo2

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'XG Boost',
    predictedValue = t1_results_xg,
    exactValue     = t1_e_results_xg
)
# Out:
# ############ HbA1c Evaluation Metrics of XG Boost Regression ############
# Diff STD  =  0.23350483700821612
# MSE       =  0.05474157770646235
# ME        =  -0.01473325490951538
# MAD       =  0.18142255544662467
# RMSE      =  0.23396918110397008
# R2 score  =  0.9256323291612484
# Pearson R and p-value:  PearsonRResult(statistic=0.9763382943922359, pvalue=3.253411229721261e-05)
# ##################################################################################

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'Random Forest',
    predictedValue = t1_results_rf,
    exactValue     = t1_e_results_rf
)
# Out:
# ############ HbA1c Evaluation Metrics of Random Forest Regression ############
# Diff STD  =  0.18712463255417264
# MSE       =  0.03575997394296664
# ME        =  -0.027282702110174473
# MAD       =  0.1263148808369745
# RMSE      =  0.18910307756080186
# R2 score  =  0.9514192669847195
# Pearson R and p-value:  PearsonRResult(statistic=0.983905692798599, pvalue=1.0296741294940416e-05)
# ##################################################################################

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'Light GBM',
    predictedValue = t1_results_lg,
    exactValue     = t1_e_results_lg
)
# Out:
# ############ HbA1c Evaluation Metrics of Light GBM Regression ############
# Diff STD  =  0.2804890952093449
# MSE       =  0.08579226286957894
# ME        =  -0.08436901290297283
# MAD       =  0.17437616805137446
# RMSE      =  0.2929031629559144
# R2 score  =  0.8834492714147092
# Pearson R and p-value:  PearsonRResult(statistic=0.9540491528355808, pvalue=0.00023427819715152238)
# ##################################################################################

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'Cat Boost',
    predictedValue = t1_results_cb,
    exactValue     = t1_e_results_cb
)
# Out:
# ############ HbA1c Evaluation Metrics of Cat Boost Regression ############
# Diff STD  =  0.3111730625527996
# MSE       =  0.10755974122063366
# ME        =  -0.10359086041801735
# MAD       =  0.1908444688874491
# RMSE      =  0.32796301806855244
# R2 score  =  0.8538776599847049
# Pearson R and p-value:  PearsonRResult(statistic=0.9329711460672307, pvalue=0.0007155382658532602)
# ##################################################################################

# %% [markdown]
# Blue only with bmi and spo2

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'XG Boost',
    predictedValue = t1_results_xg,
    exactValue     = t1_e_results_xg
)
# Out:
# ############ HbA1c Evaluation Metrics of XG Boost Regression ############
# Diff STD  =  0.1523183962674083
# MSE       =  0.0232569561364096
# ME        =  0.007487475872039795
# MAD       =  0.10410674810409537
# RMSE      =  0.15250231518376894
# R2 score  =  0.9684048993264655
# Pearson R and p-value:  PearsonRResult(statistic=0.988844423605119, pvalue=3.441718435178672e-06)
# ##################################################################################

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'Random Forest',
    predictedValue = t1_results_rf,
    exactValue     = t1_e_results_rf
)
# Out:
# ############ HbA1c Evaluation Metrics of Random Forest Regression ############
# Diff STD  =  0.2276181577234165
# MSE       =  0.05862922957514814
# ME        =  -0.08257847086103032
# MAD       =  0.14450437374338898
# RMSE      =  0.24213473434257246
# R2 score  =  0.9203508662107943
# Pearson R and p-value:  PearsonRResult(statistic=0.9678470093007254, pvalue=8.110953210000234e-05)
# ##################################################################################

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'Cat Boost',
    predictedValue = t1_results_cb,
    exactValue     = t1_e_results_cb
)
# Out:
# ############ HbA1c Evaluation Metrics of Cat Boost Regression ############
# Diff STD  =  0.21177529037164589
# MSE       =  0.04849961721827367
# ME        =  -0.06042221119984548
# MAD       =  0.1450208828734586
# RMSE      =  0.2202262863925959
# R2 score  =  0.9341121735943639
# Pearson R and p-value:  PearsonRResult(statistic=0.9719334843566688, pvalue=5.411510251904735e-05)
# ##################################################################################

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'Light GBM',
    predictedValue = t1_results_lg,
    exactValue     = t1_e_results_lg
)
# Out:
# ############ HbA1c Evaluation Metrics of Light GBM Regression ############
# Diff STD  =  0.20093752964182207
# MSE       =  0.044484841568939525
# ME        =  -0.06410109788748863
# MAD       =  0.1524236030383358
# RMSE      =  0.21091429910970835
# R2 score  =  0.9395663370746735
# Pearson R and p-value:  PearsonRResult(statistic=0.9842749016501912, pvalue=9.606915799055963e-06)
# ##################################################################################

# %%
a=pd.DataFrame(train_array)
a
# Out:
#          0             1           2          3     4     5    6
# 0     10.0  17882.334007  348.766282   9.309784  99.0  26.7  5.3
# 1      9.0  19576.961656  351.833695   9.963996  99.0  26.7  5.3
# 2     11.0  18552.890705  333.946496   8.697591  99.0  26.7  5.3
# 3      9.0  17453.801011  348.551492   9.916768  99.0  26.7  5.3
# 4     10.0  16862.105126  360.474749  10.313305  99.0  26.7  5.3
# ...    ...           ...         ...        ...   ...   ...  ...
# 1640  12.0  17303.605770  399.933820  10.440673  96.0  26.0  7.4
# 1641  12.0  17965.681696  408.871990  11.487680  96.0  26.0  7.4
# 1642  11.0  17523.964355  398.548478  10.125092  96.0  26.0  7.4
# 1643  12.0  17054.910516  433.159162  11.338118  96.0  26.0  7.4
# 1644  12.0  16056.929762  391.030690  10.149707  96.0  26.0  7.4
#
# [1645 rows x 7 columns]

# %%
ltb.plot_importance(booster= lg)
plt.show()

# %% [markdown]
# ## __Test 02:__

# %% [markdown]
# >  Utilizing __Algorithm 06v2:__ Constructing Features Set _(Red, Green, Blue; Reflected, FeatureCount=4+4+r1+r2+SpO2+BMI=13)_

# %%
# Initialize
loo                = sk.model_selection.LeaveOneOut()
t2_scores          = []
t2_test_cases      = []
t2_train_cases     = []
countEpoch         = 0
percent            = 0.02
# XG Boost
t2_results_xg      = []
t2_e_results_xg    = []
# Random Forest
t2_results_rf      = []
t2_e_results_rf    = []
# Cat Boost
t2_results_cb      = []
t2_e_results_cb    = []
# Light GBM
t2_results_lg      = []
t2_e_results_lg    = []

for train_index, test_index in loo.split(PPG_csvArray):
    print('Epoch # '+str(countEpoch))
    countEpoch +=1

    X_train, X_test      = PPG_csvArray[train_index], PPG_csvArray[test_index]
    y_train, y_test      = HbA1c_Array [train_index], HbA1c_Array [test_index]
    sp_train, sp_test    = SpO2_Array  [train_index], SpO2_Array  [test_index]
    bmi_train, bmi_test  = BMI_Array   [train_index], BMI_Array   [test_index]
    
    
    # > __Algorithm 06v2:__ Constructing Features Set _(Red, Green, Blue; Reflected, FeatureCount=4+4+r1+r2+SpO2+BMI=13)_
    print('*************************************************************')
    print('*********************Training Array Set**********************')
    print('*************************************************************')
    train_array = construct_feature_set_v2(
        PPG          = X_train,
        HbA1c        = y_train,
        SpO2         = sp_train,
        BMI          = bmi_train,
        samplingRate = 32
        )
    print('*************************************************************')
    print('*********************Testing Array Set***********************')
    print('*************************************************************')
    test_array  = construct_feature_set_v2(
        PPG          = X_test,
        HbA1c        = y_test,
        SpO2         = sp_test,
        BMI          = bmi_test,
        samplingRate = 32
        )
    
    feature_train, hba1c_train = train_array[:,:-1], train_array[:,-1]
    feature_test, hba1c_test   = test_array[:,:-1],  test_array[:,-1]
    
    train = np.sort(np.array(random.sample(range(feature_test.shape[0]), int(feature_test.shape[0] * percent))))
    if train.shape[0] == 0:
        feature_train, hba1c_train = np.append(feature_train, np.expand_dims(feature_test[0],axis=0), 0), np.append(hba1c_train, np.expand_dims(hba1c_test[0],axis=0), 0)
        # feature_test, hba1c_test = np.delete(feature_test, 0, axis = 0), np.delete(hba1c_test, 0, axis = 0)
    else:
        test = np.delete(np.arange(feature_test.shape[0]), train)

        feature_train, hba1c_train = np.append(feature_train, feature_test[train], 0), np.append(hba1c_train, hba1c_test[train], 0)
        feature_test, hba1c_test = np.delete(feature_test, train, axis = 0), np.delete(hba1c_test, train, axis = 0)
    
    feature_train, hba1c_train = sk.utils.shuffle(feature_train, hba1c_train, random_state=0)
    # print(feature_train.shape)
    # print(feature_test.shape)

    # XGboost
    xg = xgb.XGBRegressor(objective="reg:squarederror", random_state=42)
    xg.fit(feature_train, hba1c_train)
    t2_results_xg.append(np.nanmean(xg.predict(feature_test)))
    t2_e_results_xg.append(np.nanmean(hba1c_test))

    # Random Forest
    rf = RandomForestRegressor(random_state=42, n_estimators=1000, n_jobs=-1)
    rf.fit(feature_train, hba1c_train)
    t2_results_rf.append(np.nanmean(rf.predict(feature_test)))
    t2_e_results_rf.append(np.nanmean(hba1c_test))

    # Cat boost
    cb = cab.CatBoostRegressor()
    cb.fit(feature_train, hba1c_train)
    t2_results_cb.append(np.nanmean(cb.predict(feature_test)))
    t2_e_results_cb.append(np.nanmean(hba1c_test))

    # Light GBM
    lg = ltb.LGBMRegressor(
        boosting_type = 'gbdt',
        num_leaves    = 13*31,
        max_depth     = 0,
        learning_rate = 0.1,
        n_estimators  = 10000
        )
    lg.fit(feature_train, hba1c_train)
    t2_results_lg.append(np.nanmean(lg.predict(feature_test)))
    t2_e_results_lg.append(np.nanmean(hba1c_test))



    t2_test_cases.append(X_test)
    t2_train_cases.append(X_train)

    clear_output(wait=True)
# Out:
# Epoch # 27
# *************************************************************
# *********************Training Array Set**********************
# *************************************************************
# PPG_data_info:./DataBase/Selected_PPG_wrist/210823_4.csv
# iCount=0 || jCount=0 || lCount=1 || fCount=13
# [7.00000000e+00 1.65506231e+02 4.04300826e+05 1.21984933e+02
#  7.00000000e+00 1.76379861e+02 4.95298018e+05 1.42733038e+02
#  3.31579491e+00 1.78859360e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=1 || lCount=2 || fCount=13
# [7.00000000e+00 1.90653961e+02 2.87406581e+05 2.03860073e+02
#  7.00000000e+00 2.01618616e+02 4.00717234e+05 2.06580621e+02
#  3.31579491e+00 1.78859360e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=2 || lCount=3 || fCount=13
# [7.00000000e+00 1.76718045e+02 3.78869686e+05 3.32783501e+02
#  7.00000000e+00 1.89761253e+02 4.60313043e+05 3.80325357e+02
#  3.31579491e+00 1.78859360e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=3 || lCount=4 || fCount=13
# [7.00000000e+00 1.76479404e+02 2.65090573e+05 1.37279895e+02
#  7.00000000e+00 1.82278052e+02 3.76473401e+05 1.35651475e+02
#  3.31579491e+00 1.78859360e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=4 || lCount=5 || fCount=13
# [7.00000000e+00 1.63245428e+02 3.72494214e+05 1.21327578e+02
#  7.00000000e+00 1.82072527e+02 4.14035351e+05 1.22907024e+02
#  3.31579491e+00 1.78859360e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=5 || lCount=6 || fCount=13
# [7.00000000e+00 1.58825317e+02 1.79899524e+05 1.04434758e+02
#  7.00000000e+00 1.72616487e+02 2.93790139e+05 1.17950652e+02
#  3.31579491e+00 1.78859360e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=6 || lCount=7 || fCount=13
# [7.00000000e+00 1.62703294e+02 2.73665588e+05 8.13469236e+01
#  7.00000000e+00 1.77117850e+02 3.87458500e+05 1.17802880e+02
#  3.31579491e+00 1.78859360e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=7 || lCount=8 || fCount=13
# [7.00000000e+00 1.68380543e+02 3.32181998e+05 7.72711712e+01
#  7.00000000e+00 1.84742559e+02 4.50049730e+05 1.29256961e+02
#  3.31579491e+00 1.78859360e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=8 || lCount=9 || fCount=13
# [7.00000000e+00 1.53484488e+02 2.11582866e+05 8.31816531e+01
#  7.00000000e+00 1.70196313e+02 3.25523300e+05 1.40100968e+02
#  3.31579491e+00 1.78859360e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=9 || lCount=10 || fCount=13
# [7.00000000e+00 1.72633525e+02 2.45649035e+05 1.17010901e+02
#  7.00000000e+00 1.80276928e+02 2.95057509e+05 1.26637930e+02
#  3.31579491e+00 1.78859360e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=10 || lCount=11 || fCount=13
# [7.00000000e+00 1.73259228e+02 4.04866795e+05 1.02378094e+02
#  8.00000000e+00 1.81609834e+02 4.95862631e+05 1.02418204e+02
#  3.31579491e+00 1.78859360e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=11 || lCount=12 || fCount=13
# [7.00000000e+00 1.63799205e+02 2.27392528e+05 9.54861953e+01
#  7.00000000e+00 1.76712728e+02 3.34962318e+05 1.00856139e+02
#  3.31579491e+00 1.78859360e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=12 || lCount=13 || fCount=13
# [7.00000000e+00 1.73221016e+02 4.36196526e+05 1.09198560e+02
#  7.00000000e+00 1.87913421e+02 5.45113672e+05 1.24678523e+02
#  3.31579491e+00 1.78859360e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=13 || lCount=14 || fCount=13
# [7.00000000e+00 1.69556821e+02 2.68616830e+05 1.36584900e+02
#  7.00000000e+00 1.82094894e+02 3.84034081e+05 1.23225793e+02
#  3.31579491e+00 1.78859360e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=14 || lCount=15 || fCount=13
# [7.00000000e+00 1.61842930e+02 3.31986874e+05 9.81921491e+01
#  7.00000000e+00 1.70780177e+02 4.32267424e+05 1.11883354e+02
#  3.31579491e+00 1.78859360e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=15 || lCount=16 || fCount=13
# [7.00000000e+00 1.75918966e+02 3.10353763e+05 1.32052858e+02
#  7.00000000e+00 1.85731639e+02 4.59694172e+05 1.56440093e+02
#  3.31579491e+00 1.78859360e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=16 || lCount=17 || fCount=13
# [7.00000000e+00 1.69532597e+02 1.88951722e+05 1.12640014e+02
#  6.00000000e+00 1.75336349e+02 2.82168606e+05 1.12610733e+02
#  3.31579491e+00 1.78859360e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=17 || lCount=18 || fCount=13
# [7.00000000e+00 1.50659325e+02 3.23452943e+05 7.75360323e+01
#  7.00000000e+00 1.60254331e+02 3.56965672e+05 7.79942034e+01
#  3.31579491e+00 1.78859360e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=18 || lCount=19 || fCount=13
# [7.00000000e+00 1.60855550e+02 1.75094917e+05 1.21986432e+02
#  7.00000000e+00 1.69329103e+02 2.54155751e+05 1.07338895e+02
#  3.31579491e+00 1.78859360e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=19 || lCount=20 || fCount=13
# [7.00000000e+00 1.54527846e+02 2.10386162e+05 8.24499898e+01
#  7.00000000e+00 1.65836569e+02 2.64027435e+05 7.68804063e+01
#  3.31579491e+00 1.78859360e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=20 || lCount=21 || fCount=13
# [7.00000000e+00 1.51861053e+02 3.54183843e+05 9.39151348e+01
#  7.00000000e+00 1.61360012e+02 3.70570771e+05 7.95753626e+01
#  3.31579491e+00 1.78859360e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=21 || lCount=22 || fCount=13
# [7.00000000e+00 1.65781707e+02 1.75867558e+05 1.01092700e+02
#  7.00000000e+00 1.68874322e+02 2.61333649e+05 8.92553748e+01
#  3.31579491e+00 1.78859360e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=22 || lCount=23 || fCount=13
# [7.00000000e+00 1.61852058e+02 3.47315339e+05 7.51518350e+01
#  7.00000000e+00 1.71657177e+02 3.14066984e+05 7.84280612e+01
#  3.31579491e+00 1.78859360e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=23 || lCount=24 || fCount=13
# [7.00000000e+00 1.57128236e+02 2.57864657e+05 6.67796138e+01
#  7.00000000e+00 1.62429678e+02 3.19663704e+05 7.20213816e+01
#  3.31579491e+00 1.78859360e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# iCount=0 || jCount=24 || lCount=25 || fCount=13
# [7.00000000e+00 1.59156479e+02 2.12086302e+05 8.99044813e+01
#  7.00000000e+00 1.69678406e+02 2.69975446e+05 9.40795648e+01
#  3.31579491e+00 1.78859360e+00 9.60000000e+01 2.87100000e+01
#  8.40000000e+00]
# PPG_data_info:./DataBase/Selected_PPG_wrist/210830_0.csv
# iCount=1 || jCount=0 || lCount=26 || fCount=13
# [8.00000000e+00 5.12322934e+01 9.53568453e+03 2.64355753e+00
#  6.00000000e+00 7.00403359e+01 3.16619611e+04 6.34442963e+00
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=1 || lCount=27 || fCount=13
# [4.00000000e+00 5.60134685e+01 2.09812966e+03 4.17824707e+00
#  4.00000000e+00 7.26363877e+01 7.60432046e+03 1.00261900e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=2 || lCount=28 || fCount=13
# [7.00000000e+00 4.25187792e+01 3.15732881e+03 1.26984254e+00
#  6.00000000e+00 6.05091792e+01 1.41838561e+04 4.39541225e+00
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=3 || lCount=29 || fCount=13
# [8.00000000e+00 4.47505688e+01 8.39845535e+02 1.57534440e+00
#  7.00000000e+00 6.18446956e+01 4.38392967e+03 7.39059497e+00
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=4 || lCount=30 || fCount=13
# [9.00000000e+00 4.10737240e+01 3.98153813e+02 1.21782496e+00
#  7.00000000e+00 5.74292063e+01 1.76293970e+03 2.88071105e+00
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=5 || lCount=31 || fCount=13
# [9.00000000e+00 3.69395315e+01 1.14850350e+02 6.77587623e-01
#  9.00000000e+00 5.01918237e+01 1.85745517e+03 1.51734282e+00
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=6 || lCount=32 || fCount=13
# [8.00000000e+00 3.64577916e+01 5.06546280e+02 6.71556815e-01
#  7.00000000e+00 5.69223473e+01 2.36001974e+03 2.52330341e+00
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=7 || lCount=33 || fCount=13
# [7.00000000e+00 3.99018253e+01 3.38972921e+02 1.32615293e+00
#  7.00000000e+00 6.45449370e+01 4.99955321e+03 5.46724027e+00
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=8 || lCount=34 || fCount=13
# [8.00000000e+00 4.87684392e+01 1.60092081e+03 1.54364698e+00
#  7.00000000e+00 7.13619699e+01 9.39778975e+03 6.32166266e+00
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=9 || lCount=35 || fCount=13
# [1.00000000e+01 5.13232288e+01 2.09418103e+03 1.52011367e+00
#  6.00000000e+00 7.05298172e+01 1.09462727e+04 6.04230580e+00
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=10 || lCount=36 || fCount=13
# [1.10000000e+01 5.05962675e+01 4.57192496e+02 1.94067939e+00
#  7.00000000e+00 7.51803121e+01 8.68933575e+03 8.00549287e+00
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=11 || lCount=37 || fCount=13
# [8.00000000e+00 4.93902332e+01 2.44884763e+03 1.46601121e+00
#  6.00000000e+00 7.18841103e+01 1.14527716e+04 7.63648493e+00
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=12 || lCount=38 || fCount=13
# [5.00000000e+00 4.84363601e+01 4.47080048e+03 1.44922646e+00
#  7.00000000e+00 7.09773555e+01 2.19664106e+04 4.99618403e+00
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=13 || lCount=39 || fCount=13
# [8.00000000e+00 5.15728542e+01 1.95716818e+03 1.56601786e+00
#  6.00000000e+00 7.37021877e+01 1.81707147e+04 5.80078348e+00
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=14 || lCount=40 || fCount=13
# [8.00000000e+00 5.30011764e+01 1.20959697e+03 1.14548897e+00
#  6.00000000e+00 7.32790284e+01 1.10959898e+04 8.55651806e+00
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=15 || lCount=41 || fCount=13
# [8.00000000e+00 5.44412403e+01 4.90454308e+03 1.19981387e+00
#  6.00000000e+00 7.30650968e+01 1.78319598e+04 5.71801119e+00
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=16 || lCount=42 || fCount=13
# [6.00000000e+00 5.38891239e+01 2.85111435e+03 2.89505383e+00
#  6.00000000e+00 7.41503461e+01 1.22965652e+04 1.02945684e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=17 || lCount=43 || fCount=13
# [7.00000000e+00 4.75905907e+01 3.64693093e+02 1.46499405e+00
#  7.00000000e+00 6.93572187e+01 5.28538381e+03 5.47254413e+00
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=18 || lCount=44 || fCount=13
# [6.00000000e+00 4.82727402e+01 1.66452911e+03 1.78554721e+00
#  6.00000000e+00 7.12197410e+01 1.10928116e+04 7.24772684e+00
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=19 || lCount=45 || fCount=13
# [7.00000000e+00 5.65172756e+01 3.31348254e+03 1.93268726e+00
#  7.00000000e+00 8.25318816e+01 1.70493298e+04 7.36804507e+00
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=20 || lCount=46 || fCount=13
# [1.10000000e+01 5.02638766e+01 8.95921545e+02 1.92324818e+00
#  7.00000000e+00 7.57463093e+01 9.09293230e+03 9.35808689e+00
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=21 || lCount=47 || fCount=13
# [8.00000000e+00 4.79276348e+01 1.76104788e+03 1.45731321e+00
#  6.00000000e+00 6.93688344e+01 1.31742768e+04 7.07978065e+00
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=22 || lCount=48 || fCount=13
# [7.00000000e+00 5.06468239e+01 1.13120037e+03 1.48512286e+00
#  7.00000000e+00 8.08914678e+01 8.11231442e+03 8.23676677e+00
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=23 || lCount=49 || fCount=13
# [7.00000000e+00 4.88243455e+01 1.72712940e+03 1.80457525e+00
#  7.00000000e+00 8.06430532e+01 1.44797696e+04 1.09251716e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=24 || lCount=50 || fCount=13
# [6.00000000e+00 5.66221939e+01 3.85056800e+03 2.45431652e+00
#  6.00000000e+00 8.48578448e+01 2.62053129e+04 1.07334883e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=25 || lCount=51 || fCount=13
# [7.00000000e+00 5.76739008e+01 4.46312115e+03 2.63282543e+00
#  7.00000000e+00 9.17027908e+01 2.20037542e+04 1.23338834e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=26 || lCount=52 || fCount=13
# [6.00000000e+00 5.63803489e+01 1.58908915e+03 2.99883491e+00
#  6.00000000e+00 8.41443728e+01 1.52048797e+04 1.04408478e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=27 || lCount=53 || fCount=13
# [7.00000000e+00 6.05884238e+01 9.61704694e+03 2.51049953e+00
#  7.00000000e+00 8.88407267e+01 4.21263039e+04 1.19339081e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=28 || lCount=54 || fCount=13
# [6.00000000e+00 6.15225191e+01 7.45396614e+03 3.71764490e+00
#  6.00000000e+00 8.79601605e+01 4.19679469e+04 1.43515594e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=29 || lCount=55 || fCount=13
# [7.00000000e+00 5.74076142e+01 2.27639480e+03 5.64319517e+00
#  7.00000000e+00 8.94422127e+01 2.31675924e+04 2.55152753e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=30 || lCount=56 || fCount=13
# [6.00000000e+00 5.27896225e+01 1.70124613e+03 2.32993657e+00
#  6.00000000e+00 8.21041245e+01 1.74120694e+04 1.15754884e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=31 || lCount=57 || fCount=13
# [7.00000000e+00 5.12917478e+01 4.39966101e+03 2.77622045e+00
#  7.00000000e+00 7.88355912e+01 2.06357588e+04 1.29735481e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=32 || lCount=58 || fCount=13
# [6.00000000e+00 5.36956840e+01 3.12289724e+03 3.25915802e+00
#  6.00000000e+00 8.03692302e+01 3.39084149e+04 1.51925292e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=33 || lCount=59 || fCount=13
# [7.00000000e+00 6.19477935e+01 1.50899178e+03 6.39914727e+00
#  7.00000000e+00 9.72383472e+01 1.54416372e+04 3.18306608e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=34 || lCount=60 || fCount=13
# [6.00000000e+00 5.93745871e+01 8.99745894e+03 4.73656323e+00
#  6.00000000e+00 9.19880397e+01 4.60571566e+04 2.66199193e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=35 || lCount=61 || fCount=13
# [7.00000000e+00 5.79959021e+01 4.33512273e+03 4.65780627e+00
#  6.00000000e+00 8.92510346e+01 4.10708072e+04 2.19328855e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=36 || lCount=62 || fCount=13
# [8.00000000e+00 5.53029037e+01 9.16841223e+02 2.72586973e+00
#  6.00000000e+00 8.41542389e+01 1.44587954e+04 1.69575935e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=37 || lCount=63 || fCount=13
# [8.00000000e+00 6.41665899e+01 6.52654285e+03 4.09576648e+00
#  6.00000000e+00 8.94808368e+01 3.18497520e+04 2.30217268e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=38 || lCount=64 || fCount=13
# [6.00000000e+00 6.91210599e+01 1.30408924e+04 4.53191179e+00
#  6.00000000e+00 9.79936624e+01 5.14483777e+04 2.15622325e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=39 || lCount=65 || fCount=13
# [7.00000000e+00 6.22296686e+01 3.66239036e+03 2.95005071e+00
#  7.00000000e+00 9.55694292e+01 3.26277258e+04 2.05262554e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=40 || lCount=66 || fCount=13
# [6.00000000e+00 6.15679463e+01 6.51038650e+03 3.61760749e+00
#  6.00000000e+00 9.88971960e+01 5.70399517e+04 2.60278312e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=41 || lCount=67 || fCount=13
# [6.00000000e+00 7.49224944e+01 1.57191352e+04 6.49110070e+00
#  6.00000000e+00 1.18893119e+02 9.19770940e+04 3.83748009e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=42 || lCount=68 || fCount=13
# [6.00000000e+00 7.63232524e+01 2.55203947e+04 8.20044921e+00
#  6.00000000e+00 1.20734145e+02 1.74855011e+05 4.60728358e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=43 || lCount=69 || fCount=13
# [6.00000000e+00 7.27834798e+01 8.72405704e+03 1.05279573e+01
#  6.00000000e+00 1.13635339e+02 7.81363502e+04 6.34268080e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=44 || lCount=70 || fCount=13
# [7.00000000e+00 6.82333525e+01 1.10769744e+04 6.48584836e+00
#  6.00000000e+00 1.02004683e+02 8.47729203e+04 4.05284215e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=45 || lCount=71 || fCount=13
# [6.00000000e+00 7.00851777e+01 1.43890552e+04 7.77484314e+00
#  6.00000000e+00 1.08425234e+02 8.13491071e+04 4.54300832e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=46 || lCount=72 || fCount=13
# [6.00000000e+00 6.44169526e+01 1.27763373e+04 5.59265145e+00
#  6.00000000e+00 1.06042814e+02 8.17183792e+04 3.67784029e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=47 || lCount=73 || fCount=13
# [6.00000000e+00 6.09385792e+01 5.71845825e+03 5.71356928e+00
#  6.00000000e+00 9.93804986e+01 5.45024788e+04 3.01685613e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=48 || lCount=74 || fCount=13
# [6.00000000e+00 6.38100278e+01 5.78460114e+03 5.55225497e+00
#  6.00000000e+00 1.06175830e+02 6.88719431e+04 4.75650006e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=49 || lCount=75 || fCount=13
# [6.00000000e+00 6.98183117e+01 8.57968235e+03 9.12556226e+00
#  6.00000000e+00 1.10932401e+02 7.92573384e+04 4.92786253e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=50 || lCount=76 || fCount=13
# [7.00000000e+00 7.53403357e+01 3.21638459e+04 8.30774465e+00
#  7.00000000e+00 1.16842253e+02 1.74342869e+05 4.68551212e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=51 || lCount=77 || fCount=13
# [6.00000000e+00 8.03766001e+01 1.73446795e+04 8.96278229e+00
#  6.00000000e+00 1.21394018e+02 1.13304970e+05 5.62596941e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=52 || lCount=78 || fCount=13
# [7.00000000e+00 7.34952572e+01 9.84936455e+03 7.37389501e+00
#  6.00000000e+00 1.16008028e+02 7.83999228e+04 6.37836885e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=53 || lCount=79 || fCount=13
# [6.00000000e+00 7.79128788e+01 1.59932277e+04 9.06015974e+00
#  6.00000000e+00 1.16681271e+02 9.60683257e+04 5.16139324e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=54 || lCount=80 || fCount=13
# [6.00000000e+00 7.47461970e+01 2.08961658e+04 9.58505230e+00
#  6.00000000e+00 1.17072582e+02 1.29181372e+05 5.00121898e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=55 || lCount=81 || fCount=13
# [7.00000000e+00 7.40763214e+01 1.52367995e+04 9.24082247e+00
#  6.00000000e+00 1.17092502e+02 1.33883840e+05 4.97955730e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=56 || lCount=82 || fCount=13
# [6.00000000e+00 7.31449497e+01 1.28357588e+04 8.44568669e+00
#  6.00000000e+00 1.18791326e+02 9.67430173e+04 5.90647654e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=57 || lCount=83 || fCount=13
# [7.00000000e+00 8.58431304e+01 2.68828349e+04 1.23963866e+01
#  7.00000000e+00 1.34194984e+02 1.50294400e+05 7.49409093e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=58 || lCount=84 || fCount=13
# [6.00000000e+00 8.54611824e+01 2.81455072e+04 1.38847099e+01
#  6.00000000e+00 1.32190388e+02 1.81088513e+05 8.65943717e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=59 || lCount=85 || fCount=13
# [7.00000000e+00 7.63004621e+01 1.03034440e+04 1.05588166e+01
#  7.00000000e+00 1.20774295e+02 7.67734040e+04 6.36606619e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=60 || lCount=86 || fCount=13
# [6.00000000e+00 7.78939777e+01 2.80523619e+04 9.05950196e+00
#  6.00000000e+00 1.22154673e+02 1.84688206e+05 5.32797866e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=61 || lCount=87 || fCount=13
# [7.00000000e+00 8.56724868e+01 1.46229319e+04 1.45427548e+01
#  7.00000000e+00 1.40012252e+02 9.59664201e+04 1.06690028e+02
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=62 || lCount=88 || fCount=13
# [6.00000000e+00 7.41116461e+01 7.60786270e+03 1.33150429e+01
#  6.00000000e+00 1.24514111e+02 7.13529333e+04 8.64178713e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=63 || lCount=89 || fCount=13
# [7.00000000e+00 7.59140962e+01 1.79644819e+04 1.06795670e+01
#  7.00000000e+00 1.22618605e+02 1.40311497e+05 6.14735990e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=64 || lCount=90 || fCount=13
# [6.00000000e+00 8.35696161e+01 2.30130725e+04 1.71441342e+01
#  6.00000000e+00 1.29882715e+02 1.25859493e+05 9.02838127e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=65 || lCount=91 || fCount=13
# [7.00000000e+00 8.46367897e+01 2.10725302e+04 1.75280016e+01
#  7.00000000e+00 1.34496293e+02 1.41036516e+05 9.43781266e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=66 || lCount=92 || fCount=13
# [6.00000000e+00 8.08009805e+01 6.65670050e+03 1.73707725e+01
#  6.00000000e+00 1.26042172e+02 5.47518408e+04 1.25053815e+02
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=67 || lCount=93 || fCount=13
# [7.00000000e+00 7.71826198e+01 2.39013244e+04 7.69803122e+00
#  7.00000000e+00 1.15141670e+02 1.01027768e+05 3.75641080e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=68 || lCount=94 || fCount=13
# [6.00000000e+00 8.21717035e+01 8.33195407e+03 1.56977154e+01
#  6.00000000e+00 1.21812427e+02 5.20345940e+04 6.41081143e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=69 || lCount=95 || fCount=13
# [9.00000000e+00 8.65862862e+01 1.50048239e+04 1.60981706e+01
#  7.00000000e+00 1.34861710e+02 1.30117245e+05 8.00628874e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=70 || lCount=96 || fCount=13
# [8.00000000e+00 8.93174118e+01 3.35070523e+04 1.73713633e+01
#  6.00000000e+00 1.37685341e+02 1.79830548e+05 9.38564164e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=71 || lCount=97 || fCount=13
# [6.00000000e+00 8.99471544e+01 4.98167078e+04 1.91445394e+01
#  6.00000000e+00 1.36261412e+02 2.63552772e+05 9.86989696e+01
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=72 || lCount=98 || fCount=13
# [6.00000000e+00 8.77763523e+01 2.08970507e+04 2.30995088e+01
#  6.00000000e+00 1.34054362e+02 1.67327272e+05 1.22023614e+02
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=73 || lCount=99 || fCount=13
# [6.00000000e+00 8.63472787e+01 1.36639917e+04 2.04933707e+01
#  6.00000000e+00 1.32143976e+02 1.25820186e+05 1.21551345e+02
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=74 || lCount=100 || fCount=13
# [6.00000000e+00 9.46969801e+01 5.28711406e+04 2.71571620e+01
#  6.00000000e+00 1.44137937e+02 2.99058504e+05 1.60277064e+02
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=75 || lCount=101 || fCount=13
# [6.00000000e+00 9.47317932e+01 4.86204925e+04 2.15825046e+01
#  6.00000000e+00 1.43780429e+02 2.68463955e+05 1.11939540e+02
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=76 || lCount=102 || fCount=13
# [6.00000000e+00 9.06960227e+01 3.44609338e+04 2.51272104e+01
#  6.00000000e+00 1.39959431e+02 2.30265028e+05 1.25029564e+02
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=77 || lCount=103 || fCount=13
# [6.00000000e+00 8.86133125e+01 2.95167609e+04 2.35362380e+01
#  6.00000000e+00 1.42479571e+02 2.25653140e+05 1.29509477e+02
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=78 || lCount=104 || fCount=13
# [6.00000000e+00 9.17723380e+01 3.98968550e+04 2.61400730e+01
#  6.00000000e+00 1.43347168e+02 2.33345820e+05 1.51955520e+02
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=79 || lCount=105 || fCount=13
# [6.00000000e+00 9.76634487e+01 4.19105065e+04 3.22763981e+01
#  6.00000000e+00 1.50796774e+02 2.31399859e+05 1.79851694e+02
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=80 || lCount=106 || fCount=13
# [6.00000000e+00 8.86886352e+01 4.20747042e+04 2.26202808e+01
#  6.00000000e+00 1.40548838e+02 2.89156917e+05 1.37981542e+02
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=81 || lCount=107 || fCount=13
# [7.00000000e+00 9.25287018e+01 3.38439569e+04 2.28207986e+01
#  7.00000000e+00 1.49321423e+02 2.44748424e+05 1.44646102e+02
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=82 || lCount=108 || fCount=13
# [6.00000000e+00 1.01961841e+02 6.49033210e+04 2.68909732e+01
#  6.00000000e+00 1.57215204e+02 3.77943577e+05 1.58811443e+02
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=83 || lCount=109 || fCount=13
# [7.00000000e+00 1.05040384e+02 5.79507292e+04 3.69122757e+01
#  7.00000000e+00 1.64029659e+02 3.29330605e+05 2.45258975e+02
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=84 || lCount=110 || fCount=13
# [6.00000000e+00 1.00012467e+02 3.14447349e+04 6.18536069e+01
#  6.00000000e+00 1.57710474e+02 2.51097473e+05 2.81971105e+02
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=85 || lCount=111 || fCount=13
# [6.00000000e+00 9.91288789e+01 5.84562977e+04 3.01945242e+01
#  6.00000000e+00 1.52926253e+02 3.57175630e+05 1.64424208e+02
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=86 || lCount=112 || fCount=13
# [6.00000000e+00 1.05587017e+02 7.33631046e+04 3.26242943e+01
#  6.00000000e+00 1.55515906e+02 3.90114805e+05 1.65774260e+02
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=87 || lCount=113 || fCount=13
# [6.00000000e+00 1.01970629e+02 4.80127828e+04 3.36297961e+01
#  6.00000000e+00 1.57462301e+02 2.74915706e+05 1.92476994e+02
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=88 || lCount=114 || fCount=13
# [6.00000000e+00 9.58968292e+01 4.34915214e+04 4.15286231e+01
#  6.00000000e+00 1.52010508e+02 3.49567613e+05 2.09586303e+02
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=89 || lCount=115 || fCount=13
# [6.00000000e+00 1.03099301e+02 3.87148053e+04 5.22588913e+01
#  6.00000000e+00 1.65625547e+02 3.08889418e+05 4.50932398e+02
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=90 || lCount=116 || fCount=13
# [6.00000000e+00 1.06636450e+02 7.13998986e+04 3.39660793e+01
#  6.00000000e+00 1.59075185e+02 3.99388711e+05 2.10868500e+02
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=91 || lCount=117 || fCount=13
# [5.00000000e+00 1.06317987e+02 1.08197875e+05 3.19375711e+01
#  5.00000000e+00 1.56122137e+02 4.89289072e+05 2.00803652e+02
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=92 || lCount=118 || fCount=13
# [6.00000000e+00 1.08333461e+02 5.92507816e+04 3.67792691e+01
#  6.00000000e+00 1.58782098e+02 3.73506135e+05 2.01462573e+02
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# iCount=1 || jCount=93 || lCount=119 || fCount=13
# [6.00000000e+00 1.02915505e+02 4.58243931e+04 4.39237056e+01
#  6.00000000e+00 1.60868594e+02 3.10302483e+05 2.28733447e+02
#  2.54420784e+00 1.34425325e+00 9.70000000e+01 2.36000000e+01
#  5.40000000e+00]
# PPG_data_info:./DataBase/Selected_PPG_wrist/210927_0.csv
# iCount=2 || jCount=0 || lCount=120 || fCount=13
# [1.40000000e+01 6.46222849e+01 4.73490623e+02 2.74344745e+00
#  1.20000000e+01 1.02941878e+02 4.81418441e+03 1.46249977e+01
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=1 || lCount=121 || fCount=13
# [1.20000000e+01 7.29648306e+01 6.54579822e+02 4.65405520e+00
#  1.20000000e+01 1.14722207e+02 7.35302721e+03 4.59615064e+01
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=2 || lCount=122 || fCount=13
# [1.40000000e+01 1.04876995e+02 4.67242281e+03 1.94787148e+01
#  1.20000000e+01 1.75239688e+02 5.60615108e+04 1.19996103e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=3 || lCount=123 || fCount=13
# [1.10000000e+01 1.50396459e+02 4.23762157e+04 9.83078416e+01
#  1.20000000e+01 2.41978546e+02 2.35667569e+05 4.11625336e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=4 || lCount=124 || fCount=13
# [1.20000000e+01 1.25741332e+02 9.72566000e+03 1.08445722e+02
#  1.10000000e+01 2.38894983e+02 1.57143735e+05 3.63273460e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=5 || lCount=125 || fCount=13
# [1.20000000e+01 9.33532848e+01 1.51302159e+03 1.89460054e+01
#  1.20000000e+01 2.27538815e+02 1.33624248e+05 1.73642663e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=6 || lCount=126 || fCount=13
# [1.40000000e+01 8.23272750e+01 6.66442704e+03 1.11932125e+01
#  1.20000000e+01 2.34249391e+02 2.06291125e+05 1.71334635e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=7 || lCount=127 || fCount=13
# [1.40000000e+01 7.50836679e+01 4.72349865e+02 6.98876049e+00
#  1.20000000e+01 2.31065510e+02 1.45731967e+05 1.62230469e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=8 || lCount=128 || fCount=13
# [1.40000000e+01 6.49385534e+01 2.85993743e+02 3.03456912e+00
#  1.20000000e+01 2.18775844e+02 1.30896689e+05 1.59192516e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=9 || lCount=129 || fCount=13
# [1.30000000e+01 1.02013469e+02 2.29446035e+03 1.87927103e+01
#  1.10000000e+01 2.18040063e+02 1.09953575e+05 1.47130951e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=10 || lCount=130 || fCount=13
# [1.20000000e+01 1.45383349e+02 3.30326460e+04 4.28004842e+01
#  1.20000000e+01 2.30882556e+02 1.68482037e+05 1.61262727e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=11 || lCount=131 || fCount=13
# [1.10000000e+01 1.82757768e+02 7.32171144e+04 7.88029917e+01
#  1.10000000e+01 2.47114039e+02 2.98764688e+05 2.07127146e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=12 || lCount=132 || fCount=13
# [1.10000000e+01 2.02203411e+02 7.29091029e+04 9.42399545e+01
#  1.10000000e+01 2.66939505e+02 2.51129527e+05 2.70549013e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=13 || lCount=133 || fCount=13
# [1.10000000e+01 1.94729988e+02 9.28373510e+04 9.29314811e+01
#  1.20000000e+01 2.48151195e+02 2.85995037e+05 2.49745462e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=14 || lCount=134 || fCount=13
# [1.20000000e+01 2.01791873e+02 6.49025625e+04 1.05569433e+02
#  1.20000000e+01 2.51805806e+02 1.32061535e+05 2.67049696e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=15 || lCount=135 || fCount=13
# [1.10000000e+01 1.99400532e+02 7.66107147e+04 1.01850890e+02
#  1.10000000e+01 2.60334970e+02 2.66726971e+05 2.90753906e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=16 || lCount=136 || fCount=13
# [1.20000000e+01 2.05003535e+02 8.54469901e+04 1.00117913e+02
#  1.20000000e+01 3.00828194e+02 4.71866325e+05 3.33542335e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=17 || lCount=137 || fCount=13
# [1.10000000e+01 1.89777947e+02 6.84075118e+04 9.26492428e+01
#  1.10000000e+01 2.87487292e+02 4.22791381e+05 3.97724722e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=18 || lCount=138 || fCount=13
# [1.20000000e+01 1.70647506e+02 3.82756810e+04 7.87559159e+01
#  1.20000000e+01 2.76746546e+02 2.98478293e+05 3.64071308e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=19 || lCount=139 || fCount=13
# [1.10000000e+01 1.64494774e+02 2.58958781e+04 7.73928484e+01
#  1.10000000e+01 2.71344452e+02 2.39689786e+05 3.33159115e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=20 || lCount=140 || fCount=13
# [1.20000000e+01 1.50933629e+02 2.73625301e+04 3.69159088e+01
#  1.20000000e+01 2.24496836e+02 2.45116319e+05 1.84775264e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=21 || lCount=141 || fCount=13
# [1.10000000e+01 1.65253293e+02 3.25742943e+04 1.02462214e+02
#  1.10000000e+01 2.29815613e+02 7.48346825e+04 3.96027140e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=22 || lCount=142 || fCount=13
# [1.10000000e+01 1.81284912e+02 8.78347588e+04 7.76787404e+01
#  1.00000000e+01 2.32416215e+02 3.29236152e+05 2.25650326e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=23 || lCount=143 || fCount=13
# [1.10000000e+01 1.86855072e+02 7.68517606e+04 7.70596442e+01
#  1.10000000e+01 2.64140714e+02 3.38754738e+05 2.08943024e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=24 || lCount=144 || fCount=13
# [1.10000000e+01 2.06557033e+02 7.15622005e+04 1.13800813e+02
#  1.10000000e+01 2.60996092e+02 2.33258268e+05 2.06566213e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=25 || lCount=145 || fCount=13
# [1.20000000e+01 2.06271479e+02 1.99634045e+05 1.14282152e+02
#  1.10000000e+01 2.43612783e+02 2.31650503e+05 2.05349053e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=26 || lCount=146 || fCount=13
# [1.10000000e+01 2.15717531e+02 8.22526664e+04 1.86000986e+02
#  1.10000000e+01 2.33997918e+02 1.45013888e+05 2.07114086e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=27 || lCount=147 || fCount=13
# [1.20000000e+01 1.94204806e+02 5.97360648e+04 1.22280553e+02
#  1.20000000e+01 2.17114057e+02 1.36354761e+05 1.41748331e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=28 || lCount=148 || fCount=13
# [1.20000000e+01 1.96634016e+02 4.44002788e+04 9.21408797e+01
#  1.10000000e+01 2.09643117e+02 8.16042599e+04 1.24605165e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=29 || lCount=149 || fCount=13
# [1.20000000e+01 2.16191634e+02 1.26938390e+05 1.10596889e+02
#  1.20000000e+01 2.27957932e+02 1.23689859e+05 1.51249279e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=30 || lCount=150 || fCount=13
# [1.10000000e+01 1.96532062e+02 8.22463394e+04 1.18667832e+02
#  1.10000000e+01 2.46641109e+02 1.91991668e+05 2.31205656e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=31 || lCount=151 || fCount=13
# [1.20000000e+01 1.71999567e+02 2.25565841e+04 8.81617079e+01
#  1.20000000e+01 2.74760789e+02 3.59792861e+05 3.54385597e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=32 || lCount=152 || fCount=13
# [1.10000000e+01 1.62344395e+02 4.15163381e+04 6.62658137e+01
#  1.10000000e+01 2.82751957e+02 3.12411816e+05 3.57172013e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=33 || lCount=153 || fCount=13
# [1.20000000e+01 2.22543064e+02 1.23884186e+05 2.32111579e+02
#  1.20000000e+01 3.46083317e+02 5.77593597e+05 1.26948126e+03
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=34 || lCount=154 || fCount=13
# [1.20000000e+01 2.29798541e+02 2.40709447e+05 2.44416368e+02
#  1.10000000e+01 3.60912558e+02 1.65905814e+06 1.34335224e+03
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=35 || lCount=155 || fCount=13
# [1.20000000e+01 2.13997494e+02 6.62436845e+04 2.46103160e+02
#  1.20000000e+01 3.44752272e+02 6.23398944e+05 1.31756038e+03
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=36 || lCount=156 || fCount=13
# [1.10000000e+01 1.55526688e+02 4.64946399e+04 1.28818592e+02
#  1.10000000e+01 2.46708100e+02 2.50586613e+05 7.04891127e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=37 || lCount=157 || fCount=13
# [1.20000000e+01 1.15047093e+02 4.50128382e+03 1.28501641e+01
#  1.20000000e+01 1.86883656e+02 5.65918589e+04 1.37279148e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=38 || lCount=158 || fCount=13
# [1.20000000e+01 1.35901683e+02 1.32397286e+04 4.69248446e+01
#  1.20000000e+01 1.70460600e+02 4.56106391e+04 9.78348048e+01
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=39 || lCount=159 || fCount=13
# [1.10000000e+01 1.72245804e+02 5.45471543e+04 7.36830376e+01
#  1.10000000e+01 1.68955745e+02 4.50787170e+04 1.06477601e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=40 || lCount=160 || fCount=13
# [1.20000000e+01 1.88712398e+02 8.12862412e+04 8.63017772e+01
#  1.20000000e+01 2.05066505e+02 5.99448546e+04 2.24118656e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=41 || lCount=161 || fCount=13
# [1.10000000e+01 1.67826153e+02 3.20492925e+04 1.13697239e+02
#  1.10000000e+01 2.17053536e+02 1.96463106e+05 2.96116690e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=42 || lCount=162 || fCount=13
# [1.20000000e+01 1.61718301e+02 1.92836755e+04 8.07324387e+01
#  1.20000000e+01 2.66610614e+02 2.25530259e+05 3.72809820e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=43 || lCount=163 || fCount=13
# [1.10000000e+01 1.94344878e+02 1.01435575e+05 1.43166384e+02
#  1.10000000e+01 2.99762983e+02 5.44345332e+05 6.41067149e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=44 || lCount=164 || fCount=13
# [1.20000000e+01 1.90825731e+02 9.60995809e+04 1.49262915e+02
#  1.20000000e+01 3.01128562e+02 6.04794678e+05 6.94793196e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=45 || lCount=165 || fCount=13
# [1.00000000e+01 1.79344893e+02 2.63083209e+04 2.01672242e+02
#  1.00000000e+01 2.81759108e+02 2.36308850e+05 1.05505577e+03
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=46 || lCount=166 || fCount=13
# [9.00000000e+00 1.61088991e+02 1.19004251e+05 1.25802665e+02
#  1.00000000e+01 2.36396592e+02 3.58940530e+05 5.46107439e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=47 || lCount=167 || fCount=13
# [1.10000000e+01 1.62539174e+02 4.23806309e+04 1.02049897e+02
#  1.10000000e+01 2.29678326e+02 1.33569246e+05 3.54375677e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=48 || lCount=168 || fCount=13
# [1.10000000e+01 1.49541644e+02 2.70084823e+04 3.94588969e+01
#  1.10000000e+01 2.08977952e+02 1.09188435e+05 1.03370654e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=49 || lCount=169 || fCount=13
# [1.10000000e+01 1.43069842e+02 2.86136684e+04 3.49041321e+01
#  1.20000000e+01 2.09191886e+02 1.40100205e+05 1.47387140e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=50 || lCount=170 || fCount=13
# [1.10000000e+01 1.33572743e+02 1.57049932e+04 5.03747323e+01
#  1.10000000e+01 1.89442744e+02 8.21158088e+04 2.47025715e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=51 || lCount=171 || fCount=13
# [1.20000000e+01 1.12469233e+02 4.25243224e+03 1.29217252e+01
#  1.00000000e+01 1.46870291e+02 1.47875358e+04 6.69373431e+01
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=52 || lCount=172 || fCount=13
# [9.00000000e+00 1.31972082e+02 7.97757502e+03 1.05668676e+02
#  9.00000000e+00 1.71925530e+02 2.99111331e+04 2.63618598e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=53 || lCount=173 || fCount=13
# [1.20000000e+01 1.44024635e+02 6.03846432e+04 6.95499876e+01
#  1.20000000e+01 2.27777578e+02 2.68517036e+05 3.07862313e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=54 || lCount=174 || fCount=13
# [1.10000000e+01 1.67322504e+02 2.13626178e+04 1.88893410e+02
#  1.10000000e+01 2.57750429e+02 2.27567198e+05 5.28629832e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=55 || lCount=175 || fCount=13
# [1.20000000e+01 1.95969703e+02 9.34229071e+04 1.40448325e+02
#  1.20000000e+01 2.77904925e+02 3.93896417e+05 4.58221994e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=56 || lCount=176 || fCount=13
# [1.10000000e+01 2.35112872e+02 2.04177096e+05 1.61594624e+02
#  1.10000000e+01 3.16947750e+02 7.90681947e+05 5.26500343e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=57 || lCount=177 || fCount=13
# [1.20000000e+01 2.22181312e+02 1.43657452e+05 1.75383667e+02
#  1.10000000e+01 2.88459177e+02 5.13339296e+05 6.35234208e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=58 || lCount=178 || fCount=13
# [1.10000000e+01 1.69954771e+02 3.63261872e+04 7.82334239e+01
#  1.10000000e+01 2.23871637e+02 8.51651213e+04 2.72738759e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=59 || lCount=179 || fCount=13
# [1.00000000e+01 1.19215528e+02 1.72344219e+04 2.42191182e+01
#  1.20000000e+01 1.72115486e+02 7.65762833e+04 7.12671226e+01
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=60 || lCount=180 || fCount=13
# [1.10000000e+01 9.14105873e+01 1.30751034e+03 2.37330026e+01
#  1.10000000e+01 1.60126940e+02 2.71346213e+04 5.92312186e+01
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=61 || lCount=181 || fCount=13
# [1.30000000e+01 8.23874918e+01 4.94810404e+02 3.18484697e+01
#  1.10000000e+01 1.70778297e+02 3.74135870e+04 1.55258863e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=62 || lCount=182 || fCount=13
# [1.10000000e+01 1.14599056e+02 1.71578118e+04 3.44754983e+01
#  1.10000000e+01 2.12489671e+02 1.96393283e+05 2.22042130e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=63 || lCount=183 || fCount=13
# [1.10000000e+01 1.47739631e+02 2.69940758e+04 3.93904007e+01
#  1.10000000e+01 2.17195694e+02 1.56291011e+05 1.96690889e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=64 || lCount=184 || fCount=13
# [1.10000000e+01 1.40722730e+02 4.67654932e+04 1.06995321e+02
#  1.10000000e+01 1.92200140e+02 1.20449226e+05 1.79450330e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=65 || lCount=185 || fCount=13
# [7.00000000e+00 1.07952198e+02 1.97667271e+04 1.07415357e+02
#  9.00000000e+00 1.39261523e+02 1.22584000e+05 1.56372833e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=66 || lCount=186 || fCount=13
# [1.40000000e+01 7.76227329e+01 9.80025793e+02 6.10337070e+00
#  6.00000000e+00 8.93257195e+01 5.19135079e+03 3.05915209e+01
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=67 || lCount=187 || fCount=13
# [6.00000000e+00 1.32522426e+02 1.46094463e+04 1.43507264e+02
#  6.00000000e+00 1.43209742e+02 5.27108930e+04 5.38820869e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=68 || lCount=188 || fCount=13
# [4.00000000e+00 1.58937978e+02 3.56082823e+06 3.84805119e+02
#  4.00000000e+00 1.89364998e+02 1.11145815e+07 1.18576197e+03
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=69 || lCount=189 || fCount=13
# [5.00000000e+00 1.50304994e+02 1.52868857e+06 4.11317444e+02
#  4.00000000e+00 1.88936486e+02 4.94615844e+06 1.31782471e+03
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=70 || lCount=190 || fCount=13
# [8.00000000e+00 9.62910508e+01 3.25096017e+04 3.28256249e+02
#  4.00000000e+00 1.19008030e+02 1.11110372e+05 9.34066150e+02
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=71 || lCount=191 || fCount=13
# [1.00000000e+01 7.92306129e+01 2.98531116e+03 2.00660575e+01
#  1.00000000e+01 8.63461464e+01 1.00962881e+04 7.25952223e+01
#  1.46306784e+00 1.07696419e+00 9.70000000e+01 2.87100000e+01
#  7.60000000e+00]
# iCount=2 || jCount=72 || lCount=192 || fCount=13
# [1.10000000e+01 8.07123519e+01 1.86665564e+03 7.40409395e+00
#  1.10000000e+01 8.00188235e+01 2.55169457e+03 4.37832554e+01
# ...
# 693:	learn: 0.0093170	total: 1.79s	remaining: 790ms
# 694:	learn: 0.0092917	total: 1.79s	remaining: 787ms
# 695:	learn: 0.0092786	total: 1.8s	remaining: 785ms
# 696:	learn: 0.0092706	total: 1.8s	remaining: 782ms
# 697:	learn: 0.0092558	total: 1.8s	remaining: 780ms
# 698:	learn: 0.0092413	total: 1.8s	remaining: 777ms
# 699:	learn: 0.0092362	total: 1.81s	remaining: 774ms
# 700:	learn: 0.0092132	total: 1.81s	remaining: 772ms
# 701:	learn: 0.0092045	total: 1.81s	remaining: 769ms
# 702:	learn: 0.0091977	total: 1.81s	remaining: 767ms
# 703:	learn: 0.0091949	total: 1.82s	remaining: 764ms
# 704:	learn: 0.0091912	total: 1.82s	remaining: 762ms
# 705:	learn: 0.0091801	total: 1.82s	remaining: 759ms
# 706:	learn: 0.0091755	total: 1.82s	remaining: 757ms
# 707:	learn: 0.0091690	total: 1.83s	remaining: 754ms
# 708:	learn: 0.0091547	total: 1.83s	remaining: 751ms
# 709:	learn: 0.0091360	total: 1.83s	remaining: 749ms
# 710:	learn: 0.0091288	total: 1.83s	remaining: 746ms
# 711:	learn: 0.0091208	total: 1.84s	remaining: 744ms
# 712:	learn: 0.0091045	total: 1.84s	remaining: 741ms
# 713:	learn: 0.0090948	total: 1.84s	remaining: 739ms
# 714:	learn: 0.0090765	total: 1.85s	remaining: 736ms
# 715:	learn: 0.0090633	total: 1.85s	remaining: 733ms
# 716:	learn: 0.0090381	total: 1.85s	remaining: 731ms
# 717:	learn: 0.0090347	total: 1.85s	remaining: 728ms
# 718:	learn: 0.0090209	total: 1.86s	remaining: 726ms
# 719:	learn: 0.0090093	total: 1.86s	remaining: 723ms
# 720:	learn: 0.0090029	total: 1.86s	remaining: 721ms
# 721:	learn: 0.0090005	total: 1.86s	remaining: 718ms
# 722:	learn: 0.0089962	total: 1.87s	remaining: 715ms
# 723:	learn: 0.0089812	total: 1.87s	remaining: 713ms
# 724:	learn: 0.0089678	total: 1.87s	remaining: 710ms
# 725:	learn: 0.0089484	total: 1.88s	remaining: 708ms
# 726:	learn: 0.0089413	total: 1.88s	remaining: 705ms
# 727:	learn: 0.0089336	total: 1.88s	remaining: 703ms
# 728:	learn: 0.0089172	total: 1.88s	remaining: 700ms
# 729:	learn: 0.0089024	total: 1.89s	remaining: 698ms
# 730:	learn: 0.0088915	total: 1.89s	remaining: 695ms
# 731:	learn: 0.0088813	total: 1.89s	remaining: 693ms
# 732:	learn: 0.0088745	total: 1.89s	remaining: 690ms
# 733:	learn: 0.0088552	total: 1.9s	remaining: 687ms
# 734:	learn: 0.0088422	total: 1.9s	remaining: 685ms
# 735:	learn: 0.0088308	total: 1.9s	remaining: 682ms
# 736:	learn: 0.0088279	total: 1.9s	remaining: 680ms
# 737:	learn: 0.0088044	total: 1.91s	remaining: 677ms
# 738:	learn: 0.0087927	total: 1.91s	remaining: 675ms
# 739:	learn: 0.0087890	total: 1.91s	remaining: 672ms
# 740:	learn: 0.0087753	total: 1.91s	remaining: 669ms
# 741:	learn: 0.0087668	total: 1.92s	remaining: 667ms
# 742:	learn: 0.0087559	total: 1.92s	remaining: 664ms
# 743:	learn: 0.0087463	total: 1.92s	remaining: 662ms
# 744:	learn: 0.0087381	total: 1.93s	remaining: 659ms
# 745:	learn: 0.0087256	total: 1.93s	remaining: 657ms
# 746:	learn: 0.0087153	total: 1.93s	remaining: 654ms
# 747:	learn: 0.0087097	total: 1.93s	remaining: 651ms
# 748:	learn: 0.0086965	total: 1.94s	remaining: 649ms
# 749:	learn: 0.0086884	total: 1.94s	remaining: 646ms
# 750:	learn: 0.0086773	total: 1.94s	remaining: 644ms
# 751:	learn: 0.0086672	total: 1.94s	remaining: 641ms
# 752:	learn: 0.0086559	total: 1.95s	remaining: 639ms
# 753:	learn: 0.0086485	total: 1.95s	remaining: 636ms
# 754:	learn: 0.0086302	total: 1.95s	remaining: 633ms
# 755:	learn: 0.0086143	total: 1.95s	remaining: 631ms
# 756:	learn: 0.0085992	total: 1.96s	remaining: 628ms
# 757:	learn: 0.0085916	total: 1.96s	remaining: 626ms
# 758:	learn: 0.0085879	total: 1.96s	remaining: 623ms
# 759:	learn: 0.0085776	total: 1.97s	remaining: 621ms
# 760:	learn: 0.0085725	total: 1.97s	remaining: 618ms
# 761:	learn: 0.0085601	total: 1.97s	remaining: 616ms
# 762:	learn: 0.0085495	total: 1.97s	remaining: 613ms
# 763:	learn: 0.0085376	total: 1.98s	remaining: 610ms
# 764:	learn: 0.0085256	total: 1.98s	remaining: 608ms
# 765:	learn: 0.0085223	total: 1.98s	remaining: 605ms
# 766:	learn: 0.0085005	total: 1.98s	remaining: 603ms
# 767:	learn: 0.0084893	total: 1.99s	remaining: 600ms
# 768:	learn: 0.0084828	total: 1.99s	remaining: 598ms
# 769:	learn: 0.0084686	total: 1.99s	remaining: 595ms
# 770:	learn: 0.0084634	total: 1.99s	remaining: 593ms
# 771:	learn: 0.0084594	total: 2s	remaining: 590ms
# 772:	learn: 0.0084454	total: 2s	remaining: 587ms
# 773:	learn: 0.0084325	total: 2s	remaining: 585ms
# 774:	learn: 0.0084248	total: 2s	remaining: 582ms
# 775:	learn: 0.0084138	total: 2.01s	remaining: 580ms
# 776:	learn: 0.0083990	total: 2.01s	remaining: 577ms
# 777:	learn: 0.0083872	total: 2.01s	remaining: 575ms
# 778:	learn: 0.0083814	total: 2.02s	remaining: 572ms
# 779:	learn: 0.0083715	total: 2.02s	remaining: 570ms
# 780:	learn: 0.0083662	total: 2.02s	remaining: 567ms
# 781:	learn: 0.0083567	total: 2.02s	remaining: 564ms
# 782:	learn: 0.0083500	total: 2.03s	remaining: 562ms
# 783:	learn: 0.0083395	total: 2.03s	remaining: 559ms
# 784:	learn: 0.0083317	total: 2.03s	remaining: 557ms
# 785:	learn: 0.0083184	total: 2.03s	remaining: 554ms
# 786:	learn: 0.0082989	total: 2.04s	remaining: 552ms
# 787:	learn: 0.0082838	total: 2.04s	remaining: 549ms
# 788:	learn: 0.0082796	total: 2.04s	remaining: 546ms
# 789:	learn: 0.0082752	total: 2.04s	remaining: 544ms
# 790:	learn: 0.0082509	total: 2.05s	remaining: 541ms
# 791:	learn: 0.0082391	total: 2.05s	remaining: 539ms
# 792:	learn: 0.0082299	total: 2.05s	remaining: 536ms
# 793:	learn: 0.0082261	total: 2.06s	remaining: 533ms
# 794:	learn: 0.0082110	total: 2.06s	remaining: 531ms
# 795:	learn: 0.0081975	total: 2.06s	remaining: 528ms
# 796:	learn: 0.0081888	total: 2.06s	remaining: 526ms
# 797:	learn: 0.0081731	total: 2.07s	remaining: 523ms
# 798:	learn: 0.0081632	total: 2.07s	remaining: 520ms
# 799:	learn: 0.0081579	total: 2.07s	remaining: 518ms
# 800:	learn: 0.0081557	total: 2.07s	remaining: 515ms
# 801:	learn: 0.0081406	total: 2.08s	remaining: 513ms
# 802:	learn: 0.0081281	total: 2.08s	remaining: 510ms
# 803:	learn: 0.0081177	total: 2.08s	remaining: 508ms
# 804:	learn: 0.0081059	total: 2.08s	remaining: 505ms
# 805:	learn: 0.0081001	total: 2.09s	remaining: 503ms
# 806:	learn: 0.0080907	total: 2.09s	remaining: 500ms
# 807:	learn: 0.0080755	total: 2.09s	remaining: 497ms
# 808:	learn: 0.0080704	total: 2.1s	remaining: 495ms
# 809:	learn: 0.0080610	total: 2.1s	remaining: 492ms
# 810:	learn: 0.0080530	total: 2.1s	remaining: 490ms
# 811:	learn: 0.0080468	total: 2.1s	remaining: 487ms
# 812:	learn: 0.0080341	total: 2.11s	remaining: 485ms
# 813:	learn: 0.0080234	total: 2.11s	remaining: 482ms
# 814:	learn: 0.0080178	total: 2.11s	remaining: 480ms
# 815:	learn: 0.0080114	total: 2.12s	remaining: 477ms
# 816:	learn: 0.0080013	total: 2.12s	remaining: 474ms
# 817:	learn: 0.0079962	total: 2.12s	remaining: 472ms
# 818:	learn: 0.0079898	total: 2.12s	remaining: 469ms
# 819:	learn: 0.0079763	total: 2.13s	remaining: 467ms
# 820:	learn: 0.0079700	total: 2.13s	remaining: 464ms
# 821:	learn: 0.0079598	total: 2.13s	remaining: 462ms
# 822:	learn: 0.0079470	total: 2.13s	remaining: 459ms
# 823:	learn: 0.0079410	total: 2.14s	remaining: 457ms
# 824:	learn: 0.0079363	total: 2.14s	remaining: 454ms
# 825:	learn: 0.0079267	total: 2.14s	remaining: 452ms
# 826:	learn: 0.0079216	total: 2.15s	remaining: 449ms
# 827:	learn: 0.0079169	total: 2.15s	remaining: 447ms
# 828:	learn: 0.0079070	total: 2.15s	remaining: 444ms
# 829:	learn: 0.0079005	total: 2.16s	remaining: 442ms
# 830:	learn: 0.0078923	total: 2.16s	remaining: 439ms
# 831:	learn: 0.0078808	total: 2.16s	remaining: 436ms
# 832:	learn: 0.0078749	total: 2.16s	remaining: 434ms
# 833:	learn: 0.0078642	total: 2.17s	remaining: 431ms
# 834:	learn: 0.0078487	total: 2.17s	remaining: 429ms
# 835:	learn: 0.0078357	total: 2.17s	remaining: 426ms
# 836:	learn: 0.0078282	total: 2.17s	remaining: 424ms
# 837:	learn: 0.0078225	total: 2.18s	remaining: 421ms
# 838:	learn: 0.0078175	total: 2.18s	remaining: 419ms
# 839:	learn: 0.0078097	total: 2.18s	remaining: 416ms
# 840:	learn: 0.0077962	total: 2.19s	remaining: 414ms
# 841:	learn: 0.0077892	total: 2.19s	remaining: 411ms
# 842:	learn: 0.0077759	total: 2.19s	remaining: 408ms
# 843:	learn: 0.0077634	total: 2.19s	remaining: 406ms
# 844:	learn: 0.0077550	total: 2.2s	remaining: 403ms
# 845:	learn: 0.0077473	total: 2.2s	remaining: 401ms
# 846:	learn: 0.0077396	total: 2.2s	remaining: 398ms
# 847:	learn: 0.0077330	total: 2.21s	remaining: 395ms
# 848:	learn: 0.0077229	total: 2.21s	remaining: 393ms
# 849:	learn: 0.0077094	total: 2.21s	remaining: 390ms
# 850:	learn: 0.0077032	total: 2.21s	remaining: 388ms
# 851:	learn: 0.0076954	total: 2.22s	remaining: 385ms
# 852:	learn: 0.0076832	total: 2.22s	remaining: 382ms
# 853:	learn: 0.0076779	total: 2.22s	remaining: 380ms
# 854:	learn: 0.0076729	total: 2.22s	remaining: 377ms
# 855:	learn: 0.0076706	total: 2.23s	remaining: 375ms
# 856:	learn: 0.0076609	total: 2.23s	remaining: 372ms
# 857:	learn: 0.0076530	total: 2.23s	remaining: 369ms
# 858:	learn: 0.0076418	total: 2.23s	remaining: 367ms
# 859:	learn: 0.0076359	total: 2.24s	remaining: 364ms
# 860:	learn: 0.0076233	total: 2.24s	remaining: 362ms
# 861:	learn: 0.0076117	total: 2.24s	remaining: 359ms
# 862:	learn: 0.0076025	total: 2.24s	remaining: 356ms
# 863:	learn: 0.0075918	total: 2.25s	remaining: 354ms
# 864:	learn: 0.0075834	total: 2.25s	remaining: 351ms
# 865:	learn: 0.0075803	total: 2.25s	remaining: 349ms
# 866:	learn: 0.0075746	total: 2.25s	remaining: 346ms
# 867:	learn: 0.0075642	total: 2.26s	remaining: 343ms
# 868:	learn: 0.0075552	total: 2.26s	remaining: 341ms
# 869:	learn: 0.0075501	total: 2.26s	remaining: 338ms
# 870:	learn: 0.0075423	total: 2.27s	remaining: 336ms
# 871:	learn: 0.0075370	total: 2.27s	remaining: 333ms
# 872:	learn: 0.0075340	total: 2.27s	remaining: 330ms
# 873:	learn: 0.0075271	total: 2.27s	remaining: 328ms
# 874:	learn: 0.0075219	total: 2.27s	remaining: 325ms
# 875:	learn: 0.0075084	total: 2.28s	remaining: 323ms
# 876:	learn: 0.0074999	total: 2.28s	remaining: 320ms
# 877:	learn: 0.0074891	total: 2.28s	remaining: 317ms
# 878:	learn: 0.0074808	total: 2.29s	remaining: 315ms
# 879:	learn: 0.0074755	total: 2.29s	remaining: 312ms
# 880:	learn: 0.0074661	total: 2.29s	remaining: 310ms
# 881:	learn: 0.0074613	total: 2.29s	remaining: 307ms
# 882:	learn: 0.0074523	total: 2.3s	remaining: 304ms
# 883:	learn: 0.0074455	total: 2.3s	remaining: 302ms
# 884:	learn: 0.0074367	total: 2.3s	remaining: 299ms
# 885:	learn: 0.0074229	total: 2.31s	remaining: 297ms
# 886:	learn: 0.0074193	total: 2.31s	remaining: 294ms
# 887:	learn: 0.0074049	total: 2.31s	remaining: 291ms
# 888:	learn: 0.0073968	total: 2.31s	remaining: 289ms
# 889:	learn: 0.0073872	total: 2.32s	remaining: 286ms
# 890:	learn: 0.0073774	total: 2.32s	remaining: 284ms
# 891:	learn: 0.0073673	total: 2.32s	remaining: 281ms
# 892:	learn: 0.0073588	total: 2.33s	remaining: 279ms
# 893:	learn: 0.0073540	total: 2.33s	remaining: 276ms
# 894:	learn: 0.0073479	total: 2.33s	remaining: 273ms
# 895:	learn: 0.0073385	total: 2.33s	remaining: 271ms
# 896:	learn: 0.0073305	total: 2.34s	remaining: 268ms
# 897:	learn: 0.0073197	total: 2.34s	remaining: 266ms
# 898:	learn: 0.0073159	total: 2.34s	remaining: 263ms
# 899:	learn: 0.0073133	total: 2.34s	remaining: 260ms
# 900:	learn: 0.0073091	total: 2.35s	remaining: 258ms
# 901:	learn: 0.0073012	total: 2.35s	remaining: 255ms
# 902:	learn: 0.0072928	total: 2.35s	remaining: 253ms
# 903:	learn: 0.0072887	total: 2.35s	remaining: 250ms
# 904:	learn: 0.0072862	total: 2.36s	remaining: 247ms
# 905:	learn: 0.0072840	total: 2.36s	remaining: 245ms
# 906:	learn: 0.0072763	total: 2.36s	remaining: 242ms
# 907:	learn: 0.0072690	total: 2.37s	remaining: 240ms
# 908:	learn: 0.0072629	total: 2.37s	remaining: 237ms
# 909:	learn: 0.0072499	total: 2.37s	remaining: 235ms
# 910:	learn: 0.0072414	total: 2.37s	remaining: 232ms
# 911:	learn: 0.0072349	total: 2.38s	remaining: 229ms
# 912:	learn: 0.0072292	total: 2.38s	remaining: 227ms
# 913:	learn: 0.0072229	total: 2.38s	remaining: 224ms
# 914:	learn: 0.0072188	total: 2.38s	remaining: 222ms
# 915:	learn: 0.0072143	total: 2.39s	remaining: 219ms
# 916:	learn: 0.0072060	total: 2.39s	remaining: 216ms
# 917:	learn: 0.0072039	total: 2.39s	remaining: 214ms
# 918:	learn: 0.0071903	total: 2.39s	remaining: 211ms
# 919:	learn: 0.0071830	total: 2.4s	remaining: 208ms
# 920:	learn: 0.0071758	total: 2.4s	remaining: 206ms
# 921:	learn: 0.0071712	total: 2.4s	remaining: 203ms
# 922:	learn: 0.0071670	total: 2.4s	remaining: 201ms
# 923:	learn: 0.0071615	total: 2.41s	remaining: 198ms
# 924:	learn: 0.0071589	total: 2.41s	remaining: 195ms
# 925:	learn: 0.0071534	total: 2.41s	remaining: 193ms
# 926:	learn: 0.0071508	total: 2.42s	remaining: 190ms
# 927:	learn: 0.0071426	total: 2.42s	remaining: 188ms
# 928:	learn: 0.0071365	total: 2.42s	remaining: 185ms
# 929:	learn: 0.0071272	total: 2.42s	remaining: 182ms
# 930:	learn: 0.0071179	total: 2.42s	remaining: 180ms
# 931:	learn: 0.0071104	total: 2.43s	remaining: 177ms
# 932:	learn: 0.0070980	total: 2.43s	remaining: 175ms
# 933:	learn: 0.0070928	total: 2.43s	remaining: 172ms
# 934:	learn: 0.0070823	total: 2.44s	remaining: 169ms
# 935:	learn: 0.0070773	total: 2.44s	remaining: 167ms
# 936:	learn: 0.0070743	total: 2.44s	remaining: 164ms
# 937:	learn: 0.0070657	total: 2.44s	remaining: 162ms
# 938:	learn: 0.0070618	total: 2.45s	remaining: 159ms
# 939:	learn: 0.0070592	total: 2.45s	remaining: 156ms
# 940:	learn: 0.0070541	total: 2.45s	remaining: 154ms
# 941:	learn: 0.0070493	total: 2.45s	remaining: 151ms
# 942:	learn: 0.0070444	total: 2.46s	remaining: 149ms
# 943:	learn: 0.0070353	total: 2.46s	remaining: 146ms
# 944:	learn: 0.0070273	total: 2.46s	remaining: 143ms
# 945:	learn: 0.0070253	total: 2.46s	remaining: 141ms
# 946:	learn: 0.0070197	total: 2.47s	remaining: 138ms
# 947:	learn: 0.0070184	total: 2.47s	remaining: 135ms
# 948:	learn: 0.0070145	total: 2.47s	remaining: 133ms
# 949:	learn: 0.0070075	total: 2.47s	remaining: 130ms
# 950:	learn: 0.0070014	total: 2.48s	remaining: 128ms
# 951:	learn: 0.0069955	total: 2.48s	remaining: 125ms
# 952:	learn: 0.0069911	total: 2.48s	remaining: 122ms
# 953:	learn: 0.0069822	total: 2.48s	remaining: 120ms
# 954:	learn: 0.0069756	total: 2.49s	remaining: 117ms
# 955:	learn: 0.0069661	total: 2.49s	remaining: 115ms
# 956:	learn: 0.0069590	total: 2.49s	remaining: 112ms
# 957:	learn: 0.0069555	total: 2.49s	remaining: 109ms
# 958:	learn: 0.0069462	total: 2.5s	remaining: 107ms
# 959:	learn: 0.0069353	total: 2.5s	remaining: 104ms
# 960:	learn: 0.0069254	total: 2.5s	remaining: 102ms
# 961:	learn: 0.0069161	total: 2.5s	remaining: 98.9ms
# 962:	learn: 0.0069118	total: 2.51s	remaining: 96.3ms
# 963:	learn: 0.0069063	total: 2.51s	remaining: 93.7ms
# 964:	learn: 0.0068960	total: 2.51s	remaining: 91.1ms
# 965:	learn: 0.0068868	total: 2.51s	remaining: 88.5ms
# 966:	learn: 0.0068818	total: 2.52s	remaining: 85.9ms
# 967:	learn: 0.0068668	total: 2.52s	remaining: 83.3ms
# 968:	learn: 0.0068650	total: 2.52s	remaining: 80.7ms
# 969:	learn: 0.0068597	total: 2.52s	remaining: 78.1ms
# 970:	learn: 0.0068533	total: 2.53s	remaining: 75.5ms
# 971:	learn: 0.0068491	total: 2.53s	remaining: 72.9ms
# 972:	learn: 0.0068437	total: 2.53s	remaining: 70.3ms
# 973:	learn: 0.0068422	total: 2.54s	remaining: 67.7ms
# 974:	learn: 0.0068347	total: 2.54s	remaining: 65.1ms
# 975:	learn: 0.0068323	total: 2.54s	remaining: 62.5ms
# 976:	learn: 0.0068301	total: 2.54s	remaining: 59.9ms
# 977:	learn: 0.0068226	total: 2.54s	remaining: 57.3ms
# 978:	learn: 0.0068157	total: 2.55s	remaining: 54.7ms
# 979:	learn: 0.0068074	total: 2.55s	remaining: 52.1ms
# 980:	learn: 0.0068042	total: 2.55s	remaining: 49.5ms
# 981:	learn: 0.0067969	total: 2.56s	remaining: 46.9ms
# 982:	learn: 0.0067879	total: 2.56s	remaining: 44.3ms
# 983:	learn: 0.0067851	total: 2.56s	remaining: 41.7ms
# 984:	learn: 0.0067814	total: 2.56s	remaining: 39.1ms
# 985:	learn: 0.0067750	total: 2.57s	remaining: 36.5ms
# 986:	learn: 0.0067709	total: 2.57s	remaining: 33.9ms
# 987:	learn: 0.0067612	total: 2.57s	remaining: 31.3ms
# 988:	learn: 0.0067580	total: 2.58s	remaining: 28.7ms
# 989:	learn: 0.0067485	total: 2.58s	remaining: 26.1ms
# 990:	learn: 0.0067386	total: 2.58s	remaining: 23.4ms
# 991:	learn: 0.0067303	total: 2.58s	remaining: 20.8ms
# 992:	learn: 0.0067291	total: 2.59s	remaining: 18.2ms
# 993:	learn: 0.0067226	total: 2.59s	remaining: 15.6ms
# 994:	learn: 0.0067120	total: 2.59s	remaining: 13ms
# 995:	learn: 0.0067034	total: 2.6s	remaining: 10.4ms
# 996:	learn: 0.0066977	total: 2.6s	remaining: 7.82ms
# 997:	learn: 0.0066903	total: 2.6s	remaining: 5.21ms
# 998:	learn: 0.0066830	total: 2.6s	remaining: 2.61ms
# 999:	learn: 0.0066814	total: 2.61s	remaining: 0us

# %% [markdown]
# > Evaluation of __Test 2__

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'XG Boost',
    predictedValue = t2_results_xg,
    exactValue     = t2_e_results_xg
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 evaluation_metrics_including_BA_and_EGA_plot(
#       2     modelName      = 'XG Boost',
# ----> 3     predictedValue = t2_results_xg,
#       4     exactValue     = t2_e_results_xg
#       5 )
#
# NameError: name 't2_results_xg' is not defined

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'Random Forest',
    predictedValue = t2_results_rf,
    exactValue     = t2_e_results_rf
)
# Out:
# ############ HbA1c Evaluation Metrics of Random Forest Regression ############
# Diff STD  =  0.4419426775429377
# MSE       =  0.1985060279805893
# ME        =  -0.056503962221850425
# MAD       =  0.324238855131559
# RMSE      =  0.44554015305086625
# R2 score  =  0.7562321226496531
# Pearson R and p-value:  PearsonRResult(statistic=0.8790768775485958, pvalue=7.510990867807378e-10)
# ##################################################################################

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'Cat Boost',
    predictedValue = t2_results_cb,
    exactValue     = t2_e_results_cb
)
# Out:
# ############ HbA1c Evaluation Metrics of Cat Boost Regression ############
# Diff STD  =  0.3106458801028231
# MSE       =  0.09689626520481305
# ME        =  -0.01988472730402654
# MAD       =  0.23098021750108452
# RMSE      =  0.31128164932230273
# R2 score  =  0.8810101782175439
# Pearson R and p-value:  PearsonRResult(statistic=0.9480598042866746, pvalue=1.8970940195573504e-14)
# ##################################################################################

# %%
evaluation_metrics_including_BA_and_EGA_plot(
    modelName      = 'Light GBM',
    predictedValue = t2_results_lg,
    exactValue     = t2_e_results_lg
)
# Out:
# ############ HbA1c Evaluation Metrics of Light GBM Regression ############
# Diff STD  =  0.5872699328410358
# MSE       =  0.3473116202337559
# ME        =  -0.04925084988750271
# MAD       =  0.3858293827068556
# RMSE      =  0.5893315028349968
# R2 score  =  0.5734970000418769
# Pearson R and p-value:  PearsonRResult(statistic=0.7630965589989107, pvalue=2.3344459339734676e-06)
# ##################################################################################

# %%
ltb.plot_importance(booster= lg)
plt.show()
